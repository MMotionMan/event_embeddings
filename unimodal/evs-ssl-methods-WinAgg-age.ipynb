# %% [markdown]
# # Импортируем необходимые библиотеки

# %%
# !pip install pytorch-lifestream
# !pip install comet_ml
# Out:
# Collecting pytorch-lifestream
#   Downloading pytorch-lifestream-0.6.0.tar.gz (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.4/163.4 kB 6.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: duckdb in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (1.1.3)
# Collecting hydra-core>=1.1.2 (from pytorch-lifestream)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: numpy>=1.21.5 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (1.26.4)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (2.3.0)
# Requirement already satisfied: pandas>=1.3.5 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (2.2.2)
# Requirement already satisfied: pyarrow>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (17.0.0)
# Requirement already satisfied: pytorch-lightning>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (2.5.0.post0)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (1.2.2)
# Requirement already satisfied: torch>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (2.5.1+cu121)
# Requirement already satisfied: torchmetrics>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (1.6.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (4.47.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from hydra-core>=1.1.2->pytorch-lifestream) (4.9.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from hydra-core>=1.1.2->pytorch-lifestream) (24.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.5->pytorch-lifestream) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.5->pytorch-lifestream) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.5->pytorch-lifestream) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.5->pytorch-lifestream) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.5->pytorch-lifestream) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.5->pytorch-lifestream) (2.4.1)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.10/dist-packages (from omegaconf->pytorch-lifestream) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->pytorch-lifestream) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->pytorch-lifestream) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->pytorch-lifestream) (2024.2)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.6.0->pytorch-lifestream) (4.67.1)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (2024.9.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.6.0->pytorch-lifestream) (4.12.2)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.6.0->pytorch-lifestream) (0.11.9)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->pytorch-lifestream) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->pytorch-lifestream) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->pytorch-lifestream) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch-lifestream) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch-lifestream) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch-lifestream) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch-lifestream) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.12.0->pytorch-lifestream) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers->pytorch-lifestream) (0.27.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->pytorch-lifestream) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->pytorch-lifestream) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers->pytorch-lifestream) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->pytorch-lifestream) (0.4.5)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (3.11.10)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.10.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (75.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.5->pytorch-lifestream) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.12.0->pytorch-lifestream) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.21.5->pytorch-lifestream) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.21.5->pytorch-lifestream) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.5->pytorch-lifestream) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.21.5->pytorch-lifestream) (2024.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->pytorch-lifestream) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->pytorch-lifestream) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->pytorch-lifestream) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->pytorch-lifestream) (2024.12.14)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (1.18.3)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.21.5->pytorch-lifestream) (2024.2.0)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 9.2 MB/s eta 0:00:00
# Building wheels for collected packages: pytorch-lifestream
#   Building wheel for pytorch-lifestream (pyproject.toml) ... done
#   Created wheel for pytorch-lifestream: filename=pytorch_lifestream-0.6.0-py3-none-any.whl size=274640 sha256=774b121b85750ea9c7c63e05046647bf9e631e70cf28d67f31a13601b2a1c87e
#   Stored in directory: /root/.cache/pip/wheels/90/76/b4/0a944bc7c5a69201e4d757cc54886971117a2a581740e7f11d
# Successfully built pytorch-lifestream
# Installing collected packages: hydra-core, pytorch-lifestream
# Successfully installed hydra-core-1.3.2 pytorch-lifestream-0.6.0
# Collecting comet_ml
#   Downloading comet_ml-3.48.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting everett<3.2.0,>=1.0.1 (from everett[ini]<3.2.0,>=1.0.1->comet_ml)
#   Downloading everett-3.1.0-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (4.23.0)
# Requirement already satisfied: psutil>=5.6.3 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (5.9.5)
# Collecting python-box<7.0.0 (from comet_ml)
#   Downloading python_box-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.8 kB)
# Requirement already satisfied: requests-toolbelt>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (1.0.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (2.32.3)
# Collecting semantic-version>=2.8.0 (from comet_ml)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: sentry-sdk>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (2.19.2)
# Collecting simplejson (from comet_ml)
#   Downloading simplejson-3.19.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (2.2.3)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (1.17.0)
# Requirement already satisfied: wurlitzer>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (3.1.1)
# Collecting dulwich!=0.20.33,>=0.20.6 (from comet_ml)
#   Downloading dulwich-0.22.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: rich>=13.3.2 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (13.9.4)
# Collecting configobj (from everett[ini]<3.2.0,>=1.0.1->comet_ml)
#   Downloading configobj-5.0.9-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (0.22.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml) (2024.12.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet_ml) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet_ml) (2.18.0)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet_ml) (4.12.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=13.3.2->comet_ml) (0.1.2)
# Downloading comet_ml-3.48.1-py3-none-any.whl (710 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 710.5/710.5 kB 15.9 MB/s eta 0:00:0000:01
# Downloading dulwich-0.22.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (980 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 980.3/980.3 kB 38.3 MB/s eta 0:00:00
# Downloading everett-3.1.0-py2.py3-none-any.whl (35 kB)
# Downloading python_box-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 82.6 MB/s eta 0:00:00:00:01
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading simplejson-3.19.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 9.9 MB/s eta 0:00:00
# Downloading configobj-5.0.9-py2.py3-none-any.whl (35 kB)
# Installing collected packages: everett, simplejson, semantic-version, python-box, dulwich, configobj, comet_ml
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.3.0
#     Uninstalling python-box-7.3.0:
#       Successfully uninstalled python-box-7.3.0
# Successfully installed comet_ml-3.48.1 configobj-5.0.9 dulwich-0.22.7 everett-3.1.0 python-box-6.1.0 semantic-version-2.10.0 simplejson-3.19.3

# %%
# data preprocessing
import os
import numpy as np
import pandas as pd
import pickle

# misc
from tqdm import tqdm
from functools import partial

# logging
import comet_ml

# classical ML
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score
from catboost import CatBoostClassifier

# basic deep learning libs
import torch
import pytorch_lightning as pl
import torchmetrics

# ptls
from ptls.nn import TrxEncoder, RnnSeqEncoder, TransformerEncoder, GptEncoder, Head
from ptls.frames import PtlsDataModule
from ptls.frames.coles import CoLESModule
from ptls.frames.coles import ColesDataset
from ptls.frames.coles.split_strategy import SampleSlices
from ptls.frames.cpc import CpcModule
from ptls.frames.cpc import CpcDataset
from ptls.frames.gpt import GptDataset
from ptls.frames.supervised import SeqToTargetDataset, SequenceToTarget
from ptls.data_load.datasets import MemoryMapDataset
from ptls.data_load.datasets import inference_data_loader
from ptls.frames.inference_module import InferenceModule
from ptls.data_load.iterable_processing import SeqLenFilter
from ptls.preprocessing import PandasDataPreprocessor
from ptls.data_load.utils import collate_feature_dict
from ptls.frames.inference_module import InferenceModule

# %%
def seed_everything(seed):
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
comet_ml.login()

# %%
from pytorch_lightning.loggers import CometLogger

# %% [markdown]
# # Эксперименты.

# %% [markdown]
# **Данные:**

# %%
path_data = "https://huggingface.co/datasets/dllllb/age-group-prediction/resolve/main/transactions_train.csv.gz?download=true"
data = pd.read_csv(path_data, compression="gzip")
data
# Out:
#           client_id  trans_date  small_group  amount_rur
# 0             33172           6            4      71.463
# 1             33172           6           35      45.017
# 2             33172           8           11      13.887
# 3             33172           9           11      15.983
# 4             33172          10           11      21.341
# ...             ...         ...          ...         ...
# 26450572      43300         727           25       7.602
# 26450573      43300         727           15       3.709
# 26450574      43300         727            1       6.448
# 26450575      43300         727           11      24.669
# 26450576      43300         729            3      19.408
#
# [26450577 rows x 4 columns]

# %%
path_target = "https://huggingface.co/datasets/dllllb/age-group-prediction/resolve/main/train_target.csv?download=true"
target = pd.read_csv(path_target)
target
# Out:
#        client_id  bins
# 0          24662     2
# 1           1046     0
# 2          34089     2
# 3          34848     1
# 4          47076     3
# ...          ...   ...
# 29995      14303     1
# 29996      22301     2
# 29997      25731     0
# 29998      16820     3
# 29999       5265     0
#
# [30000 rows x 2 columns]

# %%
target_train, target_test = train_test_split(target, test_size=0.1, stratify=target["bins"], random_state=42)

# %%
trx_data_train = pd.merge(data, target_train["client_id"], on="client_id", how="inner")
trx_data_test = pd.merge(data, target_test["client_id"], on="client_id", how="inner")

# %% [markdown]
# ---

# %% [markdown]
# **Квантизация непрерывных признаков (опциональный шаг, нужен только для GPT):**

# %%
def digitize(input_array: np.array, q_count: int = 1, bins: np.array = None):
    """Quantile-based discretization function.

    Parameters:
    -------
    input_array (np.array): Input array.
    q_count (int): Amount of quantiles. Used only if input parameter `bins` is None.
    bins (np.array):
        If None, then calculate bins as quantiles of input array,
        otherwise only apply bins to input_array. Default: None

    Returns
    -------
    out_array (np.array of ints): discretized input_array
    bins (np.array of floats):
        Returned only if input parameter `bins` is None.
    """

    if bins is None:
        return_bins = True
        bins = np.quantile(input_array, q=[i / q_count for i in range(1, q_count)], axis=0)
    else:
        return_bins = False

    out_array = np.digitize(input_array, bins)

    if return_bins:
        return out_array, bins
    else:
        return out_array

# %%
BINS_NUM = 128

# %%
numeric_features = ["amount_rur"]

for feat in numeric_features:
    trx_data_train[feat], bins = digitize(trx_data_train[feat], q_count=BINS_NUM)
    trx_data_test[feat] = digitize(trx_data_test[feat], bins=bins)

# %%
import gc

gc.collect()
# Out:
# 234

# %% [markdown]
# ---

# %%
preprocessor = PandasDataPreprocessor(
    col_id="client_id",
    col_event_time="trans_date",
    event_time_transformation="none",
    cols_category=["small_group"],
    cols_numerical=["amount_rur"],
    return_records=False,
)

# %%
data_train = preprocessor.fit_transform(trx_data_train)
data_test = preprocessor.transform(trx_data_test)

# %%
target_train.rename(columns={"bins": "target"}, inplace=True)
target_test.rename(columns={"bins": "target"}, inplace=True)
target_train.sort_values(by="client_id", inplace=True)
target_test.sort_values(by="client_id", inplace=True)
target_train = target_train["target"]
target_test = target_test["target"]
target_train.reset_index(drop=True, inplace=True)
target_test.reset_index(drop=True, inplace=True)

# %%
data_train = data_train.to_dict(orient="records")
data_test = data_test.to_dict(orient="records")

# %% [markdown]
# ---

# %% [markdown]
# **Window Aggregator Class:**

# %%
from ptls.data_load.padded_batch import PaddedBatch


class WinAggregator(TrxEncoder):
    """The NN layer, a combination of TrxEncoder and Mean Aggregation within a window of #`agg_samples` transactions 
       (works like nn.Sequential([TrxEncoder, Mean Window Aggregation])).
       It is supposed that any two different windows do not overlap here.
       
       The types of the input and output are `PaddedBatch` of shapes (B, L, T) and (B, L', T) respectively, where 
       B means batch_size,
       L/L' means the max length of a sequence of transactions in a batch (the length is the same as #trx)
       T means the dimension of a single transaction.

       Parameters
        agg_samples (int):
            The number of transactions in a sliding aggregation window.

        use_pre_agg_attention (bool):
            If True, the attention layer will be used between trx encoding step and aggregation step.

        use_window_attention (bool):
            If True, the attention layer will be applied to transactions in a sliding window before pooling.
            
        embeddings:
            You can find info about this param in TrxEncoder desc.
        
        numeric_values:
            You can find info about this param in TrxEncoder desc.

        embeddings_noise:
            You can find info about this param in TrxEncoder desc.
            
        emb_dropout:
            You can find info about this param in TrxEncoder desc.
            
        spatial_dropout:
            You can find info about this param in TrxEncoder desc.

        use_batch_norm:
            You can find info about this param in TrxEncoder desc.

        orthogonal_init:
            You can find info about this param in TrxEncoder desc.
            
        linear_projection_size:
            You can find info about this param in TrxEncoder desc.

        out_of_index:
            You can find info about this param in TrxEncoder desc.

        norm_embeddings:
            Keep default value for this parameter
        
        clip_replace_value:
            Not used. Keep default value for this parameter
        
        positions: 
            Not used. Keep default value for this parameter
       """

    def __init__(self,
                 agg_samples=3,
                 use_pre_agg_attention=False,
                 use_window_attention=False,
                 embeddings=None,
                 numeric_values=None,
                 custom_embeddings=None,
                 embeddings_noise: float = 0,
                 norm_embeddings=None,
                 use_batch_norm=False,
                 use_batch_norm_with_lens=False,
                 clip_replace_value=None,
                 positions=None,
                 emb_dropout=0,
                 spatial_dropout=False,
                 orthogonal_init=False,
                 linear_projection_size=0,
                 out_of_index: str = 'clip',
                 ):
        super().__init__(
            embeddings=embeddings,
            numeric_values=numeric_values,
            custom_embeddings=custom_embeddings,
            embeddings_noise=embeddings_noise,
            norm_embeddings=norm_embeddings,
            use_batch_norm=use_batch_norm,
            use_batch_norm_with_lens=use_batch_norm_with_lens,
            clip_replace_value=clip_replace_value,
            positions=positions,
            emb_dropout=emb_dropout,
            spatial_dropout=spatial_dropout,
            orthogonal_init=orthogonal_init,
            linear_projection_size=linear_projection_size,
            out_of_index=out_of_index
        )

        self.agg_samples = agg_samples

        self.use_pre_agg_attention = use_pre_agg_attention        
        if self.use_pre_agg_attention:
            pass # Not Implemented

        self.use_window_attention = use_window_attention
        if self.use_window_attention:
            pass # Not Implemented

    def forward(self, pb: PaddedBatch):
        embeds = super().forward(pb)

        if self.use_pre_agg_attention:
            pass # Not Implemented

        mask = torch.arange(embeds.payload.shape[1], device=embeds.device)[None, :] + torch.ones((embeds.seq_lens.shape[0], embeds.payload.shape[1]), device=embeds.device)
        mask[mask > embeds.seq_lens[:, None]] = 0.
        mask[mask > 0.] = 1.
        mask = mask[:, :, None]
    
        masked_embeds = embeds.payload * mask
    
        num_samples_to_add = self.agg_samples - (masked_embeds.shape[1] % self.agg_samples)  
        if num_samples_to_add > 0:
            additional_samples = torch.zeros((masked_embeds.shape[0], num_samples_to_add, masked_embeds.shape[2]), device=masked_embeds.device)
            masked_embeds = torch.cat((masked_embeds, additional_samples), dim=1)
            mask_additional_samples = torch.zeros((mask.shape[0], num_samples_to_add, mask.shape[2]), device=mask.device)
            mask = torch.cat((mask, mask_additional_samples), dim=1)
    
        masked_embeds = torch.reshape(masked_embeds, (masked_embeds.shape[0], masked_embeds.shape[1] // self.agg_samples, self.agg_samples, masked_embeds.shape[2]))
        mask = torch.reshape(mask, (mask.shape[0], mask.shape[1] // self.agg_samples, self.agg_samples, mask.shape[2]))

        if self.use_window_attention:
            pass # Not Implemented
        
        mask = torch.sum(mask, dim=2)
        mask[mask == 0.] = 1.
    
        mean_embeds = torch.sum(masked_embeds, dim=2) / mask

        new_seq_lens = embeds.seq_lens // self.agg_samples
        div_mod_seq_lens = ((embeds.seq_lens % self.agg_samples) > 0).int()
        new_seq_lens += div_mod_seq_lens

        return PaddedBatch(mean_embeds, new_seq_lens)

# %%
# seed_everything(0)

# %%
# device = "cuda:0"

# %%
# trx_encoder_params = dict(
#     embeddings_noise=0.003,
#     numeric_values={"amount_rur": "log"},
#     embeddings={
#         "trans_date": {"in": 800, "out": 16},
#         "small_group": {"in": 250, "out": 16},
#     },
# )

# trx_encoder = TrxEncoder(**trx_encoder_params).to(device)

# %%
# from ptls.data_load.padded_batch import PaddedBatch


# train_loader = inference_data_loader(data_train, num_workers=0, batch_size=128)
# agg_samples = 5
# use_attention = False
# trx_encoder.eval()

# for i, batch in tqdm(enumerate(train_loader)):
#     batch = batch.to(device)
        
#     embeds = trx_encoder(batch)
    
#     mask = torch.arange(embeds.payload.shape[1], device=embeds.device)[None, :] + torch.ones((embeds.seq_lens.shape[0], embeds.payload.shape[1]), device=embeds.device)
#     mask[mask > embeds.seq_lens[:, None]] = 0.
#     mask[mask > 0.] = 1.
#     mask = mask[:, :, None]
    
#     masked_embeds = embeds.payload * mask
    
#     num_samples_to_add = agg_samples - (masked_embeds.shape[1] % agg_samples)  
#     if num_samples_to_add > 0:
#         additional_samples = torch.zeros((masked_embeds.shape[0], num_samples_to_add, masked_embeds.shape[2]), device=masked_embeds.device)
#         masked_embeds = torch.cat((masked_embeds, additional_samples), dim=1)

#         mask_additional_samples = torch.zeros((mask.shape[0], num_samples_to_add, mask.shape[2]), device=mask.device)
#         mask = torch.cat((mask, mask_additional_samples), dim=1)
    
#     masked_embeds = torch.reshape(masked_embeds, (masked_embeds.shape[0], masked_embeds.shape[1] // agg_samples, agg_samples, masked_embeds.shape[2]))
#     mask = torch.reshape(mask, (mask.shape[0], mask.shape[1] // agg_samples, agg_samples, mask.shape[2]))

#     mask = torch.sum(mask, dim=2)
#     mask[mask == 0.] = 1.
    
#     mean_embeds = torch.sum(masked_embeds, dim=2) / mask

#     new_seq_lens = embeds.seq_lens // agg_samples
#     div_mod_seq_lens = ((embeds.seq_lens % agg_samples) > 0).int()
#     new_seq_lens += div_mod_seq_lens

#     out = PaddedBatch(mean_embeds, new_seq_lens)

#     if i == 0:
#         print(out.payload)

# %%
# seed_everything(0)

# %%
# agg_encoder_params = dict(
#     embeddings_noise=0.003,
#     numeric_values={"amount_rur": "log"},
#     embeddings={
#         "trans_date": {"in": 800, "out": 16},
#         "small_group": {"in": 250, "out": 16},
#     },
#     agg_samples=5,
#     use_pre_agg_attention=False,
#     use_window_attention=False
# )

# trx_encoder = WinAggregator(**agg_encoder_params)

# %%
# trx_encoder.to(device)
# Out:
# WinAggregator(
#   (embeddings): ModuleDict(
#     (trans_date): NoisyEmbedding(
#       800, 16, padding_idx=0
#       (dropout): Dropout(p=0, inplace=False)
#     )
#     (small_group): NoisyEmbedding(
#       250, 16, padding_idx=0
#       (dropout): Dropout(p=0, inplace=False)
#     )
#   )
#   (custom_embeddings): ModuleDict(
#     (amount_rur): LogScaler()
#   )
# )

# %%
# train_loader = inference_data_loader(data_train, num_workers=0, batch_size=128)
# trx_encoder.eval()

# for i, batch in tqdm(enumerate(train_loader)):
#     batch = batch.to(device)    
#     embeds = trx_encoder(batch)

#     if i == 0:
#         print(embeds.payload)

# %% [markdown]
# # Sliding Window Aggregation (Mean Pooling)

# %% [markdown]
# - **COLES:**

# %%
seed_everything(0)

# %% [markdown]
# **DataLoaders:**

# %%
data = PtlsDataModule(
    train_data=ColesDataset(
        MemoryMapDataset(
            data=data_train,
            i_filters=[SeqLenFilter(min_seq_len=25)],
        ),
        splitter=SampleSlices(
            split_count=5,
            cnt_min=30,
            cnt_max=190,
        ),
    ),
    train_num_workers=4,
    train_batch_size=128,
    valid_data=ColesDataset(
        MemoryMapDataset(
            data=data_test,
            i_filters=[SeqLenFilter(min_seq_len=25)],
        ),
        splitter=SampleSlices(
            split_count=5,
            cnt_min=30,
            cnt_max=190,
        ),
    ),
    valid_num_workers=4,
    valid_batch_size=128
)

# %% [markdown]
# **Модель:**

# %%
N_EPOCHS = 20

# %%
agg_encoder_params = dict(
    embeddings_noise=0.003,
    numeric_values={"amount_rur": "log"},
    embeddings={
        "trans_date": {"in": 800, "out": 16},
        "small_group": {"in": 250, "out": 16},
    },
    agg_samples=20,
    use_pre_agg_attention=False,
    use_window_attention=False
)

trx_encoder = WinAggregator(**agg_encoder_params)

seq_encoder = RnnSeqEncoder(
    trx_encoder=trx_encoder,
    hidden_size=512,
    type="gru",
)

coles = CoLESModule(
    seq_encoder=seq_encoder,
    optimizer_partial=partial(torch.optim.Adam, lr=3e-3, weight_decay=5e-4),
    lr_scheduler_partial=partial(torch.optim.lr_scheduler.CosineAnnealingLR, T_max=N_EPOCHS, eta_min=5e-5)
)

# %% [markdown]
# **Обучение:**

# %%
logger = CometLogger(project_name="EvS_SSL", experiment_name="CoLES_WinAgg")

trainer = pl.Trainer(
    logger=logger,
    max_epochs=N_EPOCHS,
    accelerator="gpu",
    devices=1,
    enable_progress_bar=True
)

# %%
trainer.fit(coles, data)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/askoro/evs-ssl/d944aa2ac9164fd18f6495d36e136ff1
#
# COMET INFO: Couldn't find a Git repository in '/kaggle/working' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : CoLES_WinAgg
# COMET INFO:     url                   : https://www.comet.com/askoro/evs-ssl/d944aa2ac9164fd18f6495d36e136ff1
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [506]              : (181.281005859375, 683.1492919921875)
# COMET INFO:     seq_len [84]            : (105.6421890258789, 115.37187957763672)
# COMET INFO:     valid/recall_top_k [20] : (0.4913947284221649, 0.6664039492607117)
# COMET INFO:   Others:
# COMET INFO:     Name : CoLES_WinAgg
# COMET INFO:   Parameters:
# COMET INFO:     test_batch_size   : None
# COMET INFO:     test_drop_last    : False
# COMET INFO:     test_num_workers  : None
# COMET INFO:     train_batch_size  : 128
# COMET INFO:     train_drop_last   : False
# COMET INFO:     train_num_workers : 4
# COMET INFO:     valid_batch_size  : 128
# COMET INFO:     valid_drop_last   : False
# COMET INFO:     valid_num_workers : 4
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:

# %%
trainer.logged_metrics
# Out:
# {'loss': tensor(174.7807),
#  'seq_len': tensor(112.2350),
#  'valid/recall_top_k': tensor(0.6652)}

# %%
torch.save(seq_encoder.state_dict(), "coles_enc_win_agg.pt")

# %% [markdown]
# **Измерим качество на тесте (catboost поверх эмбеддингов):**

# %%
encoder = coles.seq_encoder

device = "cuda:0"

encoder.to(device)
# Out:
# RnnSeqEncoder(
#   (trx_encoder): WinAggregator(
#     (embeddings): ModuleDict(
#       (trans_date): NoisyEmbedding(
#         800, 16, padding_idx=0
#         (dropout): Dropout(p=0, inplace=False)
#       )
#       (small_group): NoisyEmbedding(
#         250, 16, padding_idx=0
#         (dropout): Dropout(p=0, inplace=False)
#       )
#     )
#     (custom_embeddings): ModuleDict(
#       (amount_rur): LogScaler()
#     )
#   )
#   (seq_encoder): RnnEncoder(
#     (rnn): GRU(33, 512, batch_first=True)
#     (reducer): LastStepEncoder()
#   )
# )

# %%
from tqdm import tqdm

seed_everything(0)

# %%
train_loader = inference_data_loader(data_train, num_workers=0, batch_size=128)
encoder.eval()
train_embeds = None

for i, batch in tqdm(enumerate(train_loader)):
    train_embeds_batch = encoder(batch.to(device))
    if i == 0:
        train_embeds = train_embeds_batch.detach().cpu().numpy()
    else:
        train_embeds = np.concatenate([train_embeds, train_embeds_batch.detach().cpu().numpy()], axis=0)
    
train_embeds
# Out:
# 211it [00:05, 35.41it/s]
# array([[ 0.00452117, -0.02827387,  0.9337678 , ...,  0.00495588,
#          0.0193441 ,  0.09391169],
#        [ 0.04560404, -0.03634291,  0.8987108 , ..., -0.04580244,
#         -0.00496499,  0.15117761],
#        [ 0.03072902, -0.13078159,  0.99990016, ..., -0.09737144,
#         -0.0161845 ,  0.968005  ],
#        ...,
#        [ 0.00750701, -0.00894194,  0.9967334 , ...,  0.01608533,
#          0.00373627,  0.6375581 ],
#        [ 0.0071538 ,  0.0496349 ,  0.99902135, ..., -0.03007819,
#         -0.02328188,  0.16292547],
#        [-0.02030775, -0.06471202,  0.9840942 , ..., -0.03953908,
#          0.00458581,  0.41498113]], dtype=float32)

# %%
test_loader = inference_data_loader(data_test, num_workers=0, batch_size=128)
encoder.eval()
test_embeds = None

for i, batch in tqdm(enumerate(test_loader)):
    test_embeds_batch = encoder(batch.to(device))
    if i == 0:
        test_embeds = test_embeds_batch.detach().cpu().numpy()
    else:
        test_embeds = np.concatenate([test_embeds, test_embeds_batch.detach().cpu().numpy()], axis=0)
    
test_embeds
# Out:
# 24it [00:00, 52.54it/s]
# array([[-0.00913762, -0.0365316 ,  0.9914088 , ...,  0.06454185,
#         -0.01362646,  0.36703894],
#        [-0.01873677, -0.1018367 ,  0.9499835 , ..., -0.01761043,
#          0.06090444,  0.62053996],
#        [ 0.01613991, -0.04726062,  0.58812404, ..., -0.04554856,
#          0.12404823, -0.04990862],
#        ...,
#        [ 0.06967799, -0.10422407,  0.9955157 , ...,  0.16319045,
#         -0.20528884, -0.62589127],
#        [ 0.01730782, -0.03003943,  0.99920636, ...,  0.02860174,
#         -0.01038891,  0.9474452 ],
#        [-0.01291906, -0.03034842,  0.88051796, ...,  0.00866131,
#          0.09558208,  0.8824644 ]], dtype=float32)

# %%
clf = CatBoostClassifier(loss_function='MultiClass', task_type="GPU", devices='0')

clf.fit(train_embeds, target_train, plot_file="catboost_log.html")
# Out:
# Learning rate set to 0.12714
# 0:	learn: 1.3141301	total: 17.6ms	remaining: 17.5s
# 1:	learn: 1.2588322	total: 28.3ms	remaining: 14.1s
# 2:	learn: 1.2151895	total: 39.4ms	remaining: 13.1s
# 3:	learn: 1.1806934	total: 51.2ms	remaining: 12.8s
# 4:	learn: 1.1523811	total: 63ms	remaining: 12.5s
# 5:	learn: 1.1282296	total: 74.5ms	remaining: 12.3s
# 6:	learn: 1.1078615	total: 85.9ms	remaining: 12.2s
# 7:	learn: 1.0897215	total: 97.2ms	remaining: 12.1s
# 8:	learn: 1.0743169	total: 108ms	remaining: 11.9s
# 9:	learn: 1.0604403	total: 119ms	remaining: 11.8s
# 10:	learn: 1.0485289	total: 131ms	remaining: 11.8s
# 11:	learn: 1.0382023	total: 143ms	remaining: 11.8s
# 12:	learn: 1.0289413	total: 155ms	remaining: 11.8s
# 13:	learn: 1.0206798	total: 167ms	remaining: 11.8s
# 14:	learn: 1.0139099	total: 178ms	remaining: 11.7s
# 15:	learn: 1.0076668	total: 191ms	remaining: 11.7s
# 16:	learn: 1.0017263	total: 203ms	remaining: 11.7s
# 17:	learn: 0.9956908	total: 214ms	remaining: 11.7s
# 18:	learn: 0.9909684	total: 225ms	remaining: 11.6s
# 19:	learn: 0.9868546	total: 236ms	remaining: 11.5s
# 20:	learn: 0.9829675	total: 246ms	remaining: 11.5s
# 21:	learn: 0.9792155	total: 257ms	remaining: 11.4s
# 22:	learn: 0.9756810	total: 268ms	remaining: 11.4s
# 23:	learn: 0.9721797	total: 279ms	remaining: 11.4s
# 24:	learn: 0.9693171	total: 291ms	remaining: 11.4s
# 25:	learn: 0.9668077	total: 303ms	remaining: 11.3s
# 26:	learn: 0.9645660	total: 314ms	remaining: 11.3s
# 27:	learn: 0.9622967	total: 325ms	remaining: 11.3s
# 28:	learn: 0.9598989	total: 335ms	remaining: 11.2s
# 29:	learn: 0.9574866	total: 346ms	remaining: 11.2s
# 30:	learn: 0.9553518	total: 356ms	remaining: 11.1s
# 31:	learn: 0.9532639	total: 367ms	remaining: 11.1s
# 32:	learn: 0.9508568	total: 377ms	remaining: 11s
# 33:	learn: 0.9487338	total: 388ms	remaining: 11s
# 34:	learn: 0.9469384	total: 399ms	remaining: 11s
# 35:	learn: 0.9449589	total: 410ms	remaining: 11s
# 36:	learn: 0.9430342	total: 420ms	remaining: 10.9s
# 37:	learn: 0.9414452	total: 431ms	remaining: 10.9s
# 38:	learn: 0.9399426	total: 442ms	remaining: 10.9s
# 39:	learn: 0.9385158	total: 452ms	remaining: 10.9s
# 40:	learn: 0.9373058	total: 462ms	remaining: 10.8s
# 41:	learn: 0.9356829	total: 473ms	remaining: 10.8s
# 42:	learn: 0.9341247	total: 484ms	remaining: 10.8s
# 43:	learn: 0.9329753	total: 494ms	remaining: 10.7s
# 44:	learn: 0.9312101	total: 505ms	remaining: 10.7s
# 45:	learn: 0.9299995	total: 515ms	remaining: 10.7s
# 46:	learn: 0.9288996	total: 526ms	remaining: 10.7s
# 47:	learn: 0.9278528	total: 536ms	remaining: 10.6s
# 48:	learn: 0.9267408	total: 546ms	remaining: 10.6s
# 49:	learn: 0.9255050	total: 557ms	remaining: 10.6s
# 50:	learn: 0.9238516	total: 568ms	remaining: 10.6s
# 51:	learn: 0.9229722	total: 578ms	remaining: 10.5s
# 52:	learn: 0.9219418	total: 588ms	remaining: 10.5s
# 53:	learn: 0.9205883	total: 598ms	remaining: 10.5s
# 54:	learn: 0.9193678	total: 609ms	remaining: 10.5s
# 55:	learn: 0.9185835	total: 619ms	remaining: 10.4s
# 56:	learn: 0.9175494	total: 629ms	remaining: 10.4s
# 57:	learn: 0.9169592	total: 641ms	remaining: 10.4s
# 58:	learn: 0.9158519	total: 652ms	remaining: 10.4s
# 59:	learn: 0.9146274	total: 663ms	remaining: 10.4s
# 60:	learn: 0.9136069	total: 674ms	remaining: 10.4s
# 61:	learn: 0.9129142	total: 684ms	remaining: 10.3s
# 62:	learn: 0.9119834	total: 694ms	remaining: 10.3s
# 63:	learn: 0.9108009	total: 705ms	remaining: 10.3s
# 64:	learn: 0.9100224	total: 715ms	remaining: 10.3s
# 65:	learn: 0.9090616	total: 725ms	remaining: 10.3s
# 66:	learn: 0.9082825	total: 735ms	remaining: 10.2s
# 67:	learn: 0.9073034	total: 745ms	remaining: 10.2s
# 68:	learn: 0.9061081	total: 756ms	remaining: 10.2s
# 69:	learn: 0.9053500	total: 765ms	remaining: 10.2s
# 70:	learn: 0.9045425	total: 776ms	remaining: 10.1s
# 71:	learn: 0.9038140	total: 785ms	remaining: 10.1s
# 72:	learn: 0.9028015	total: 796ms	remaining: 10.1s
# 73:	learn: 0.9019304	total: 806ms	remaining: 10.1s
# 74:	learn: 0.9006662	total: 816ms	remaining: 10.1s
# 122:	learn: 0.8646766	total: 1.32s	remaining: 9.38s
# 123:	learn: 0.8638605	total: 1.33s	remaining: 9.38s
# 124:	learn: 0.8632687	total: 1.34s	remaining: 9.36s
# 125:	learn: 0.8626573	total: 1.35s	remaining: 9.35s
# 126:	learn: 0.8619820	total: 1.36s	remaining: 9.33s
# 127:	learn: 0.8611822	total: 1.37s	remaining: 9.32s
# 128:	learn: 0.8608345	total: 1.38s	remaining: 9.31s
# 129:	learn: 0.8601474	total: 1.39s	remaining: 9.3s
# 130:	learn: 0.8594343	total: 1.4s	remaining: 9.29s
# 131:	learn: 0.8589206	total: 1.41s	remaining: 9.27s
# 132:	learn: 0.8583730	total: 1.42s	remaining: 9.26s
# 133:	learn: 0.8577255	total: 1.43s	remaining: 9.24s
# 134:	learn: 0.8571482	total: 1.44s	remaining: 9.22s
# 135:	learn: 0.8566939	total: 1.45s	remaining: 9.21s
# 136:	learn: 0.8561879	total: 1.46s	remaining: 9.2s
# 137:	learn: 0.8553937	total: 1.47s	remaining: 9.19s
# 138:	learn: 0.8548883	total: 1.48s	remaining: 9.17s
# 139:	learn: 0.8543198	total: 1.49s	remaining: 9.15s
# 140:	learn: 0.8535811	total: 1.5s	remaining: 9.14s
# 141:	learn: 0.8530509	total: 1.51s	remaining: 9.12s
# 142:	learn: 0.8524520	total: 1.52s	remaining: 9.11s
# 143:	learn: 0.8517185	total: 1.53s	remaining: 9.1s
# 144:	learn: 0.8511544	total: 1.54s	remaining: 9.08s
# 145:	learn: 0.8504801	total: 1.55s	remaining: 9.06s
# 146:	learn: 0.8498272	total: 1.56s	remaining: 9.05s
# 147:	learn: 0.8492413	total: 1.57s	remaining: 9.04s
# 148:	learn: 0.8487560	total: 1.58s	remaining: 9.02s
# 149:	learn: 0.8481905	total: 1.59s	remaining: 9.01s
# 150:	learn: 0.8475605	total: 1.6s	remaining: 8.99s
# 151:	learn: 0.8470794	total: 1.61s	remaining: 8.98s
# 152:	learn: 0.8463322	total: 1.62s	remaining: 8.96s
# 153:	learn: 0.8456326	total: 1.63s	remaining: 8.95s
# 154:	learn: 0.8448556	total: 1.64s	remaining: 8.94s
# 155:	learn: 0.8442527	total: 1.65s	remaining: 8.93s
# 156:	learn: 0.8435399	total: 1.66s	remaining: 8.92s
# 157:	learn: 0.8429777	total: 1.67s	remaining: 8.9s
# 158:	learn: 0.8423100	total: 1.68s	remaining: 8.89s
# 159:	learn: 0.8417713	total: 1.69s	remaining: 8.88s
# 160:	learn: 0.8413681	total: 1.7s	remaining: 8.86s
# 161:	learn: 0.8407931	total: 1.71s	remaining: 8.85s
# 162:	learn: 0.8402831	total: 1.72s	remaining: 8.84s
# 163:	learn: 0.8395640	total: 1.73s	remaining: 8.83s
# 164:	learn: 0.8390082	total: 1.74s	remaining: 8.82s
# 165:	learn: 0.8383374	total: 1.75s	remaining: 8.8s
# 166:	learn: 0.8378003	total: 1.76s	remaining: 8.79s
# 167:	learn: 0.8372567	total: 1.77s	remaining: 8.77s
# 168:	learn: 0.8367249	total: 1.78s	remaining: 8.76s
# 169:	learn: 0.8360962	total: 1.79s	remaining: 8.74s
# 170:	learn: 0.8354229	total: 1.8s	remaining: 8.73s
# 171:	learn: 0.8349538	total: 1.81s	remaining: 8.72s
# 172:	learn: 0.8344959	total: 1.82s	remaining: 8.71s
# 173:	learn: 0.8337525	total: 1.83s	remaining: 8.7s
# 174:	learn: 0.8332222	total: 1.84s	remaining: 8.69s
# 175:	learn: 0.8327854	total: 1.85s	remaining: 8.68s
# 176:	learn: 0.8319270	total: 1.86s	remaining: 8.67s
# 177:	learn: 0.8313003	total: 1.88s	remaining: 8.66s
# 178:	learn: 0.8305586	total: 1.89s	remaining: 8.65s
# 179:	learn: 0.8298014	total: 1.9s	remaining: 8.64s
# 180:	learn: 0.8291570	total: 1.91s	remaining: 8.63s
# 181:	learn: 0.8286401	total: 1.92s	remaining: 8.61s
# 182:	learn: 0.8281513	total: 1.93s	remaining: 8.6s
# 183:	learn: 0.8277174	total: 1.94s	remaining: 8.59s
# 184:	learn: 0.8270381	total: 1.95s	remaining: 8.57s
# 185:	learn: 0.8266321	total: 1.96s	remaining: 8.56s
# 186:	learn: 0.8261092	total: 1.97s	remaining: 8.55s
# 187:	learn: 0.8254779	total: 1.98s	remaining: 8.53s
# 188:	learn: 0.8250270	total: 1.99s	remaining: 8.52s
# 189:	learn: 0.8244144	total: 2s	remaining: 8.51s
# 190:	learn: 0.8237496	total: 2.01s	remaining: 8.5s
# 191:	learn: 0.8230298	total: 2.02s	remaining: 8.48s
# 192:	learn: 0.8223075	total: 2.03s	remaining: 8.47s
# 193:	learn: 0.8216850	total: 2.04s	remaining: 8.46s
# 194:	learn: 0.8212101	total: 2.05s	remaining: 8.45s
# 195:	learn: 0.8205930	total: 2.06s	remaining: 8.44s
# 196:	learn: 0.8199504	total: 2.07s	remaining: 8.42s
# 197:	learn: 0.8194392	total: 2.08s	remaining: 8.41s
# 198:	learn: 0.8185725	total: 2.09s	remaining: 8.4s
# 199:	learn: 0.8181492	total: 2.1s	remaining: 8.39s
# 200:	learn: 0.8175276	total: 2.11s	remaining: 8.38s
# 201:	learn: 0.8170901	total: 2.12s	remaining: 8.37s
# 202:	learn: 0.8164162	total: 2.13s	remaining: 8.36s
# 203:	learn: 0.8159560	total: 2.14s	remaining: 8.35s
# 204:	learn: 0.8153056	total: 2.15s	remaining: 8.34s
# 205:	learn: 0.8147788	total: 2.16s	remaining: 8.32s
# 206:	learn: 0.8141375	total: 2.17s	remaining: 8.31s
# 207:	learn: 0.8135404	total: 2.18s	remaining: 8.3s
# 208:	learn: 0.8129949	total: 2.19s	remaining: 8.29s
# 209:	learn: 0.8124867	total: 2.2s	remaining: 8.28s
# 210:	learn: 0.8118003	total: 2.21s	remaining: 8.27s
# 211:	learn: 0.8112684	total: 2.22s	remaining: 8.26s
# 212:	learn: 0.8107270	total: 2.23s	remaining: 8.24s
# 213:	learn: 0.8099484	total: 2.24s	remaining: 8.23s
# 214:	learn: 0.8095266	total: 2.25s	remaining: 8.22s
# 772:	learn: 0.5676559	total: 8.06s	remaining: 2.37s
# 773:	learn: 0.5673359	total: 8.07s	remaining: 2.35s
# 774:	learn: 0.5670075	total: 8.08s	remaining: 2.34s
# 775:	learn: 0.5666241	total: 8.09s	remaining: 2.33s
# 776:	learn: 0.5663583	total: 8.1s	remaining: 2.32s
# 777:	learn: 0.5660009	total: 8.11s	remaining: 2.31s
# 778:	learn: 0.5657338	total: 8.12s	remaining: 2.3s
# 779:	learn: 0.5654608	total: 8.13s	remaining: 2.29s
# 780:	learn: 0.5650518	total: 8.14s	remaining: 2.28s
# 781:	learn: 0.5647015	total: 8.15s	remaining: 2.27s
# 782:	learn: 0.5644662	total: 8.16s	remaining: 2.26s
# 783:	learn: 0.5641101	total: 8.17s	remaining: 2.25s
# 784:	learn: 0.5637687	total: 8.18s	remaining: 2.24s
# 785:	learn: 0.5633702	total: 8.19s	remaining: 2.23s
# 786:	learn: 0.5630616	total: 8.2s	remaining: 2.22s
# 787:	learn: 0.5627199	total: 8.21s	remaining: 2.21s
# 788:	learn: 0.5624138	total: 8.22s	remaining: 2.2s
# 789:	learn: 0.5619835	total: 8.23s	remaining: 2.19s
# 790:	learn: 0.5617177	total: 8.24s	remaining: 2.18s
# 791:	learn: 0.5614002	total: 8.25s	remaining: 2.17s
# 792:	learn: 0.5610446	total: 8.26s	remaining: 2.16s
# 793:	learn: 0.5606831	total: 8.27s	remaining: 2.15s
# 794:	learn: 0.5603319	total: 8.28s	remaining: 2.13s
# 795:	learn: 0.5600681	total: 8.29s	remaining: 2.13s
# 796:	learn: 0.5597881	total: 8.3s	remaining: 2.11s
# 797:	learn: 0.5594229	total: 8.31s	remaining: 2.1s
# 798:	learn: 0.5591216	total: 8.32s	remaining: 2.09s
# 799:	learn: 0.5589449	total: 8.34s	remaining: 2.08s
# 800:	learn: 0.5586431	total: 8.35s	remaining: 2.07s
# 801:	learn: 0.5584065	total: 8.36s	remaining: 2.06s
# 802:	learn: 0.5582354	total: 8.37s	remaining: 2.05s
# 803:	learn: 0.5577741	total: 8.38s	remaining: 2.04s
# 804:	learn: 0.5574219	total: 8.39s	remaining: 2.03s
# 805:	learn: 0.5570666	total: 8.4s	remaining: 2.02s
# 806:	learn: 0.5567148	total: 8.41s	remaining: 2.01s
# 807:	learn: 0.5564100	total: 8.42s	remaining: 2s
# 808:	learn: 0.5560544	total: 8.43s	remaining: 1.99s
# 809:	learn: 0.5556420	total: 8.44s	remaining: 1.98s
# 810:	learn: 0.5552341	total: 8.45s	remaining: 1.97s
# 811:	learn: 0.5549064	total: 8.46s	remaining: 1.96s
# 812:	learn: 0.5545132	total: 8.47s	remaining: 1.95s
# 813:	learn: 0.5541672	total: 8.48s	remaining: 1.94s
# 814:	learn: 0.5538963	total: 8.49s	remaining: 1.93s
# 815:	learn: 0.5536229	total: 8.5s	remaining: 1.92s
# 816:	learn: 0.5532365	total: 8.51s	remaining: 1.91s
# 817:	learn: 0.5528645	total: 8.52s	remaining: 1.9s
# 818:	learn: 0.5526368	total: 8.53s	remaining: 1.89s
# 819:	learn: 0.5524446	total: 8.54s	remaining: 1.88s
# 820:	learn: 0.5520694	total: 8.55s	remaining: 1.86s
# 821:	learn: 0.5518448	total: 8.56s	remaining: 1.85s
# 822:	learn: 0.5514952	total: 8.57s	remaining: 1.84s
# 823:	learn: 0.5511965	total: 8.58s	remaining: 1.83s
# 824:	learn: 0.5508718	total: 8.59s	remaining: 1.82s
# 825:	learn: 0.5503714	total: 8.6s	remaining: 1.81s
# 826:	learn: 0.5501227	total: 8.61s	remaining: 1.8s
# 827:	learn: 0.5497286	total: 8.62s	remaining: 1.79s
# 828:	learn: 0.5494345	total: 8.63s	remaining: 1.78s
# 829:	learn: 0.5491293	total: 8.64s	remaining: 1.77s
# 830:	learn: 0.5488389	total: 8.65s	remaining: 1.76s
# 831:	learn: 0.5486462	total: 8.66s	remaining: 1.75s
# 832:	learn: 0.5481725	total: 8.67s	remaining: 1.74s
# 833:	learn: 0.5479448	total: 8.68s	remaining: 1.73s
# 834:	learn: 0.5476809	total: 8.69s	remaining: 1.72s
# 835:	learn: 0.5473250	total: 8.7s	remaining: 1.71s
# 836:	learn: 0.5467646	total: 8.71s	remaining: 1.7s
# 837:	learn: 0.5464827	total: 8.72s	remaining: 1.69s
# 838:	learn: 0.5460748	total: 8.73s	remaining: 1.68s
# 839:	learn: 0.5457336	total: 8.74s	remaining: 1.67s
# 840:	learn: 0.5453313	total: 8.75s	remaining: 1.66s
# 841:	learn: 0.5449837	total: 8.77s	remaining: 1.64s
# 842:	learn: 0.5447178	total: 8.78s	remaining: 1.63s
# 843:	learn: 0.5443003	total: 8.79s	remaining: 1.62s
# 844:	learn: 0.5438925	total: 8.79s	remaining: 1.61s
# 845:	learn: 0.5435933	total: 8.81s	remaining: 1.6s
# 846:	learn: 0.5432285	total: 8.82s	remaining: 1.59s
# 847:	learn: 0.5429495	total: 8.83s	remaining: 1.58s
# 848:	learn: 0.5425574	total: 8.84s	remaining: 1.57s
# 849:	learn: 0.5420849	total: 8.85s	remaining: 1.56s
# 850:	learn: 0.5417360	total: 8.86s	remaining: 1.55s
# 851:	learn: 0.5414905	total: 8.87s	remaining: 1.54s
# 852:	learn: 0.5410013	total: 8.88s	remaining: 1.53s
# 853:	learn: 0.5407514	total: 8.89s	remaining: 1.52s
# 854:	learn: 0.5405364	total: 8.9s	remaining: 1.51s
# 855:	learn: 0.5402856	total: 8.91s	remaining: 1.5s
# 856:	learn: 0.5400329	total: 8.92s	remaining: 1.49s
# 857:	learn: 0.5396870	total: 8.93s	remaining: 1.48s
# 858:	learn: 0.5393081	total: 8.94s	remaining: 1.47s
# 859:	learn: 0.5390809	total: 8.95s	remaining: 1.46s
# 860:	learn: 0.5386639	total: 8.96s	remaining: 1.45s
# 861:	learn: 0.5383128	total: 8.97s	remaining: 1.44s
# 862:	learn: 0.5380694	total: 8.98s	remaining: 1.43s
# 863:	learn: 0.5378947	total: 8.99s	remaining: 1.41s
# 864:	learn: 0.5375658	total: 9s	remaining: 1.4s
# 959:	learn: 0.5079076	total: 9.99s	remaining: 416ms
# 960:	learn: 0.5075918	total: 10s	remaining: 406ms
# 961:	learn: 0.5073479	total: 10s	remaining: 395ms
# 962:	learn: 0.5070666	total: 10s	remaining: 385ms
# 963:	learn: 0.5067151	total: 10s	remaining: 375ms
# 964:	learn: 0.5063494	total: 10s	remaining: 364ms
# 965:	learn: 0.5060807	total: 10.1s	remaining: 354ms
# 966:	learn: 0.5057129	total: 10.1s	remaining: 343ms
# 967:	learn: 0.5054705	total: 10.1s	remaining: 333ms
# 968:	learn: 0.5051248	total: 10.1s	remaining: 323ms
# 969:	learn: 0.5049049	total: 10.1s	remaining: 312ms
# 970:	learn: 0.5045844	total: 10.1s	remaining: 302ms
# 971:	learn: 0.5044436	total: 10.1s	remaining: 291ms
# 972:	learn: 0.5042023	total: 10.1s	remaining: 281ms
# 973:	learn: 0.5038902	total: 10.1s	remaining: 270ms
# 974:	learn: 0.5034830	total: 10.1s	remaining: 260ms
# 975:	learn: 0.5031110	total: 10.2s	remaining: 250ms
# 976:	learn: 0.5028563	total: 10.2s	remaining: 239ms
# 977:	learn: 0.5025957	total: 10.2s	remaining: 229ms
# 978:	learn: 0.5023050	total: 10.2s	remaining: 218ms
# 979:	learn: 0.5020670	total: 10.2s	remaining: 208ms
# 980:	learn: 0.5016725	total: 10.2s	remaining: 198ms
# 981:	learn: 0.5013021	total: 10.2s	remaining: 187ms
# 982:	learn: 0.5010455	total: 10.2s	remaining: 177ms
# 983:	learn: 0.5008070	total: 10.2s	remaining: 166ms
# 984:	learn: 0.5004178	total: 10.2s	remaining: 156ms
# 985:	learn: 0.5001602	total: 10.3s	remaining: 146ms
# 986:	learn: 0.4998226	total: 10.3s	remaining: 135ms
# 987:	learn: 0.4996141	total: 10.3s	remaining: 125ms
# 988:	learn: 0.4993995	total: 10.3s	remaining: 114ms
# 989:	learn: 0.4991551	total: 10.3s	remaining: 104ms
# 990:	learn: 0.4987861	total: 10.3s	remaining: 93.6ms
# 991:	learn: 0.4983298	total: 10.3s	remaining: 83.2ms
# 992:	learn: 0.4980673	total: 10.3s	remaining: 72.8ms
# 993:	learn: 0.4979324	total: 10.3s	remaining: 62.4ms
# 994:	learn: 0.4976379	total: 10.3s	remaining: 52ms
# 995:	learn: 0.4973093	total: 10.4s	remaining: 41.6ms
# 996:	learn: 0.4969724	total: 10.4s	remaining: 31.2ms
# 997:	learn: 0.4966859	total: 10.4s	remaining: 20.8ms
# 998:	learn: 0.4963793	total: 10.4s	remaining: 10.4ms
# 999:	learn: 0.4961331	total: 10.4s	remaining: 0us

# %%
test_pred = clf.predict(test_embeds)
test_proba = clf.predict_proba(test_embeds)

# %%
print("Accuracy:", accuracy_score(target_test, test_pred))
print("ROC-AUC:", roc_auc_score(target_test, test_proba, average="weighted", multi_class="ovr"))
# Out:
# Accuracy: 0.5623333333333334
# ROC-AUC: 0.8212206273323065

# %% [markdown]
# - COLES embeds + Catboost:
#   - `Accuracy: 0.6063333333333333`
#   -  `ROC-AUC: 0.8485032660206542`
#
# \
#
# - COLES embeds (w/ Window Aggregation, 3 trx window) + Catboost:
#   - `Accuracy: 0.5793333333333334`
#   - `ROC-AUC: 0.8322195150062717`
#
# \
#
# - COLES embeds (w/ Window Aggregation, 5 trx window) + Catboost:
#   - `Accuracy: 0.565`
#   - `ROC-AUC: 0.8228954034229273`
#
# \
#
# - COLES embeds (w/ Window Aggregation, 20 trx window) + Catboost:
#   - `Accuracy: 0.5623333333333334`
#   - `ROC-AUC: 0.8212206273323065`

# %% [markdown]
# ---

# %% [markdown]
# - **CPC modeling:**

# %%
seed_everything(0)

# %% [markdown]
# **DataLoaders:**

# %%
data = PtlsDataModule(
    train_data=CpcDataset(
        MemoryMapDataset(data=data_train),
        min_len=1000,
        max_len=1200
    ),
    train_num_workers=4,
    train_batch_size=64,
    valid_data=CpcDataset(
        MemoryMapDataset(data=data_test),
        min_len=1000,
        max_len=1200
    ),
    valid_num_workers=4,
    valid_batch_size=64
)

# %% [markdown]
# **Модель:**

# %%
N_EPOCHS = 15

# %%
agg_encoder_params = dict(
    embeddings_noise=0.003,
    numeric_values={"amount_rur": "log"},
    embeddings={
        "trans_date": {"in": 800, "out": 128},
        "small_group": {"in": 250, "out": 128},
    },
    agg_samples=20,
    use_pre_agg_attention=False,
    use_window_attention=False
)

trx_encoder = WinAggregator(**agg_encoder_params)

seq_encoder = RnnSeqEncoder(
    trx_encoder=trx_encoder,
    hidden_size=512,
    type="gru"
)

cpc = CpcModule(
    seq_encoder=seq_encoder,
    n_forward_steps=6,
    n_negatives=40,
    optimizer_partial=partial(torch.optim.Adam, lr=2e-3),
    lr_scheduler_partial=partial(torch.optim.lr_scheduler.StepLR, step_size=5, gamma=0.5)
)

# %% [markdown]
# **Обучение:**

# %%
logger = CometLogger(project_name="EvS_SSL", experiment_name="CPC_modeling_WinAgg")

trainer = pl.Trainer(
    logger=logger,
    max_epochs=N_EPOCHS,
    accelerator="gpu",
    devices=1,
    enable_progress_bar=True
)

# %%
trainer.fit(cpc, data)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/askoro/evs-ssl/e6d095de1b0c43eaaa2b3afb5d762a43
#
# COMET INFO: Couldn't find a Git repository in '/kaggle/working' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : CPC_modeling_WinAgg
# COMET INFO:     url                   : https://www.comet.com/askoro/evs-ssl/e6d095de1b0c43eaaa2b3afb5d762a43
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [759]              : (0.6028669476509094, 3.8364548683166504)
# COMET INFO:     seq_len [126]           : (834.5, 905.59375)
# COMET INFO:     valid/cpc_accuracy [15] : (0.8311789631843567, 0.8848307132720947)
# COMET INFO:   Others:
# COMET INFO:     Name : CPC_modeling_WinAgg
# COMET INFO:   Parameters:
# COMET INFO:     test_batch_size   : None
# COMET INFO:     test_drop_last    : False
# COMET INFO:     test_num_workers  : None
# COMET INFO:     train_batch_size  : 64
# COMET INFO:     train_drop_last   : False
# COMET INFO:     train_num_workers : 4
# COMET INFO:     valid_batch_size  : 64
# COMET INFO:     valid_drop_last   : False
# COMET INFO:     valid_num_workers : 4
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:

# %%
trainer.logged_metrics
# Out:
# {'loss': tensor(0.8090),
#  'seq_len': tensor(865.0715),
#  'valid/cpc_accuracy': tensor(0.8848)}

# %%
torch.save(seq_encoder.state_dict(), "cpc_enc_win_agg_trx20.pt")

# %% [markdown]
# **Измерим качество на тесте (catboost поверх эмбеддингов):**

# %%
encoder = cpc.seq_encoder

device = "cuda:0"

encoder.to(device)
# Out:
# RnnSeqEncoder(
#   (trx_encoder): WinAggregator(
#     (embeddings): ModuleDict(
#       (trans_date): NoisyEmbedding(
#         800, 128, padding_idx=0
#         (dropout): Dropout(p=0, inplace=False)
#       )
#       (small_group): NoisyEmbedding(
#         250, 128, padding_idx=0
#         (dropout): Dropout(p=0, inplace=False)
#       )
#     )
#     (custom_embeddings): ModuleDict(
#       (amount_rur): LogScaler()
#     )
#   )
#   (seq_encoder): RnnEncoder(
#     (rnn): GRU(257, 512, batch_first=True)
#     (reducer): LastStepEncoder()
#   )
# )

# %%
encoder.seq_encoder.is_reduce_sequence = True

# %%
from tqdm import tqdm

seed_everything(0)

# %%
train_loader = inference_data_loader(data_train, num_workers=0, batch_size=128)
encoder.eval()
train_embeds = None

for i, batch in tqdm(enumerate(train_loader)):
    train_embeds_batch = encoder(batch.to(device))
    if i == 0:
        train_embeds = train_embeds_batch.detach().cpu().numpy()
    else:
        train_embeds = np.concatenate([train_embeds, train_embeds_batch.detach().cpu().numpy()], axis=0)
    
train_embeds
# Out:
# 211it [00:06, 32.54it/s]
# array([[ 0.1269838 ,  0.06069179, -0.8039373 , ...,  0.18366602,
#         -0.08507717, -0.09044018],
#        [ 0.24877743,  0.05744626, -0.9161373 , ..., -0.05227854,
#         -0.2074807 ,  0.03470141],
#        [ 0.54053456,  0.24899046, -0.7695131 , ..., -0.01845624,
#         -0.0511656 , -0.17779744],
#        ...,
#        [ 0.25679582,  0.1806997 , -0.7733664 , ..., -0.5018151 ,
#         -0.34194958, -0.2643399 ],
#        [ 0.07263993,  0.20356496, -0.56089795, ...,  0.04252471,
#         -0.16948244, -0.04190145],
#        [ 0.1883829 ,  0.09145279, -0.8739188 , ...,  0.17472775,
#         -0.37370485, -0.05681634]], dtype=float32)

# %%
test_loader = inference_data_loader(data_test, num_workers=0, batch_size=128)
encoder.eval()
test_embeds = None

for i, batch in tqdm(enumerate(test_loader)):
    test_embeds_batch = encoder(batch.to(device))
    if i == 0:
        test_embeds = test_embeds_batch.detach().cpu().numpy()
    else:
        test_embeds = np.concatenate([test_embeds, test_embeds_batch.detach().cpu().numpy()], axis=0)
    
test_embeds
# Out:
# 24it [00:00, 47.60it/s]
# array([[ 0.20589167, -0.02757158, -0.71205354, ..., -0.01409675,
#         -0.23025711,  0.03673205],
#        [ 0.10020506,  0.0552436 ,  0.44483566, ...,  0.09490182,
#         -0.47456124, -0.05336427],
#        [ 0.10850395,  0.04108413, -0.9087362 , ...,  0.7003215 ,
#         -0.27659315, -0.1418961 ],
#        ...,
#        [ 0.2944248 , -0.09982838, -0.9190626 , ...,  0.18788023,
#         -0.58525664, -0.09479044],
#        [-0.00449984,  0.06880501, -0.5330772 , ..., -0.03484499,
#         -0.05156473, -0.04935532],
#        [ 0.0023348 , -0.09331447, -0.19638704, ...,  0.50846523,
#         -0.20731081, -0.04913478]], dtype=float32)

# %%
clf = CatBoostClassifier(loss_function='MultiClass', task_type="GPU", devices='
# 457:	learn: 0.6300182	total: 20.1s	remaining: 23.8s
# 458:	learn: 0.6295822	total: 20.1s	remaining: 23.7s
# 459:	learn: 0.6290815	total: 20.2s	remaining: 23.7s
# 460:	learn: 0.6284521	total: 20.2s	remaining: 23.6s
# 461:	learn: 0.6278331	total: 20.2s	remaining: 23.5s
# 462:	learn: 0.6270200	total: 20.2s	remaining: 23.4s
# 463:	learn: 0.6264165	total: 20.2s	remaining: 23.3s
# 464:	learn: 0.6257880	total: 20.2s	remaining: 23.2s
# 465:	learn: 0.6253332	total: 20.2s	remaining: 23.2s
# 466:	learn: 0.6247810	total: 20.2s	remaining: 23.1s
# 467:	learn: 0.6240645	total: 20.2s	remaining: 23s
# 468:	learn: 0.6236274	total: 20.2s	remaining: 22.9s
# 469:	learn: 0.6231078	total: 20.3s	remaining: 22.8s
# 470:	learn: 0.6226989	total: 20.3s	remaining: 22.8s
# 471:	learn: 0.6222880	total: 20.3s	remaining: 22.7s
# 472:	learn: 0.6216128	total: 20.3s	remaining: 22.6s
# 473:	learn: 0.6212789	total: 20.3s	remaining: 22.5s
# 474:	learn: 0.6209243	total: 20.3s	remaining: 22.4s
# 475:	learn: 0.6204683	total: 20.3s	remaining: 22.4s
# 476:	learn: 0.6199903	total: 20.3s	remaining: 22.3s
# 477:	learn: 0.6194588	total: 20.3s	remaining: 22.2s
# 478:	learn: 0.6190435	total: 20.3s	remaining: 22.1s
# 479:	learn: 0.6185708	total: 20.4s	remaining: 22.1s
# 480:	learn: 0.6180184	total: 20.4s	remaining: 22s
# 481:	learn: 0.6176071	total: 20.4s	remaining: 21.9s
# 482:	learn: 0.6170527	total: 20.4s	remaining: 21.8s
# 483:	learn: 0.6165006	total: 20.4s	remaining: 21.7s
# 484:	learn: 0.6160817	total: 20.4s	remaining: 21.7s
# 485:	learn: 0.6156282	total: 20.4s	remaining: 21.6s
# 486:	learn: 0.6151587	total: 20.4s	remaining: 21.5s
# 487:	learn: 0.6148352	total: 20.4s	remaining: 21.4s
# 488:	learn: 0.6144115	total: 20.4s	remaining: 21.4s
# 489:	learn: 0.6140349	total: 20.5s	remaining: 21.3s
# 490:	learn: 0.6135299	total: 20.5s	remaining: 21.2s
# 491:	learn: 0.6129102	total: 20.5s	remaining: 21.1s
# 492:	learn: 0.6125871	total: 20.5s	remaining: 21.1s
# 493:	learn: 0.6119541	total: 20.5s	remaining: 21s
# 494:	learn: 0.6114836	total: 20.5s	remaining: 20.9s
# 495:	learn: 0.6109864	total: 20.5s	remaining: 20.9s
# 496:	learn: 0.6106251	total: 20.5s	remaining: 20.8s
# 497:	learn: 0.6103099	total: 20.5s	remaining: 20.7s
# 498:	learn: 0.6099295	total: 20.6s	remaining: 20.6s
# 499:	learn: 0.6092402	total: 20.6s	remaining: 20.6s
# 500:	learn: 0.6087181	total: 20.6s	remaining: 20.5s
# 501:	learn: 0.6080888	total: 20.6s	remaining: 20.4s
# 502:	learn: 0.6076296	total: 20.6s	remaining: 20.3s
# 503:	learn: 0.6070943	total: 20.6s	remaining: 20.3s
# 972:	learn: 0.4178047	total: 25.3s	remaining: 702ms
# 973:	learn: 0.4174662	total: 25.3s	remaining: 675ms
# 974:	learn: 0.4171164	total: 25.3s	remaining: 649ms
# 975:	learn: 0.4169638	total: 25.3s	remaining: 623ms
# 976:	learn: 0.4167546	total: 25.3s	remaining: 596ms
# 977:	learn: 0.4164988	total: 25.3s	remaining: 570ms
# 978:	learn: 0.4161186	total: 25.3s	remaining: 544ms
# 979:	learn: 0.4156499	total: 25.4s	remaining: 517ms
# 980:	learn: 0.4153724	total: 25.4s	remaining: 491ms
# 981:	learn: 0.4150497	total: 25.4s	remaining: 465ms
# 982:	learn: 0.4147415	total: 25.4s	remaining: 439ms
# 983:	learn: 0.4143927	total: 25.4s	remaining: 413ms
# 984:	learn: 0.4139994	total: 25.4s	remaining: 387ms
# 985:	learn: 0.4136620	total: 25.4s	remaining: 361ms
# 986:	learn: 0.4133452	total: 25.4s	remaining: 335ms
# 987:	learn: 0.4130852	total: 25.4s	remaining: 309ms
# 988:	learn: 0.4128469	total: 25.4s	remaining: 283ms
# 989:	learn: 0.4125648	total: 25.5s	remaining: 257ms
# 990:	learn: 0.4122333	total: 25.5s	remaining: 231ms
# 991:	learn: 0.4119524	total: 25.5s	remaining: 205ms
# 992:	learn: 0.4117561	total: 25.5s	remaining: 180ms
# 993:	learn: 0.4113736	total: 25.5s	remaining: 154ms
# 994:	learn: 0.4109791	total: 25.5s	remaining: 128ms
# 995:	learn: 0.4105599	total: 25.5s	remaining: 102ms
# 996:	learn: 0.4102701	total: 25.5s	remaining: 76.8ms
# 997:	learn: 0.4098912	total: 25.5s	remaining: 51.2ms
# 998:	learn: 0.4094686	total: 25.5s	remaining: 25.6ms
# 999:	learn: 0.4092895	total: 25.6s	remaining: 0us

# %%
test_pred = clf.predict(test_embeds)
test_proba = clf.predict_proba(test_embeds)

# %%
print("Accuracy:", accuracy_score(target_test, test_pred))
print("ROC-AUC:", roc_auc_score(target_test, test_proba, average="weighted", multi_class="ovr"))
# Out:
# Accuracy: 0.585
# ROC-AUC: 0.8302730752867178

# %% [markdown]
# - CPC context embeds + Catboost:
#   - `Accuracy: 0.5763333333333334`
#   - ` ROC-AUC: 0.8252403572367512`
#
# \
#
# - CPC context embeds (w/ Window Aggregation, 3 trx window) + Catboost:
#   - `Accuracy: 0.5756666666666667`
#   - ` ROC-AUC: 0.8313551234048895`
#
# \
#
# - CPC context embeds (w/ Window Aggregation, 5 trx window) + Catboost:
#   - `Accuracy: 0.595`
#   - ` ROC-AUC: 0.8372577763355443`
#
# \
#
# - CPC context embeds (w/ Window Aggregation, 10 trx window) + Catboost:
#   - `Accuracy: 0.5896666666666667`
#   - ` ROC-AUC: 0.8336245102246188`
#
# \
#
# - CPC context embeds (w/ Window Aggregation, 20 trx window) + Catboost:
#   - `Accuracy: 0.585`
#   - ` ROC-AUC: 0.8302730752867178`
#
# **Интересно - как в случае с агрегацией (любой такого типа) вырос ROC-AUC по сравнению с бейзлайном (без агрегации). Зависимость от размера окна следующая: сначала с увеличением размера окна качество растёт, затем достигается оптимальный размер окна - при нём качество максимально, после дальнейшего увеличения окна качество падает.**
#
# **Здесь оптимальный размер окна равен 5 - будем далее использовать именно такое значение при агрегации с помощью `WinAggregator` для CPC.**

# %% [markdown]
# ---

# %% [markdown]
# - **GPT:**

# %%
seed_everything(0)

# %% [markdown]
# **DataLoaders:**

# %%
data = PtlsDataModule(
    train_data=GptDataset(
        MemoryMapDataset(data=data_train),
        min_len=1000,
        max_len=1200
    ),
    train_num_workers=4,
    train_batch_size=16,
    valid_data=GptDataset(
        MemoryMapDataset(data=data_test),
        min_len=1000,
        max_len=1200
    ),
    valid_num_workers=4,
    valid_batch_size=16
)

# %% [markdown]
# **Модель:**

# %%
from torchmetrics import MeanMetric
from typing import Tuple, Dict, List, Union
from torch import nn
import torch.nn.functional as F 
from ptls.nn.seq_encoder.abs_seq_encoder import AbsSeqEncoder
from ptls.nn import PBL2Norm
from ptls.data_load.padded_batch import PaddedBatch


class MeanPooling(torch.nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, pb: PaddedBatch):
        payload = pb.payload # (B, T, H)
        mask = pb.seq_len_mask.bool()
        pb_mean = payload.sum(dim=1) / mask.float().sum(dim=1, keepdim=True)
        return pb_mean


class StatPooling(torch.nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, pb: PaddedBatch):
        payload = pb.payload # (B, T, H)
        mask = pb.seq_len_mask.bool()
        inf_mask = torch.zeros_like(mask, device=mask.device).float()
        inf_mask[~mask] = -torch.inf
        
        pb_mean = payload.sum(dim=1) / mask.float().sum(dim=1, keepdim=True)
        pb_max = torch.max(payload + inf_mask.unsqueeze(-1), dim=1)[0]
        pb_stat = torch.cat((pb_mean, pb_max), dim=1)
        return pb_stat


class GPTHead(torch.nn.Module):   
    def __init__(self, input_size, n_classes, hidden_size=64, drop_p=0.1):
        super().__init__()
        self.head = nn.Sequential(
            nn.Linear(input_size, hidden_size, bias=True),
            nn.GELU(),
            nn.Dropout(drop_p),
            nn.Linear(hidden_size, n_classes)
        )
    def forward(self, x):
        x = self.head(x)
        return x


class GptPretrainModule(pl.LightningModule):
    """GPT2 Language model

    Sequence transactions are encoded by `trx_encoder`.
    Then `seq_encoder` encodes the given sequence 
    (we actually use NN to modify sequence transactions representations,
    then (during inference) we calculate the mean of these encoded transactions to get the representation of the whole sequence).
    After this we use heads to predict the classes of features of the future transaction.

    Parameters
    ----------
    trx_encoder:
        Module for transform dict with feature sequences to sequence of transaction representations
    seq_encoder:
        Module for sequence processing. Generally this is transformer based encoder. Rnn is also possible
        Should work without sequence reduction
    head_hidden_size:
        Hidden size of heads for feature prediction
    seed_seq_len:
         Size of starting sequence without loss 
    total_steps:
        total_steps expected in OneCycle lr scheduler
    max_lr:
        max_lr of OneCycle lr scheduler
    weight_decay:
        weight_decay of Adam optimizer
    pct_start:
        % of total_steps when lr increase
    norm_predict:
        use l2 norm for transformer output or not
    """

    def __init__(self,
                 trx_encoder: torch.nn.Module,
                 seq_encoder: AbsSeqEncoder,
                 head_hidden_size: int = 64,
                 total_steps: int = 64000,
                 seed_seq_len: int = 16,
                 max_lr: float = 0.00005,
                 weight_decay: float = 0.0,
                 pct_start: float = 0.1,
                 norm_predict: bool = False
                 ):

        super().__init__()
        self.save_hyperparameters(ignore=['trx_encoder', 'seq_encoder'])

        self.trx_encoder = trx_encoder
        self._seq_encoder = seq_encoder
        self._seq_encoder.is_reduce_sequence = False

        self.head = nn.ModuleDict()
        for col_name, noisy_emb in self.trx_encoder.embeddings.items():
            self.head[col_name] = GPTHead(input_size=self._seq_encoder.embedding_size, hidden_size=head_hidden_size, n_classes=noisy_emb.num_embeddings)

        if self.hparams.norm_predict:
            self.fn_norm_predict = PBL2Norm()

        self.loss = nn.CrossEntropyLoss(ignore_index=0)

        self.train_gpt_loss = MeanMetric()
        self.valid_gpt_loss = MeanMetric()

    def forward(self, batch: PaddedBatch):
        z_trx = self.trx_encoder(batch) 
        out = self._seq_encoder(z_trx)
        if self.hparams.norm_predict:
            out = self.fn_norm_predict(out)
        return out

    def loss_gpt(self, logits, labels):
        loss = 0
        for col_name, head in self.head.items():
            y_pred = head(logits[:, self.hparams.seed_seq_len:-1, :])
            y_pred = y_pred.view(-1, y_pred.size(-1))

            y_true = labels[col_name][:, self.hparams.seed_seq_len+1:]
            y_true = torch.flatten(y_true.long())

            loss += self.loss(y_pred, y_true)
            
        return loss

    def training_step(self, batch, batch_idx):
        out = self.forward(batch)  # PB: B, T, H
        out = out.payload if isinstance(out, PaddedBatch) else out
        labels = batch.payload

        loss_gpt = self.loss_gpt(out, labels)
        self.train_gpt_loss(loss_gpt)
        self.log('loss', loss_gpt, sync_dist=True)
        return loss_gpt

    def validation_step(self, batch, batch_idx):
        out = self.forward(batch)  # PB: B, T, H
        out = out.payload if isinstance(out, PaddedBatch) else out
        labels = batch.payload

        loss_gpt = self.loss_gpt(out, labels)
        self.valid_gpt_loss(loss_gpt)

    def on_training_epoch_end(self):
        self.log('train loss (by epochs)', self.train_gpt_loss, prog_bar=True, logger=True, sync_dist=True, rank_zero_only=True)

    def on_validation_epoch_end(self):
        self.log('val loss (by epochs)', self.valid_gpt_loss, prog_bar=True, logger=True, sync_dist=True, rank_zero_only=True)

    def configure_optimizers(self):
        optim = torch.optim.NAdam(self.parameters(),
                                  lr=self.hparams.max_lr,
                                  weight_decay=self.hparams.weight_decay
                                 )
        
        scheduler = torch.optim.lr_scheduler.OneCycleLR(
            optimizer=optim,
            max_lr=self.hparams.max_lr,
            total_steps=self.hparams.total_steps,
            pct_start=self.hparams.pct_start,
            anneal_strategy='cos',
            cycle_momentum=False,
            div_factor=25.0,
            final_div_factor=10000.0,
            three_phase=False
        )
        
        scheduler = {'scheduler': scheduler, 'interval': 'step'}
        return [optim], [scheduler]
    
    @property
    def seq_encoder(self):
        return GPTInferenceModule(pretrained_model=self)


class GPTInferenceModule(torch.nn.Module):
    def __init__(self, pretrained_model):
        super().__init__()
        self.model = pretrained_model
        self.model.is_reduce_sequence = False
        self.mean_pooling = MeanPooling()
        self.stat_pooling = StatPooling()

    def forward(self, batch, eval_strategy="mean"):
        z_trx = self.model.trx_encoder(batch)
        out = self.model._seq_encoder(z_trx)
        out = out if isinstance(out, PaddedBatch) else PaddedBatch(out, batch.seq_lens)

        if eval_strategy == "mean":
            out = self.mean_pooling(out)
        elif eval_strategy == "stat":
            out = self.stat_pooling(out)

        if self.model.hparams.norm_predict:
            out = out / (out.pow(2).sum(dim=-1, keepdim=True) + 1e-9).pow(0.5)
        return out

# %%
class WinAggGPTPretrainModule_MultiPred(GptPretrainModule):
    def __init__(self,
                 trx_encoder: torch.nn.Module,
                 seq_encoder: AbsSeqEncoder,
                 head_hidden_size: int = 64,
                 total_steps: int = 64000,
                 seed_seq_len: int = 16,
                 max_lr: float = 0.00005,
                 weight_decay: float = 0.0,
                 pct_start: float = 0.1,
                 norm_predict: bool = False
                 ):
        super().__init__(
            trx_encoder=trx_encoder,
            seq_encoder=seq_encoder,
            head_hidden_size=head_hidden_size,
            total_steps=total_steps,
            seed_seq_len=seed_seq_len,
            max_lr=max_lr,
            weight_decay=weight_decay,
            pct_start=pct_start,
            norm_predict=norm_predict
        )
        self.agg_samples = trx_encoder.agg_samples

    def loss_gpt(self, logits, labels):
        loss = 0
        
        for col_name, head in self.head.items():
            n_obj = 0
            out = head(logits[:, self.hparams.seed_seq_len:-1, :])
            
            for shift in range(self.agg_samples):
                y_true = labels[col_name][:, ((self.hparams.seed_seq_len + 1) * self.agg_samples + shift)::self.agg_samples]
                y_true = torch.flatten(y_true.long())
                
                if y_true.shape[0] < out.shape[0] * out.shape[1]:
                    pred = out[:, :-1, :]
                    pred = pred.reshape(-1, pred.size(-1))
                else:
                    pred = out.reshape(-1, out.size(-1))
                n_obj += pred.shape[0] 
                    
                loss += self.loss(pred, y_true) * pred.shape[0]
                
        return loss / n_obj


class WinAggGPTPretrainModule(GptPretrainModule):
    def __init__(self,
                 trx_encoder: torch.nn.Module,
                 seq_encoder: AbsSeqEncoder,
                 head_hidden_size: int = 64,
                 total_steps: int = 64000,
                 seed_seq_len: int = 16,
                 max_lr: float = 0.00005,
                 weight_decay: float = 0.0,
                 pct_start: float = 0.1,
                 norm_predict: bool = False
                 ):
        super().__init__(
            trx_encoder=trx_encoder,
            seq_encoder=seq_encoder,
            head_hidden_size=head_hidden_size,
            total_steps=total_steps,
            seed_seq_len=seed_seq_len,
            max_lr=max_lr,
            weight_decay=weight_decay,
            pct_start=pct_start,
            norm_predict=norm_predict
        )
        self.agg_samples = trx_encoder.agg_samples

    def loss_gpt(self, logits, labels):
        loss = 0
        
        for col_name, head in self.head.items():
            out = head(logits[:, self.hparams.seed_seq_len:-1, :])
            
            y_true = labels[col_name][:, ((self.hparams.seed_seq_len + 1) * self.agg_samples)::self.agg_samples]
            y_true = torch.flatten(y_true.long())
            
            if y_true.shape[0] < out.shape[0] * out.shape[1]:
                pred = out[:, :-1, :]
                pred = pred.reshape(-1, pred.size(-1))
            else:
                pred = out.reshape(-1, out.size(-1))
                    
            loss += self.loss(pred, y_true)
                
        return loss


class WinAggGPTPretrainModule_MultiLabel(GptPretrainModule):
    def __init__(self,
                 trx_encoder: torch.nn.Module,
                 seq_encoder: AbsSeqEncoder,
                 head_hidden_size: int = 64,
                 total_steps: int = 64000,
                 seed_seq_len: int = 16,
                 max_lr: float = 0.00005,
                 weight_decay: float = 0.0,
                 pct_start: float = 0.1,
                 norm_predict: bool = False
                 ):
        super().__init__(
            trx_encoder=trx_encoder,
            seq_encoder=seq_encoder,
            head_hidden_size=head_hidden_size,
            total_steps=total_steps,
            seed_seq_len=seed_seq_len,
            max_lr=max_lr,
            weight_decay=weight_decay,
            pct_start=pct_start,
            norm_predict=norm_predict
        )
        self.agg_samples = trx_encoder.agg_samples
        self.loss = nn.MultiLabelSoftMarginLoss()

    def loss_gpt(self, logits, labels):
        loss = 0
        
        for col_name, head in self.head.items():
            pred = head(logits[:, self.hparams.seed_seq_len:-1, :])

            ohe_labels = torch.zeros((pred.shape[0] * pred.shape[1], pred.shape[2]), device=pred.device)
            
            for shift in range(self.agg_samples):
                y_true = labels[col_name][:, ((self.hparams.seed_seq_len + 1) * self.agg_samples + shift)::self.agg_samples]
                y_true = torch.flatten(y_true.long())
                ohe_labels_part = F.one_hot(y_true, num_classes=pred.shape[2])
                
                if ohe_labels_part.shape[0] < pred.shape[0] * pred.shape[1]:
                    padding = torch.zeros((pred.shape[0], 1, pred.shape[2]), device=ohe_labels_part.device)
                    ohe_labels_part = torch.cat((ohe_labels_part.reshape(pred.shape[0], pred.shape[1] - 1, pred.shape[2]), padding), dim=1).reshape(pred.shape[0] * pred.shape[1], pred.shape[2])
                
                ohe_labels += ohe_labels_part

            ohe_labels[ohe_labels > 1] = 1
            
            pred = pred.reshape(-1, pred.size(-1))

            loss += self.loss(pred, ohe_labels)
                
        return loss

# %%
N_EPOCHS = 15

# %%
agg_encoder_params = dict(
    embeddings_noise=0.003,
    embeddings={
        "trans_date": {"in": 730, "out": 64},
        "small_group": {"in": 204, "out": 64},
        "amount_rur": {"in": BINS_NUM, "out": 64}
    },
    agg_samples=10,
    use_pre_agg_attention=False,
    use_window_attention=False
)

trx_encoder = WinAggregator(**agg_encoder_params)

seq_encoder = GptEncoder(
    n_embd=trx_encoder.output_size,
    n_layer=6,
    n_head=6,
    n_inner=256,
    activation_function="gelu_new",
    resid_pdrop=0.1,
    embd_pdrop=0.1,
    attn_pdrop=0.1,
    n_positions=2048,
    use_positional_encoding=True,
    use_start_random_shift=True,
    is_reduce_sequence=False
)

gpt = WinAggGPTPretrainModule_MultiLabel(
    trx_encoder=trx_encoder,
    seq_encoder=seq_encoder,
    head_hidden_size=256,
    total_steps=(N_EPOCHS * 1688), # num_epochs * num_steps_per_epoch
    seed_seq_len=16,
    max_lr=1e-3,
    weight_decay=0.,
    pct_start=0.1,
    norm_predict=False
)

# %% [markdown]
# **Обучение:**

# %%
logger = CometLogger(project_name="EvS_SSL", experiment_name="GPT_modeling_WinAgg")

trainer = pl.Trainer(
    logger=logger,
    max_epochs=N_EPOCHS,
    accelerator="gpu",
    devices=1,
    enable_progress_bar=True
)

# %%
trainer.fit(gpt, data)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/askoro/evs-ssl/0bdd3613cfc44f44b41f124fa7499d10
#
# COMET INFO: Couldn't find a Git repository in '/kaggle/working' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : GPT_modeling_WinAgg
# COMET INFO:     url                   : https://www.comet.com/askoro/evs-ssl/0bdd3613cfc44f44b41f124fa7499d10
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [3038]               : (0.20921623706817627, 2.0972025394439697)
# COMET INFO:     val loss (by epochs) [15] : (0.24627543985843658, 0.2891102731227875)
# COMET INFO:   Others:
# COMET INFO:     Name : GPT_modeling_WinAgg
# COMET INFO:   Parameters:
# COMET INFO:     head_hidden_size  : 256
# COMET INFO:     max_lr            : 0.001
# COMET INFO:     norm_predict      : False
# COMET INFO:     pct_start         : 0.1
# COMET INFO:     seed_seq_len      : 16
# COMET INFO:     test_batch_size   : None
# COMET INFO:     test_drop_last    : False
# COMET INFO:     test_num_workers  : None
# COMET INFO:     total_steps       : 25320
# COMET INFO:     train_batch_size  : 16
# COMET INFO:     train_drop_last   : False
# COMET INFO:     train_num_workers : 4
# COMET INFO:     valid_batch_size  : 16
# COMET INFO:     valid_drop_last   : False
# COMET INFO:     valid_num_workers : 4
# COMET INFO:     weight_decay      : 0.0
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:

# %%
trainer.logged_metrics
# Out:
# {'loss': tensor(0.2285), 'val loss (by epochs)': tensor(0.2464)}

# %%
encoder = gpt.seq_encoder

# %%
torch.save(encoder.state_dict(), "gpt_WinAgg_trx10_multilabel.pt")

# %% [markdown]
# **Измерим качество на тесте (catboost поверх эмбеддингов):**

# %%
# import gdown

# gdown.download("https://drive.google.com/uc?export=download&id=1YBstN7hpEIREo7zORmPoEZ_0NyBgfjm6", "gpt_baseline_NAdam.pt")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1YBstN7hpEIREo7zORmPoEZ_0NyBgfjm6
# From (redirected): https://drive.google.com/uc?export=download&id=1YBstN7hpEIREo7zORmPoEZ_0NyBgfjm6&confirm=t&uuid=be4debcd-1d0b-4619-a15e-892431777c63
# To: /kaggle/working/gpt_baseline_NAdam.pt
# 100%|██████████| 34.7M/34.7M [00:00<00:00, 156MB/s]
# 'gpt_baseline_NAdam.pt'

# %%
# state_dict = torch.load("./gpt_baseline_NAdam.pt")
# encoder.load_state_dict(state_dict)

device = "cuda:0"

encoder.to(device)
# Out:
# GPTInferenceModule(
#   (model): WinAggGPTPretrainModule_MultiLabel(
#     (trx_encoder): WinAggregator(
#       (embeddings): ModuleDict(
#         (trans_date): NoisyEmbedding(
#           730, 64, padding_idx=0
#           (dropout): Dropout(p=0, inplace=False)
#         )
#         (small_group): NoisyEmbedding(
#           204, 64, padding_idx=0
#           (dropout): Dropout(p=0, inplace=False)
#         )
#         (amount_rur): NoisyEmbedding(
#           128, 64, padding_idx=0
#           (dropout): Dropout(p=0, inplace=False)
#         )
#       )
#       (custom_embeddings): ModuleDict()
#     )
#     (_seq_encoder): GptEncoder(
#       (transf): GPT2Model(
#         (wte): Embedding(4, 192)
#         (wpe): Embedding(2048, 192)
#         (drop): Dropout(p=0.1, inplace=False)
#         (h): ModuleList(
#           (0-5): 6 x GPT2Block(
#             (ln_1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#             (attn): GPT2SdpaAttention(
#               (c_attn): Conv1D(nf=576, nx=192)
#               (c_proj): Conv1D(nf=192, nx=192)
#               (attn_dropout): Dropout(p=0.1, inplace=False)
#               (resid_dropout): Dropout(p=0.1, inplace=False)
#             )
#             (ln_2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#             (mlp): GPT2MLP(
#               (c_fc): Conv1D(nf=256, nx=192)
#               (c_proj): Conv1D(nf=192, nx=256)
#               (act): NewGELUActivation()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (ln_f): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (head): ModuleDict(
#       (trans_date): GPTHead(
#         (head): Sequential(
#           (0): Linear(in_features=192, out_features=256, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.1, inplace=False)
#           (3): Linear(in_features=256, out_features=730, bias=True)
#         )
#       )
#       (small_group): GPTHead(
#         (head): Sequential(
#           (0): Linear(in_features=192, out_features=256, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.1, inplace=False)
#           (3): Linear(in_features=256, out_features=204, bias=True)
#         )
#       )
#       (amount_rur): GPTHead(
#         (head): Sequential(
#           (0): Linear(in_features=192, out_features=256, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.1, inplace=False)
#           (3): Linear(in_features=256, out_features=128, bias=True)
#         )
#       )
#     )
#     (loss): MultiLabelSoftMarginLoss()
#     (train_gpt_loss): MeanMetric()
#     (valid_gpt_loss): MeanMetric()
#   )
#   (mean_pooling): MeanPooling()
#   (stat_pooling): StatPooling()
# )

# %%
from tqdm import tqdm

seed_everything(0)

# %%
train_loader = inference_data_loader(data_train, num_workers=0, batch_size=8)
encoder.eval()
train_embeds = None

for i, batch in tqdm(enumerate(train_loader)):
    train_embeds_batch = encoder(batch.to(device), eval_strategy="mean")
    if i == 0:
        train_embeds = train_embeds_batch.detach().cpu().numpy()
    else:
        train_embeds = np.concatenate([train_embeds, train_embeds_batch.detach().cpu().numpy()], axis=0)
    
train_embeds
# Out:
# 3375it [00:31, 108.76it/s]
# array([[ 0.31536353, -0.0842438 ,  0.3832604 , ..., -0.10778586,
#         -0.6980415 , -0.36430973],
#        [ 0.0241911 ,  0.08230145,  0.21791126, ...,  0.8697108 ,
#         -0.30115065,  0.13838275],
#        [ 0.49131852,  0.17025314,  0.153876  , ..., -0.07249554,
#         -0.30611566,  0.12305231],
#        ...,
#        [ 1.0160196 ,  0.0417424 ,  0.00713044, ...,  0.20092922,
#          0.03901017, -0.22009598],
#        [ 0.21870992,  0.1300195 , -0.01389283, ..., -0.15358263,
#          0.0228075 , -0.03736628],
#        [ 1.5081874 ,  0.13934559,  0.21306148, ...,  0.1152389 ,
#         -0.09603833,  0.45319265]], dtype=float32)

# %%
test_loader = inference_data_loader(data_test, num_workers=0, batch_size=1)
encoder.eval()
test_embeds = None

for i, batch in tqdm(enumerate(test_loader)):
    test_embeds_batch = encoder(batch.to(device), eval_strategy="mean")
    if i == 0:
        test_embeds = test_embeds_batch.detach().cpu().numpy()
    else:
        test_embeds = np.concatenate([test_embeds, test_embeds_batch.detach().cpu().numpy()], axis=0)
    
test_embeds
# Out:
# 3000it [00:18, 158.40it/s]
# array([[ 0.51009405,  0.28176787,  0.05083818, ..., -0.12658988,
#          0.52998537, -0.48353752],
#        [-0.8570451 , -0.42433134,  0.19792302, ..., -0.12885305,
#         -0.3920125 , -0.25294182],
#        [-1.064824  , -0.11614103,  0.40162733, ..., -0.25125697,
#         -0.7998918 ,  0.03878516],
#        ...,
#        [-0.4554164 ,  0.0975307 ,  0.13601476, ..., -0.15060812,
#         -0.44560304, -0.14436284],
#        [-0.237132  ,  0.34084025,  0.02564172, ..., -0.00975494,
#          0.02818822, -0.20714563],
#        [-0.50885195,  0.16395755,  0.56415004, ..., -0.20615551,
#          0.3055933 ,  0.30488333]], dtype=float32)

# %%
clf = CatBoostClassifier(loss_function='MultiClass', task_type="GPU", devices='0')

clf.fit(train_embeds, target_train, plot_file="catboost_log.html")
# Out:
#
# 652:	learn: 0.5380236	total: 16.2s	remaining: 8.59s
# 653:	learn: 0.5375380	total: 16.2s	remaining: 8.56s
# 654:	learn: 0.5373218	total: 16.2s	remaining: 8.52s
# 655:	learn: 0.5371125	total: 16.2s	remaining: 8.49s
# 656:	learn: 0.5366211	total: 16.2s	remaining: 8.46s
# 657:	learn: 0.5362997	total: 16.2s	remaining: 8.42s
# 658:	learn: 0.5358261	total: 16.2s	remaining: 8.39s
# 659:	learn: 0.5354723	total: 16.2s	remaining: 8.36s
# 660:	learn: 0.5350568	total: 16.2s	remaining: 8.32s
# 661:	learn: 0.5348029	total: 16.2s	remaining: 8.29s
# 662:	learn: 0.5343642	total: 16.2s	remaining: 8.25s
# 663:	learn: 0.5340617	total: 16.2s	remaining: 8.22s
# 664:	learn: 0.5336283	total: 16.3s	remaining: 8.19s
# 665:	learn: 0.5331976	total: 16.3s	remaining: 8.15s
# 666:	learn: 0.5326150	total: 16.3s	remaining: 8.12s
# 667:	learn: 0.5323751	total: 16.3s	remaining: 8.09s
# 668:	learn: 0.5321362	total: 16.3s	remaining: 8.05s
# 669:	learn: 0.5319252	total: 16.3s	remaining: 8.02s
# 670:	learn: 0.5315305	total: 16.3s	remaining: 7.99s
# 671:	learn: 0.5311467	total: 16.3s	remaining: 7.96s
# 672:	learn: 0.5307623	total: 16.3s	remaining: 7.92s
# 673:	learn: 0.5305168	total: 16.3s	remaining: 7.89s
# 674:	learn: 0.5300847	total: 16.3s	remaining: 7.86s
# 675:	learn: 0.5298783	total: 16.3s	remaining: 7.83s
# 676:	learn: 0.5294481	total: 16.3s	remaining: 7.79s
# 677:	learn: 0.5290830	total: 16.3s	remaining: 7.76s
# 678:	learn: 0.5287822	total: 16.3s	remaining: 7.73s
# 679:	learn: 0.5284816	total: 16.4s	remaining: 7.7s
# 680:	learn: 0.5280571	total: 16.4s	remaining: 7.66s
# 681:	learn: 0.5277343	total: 16.4s	remaining: 7.63s
# 682:	learn: 0.5273419	total: 16.4s	remaining: 7.6s
# 683:	learn: 0.5268417	total: 16.4s	remaining: 7.57s
# 684:	learn: 0.5265087	total: 16.4s	remaining: 7.53s
# 685:	learn: 0.5261775	total: 16.4s	remaining: 7.5s
# 686:	learn: 0.5257704	total: 16.4s	remaining: 7.47s
# 687:	learn: 0.5254796	total: 16.4s	remaining: 7.44s
# 688:	learn: 0.5252413	total: 16.4s	remaining: 7.41s
# 689:	learn: 0.5248579	total: 16.4s	remaining: 7.38s
# 690:	learn: 0.5245564	total: 16.4s	remaining: 7.34s
# 691:	learn: 0.5241474	total: 16.4s	remaining: 7.31s
# 692:	learn: 0.5238197	total: 16.4s	remaining: 7.28s
# 693:	learn: 0.5233757	total: 16.4s	remaining: 7.25s
# 694:	learn: 0.5229918	total: 16.4s	remaining: 7.22s
# 695:	learn: 0.5225872	total: 16.5s	remaining: 7.19s
# 696:	learn: 0.5223386	total: 16.5s	remaining: 7.16s
# 697:	learn: 0.5220662	total: 16.5s	remaining: 7.13s
# 979:	learn: 0.4308486	total: 18.4s	remaining: 375ms
# 980:	learn: 0.4305379	total: 18.4s	remaining: 356ms
# 981:	learn: 0.4302913	total: 18.4s	remaining: 337ms
# 982:	learn: 0.4300320	total: 18.4s	remaining: 318ms
# 983:	learn: 0.4296612	total: 18.4s	remaining: 299ms
# 984:	learn: 0.4294382	total: 18.4s	remaining: 280ms
# 985:	learn: 0.4289857	total: 18.4s	remaining: 261ms
# 986:	learn: 0.4286787	total: 18.4s	remaining: 242ms
# 987:	learn: 0.4282366	total: 18.4s	remaining: 224ms
# 988:	learn: 0.4278378	total: 18.4s	remaining: 205ms
# 989:	learn: 0.4275948	total: 18.4s	remaining: 186ms
# 990:	learn: 0.4273355	total: 18.4s	remaining: 167ms
# 991:	learn: 0.4270829	total: 18.4s	remaining: 149ms
# 992:	learn: 0.4268821	total: 18.4s	remaining: 130ms
# 993:	learn: 0.4265016	total: 18.4s	remaining: 111ms
# 994:	learn: 0.4261955	total: 18.4s	remaining: 92.7ms
# 995:	learn: 0.4259120	total: 18.5s	remaining: 74.1ms
# 996:	learn: 0.4256433	total: 18.5s	remaining: 55.5ms
# 997:	learn: 0.4253332	total: 18.5s	remaining: 37ms
# 998:	learn: 0.4249016	total: 18.5s	remaining: 18.5ms
# 999:	learn: 0.4245533	total: 18.5s	remaining: 0us

# %%
test_pred = clf.predict(test_embeds)
test_proba = clf.predict_proba(test_embeds)

# %%
print("Accuracy:", accuracy_score(target_test, test_pred))
print("ROC-AUC:", roc_auc_score(target_test, test_proba, average="weighted", multi_class="ovr"))
# Out:
# Accuracy: 0.5813333333333334
# ROC-AUC: 0.8354173752048473

# %% [markdown]
# - GPT embeds + Catboost:
#   - `Accuracy: 0.6246666666666667`
#   - `ROC-AUC: 0.8523603311141598`
#
# \
#
# - GPT embeds (w/ Window Aggregation (3 trx) & next several (3) trx prediction) + Catboost:
#   - `Accuracy: 0.5906666666666667`
#   - `ROC-AUC: 0.8418245528735205`
#
# \
#
# - GPT embeds (w/ Window Aggregation (5 trx) & next several (5) trx prediction) + Catboost:
#   - `Accuracy: 0.5943333333333334`
#   - `ROC-AUC: 0.8412700721706741`
#
# \
#
# - GPT embeds (w/ Window Aggregation (3 trx) & next (1) trx prediction) + Catboost:
#   - `Accuracy: 0.5816666666666667`
#   - `ROC-AUC: 0.8384765947236289`
#
# \
#
# - GPT embeds (w/ Window Aggregation (5 trx) & next (1) trx prediction) + Catboost:
#   - `Accuracy: 0.5816666666666667`
#   - `ROC-AUC: 0.8342331978726336`
#
# \
#
# - GPT embeds (w/ Window Aggregation (3 trx), multilabel training) + Catboost:
#   - `Accuracy: 0.58`
#   - `ROC-AUC: 0.8376578210301627`
#
# \
#
# - GPT embeds (w/ Window Aggregation (5 trx), multilabel training) + Catboost:
#   - `Accuracy: 0.592`
#   - `ROC-AUC: 0.8409446751939194`

# %% [markdown]
# # Итоги.

# %% [markdown]
# | Method                  |    Accuracy   | ROC-AUC       |
# |-------------------------|---------------|---------------|
# | **Flattened Sequences** | 0.508         | 0.7635        |
# | **GRU (+ MLP)**         | 0.605         | 0.8459        |
# | **GRU (+ Catboost)**    | 0.586         | 0.8331        |
# | **CoLES**               | 0.606         | 0.8485        |
# | **CPC Modeling**        | 0.576         | 0.8252        |
# | **GPT2**                | 0.625         | 0.8524        |
