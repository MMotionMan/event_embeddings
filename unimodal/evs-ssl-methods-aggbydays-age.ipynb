# %% [markdown]
# # Импортируем необходимые библиотеки

# %%
# !pip install pytorch-lifestream
# !pip install comet_ml
# !pip install torch_scatter
# Out:
# Collecting pytorch-lifestream
#   Downloading pytorch-lifestream-0.6.0.tar.gz (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.4/163.4 kB 5.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: duckdb in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (1.1.3)
# Collecting hydra-core>=1.1.2 (from pytorch-lifestream)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: numpy>=1.21.5 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (1.26.4)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (2.3.0)
# Requirement already satisfied: pandas>=1.3.5 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (2.2.3)
# Requirement already satisfied: pyarrow>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (19.0.1)
# Requirement already satisfied: pytorch-lightning>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (2.5.0.post0)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (1.2.2)
# Requirement already satisfied: torch>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (2.5.1+cu121)
# Requirement already satisfied: torchmetrics>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (1.6.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (4.47.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from hydra-core>=1.1.2->pytorch-lifestream) (4.9.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from hydra-core>=1.1.2->pytorch-lifestream) (24.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.5->pytorch-lifestream) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.5->pytorch-lifestream) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.5->pytorch-lifestream) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.5->pytorch-lifestream) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.5->pytorch-lifestream) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.5->pytorch-lifestream) (2.4.1)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.10/dist-packages (from omegaconf->pytorch-lifestream) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->pytorch-lifestream) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->pytorch-lifestream) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->pytorch-lifestream) (2025.1)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.6.0->pytorch-lifestream) (4.67.1)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (2024.12.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.6.0->pytorch-lifestream) (4.12.2)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.6.0->pytorch-lifestream) (0.12.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->pytorch-lifestream) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->pytorch-lifestream) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->pytorch-lifestream) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch-lifestream) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch-lifestream) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch-lifestream) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch-lifestream) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.12.0->pytorch-lifestream) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers->pytorch-lifestream) (0.29.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->pytorch-lifestream) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->pytorch-lifestream) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers->pytorch-lifestream) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->pytorch-lifestream) (0.4.5)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (3.11.12)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.10.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (75.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.5->pytorch-lifestream) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.12.0->pytorch-lifestream) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.21.5->pytorch-lifestream) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.21.5->pytorch-lifestream) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.5->pytorch-lifestream) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.21.5->pytorch-lifestream) (2024.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->pytorch-lifestream) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->pytorch-lifestream) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->pytorch-lifestream) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->pytorch-lifestream) (2025.1.31)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (1.18.3)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.21.5->pytorch-lifestream) (2024.2.0)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 10.8 MB/s eta 0:00:00
# Building wheels for collected packages: pytorch-lifestream
#   Building wheel for pytorch-lifestream (pyproject.toml) ... done
#   Created wheel for pytorch-lifestream: filename=pytorch_lifestream-0.6.0-py3-none-any.whl size=274670 sha256=b87dc4fcb8d28a8c95585dbba1155a96d722797a4f1c6fbe0e1e88449455b3bd
#   Stored in directory: /root/.cache/pip/wheels/90/76/b4/0a944bc7c5a69201e4d757cc54886971117a2a581740e7f11d
# Successfully built pytorch-lifestream
# Installing collected packages: hydra-core, pytorch-lifestream
# Successfully installed hydra-core-1.3.2 pytorch-lifestream-0.6.0
# Collecting comet_ml
#   Downloading comet_ml-3.49.8-py3-none-any.whl.metadata (4.1 kB)
# Collecting dulwich!=0.20.33,>=0.20.6 (from comet_ml)
#   Downloading dulwich-0.22.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting everett<3.2.0,>=1.0.1 (from everett[ini]<3.2.0,>=1.0.1->comet_ml)
#   Downloading everett-3.1.0-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (4.23.0)
# Requirement already satisfied: psutil>=5.6.3 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (5.9.5)
# Collecting python-box<7.0.0 (from comet_ml)
#   Downloading python_box-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.8 kB)
# Requirement already satisfied: requests-toolbelt>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (1.0.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (2.32.3)
# Requirement already satisfied: rich>=13.3.2 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (13.9.4)
# Collecting semantic-version>=2.8.0 (from comet_ml)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: sentry-sdk>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (2.19.2)
# Collecting simplejson (from comet_ml)
#   Downloading simplejson-3.20.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (2.3.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (1.17.0)
# Requirement already satisfied: wurlitzer>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (3.1.1)
# Collecting configobj (from everett[ini]<3.2.0,>=1.0.1->comet_ml)
#   Downloading configobj-5.0.9-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (0.22.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet_ml) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet_ml) (2.19.1)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet_ml) (4.12.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=13.3.2->comet_ml) (0.1.2)
# Downloading comet_ml-3.49.8-py3-none-any.whl (726 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 726.7/726.7 kB 17.6 MB/s eta 0:00:0000:01
# Downloading dulwich-0.22.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 45.6 MB/s eta 0:00:00
# Downloading everett-3.1.0-py2.py3-none-any.whl (35 kB)
# Downloading python_box-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 84.8 MB/s eta 0:00:00:00:01
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading simplejson-3.20.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 7.9 MB/s eta 0:00:00
# Downloading configobj-5.0.9-py2.py3-none-any.whl (35 kB)
# Installing collected packages: everett, simplejson, semantic-version, python-box, dulwich, configobj, comet_ml
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.3.0
#     Uninstalling python-box-7.3.0:
#       Successfully uninstalled python-box-7.3.0
# Successfully installed comet_ml-3.49.8 configobj-5.0.9 dulwich-0.22.8 everett-3.1.0 python-box-6.1.0 semantic-version-2.10.0 simplejson-3.20.1
# Collecting torch_scatter
#   Downloading torch_scatter-2.1.2.tar.gz (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: torch_scatter
#   Building wheel for torch_scatter (setup.py) ... done
#   Created wheel for torch_scatter: filename=torch_scatter-2.1.2-cp310-cp310-linux_x86_64.whl size=3879857 sha256=ab428745ecc5f4d3f87df201f2c180515b6a4095d78bccc7b7b86a64d001c088
#   Stored in directory: /root/.cache/pip/wheels/92/f1/2b/3b46d54b134259f58c8363568569053248040859b1a145b3ce
# Successfully built torch_scatter
# Installing collected packages: torch_scatter
# Successfully installed torch_scatter-2.1.2

# %%
# data preprocessing
import os
import numpy as np
import pandas as pd
import pickle

# misc
from tqdm import tqdm
from functools import partial

# logging
import comet_ml

# classical ML
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score
from catboost import CatBoostClassifier

# basic deep learning libs
import torch
from torch.utils.data import DataLoader
import pytorch_lightning as pl
import torchmetrics

# ptls
from ptls.nn import TrxEncoder, RnnSeqEncoder, TransformerEncoder, GptEncoder, Head
from ptls.frames import PtlsDataModule
from ptls.frames.coles import CoLESModule
from ptls.frames.coles import ColesDataset
from ptls.frames.coles.split_strategy import SampleSlices
from ptls.frames.cpc import CpcModule
from ptls.frames.cpc import CpcDataset
from ptls.frames.gpt import GptDataset
from ptls.frames.supervised import SeqToTargetDataset, SequenceToTarget
from ptls.data_load.datasets import MemoryMapDataset
from ptls.data_load.datasets import inference_data_loader
from ptls.frames.inference_module import InferenceModule
from ptls.data_load.iterable_processing import SeqLenFilter, ToTorch, FilterNonArray, ISeqLenLimit
from ptls.data_load import IterableChain, padded_collate_wo_target
from ptls.data_load.filter_dataset import FilterDataset
from ptls.preprocessing import PandasDataPreprocessor
from ptls.data_load.utils import collate_feature_dict
from ptls.frames.inference_module import InferenceModule

# torch_scatter
import torch_scatter

# %%
def seed_everything(seed):
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
comet_ml.login()

# %%
from pytorch_lightning.loggers import CometLogger

# %% [markdown]
# # Эксперименты.

# %% [markdown]
# **Данные:**

# %%
path_data = "https://huggingface.co/datasets/dllllb/age-group-prediction/resolve/main/transactions_train.csv.gz?download=true"
data = pd.read_csv(path_data, compression="gzip")
data
# Out:
#           client_id  trans_date  small_group  amount_rur
# 0             33172           6            4      71.463
# 1             33172           6           35      45.017
# 2             33172           8           11      13.887
# 3             33172           9           11      15.983
# 4             33172          10           11      21.341
# ...             ...         ...          ...         ...
# 26450572      43300         727           25       7.602
# 26450573      43300         727           15       3.709
# 26450574      43300         727            1       6.448
# 26450575      43300         727           11      24.669
# 26450576      43300         729            3      19.408
#
# [26450577 rows x 4 columns]

# %%
path_target = "https://huggingface.co/datasets/dllllb/age-group-prediction/resolve/main/train_target.csv?download=true"
target = pd.read_csv(path_target)
target
# Out:
#        client_id  bins
# 0          24662     2
# 1           1046     0
# 2          34089     2
# 3          34848     1
# 4          47076     3
# ...          ...   ...
# 29995      14303     1
# 29996      22301     2
# 29997      25731     0
# 29998      16820     3
# 29999       5265     0
#
# [30000 rows x 2 columns]

# %%
target_train, target_test = train_test_split(target, test_size=0.1, stratify=target["bins"], random_state=42)

# %%
trx_data_train = pd.merge(data, target_train["client_id"], on="client_id", how="inner")
trx_data_test = pd.merge(data, target_test["client_id"], on="client_id", how="inner")

# %% [markdown]
# ---

# %% [markdown]
# **Квантизация непрерывных признаков (опциональный шаг, нужен только для GPT):**

# %%
def digitize(input_array: np.array, q_count: int = 1, bins: np.array = None):
    """Quantile-based discretization function.

    Parameters:
    -------
    input_array (np.array): Input array.
    q_count (int): Amount of quantiles. Used only if input parameter `bins` is None.
    bins (np.array):
        If None, then calculate bins as quantiles of input array,
        otherwise only apply bins to input_array. Default: None

    Returns
    -------
    out_array (np.array of ints): discretized input_array
    bins (np.array of floats):
        Returned only if input parameter `bins` is None.
    """

    if bins is None:
        return_bins = True
        bins = np.quantile(input_array, q=[i / q_count for i in range(1, q_count)], axis=0)
    else:
        return_bins = False

    out_array = np.digitize(input_array, bins)

    if return_bins:
        return out_array, bins
    else:
        return out_array

# %%
BINS_NUM = 128

# %%
numeric_features = ["amount_rur"]

for feat in numeric_features:
    trx_data_train[feat], bins = digitize(trx_data_train[feat], q_count=BINS_NUM)
    trx_data_test[feat] = digitize(trx_data_test[feat], bins=bins)

# %%
import gc

gc.collect()
# Out:
# 147

# %% [markdown]
# ---

# %%
preprocessor = PandasDataPreprocessor(
    col_id="client_id",
    col_event_time="trans_date",
    event_time_transformation="none",
    cols_category=["small_group"],
    cols_numerical=["amount_rur"],
    return_records=False,
)

# %%
data_train = preprocessor.fit_transform(trx_data_train)
data_test = preprocessor.transform(trx_data_test)

# %%
target_train.rename(columns={"bins": "target"}, inplace=True)
target_test.rename(columns={"bins": "target"}, inplace=True)
target_train.sort_values(by="client_id", inplace=True)
target_test.sort_values(by="client_id", inplace=True)
target_train = target_train["target"]
target_test = target_test["target"]
target_train.reset_index(drop=True, inplace=True)
target_test.reset_index(drop=True, inplace=True)

# %%
data_train = data_train.to_dict(orient="records")
data_test = data_test.to_dict(orient="records")

# %% [markdown]
# ---

# %% [markdown]
# **AddNulls (Add 'No Trx' Tokens for missing days to make a uniform time grid)**
#
# **(Если нет ни одного timestamp'а, относящегося к данному дню, то мы его добавляем; иначе ничего не делаем):**

# %%
from ptls.data_load.iterable_processing_dataset import IterableProcessingDataset

class AddNulls(IterableProcessingDataset):
    def __init__(self, null_cat, numeric_values, col_time, col_id):
        super().__init__()
        self.null_cat = null_cat
        self.numeric_values = numeric_values
        self.col_time = col_time
        self.col_id = col_id

    def __iter__(self):
        for rec in self._src:
            features = rec[0] if type(rec) is tuple else rec
            et = np.array(features[self.col_time])
    
            # Границы диапазона
            start, end = et[0], et[-1]

            # Массив полного диапазона
            complete = np.arange(start, end + 1)

            # Находим уникальные значения и их количество
            unique_vals, counts = np.unique(et, return_counts=True)

            # Для повторяющихся значений (если count > 1) создаём массив дополнительных копий (кроме первой)
            extra_list = [np.full(c - 1, val) for val, c in zip(unique_vals, counts) if c > 1]
            if extra_list:
                extra = np.concatenate(extra_list)
            else:
                extra = np.array([])  # Если повторов нет, оставляем пустым

            # Объединяем полный диапазон и дополнительные копии, затем сортируем
            new_event_time = np.sort(np.concatenate([complete, extra]))

            # Определяем, какие значения отсутствовали в исходном event_time (они появятся ровно по одному)
            missing_values = np.setdiff1d(complete, unique_vals)
            # Флаг: True – значение вставлено, False – значение присутствовало в исходном массиве
            inserted_mask = np.in1d(new_event_time, missing_values)

            # Обновляем event_time
            features[self.col_time] = torch.tensor(new_event_time, dtype=torch.int32)

            # Для остальных фич: создаём новый массив того же размера, где на позициях вставленных значений ставим 300,
            # а на остальных восстанавливаем исходные значения в порядке сортировки.
            for key, arr in features.items():
                if (key == self.col_time) | (key == self.col_id):
                    continue
                orig_arr = np.array(arr)
                if key in self.numeric_values:
                    new_arr = np.full(new_event_time.shape, 0)
                    # Индексы, где значения НЕ вставлены
                    non_inserted_idx = np.where(~inserted_mask)[0]
                    new_arr[non_inserted_idx] = orig_arr
                    features[key] = torch.tensor(new_arr, dtype=torch.float32)
                else:
                    new_arr = np.full(new_event_time.shape, self.null_cat)
                    # Индексы, где значения НЕ вставлены
                    non_inserted_idx = np.where(~inserted_mask)[0]
                    new_arr[non_inserted_idx] = orig_arr
                    features[key] = torch.tensor(new_arr, dtype=torch.int32)
            yield features

# %% [markdown]
# ---

# %% [markdown]
# **Time Aggregator Class:**

# %%
from ptls.data_load.padded_batch import PaddedBatch


class TimeAggregator(TrxEncoder):
    """The NN layer, a combination of TrxEncoder and Mean Aggregation (by `n_days` days) 
       (works like nn.Sequential([TrxEncoder, Mean Aggregation])).
       `n_days` can be `int` only.
       
       The types of the input and output are `PaddedBatch` of shapes (B, L, T) and (B, L', T) respectively, where 
       B is batch_size,
       L/L' is the max length of a sequence of transactions in a batch (the length is the same as #trx)
       T is the dimensionality of a single transaction.

       Parameters
        n_days (float):
            The number of days used for data aggregation.

        use_window_attention (bool):
            If True, the attention layer will be applied to transactions in a sliding window before pooling.
            
        embeddings:
            You can find info about this param in TrxEncoder desc.
        
        numeric_values:
            You can find info about this param in TrxEncoder desc.

        embeddings_noise:
            You can find info about this param in TrxEncoder desc.
            
        emb_dropout:
            You can find info about this param in TrxEncoder desc.
            
        spatial_dropout:
            You can find info about this param in TrxEncoder desc.

        use_batch_norm:
            You can find info about this param in TrxEncoder desc.

        orthogonal_init:
            You can find info about this param in TrxEncoder desc.
            
        linear_projection_size:
            You can find info about this param in TrxEncoder desc.

        out_of_index:
            You can find info about this param in TrxEncoder desc.

        norm_embeddings:
            Keep default value for this parameter
        
        clip_replace_value:
            Not used. Keep default value for this parameter
        
        positions: 
            Not used. Keep default value for this parameter
       """

    def __init__(self,
                 n_days=1,
                 use_window_attention=False,
                 embeddings=None,
                 numeric_values=None,
                 custom_embeddings=None,
                 time_values=None,
                 embeddings_noise: float = 0,
                 norm_embeddings=None,
                 use_batch_norm=False,
                 use_batch_norm_with_lens=False,
                 clip_replace_value=None,
                 positions=None,
                 emb_dropout=0,
                 spatial_dropout=False,
                 orthogonal_init=False,
                 linear_projection_size=0,
                 out_of_index: str = 'clip',
                ):

        
        super().__init__(
            embeddings=embeddings,
            numeric_values=numeric_values,
            custom_embeddings=custom_embeddings,
            embeddings_noise=embeddings_noise,
            norm_embeddings=norm_embeddings,
            use_batch_norm=use_batch_norm,
            use_batch_norm_with_lens=use_batch_norm_with_lens,
            clip_replace_value=clip_replace_value,
            positions=positions,
            emb_dropout=emb_dropout,
            spatial_dropout=spatial_dropout,
            orthogonal_init=orthogonal_init,
            linear_projection_size=linear_projection_size,
            out_of_index=out_of_index
        )

        self.n_days = n_days
        
        self.use_window_attention = use_window_attention

        self.numeric_feats = list(numeric_values.keys())
        
        if self.use_window_attention:
            pass # Not Implemented

    def forward(self, pb: PaddedBatch):
        for key in pb.payload.keys():
            if key in self.numeric_feats:
                pb.payload[key] = pb.payload[key].to(torch.float32)
            else:
                pb.payload[key] = pb.payload[key].to(torch.int32)
        embeds = super().forward(pb)

        timestamps = pb.payload["event_time"] // self.n_days
    
        mask = torch.arange(embeds.payload.shape[1], device=embeds.device)[None, :] + torch.ones((embeds.seq_lens.shape[0], embeds.payload.shape[1]), device=embeds.device)
        mask[mask > embeds.seq_lens[:, None]] = 0.
        mask[mask > 0.] = 1.
        mask = mask[:, :, None]
        
        masked_embeds = embeds.payload * mask

        agg_embeds = []
        seq_lens = []
        max_seq_len = 0
        for j in range(masked_embeds.shape[0]):
            curr_seq_embeds = masked_embeds[j, :, :]
            curr_timestamps = timestamps[j, :]
            
            unique_timestamps, idx = torch.unique_consecutive(curr_timestamps, return_inverse=True) 
            
            curr_agg_seq = torch_scatter.scatter(curr_seq_embeds, idx[:, None], dim=0, reduce="mean")
            if unique_timestamps[-1].item() == 0:
                curr_agg_seq = curr_agg_seq[:-1, :]
    
            agg_embeds += [curr_agg_seq]
            seq_lens += [curr_agg_seq.shape[0]]
            max_seq_len = max(max_seq_len, curr_agg_seq.shape[0])
    
        for j in range(len(agg_embeds)):
            if max_seq_len - agg_embeds[j].shape[0] > 0:
                agg_embeds[j] = torch.cat([agg_embeds[j], torch.zeros((max_seq_len - agg_embeds[j].shape[0], agg_embeds[j].shape[1]), device=agg_embeds[j].device)], dim=0)[None, :, :]
            else:
                agg_embeds[j] = agg_embeds[j][None, :, :]
    
        agg_embeds = torch.cat(agg_embeds, dim=0)
        
        seq_lens = torch.tensor(seq_lens, device=agg_embeds.device).int()
        
        return PaddedBatch(agg_embeds, seq_lens)

# %%
# seed_everything(0)

# %%
# device = "cuda:0"

# %%
# trx_encoder_params = dict(
#     embeddings_noise=0.003,
#     numeric_values={"amount_rur": "log"},
#     embeddings={
#         "trans_date": {"in": 800, "out": 16},
#         "small_group": {"in": 250, "out": 16},
#     },
# )

# trx_encoder = TrxEncoder(**trx_encoder_params).to(device)

# %%
# from ptls.data_load.padded_batch import PaddedBatch


# train_loader = inference_data_loader(data_train, num_workers=0, batch_size=128)
# agg_samples = 5
# use_attention = False
# trx_encoder.eval()

# for i, batch in tqdm(enumerate(train_loader)):
#     batch = batch.to(device)
        
#     embeds = trx_encoder(batch)
    
#     mask = torch.arange(embeds.payload.shape[1], device=embeds.device)[None, :] + torch.ones((embeds.seq_lens.shape[0], embeds.payload.shape[1]), device=embeds.device)
#     mask[mask > embeds.seq_lens[:, None]] = 0.
#     mask[mask > 0.] = 1.
#     mask = mask[:, :, None]
    
#     masked_embeds = embeds.payload * mask
    
#     num_samples_to_add = agg_samples - (masked_embeds.shape[1] % agg_samples)  
#     if num_samples_to_add > 0:
#         additional_samples = torch.zeros((masked_embeds.shape[0], num_samples_to_add, masked_embeds.shape[2]), device=masked_embeds.device)
#         masked_embeds = torch.cat((masked_embeds, additional_samples), dim=1)

#         mask_additional_samples = torch.zeros((mask.shape[0], num_samples_to_add, mask.shape[2]), device=mask.device)
#         mask = torch.cat((mask, mask_additional_samples), dim=1)
    
#     masked_embeds = torch.reshape(masked_embeds, (masked_embeds.shape[0], masked_embeds.shape[1] // agg_samples, agg_samples, masked_embeds.shape[2]))
#     mask = torch.reshape(mask, (mask.shape[0], mask.shape[1] // agg_samples, agg_samples, mask.shape[2]))

#     mask = torch.sum(mask, dim=2)
#     mask[mask == 0.] = 1.
    
#     mean_embeds = torch.sum(masked_embeds, dim=2) / mask

#     new_seq_lens = embeds.seq_lens // agg_samples
#     div_mod_seq_lens = ((embeds.seq_lens % agg_samples) > 0).int()
#     new_seq_lens += div_mod_seq_lens

#     out = PaddedBatch(mean_embeds, new_seq_lens)

#     if i == 0:
#         print(out.payload)

# %%
# seed_everything(0)

# %%
# agg_encoder_params = dict(
#     embeddings_noise=0.003,
#     numeric_values={"amount_rur": "log"},
#     embeddings={
#         "trans_date": {"in": 800, "out": 16},
#         "small_group": {"in": 250, "out": 16},
#     },
#     n_days=1,
#     use_window_attention=False
# )

# trx_encoder = TimeAggregator(**agg_encoder_params)

# %%
# device = "cuda:0"

# trx_encoder.to(device)
# Out:
# TimeAggregator(
#   (embeddings): ModuleDict(
#     (trans_date): NoisyEmbedding(
#       800, 16, padding_idx=0
#       (dropout): Dropout(p=0, inplace=False)
#     )
#     (small_group): NoisyEmbedding(
#       250, 16, padding_idx=0
#       (dropout): Dropout(p=0, inplace=False)
#     )
#   )
#   (custom_embeddings): ModuleDict(
#     (amount_rur): LogScaler()
#   )
# )

# %%
# train_loader = inference_data_loader(data_train, num_workers=0, batch_size=128)
# trx_encoder.eval()

# for i, batch in tqdm(enumerate(train_loader)):
#     batch = batch.to(device)    
#     embeds = trx_encoder(batch)

#     if i == 0:
#         print(embeds.payload)
#         print(embeds.seq_lens)
#         #print(batch.payload)

# %% [markdown]
# ---

# %% [markdown]
# **Train sequences lengths check:**

# %%
agg_encoder_params = dict(
    embeddings_noise=0.003,
    numeric_values={"amount_rur": "log"},
    embeddings={
        "trans_date": {"in": 800, "out": 16},
        "small_group": {"in": 250, "out": 16},
    },
    n_days=1, # 1, 2
    use_window_attention=False
)

trx_encoder = TimeAggregator(**agg_encoder_params)
trx_encoder.to("cuda")
# Out:
# TimeAggregator(
#   (embeddings): ModuleDict(
#     (trans_date): NoisyEmbedding(
#       800, 16, padding_idx=0
#       (dropout): Dropout(p=0, inplace=False)
#     )
#     (small_group): NoisyEmbedding(
#       250, 16, padding_idx=0
#       (dropout): Dropout(p=0, inplace=False)
#     )
#   )
#   (custom_embeddings): ModuleDict(
#     (amount_rur): LogScaler()
#   )
# )

# %%
train_loader = inference_data_loader(data_train, num_workers=0, batch_size=128)

trx_encoder.eval()

seq_lens = []

for batch in tqdm(train_loader):
    embeds_batch = trx_encoder(batch.to("cuda"))
    seq_lens += [embeds_batch.seq_lens.detach().cpu().numpy()]

seq_lens = np.concatenate(seq_lens)

threshold = int(np.quantile(seq_lens, 0.75) * 0.7)

print("Max Length:", threshold)
# Out:
# 211it [00:14, 14.60it/s]
# Max Length: 368

# %% [markdown]
# ---

# %% [markdown]
# # Aggregation By Days (Mean Pooling)

# %% [markdown]
# - **COLES:**

# %%
seed_everything(17)

# %% [markdown]
# **DataLoaders:**

# %%
data = PtlsDataModule(
    train_data=ColesDataset(
        MemoryMapDataset(
            data=data_train,
            i_filters=[
                       SeqLenFilter(min_seq_len=30), 
                       AddNulls(null_cat=1000, numeric_values=['amount_rur'], col_time='trans_date', col_id='client_id')
                      ],
        ),
        splitter=SampleSlices(
            split_count=5,
            cnt_min=30,
            cnt_max=368,
        ),
    ),
    train_num_workers=4,
    train_batch_size=128,
    valid_data=ColesDataset(
        MemoryMapDataset(
            data=data_test,
            i_filters=[
                       SeqLenFilter(min_seq_len=30),
                       AddNulls(null_cat=1000, numeric_values=['amount_rur'], col_time='trans_date', col_id='client_id')
                      ],
        ),
        splitter=SampleSlices(
            split_count=5,
            cnt_min=30,
            cnt_max=368,
        ),
    ),
    valid_num_workers=4,
    valid_batch_size=128
)

# %% [markdown]
# **Модель:**

# %%
N_EPOCHS = 20

# %%
agg_encoder_params = dict(
    embeddings_noise=0.003,
    numeric_values={"amount_rur": "log"},
    embeddings={
        "trans_date": {"in": 1001, "out": 16},
        "small_group": {"in": 1001, "out": 16},
        #"trans_date": {"in": 800, "out": 16},
        #"small_group": {"in": 250, "out": 16},
    },
    n_days=1, # 1, 2
    use_window_attention=False
)

trx_encoder = TimeAggregator(**agg_encoder_params)

seq_encoder = RnnSeqEncoder(
    trx_encoder=trx_encoder,
    hidden_size=512,
    type="gru"
)

coles = CoLESModule(
    seq_encoder=seq_encoder,
    optimizer_partial=partial(torch.optim.Adam, lr=3e-3, weight_decay=5e-4),
    lr_scheduler_partial=partial(torch.optim.lr_scheduler.CosineAnnealingLR, T_max=N_EPOCHS, eta_min=1e-6)
)

# %% [markdown]
# **Обучение:**

# %%
logger = CometLogger(project_name="EvS_SSL", experiment_name="CoLES_AggByDays (1 day, w/ AddNulls)")

trainer = pl.Trainer(
    logger=logger,
    max_epochs=N_EPOCHS,
    accelerator="gpu",
    devices=1,
    enable_progress_bar=True
)

# %%
trainer.fit(coles, data)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/askoro/evs-ssl/ece7f6aab4cb4ba985b666aa49f9e0fa
#
# COMET INFO: Couldn't find a Git repository in '/kaggle/working' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]

# %%
trainer.logged_metrics
# Out:
# {'loss': tensor(146.8837),
#  'seq_len': tensor(201.2017),
#  'valid/recall_top_k': tensor(0.7715)}

# %%
torch.save(seq_encoder.state_dict(), "coles_enc_win_agg.pt")

# %% [markdown]
# **Измерим качество на тесте (catboost поверх эмбеддингов):**

# %%
encoder = coles.seq_encoder

device = "cuda:0"

encoder.to(device)
# Out:
# RnnSeqEncoder(
#   (trx_encoder): TimeAggregator(
#     (embeddings): ModuleDict(
#       (trans_date): NoisyEmbedding(
#         1001, 16, padding_idx=0
#         (dropout): Dropout(p=0, inplace=False)
#       )
#       (small_group): NoisyEmbedding(
#         1001, 16, padding_idx=0
#         (dropout): Dropout(p=0, inplace=False)
#       )
#     )
#     (custom_embeddings): ModuleDict(
#       (amount_rur): LogScaler()
#     )
#   )
#   (seq_encoder): RnnEncoder(
#     (rnn): GRU(33, 512, batch_first=True)
#     (reducer): LastStepEncoder()
#   )
# )

# %%
from tqdm import tqdm

seed_everything(17)

# %%
train_loader = inference_data_loader(data_train, num_workers=0, batch_size=128)
encoder.eval()
train_embeds = None

for i, batch in tqdm(enumerate(train_loader)):
    train_embeds_batch = encoder(batch.to(device))
    if i == 0:
        train_embeds = train_embeds_batch.detach().cpu().numpy()
    else:
        train_embeds = np.concatenate([train_embeds, train_embeds_batch.detach().cpu().numpy()], axis=0)
    
train_embeds
# Out:
# 0it [00:00, ?it/s]
# 1it [00:00,  5.14it/s]
# 2it [00:00,  6.09it/s]
# 3it [00:00,  6.55it/s]
# 4it [00:00,  6.85it/s]
# 5it [00:00,  7.10it/s]
# 6it [00:00,  7.18it/s]
# 7it [00:01,  7.29it/s]
# 8it [00:01,  7.32it/s]
# 9it [00:01,  7.19it/s]
# 10it [00:01,  7.11it/s]
# 11it [00:01,  7.09it/s]
# 12it [00:01,  7.02it/s]
# 13it [00:01,  7.07it/s]
# 14it [00:01,  7.18it/s]
# 15it [00:02,  7.14it/s]
# 16it [00:02,  7.11it/s]
# 17it [00:02,  7.04it/s]
# 18it [00:02,  7.12it/s]
# 19it [00:02,  7.21it/s]
# 20it [00:02,  7.23it/s]
# 21it [00:02,  7.23it/s]
# 22it [00:03,  7.24it/s]
# 23it [00:03,  7.27it/s]
# 24it [00:03,  7.27it/s]
# 25it [00:03,  7.29it/s]
# 26it [00:03,  7.27it/s]
# 27it [00:03,  7.33it/s]
# 28it [00:03,  7.28it/s]
# 29it [00:04,  7.30it/s]
# 30it [00:04,  7.31it/s]
# 31it [00:04,  7.31it/s]
# 32it [00:04,  7.36it/s]
# 33it [00:04,  7.37it/s]
# 34it [00:04,  7.39it/s]
# 35it [00:04,  7.43it/s]
# 36it [00:05,  7.44it/s]
# 37it [00:05,  7.41it/s]
# 38it [00:05,  7.40it/s]
# 39it [00:05,  7.42it/s]
# 40it [00:05,  7.38it/s]
# 41it [00:05,  7.39it/s]
# 42it [00:05,  7.40it/s]
# 43it [00:05,  7.38it/s]
# 44it [00:06,  7.38it/s]
# 45it [00:06,  7.39it/s]
# 46it [00:06,  7.39it/s]
# 47it [00:06,  7.21it/s]
# 48it [00:06,  7.01it/s]
# 49it [00:06,  7.11it/s]
# 50it [00:06,  7.18it/s]
# 51it [00:07,  7.27it/s]
# 52it [00:07,  7.34it/s]
# 53it [00:07,  7.39it/s]
# 54it [00:07,  7.38it/s]
# 55it [00:07,  7.36it/s]
# 56it [00:07,  7.34it/s]
# 57it [00:07,  7.36it/s]
# 58it [00:08,  7.39it/s]
# 59it [00:08,  7.39it/s]
# 60it [00:08,  7.36it/s]
# 61it [00:08,  7.35it/s]
# 62it [00:08,  7.34it/s]
# 63it [00:08,  7.38it/s]
# 64it [00:08,  7.34it/s]
# 65it [00:08,  7.31it/s]
# 66it [00:09,  7.31it/s]
# 67it [00:09,  7.34it/s]
# 68it [00:09,  7.31it/s]
# 69it [00:09,  7.31it/s]
# 70it [00:09,  7.31it/s]
# 71it [00:09,  7.30it/s]
# 72it [00:09,  7.25it/s]
# 73it [00:10,  7.24it/s]
# 74it [00:10,  7.28it/s]
# 75it [00:10,  7.32it/s]
# 76it [00:10,  7.31it/s]
# 77it [00:10,  7.34it/s]
# 78it [00:10,  7.35it/s]
# 79it [00:10,  7.34it/s]
# 80it [00:11,  7.34it/s]
# 81it [00:11,  7.19it/s]
# 82it [00:11,  7.14it/s]
# 83it [00:11,  7.22it/s]
# 84it [00:11,  7.25it/s]
# 85it [00:11,  7.29it/s]
# 86it [00:11,  7.24it/s]
# 87it [00:12,  7.15it/s]
# 88it [00:12,  7.19it/s]
# 89it [00:12,  7.19it/s]
# 90it [00:12,  7.23it/s]
# 91it [00:12,  7.30it/s]
# 92it [00:12,  7.32it/s]
# 93it [00:12,  7.30it/s]
# 94it [00:12,  7.31it/s]
# 95it [00:13,  7.34it/s]
# 96it [00:13,  7.28it/s]
# 97it [00:13,  7.21it/s]
# 98it [00:13,  7.20it/s]
# 99it [00:13,  7.18it/s]
# 100it [00:13,  7.21it/s]
# 101it [00:13,  7.21it/s]
# 102it [00:14,  7.23it/s]
# 103it [00:14,  7.28it/s]
# 104it [00:14,  7.32it/s]
# 105it [00:14,  7.23it/s]
# 106it [00:14,  7.17it/s]
# 107it [00:14,  7.18it/s]
# 108it [00:14,  7.17it/s]
# 109it [00:15,  7.20it/s]
# 110it [00:15,  7.21it/s]
# 111it [00:15,  7.21it/s]
# 112it [00:15,  7.23it/s]
# 113it [00:15,  7.24it/s]
# 114it [00:15,  7.23it/s]
# 115it [00:15,  7.19it/s]
# 116it [00:16,  7.11it/s]
# 117it [00:16,  7.11it/s]
# 118it [00:16,  7.17it/s]
# 119it [00:16,  7.18it/s]
# 120it [00:16,  7.21it/s]
# 121it [00:16,  6.88it/s]
# 122it [00:16,  6.94it/s]
# 123it [00:17,  7.02it/s]
# 124it [00:17,  7.04it/s]
# 125it [00:17,  7.04it/s]
# 126it [00:17,  6.98it/s]
# 127it [00:17,  6.94it/s]
# 128it [00:17,  7.02it/s]
# 129it [00:17,  7.03it/s]
# 130it [00:18,  7.05it/s]
# 131it [00:18,  7.12it/s]
# 132it [00:18,  7.05it/s]
# 133it [00:18,  6.94it/s]
# 134it [00:18,  6.91it/s]
# 135it [00:18,  6.85it/s]
# 136it [00:18,  6.86it/s]
# 137it [00:19,  6.86it/s]
# 138it [00:19,  6.87it/s]
# 139it [00:19,  6.86it/s]
# 140it [00:19,  6.86it/s]
# 141it [00:19,  6.86it/s]
# 142it [00:19,  6.87it/s]
# 143it [00:19,  6.84it/s]
# 144it [00:20,  6.85it/s]
# 145it [00:20,  6.87it/s]
# 146it [00:20,  6.91it/s]
# 147it [00:20,  6.91it/s]
# 148it [00:20,  6.92it/s]
# 149it [00:20,  6.90it/s]
# 150it [00:20,  6.83it/s]
# 151it [00:21,  6.77it/s]
# 152it [00:21,  6.76it/s]
# 153it [00:21,  6.73it/s]
# 154it [00:21,  6.75it/s]
# 155it [00:21,  6.77it/s]
# 156it [00:21,  6.76it/s]
# 157it [00:21,  6.74it/s]
# 158it [00:22,  6.78it/s]
# 159it [00:22,  6.74it/s]
# 160it [00:22,  6.74it/s]
# 161it [00:22,  6.74it/s]
# 162it [00:22,  6.71it/s]
# 163it [00:22,  6.72it/s]
# 164it [00:22,  6.72it/s]
# 165it [00:23,  6.70it/s]
# 166it [00:23,  6.68it/s]
# 167it [00:23,  6.66it/s]
# 168it [00:23,  6.66it/s]
# 169it [00:23,  6.67it/s]
# 170it [00:23,  6.64it/s]
# 171it [00:24,  6.64it/s]
# 172it [00:24,  6.62it/s]
# 173it [00:24,  6.61it/s]
# 174it [00:24,  6.60it/s]
# 175it [00:24,  6.64it/s]
# 176it [00:24,  6.62it/s]
# 177it [00:24,  6.56it/s]
# 178it [00:25,  6.58it/s]
# 179it [00:25,  6.62it/s]
# 180it [00:25,  6.60it/s]
# 181it [00:25,  6.61it/s]
# 182it [00:25,  6.63it/s]
# 183it [00:25,  6.57it/s]
# 184it [00:26,  6.59it/s]
# 185it [00:26,  6.60it/s]
# 186it [00:26,  6.62it/s]
# 187it [00:26,  6.59it/s]
# 188it [00:26,  6.56it/s]
# 189it [00:26,  6.59it/s]
# 190it [00:26,  6.58it/s]
# 191it [00:27,  6.57it/s]
# 192it [00:27,  6.56it/s]
# 193it [00:27,  6.58it/s]
# 194it [00:27,  6.57it/s]
# 195it [00:27,  6.56it/s]
# 196it [00:27,  6.58it/s]
# 197it [00:28,  6.53it/s]
# 198it [00:28,  6.54it/s]
# 199it [00:28,  6.54it/s]
# 200it [00:28,  6.54it/s]
# 201it [00:28,  6.54it/s]
# 202it [00:28,  6.54it/s]
# 203it [00:28,  6.54it/s]
# 204it [00:29,  6.57it/s]
# 205it [00:29,  6.55it/s]
# 206it [00:29,  6.54it/s]
# 207it [00:29,  6.49it/s]
# 208it [00:29,  6.47it/s]
# 209it [00:29,  6.49it/s]
# 210it [00:30,  6.49it/s]
# 211it [00:30,  7.00it/s]
# array([[ 2.8425206e-03, -9.7964609e-01, -3.2377061e-01, ...,
#         -7.1829192e-02, -8.8294458e-01, -3.8477625e-03],
#        [-1.6972843e-01, -2.6135787e-01, -4.3345577e-01, ...,
#          2.9847172e-01, -7.4816060e-01,  1.5940424e-02],
#        [-9.1814564e-04,  2.4249214e-03, -5.3966939e-01, ...,
#         -3.7906498e-01,  4.1144556e-01, -6.2717512e-02],
#        ...,
#        [ 2.8373690e-02, -1.4805751e-01, -3.7862214e-01, ...,
#         -4.6238199e-01, -3.6332053e-01, -5.8375042e-02],
#        [ 4.4077501e-02, -4.3897101e-01, -2.8330559e-01, ...,
#         -5.4755992e-01,  4.0678298e-01, -2.4106253e-02],
#        [-3.9166901e-02, -1.1854508e-01, -3.2839009e-01, ...,
#          2.2816817e-01,  4.1406390e-01, -1.4972411e-02]], dtype=float32)

# %%
test_loader = inference_data_loader(data_test, num_workers=0, batch_size=128)
encoder.eval()
test_embeds = None

for i, batch in tqdm(enumerate(test_loader)):
    test_embeds_batch = encoder(batch.to(device))
    if i == 0:
        test_embeds = test_embeds_batch.detach().cpu().numpy()
    else:
        test_embeds = np.concatenate([test_embeds, test_embeds_batch.detach().cpu().numpy()], axis=0)
    
test_embeds
# Out:
# 0it [00:00, ?it/s]
# 1it [00:00,  6.68it/s]
# 2it [00:00,  7.02it/s]
# 3it [00:00,  7.14it/s]
# 4it [00:00,  7.18it/s]
# 5it [00:00,  7.09it/s]
# 6it [00:00,  7.21it/s]
# 7it [00:00,  7.28it/s]
# 8it [00:01,  7.34it/s]
# 9it [00:01,  7.38it/s]
# 10it [00:01,  7.39it/s]
# 11it [00:01,  7.42it/s]
# 12it [00:01,  7.36it/s]
# 13it [00:01,  7.37it/s]
# 14it [00:01,  7.38it/s]
# 15it [00:02,  7.33it/s]
# 16it [00:02,  7.35it/s]
# 17it [00:02,  7.31it/s]
# 18it [00:02,  7.33it/s]
# 19it [00:02,  7.41it/s]
# 20it [00:02,  7.46it/s]
# 21it [00:02,  7.38it/s]
# 22it [00:03,  7.41it/s]
# 24it [00:03,  7.47it/s]
# array([[-0.06609811, -0.09023617, -0.32359967, ...,  0.12252191,
#         -0.00967149,  0.00635439],
#        [ 0.05263222, -0.22831608, -0.29678375, ..., -0.21249671,
#         -0.75594705, -0.01233044],
#        [-0.00463578, -0.21982203, -0.46017352, ..., -0.54700077,
#         -0.4663102 ,  0.0288155 ],
#        ...,
#        [-0.02561516, -0.96200335, -0.2771003 , ...,  0.01120308,
#         -0.6018382 , -0.03068198],
#        [-0.11381032, -0.15281488, -0.39538053, ..., -0.1878948 ,
#          0.44572863, -0.00134987],
#        [ 0.00823167, -0.09243694, -0.33361372, ...,  0.16006725,
#         -0.49312705,  0.02546082]], dtype=float32)

# %%
clf = CatBoostClassifier(loss_function='MultiClass', task_type="GPU", devices='0', random_state=17)

clf.fit(train_embeds, target_train, plot_file="catboost_log.html")
# Out:
# Learning rate set to 0.12714
# 0:	learn: 1.3079071	total: 13.8ms	remaining: 13.8s
# 1:	learn: 1.2501163	total: 24.1ms	remaining: 12s
# 2:	learn: 1.2030255	total: 34.2ms	remaining: 11.4s
# 3:	learn: 1.1652435	total: 44.5ms	remaining: 11.1s
# 4:	learn: 1.1332253	total: 55.1ms	remaining: 11s
# 5:	learn: 1.1077017	total: 65.2ms	remaining: 10.8s
# 6:	learn: 1.0858117	total: 75.3ms	remaining: 10.7s
# 7:	learn: 1.0670127	total: 85.6ms	remaining: 10.6s
# 8:	learn: 1.0495838	total: 95.8ms	remaining: 10.6s
# 9:	learn: 1.0340195	total: 107ms	remaining: 10.5s
# 10:	learn: 1.0213372	total: 116ms	remaining: 10.5s
# 11:	learn: 1.0100749	total: 127ms	remaining: 10.4s
# 12:	learn: 1.0001852	total: 137ms	remaining: 10.4s
# 13:	learn: 0.9907035	total: 147ms	remaining: 10.4s
# 14:	learn: 0.9830870	total: 157ms	remaining: 10.3s
# 15:	learn: 0.9759142	total: 167ms	remaining: 10.3s
# 16:	learn: 0.9692036	total: 178ms	remaining: 10.3s
# 17:	learn: 0.9632307	total: 188ms	remaining: 10.3s
# 18:	learn: 0.9576424	total: 198ms	remaining: 10.2s
# 19:	learn: 0.9524057	total: 209ms	remaining: 10.2s
# 20:	learn: 0.9475663	total: 219ms	remaining: 10.2s
# 21:	learn: 0.9429988	total: 229ms	remaining: 10.2s
# 22:	learn: 0.9391160	total: 240ms	remaining: 10.2s
# 23:	learn: 0.9351888	total: 250ms	remaining: 10.2s
# 24:	learn: 0.9312163	total: 261ms	remaining: 10.2s
# 25:	learn: 0.9276950	total: 271ms	remaining: 10.1s
# 26:	learn: 0.9248663	total: 281ms	remaining: 10.1s
# 27:	learn: 0.9219855	total: 291ms	remaining: 10.1s
# 28:	learn: 0.9199138	total: 301ms	remaining: 10.1s
# 29:	learn: 0.9169625	total: 311ms	remaining: 10.1s
# 30:	learn: 0.9145877	total: 321ms	remaining: 10s
# 31:	learn: 0.9121657	total: 332ms	remaining: 10s
# 32:	learn: 0.9102613	total: 342ms	remaining: 10s
# 33:	learn: 0.9078799	total: 352ms	remaining: 10s
# 34:	learn: 0.9054695	total: 363ms	remaining: 10s
# 35:	learn: 0.9034349	total: 373ms	remaining: 9.99s
# 36:	learn: 0.9016047	total: 384ms	remaining: 9.99s
# 37:	learn: 0.8999151	total: 394ms	remaining: 9.97s
# 38:	learn: 0.8980383	total: 404ms	remaining: 9.96s
# 39:	learn: 0.8962641	total: 414ms	remaining: 9.95s
# 40:	learn: 0.8944620	total: 424ms	remaining: 9.93s
# 41:	learn: 0.8925922	total: 434ms	remaining: 9.91s
# 42:	learn: 0.8906968	total: 445ms	remaining: 9.9s
# 43:	learn: 0.8890802	total: 455ms	remaining: 9.89s
# 44:	learn: 0.8877849	total: 465ms	remaining: 9.86s
# 45:	learn: 0.8862363	total: 475ms	remaining: 9.85s
# 46:	learn: 0.8848066	total: 485ms	remaining: 9.83s
# 47:	learn: 0.8835059	total: 495ms	remaining: 9.82s
# 48:	learn: 0.8818350	total: 505ms	remaining: 9.81s
# 49:	learn: 0.8803818	total: 516ms	remaining: 9.8s
# 50:	learn: 0.8792148	total: 526ms	remaining: 9.78s
# 51:	learn: 0.8782234	total: 535ms	remaining: 9.76s
# 52:	learn: 0.8769436	total: 546ms	remaining: 9.76s
# 53:	learn: 0.8759431	total: 556ms	remaining: 9.74s
# 54:	learn: 0.8747333	total: 566ms	remaining: 9.73s
# 55:	learn: 0.8735633	total: 576ms	remaining: 9.71s
# 56:	learn: 0.8720114	total: 587ms	remaining: 9.71s
# 57:	learn: 0.8705687	total: 598ms	remaining: 9.71s
# 58:	learn: 0.8694634	total: 608ms	remaining: 9.69s
# 59:	learn: 0.8679784	total: 618ms	remaining: 9.68s
# 60:	learn: 0.8672019	total: 628ms	remaining: 9.66s
# 61:	learn: 0.8662836	total: 638ms	remaining: 9.65s
# 62:	learn: 0.8656261	total: 647ms	remaining: 9.62s
# 63:	learn: 0.8646348	total: 657ms	remaining: 9.61s
# 64:	learn: 0.8634153	total: 667ms	remaining: 9.6s
# 65:	learn: 0.8623067	total: 678ms	remaining: 9.59s
# 66:	learn: 0.8612302	total: 688ms	remaining: 9.58s
# 67:	learn: 0.8600333	total: 699ms	remaining: 9.57s
# 68:	learn: 0.8593668	total: 708ms	remaining: 9.55s
# 69:	learn: 0.8584652	total: 718ms	remaining: 9.53s
# 70:	learn: 0.8574175	total: 728ms	remaining: 9.52s
# 71:	learn: 0.8564912	total: 738ms	remaining: 9.51s
# 72:	learn: 0.8555472	total: 748ms	remaining: 9.5s
# 73:	learn: 0.8548961	total: 758ms	remaining: 9.48s
# 74:	learn: 0.8539982	total: 768ms	remaining: 9.47s
# 75:	learn: 0.8533272	total: 777ms	remaining: 9.45s
# 76:	learn: 0.8524657	total: 787ms	remaining: 9.43s
# 77:	learn: 0.8515344	total: 797ms	remaining: 9.42s
# 78:	learn: 0.8508417	total: 806ms	remaining: 9.4s
# 79:	learn: 0.8497368	total: 816ms	remaining: 9.39s
# 80:	learn: 0.8490033	total: 826ms	remaining: 9.37s
# 81:	learn: 0.8482570	total: 835ms	remaining: 9.35s
# 82:	learn: 0.8472757	total: 845ms	remaining: 9.33s
# 83:	learn: 0.8464154	total: 855ms	remaining: 9.32s
# 84:	learn: 0.8455069	total: 865ms	remaining: 9.31s
# 85:	learn: 0.8444025	total: 875ms	remaining: 9.3s
# 86:	learn: 0.8434986	total: 885ms	remaining: 9.28s
# 87:	learn: 0.8429337	total: 894ms	remaining: 9.27s
# 88:	learn: 0.8421910	total: 904ms	remaining: 9.25s
# 89:	learn: 0.8415670	total: 913ms	remaining: 9.23s
# 90:	learn: 0.8407709	total: 923ms	remaining: 9.22s
# 91:	learn: 0.8396314	total: 933ms	remaining: 9.21s
# 92:	learn: 0.8388056	total: 943ms	remaining: 9.2s
# 93:	learn: 0.8378890	total: 953ms	remaining: 9.18s
# 94:	learn: 0.8370747	total: 963ms	remaining: 9.17s
# 95:	learn: 0.8364316	total: 973ms	remaining: 9.16s
# 96:	learn: 0.8353203	total: 983ms	remaining: 9.15s
# 97:	learn: 0.8345488	total: 993ms	remaining: 9.14s
# 98:	learn: 0.8340546	total: 1s	remaining: 9.13s
# 99:	learn: 0.8332126	total: 1.01s	remaining: 9.12s
# 100:	learn: 0.8320850	total: 1.02s	remaining: 9.11s
# 101:	learn: 0.8311613	total: 1.03s	remaining: 9.1s
# 102:	learn: 0.8304492	total: 1.04s	remaining: 9.09s
# 103:	learn: 0.8298932	total: 1.05s	remaining: 9.07s
# 104:	learn: 0.8292777	total: 1.06s	remaining: 9.05s
# 105:	learn: 0.8282615	total: 1.07s	remaining: 9.04s
# 106:	learn: 0.8273057	total: 1.08s	remaining: 9.03s
# 107:	learn: 0.8265898	total: 1.09s	remaining: 9.02s
# 108:	learn: 0.8257497	total: 1.1s	remaining: 9.01s
# 109:	learn: 0.8250660	total: 1.11s	remaining: 9s
# 110:	learn: 0.8243542	total: 1.12s	remaining: 8.99s
# 111:	learn: 0.8234057	total: 1.13s	remaining: 8.98s
# 112:	learn: 0.8225760	total: 1.14s	remaining: 8.97s
# 113:	learn: 0.8217809	total: 1.15s	remaining: 8.96s
# 114:	learn: 0.8208414	total: 1.16s	remaining: 8.95s
# 115:	learn: 0.8200952	total: 1.17s	remaining: 8.94s
# 116:	learn: 0.8192984	total: 1.18s	remaining: 8.93s
# 117:	learn: 0.8184471	total: 1.19s	remaining: 8.93s
# 118:	learn: 0.8176382	total: 1.2s	remaining: 8.92s
# 119:	learn: 0.8167089	total: 1.22s	remaining: 8.91s
# 120:	learn: 0.8157581	total: 1.23s	remaining: 8.9s
# 121:	learn: 0.8151696	total: 1.24s	remaining: 8.89s
# 122:	learn: 0.8144799	total: 1.25s	remaining: 8.88s
# 123:	learn: 0.8139791	total: 1.25s	remaining: 8.87s
# 124:	learn: 0.8135229	total: 1.26s	remaining: 8.86s
# 125:	learn: 0.8131424	total: 1.27s	remaining: 8.85s
# 126:	learn: 0.8123627	total: 1.28s	remaining: 8.84s
# 127:	learn: 0.8119182	total: 1.29s	remaining: 8.82s
# 128:	learn: 0.8112457	total: 1.3s	remaining: 8.81s
# 129:	learn: 0.8103386	total: 1.31s	remaining: 8.8s
# 130:	learn: 0.8096877	total: 1.32s	remaining: 8.79s
# 131:	learn: 0.8090071	total: 1.33s	remaining: 8.77s
# 132:	learn: 0.8083001	total: 1.34s	remaining: 8.76s
# 133:	learn: 0.8075770	total: 1.35s	remaining: 8.75s
# 134:	learn: 0.8068014	total: 1.36s	remaining: 8.74s
# 135:	learn: 0.8060370	total: 1.37s	remaining: 8.73s
# 136:	learn: 0.8053596	total: 1.38s	remaining: 8.72s
# 137:	learn: 0.8048192	total: 1.39s	remaining: 8.71s
# 138:	learn: 0.8039116	total: 1.41s	remaining: 8.7s
# 139:	learn: 0.8032901	total: 1.42s	remaining: 8.7s
# 140:	learn: 0.8027161	total: 1.43s	remaining: 8.69s
# 141:	learn: 0.8016085	total: 1.44s	remaining: 8.68s
# 142:	learn: 0.8006911	total: 1.45s	remaining: 8.68s
# 143:	learn: 0.7999816	total: 1.46s	remaining: 8.67s
# 144:	learn: 0.7992886	total: 1.47s	remaining: 8.66s
# 145:	learn: 0.7984610	total: 1.48s	remaining: 8.66s
# 146:	learn: 0.7977796	total: 1.49s	remaining: 8.65s
# 147:	learn: 0.7972499	total: 1.5s	remaining: 8.64s
# 148:	learn: 0.7966149	total: 1.51s	remaining: 8.62s
# 149:	learn: 0.7957397	total: 1.52s	remaining: 8.61s
# 150:	learn: 0.7951830	total: 1.53s	remaining: 8.6s
# 151:	learn: 0.7945739	total: 1.54s	remaining: 8.59s
# 152:	learn: 0.7940287	total: 1.55s	remaining: 8.58s
# 153:	learn: 0.7933553	total: 1.56s	remaining: 8.57s
# 154:	learn: 0.7928204	total: 1.57s	remaining: 8.55s
# 155:	learn: 0.7920561	total: 1.58s	remaining: 8.55s
# 156:	learn: 0.7916076	total: 1.59s	remaining: 8.53s
# 157:	learn: 0.7907323	total: 1.6s	remaining: 8.52s
# 158:	learn: 0.7901685	total: 1.61s	remaining: 8.51s
# 159:	learn: 0.7897572	total: 1.62s	remaining: 8.49s
# 160:	learn: 0.7892949	total: 1.63s	remaining: 8.48s
# 161:	learn: 0.7885523	total: 1.64s	remaining: 8.47s
# 162:	learn: 0.7879964	total: 1.65s	remaining: 8.46s
# 163:	learn: 0.7873737	total: 1.66s	remaining: 8.45s
# 164:	learn: 0.7868547	total: 1.67s	remaining: 8.44s
# 165:	learn: 0.7862191	total: 1.68s	remaining: 8.44s
# 166:	learn: 0.7858011	total: 1.69s	remaining: 8.43s
# 167:	learn: 0.7850665	total: 1.7s	remaining: 8.42s
# 168:	learn: 0.7842932	total: 1.71s	remaining: 8.41s
# 169:	learn: 0.7836684	total: 1.72s	remaining: 8.4s
# 170:	learn: 0.7829849	total: 1.73s	remaining: 8.39s
# 171:	learn: 0.7823359	total: 1.74s	remaining: 8.38s
# 172:	learn: 0.7815436	total: 1.75s	remaining: 8.37s
# 173:	learn: 0.7810213	total: 1.76s	remaining: 8.36s
# 174:	learn: 0.7803696	total: 1.77s	remaining: 8.35s
# 175:	learn: 0.7796779	total: 1.78s	remaining: 8.34s
# 176:	learn: 0.7790423	total: 1.79s	remaining: 8.33s
# 177:	learn: 0.7784115	total: 1.8s	remaining: 8.32s
# 178:	learn: 0.7778215	total: 1.81s	remaining: 8.31s
# 179:	learn: 0.7772541	total: 1.82s	remaining: 8.3s
# 180:	learn: 0.7766262	total: 1.83s	remaining: 8.29s
# 181:	learn: 0.7760503	total: 1.84s	remaining: 8.27s
# 182:	learn: 0.7753409	total: 1.85s	remaining: 8.26s
# 183:	learn: 0.7748665	total: 1.86s	remaining: 8.25s
# 184:	learn: 0.7743996	total: 1.87s	remaining: 8.24s
# 185:	learn: 0.7738977	total: 1.88s	remaining: 8.22s
# 186:	learn: 0.7734340	total: 1.89s	remaining: 8.21s
# 187:	learn: 0.7729954	total: 1.9s	remaining: 8.2s
# 188:	learn: 0.7724006	total: 1.91s	remaining: 8.19s
# 189:	learn: 0.7719232	total: 1.92s	remaining: 8.17s
# 190:	learn: 0.7713359	total: 1.93s	remaining: 8.16s
# 191:	learn: 0.7708342	total: 1.94s	remaining: 8.15s
# 192:	learn: 0.7701249	total: 1.95s	remaining: 8.14s
# 193:	learn: 0.7697380	total: 1.96s	remaining: 8.13s
# 194:	learn: 0.7692568	total: 1.97s	remaining: 8.11s
# 195:	learn: 0.7686107	total: 1.98s	remaining: 8.1s
# 196:	learn: 0.7680028	total: 1.99s	remaining: 8.09s
# 197:	learn: 0.7674522	total: 1.99s	remaining: 8.08s
# 198:	learn: 0.7667867	total: 2s	remaining: 8.07s
# 199:	learn: 0.7662898	total: 2.01s	remaining: 8.06s
# 200:	learn: 0.7654246	total: 2.02s	remaining: 8.05s
# 201:	learn: 0.7649979	total: 2.03s	remaining: 8.04s
# 202:	learn: 0.7646166	total: 2.04s	remaining: 8.02s
# 203:	learn: 0.7640323	total: 2.05s	remaining: 8.01s
# 204:	learn: 0.7634386	total: 2.06s	remaining: 8s
# 205:	learn: 0.7627031	total: 2.07s	remaining: 7.99s
# 206:	learn: 0.7619353	total: 2.08s	remaining: 7.98s
# 207:	learn: 0.7615819	total: 2.09s	remaining: 7.97s
# 208:	learn: 0.7611716	total: 2.1s	remaining: 7.95s
# 209:	learn: 0.7607483	total: 2.11s	remaining: 7.94s
# 210:	learn: 0.7601664	total: 2.12s	remaining: 7.93s
# 211:	learn: 0.7596284	total: 2.13s	remaining: 7.92s
# 212:	learn: 0.7591023	total: 2.14s	remaining: 7.91s
# 213:	learn: 0.7584055	total: 2.15s	remaining: 7.9s
# 214:	learn: 0.7576493	total: 2.16s	remaining: 7.89s
# 215:	learn: 0.7572043	total: 2.17s	remaining: 7.88s
# 216:	learn: 0.7563239	total: 2.18s	remaining: 7.87s
# 217:	learn: 0.7557509	total: 2.19s	remaining: 7.86s
# 218:	learn: 0.7551790	total: 2.2s	remaining: 7.85s
# 219:	learn: 0.7545788	total: 2.21s	remaining: 7.84s
# 220:	learn: 0.7540811	total: 2.22s	remaining: 7.83s
# 221:	learn: 0.7534633	total: 2.23s	remaining: 7.81s
# 222:	learn: 0.7527873	total: 2.24s	remaining: 7.8s
# 223:	learn: 0.7520010	total: 2.25s	remaining: 7.79s
# 224:	learn: 0.7514815	total: 2.26s	remaining: 7.78s
# 225:	learn: 0.7509811	total: 2.27s	remaining: 7.77s
# 226:	learn: 0.7501481	total: 2.28s	remaining: 7.77s
# 227:	learn: 0.7494876	total: 2.29s	remaining: 7.76s
# 228:	learn: 0.7489376	total: 2.3s	remaining: 7.75s
# 229:	learn: 0.7482452	total: 2.31s	remaining: 7.74s
# 230:	learn: 0.7476965	total: 2.32s	remaining: 7.73s
# 231:	learn: 0.7471318	total: 2.33s	remaining: 7.72s
# 232:	learn: 0.7465184	total: 2.34s	remaining: 7.71s
# 233:	learn: 0.7458748	total: 2.35s	remaining: 7.71s
# 234:	learn: 0.7453216	total: 2.36s	remaining: 7.7s
# 235:	learn: 0.7445397	total: 2.37s	remaining: 7.69s
# 236:	learn: 0.7439229	total: 2.38s	remaining: 7.68s
# 237:	learn: 0.7433931	total: 2.4s	remaining: 7.67s
# 238:	learn: 0.7428178	total: 2.4s	remaining: 7.66s
# 239:	learn: 0.7421472	total: 2.42s	remaining: 7.65s
# 240:	learn: 0.7416538	total: 2.42s	remaining: 7.64s
# 241:	learn: 0.7409898	total: 2.44s	remaining: 7.63s
# 242:	learn: 0.7403761	total: 2.45s	remaining: 7.62s
# 243:	learn: 0.7395921	total: 2.46s	remaining: 7.61s
# 244:	learn: 0.7391678	total: 2.47s	remaining: 7.6s
# 245:	learn: 0.7387105	total: 2.48s	remaining: 7.59s
# 246:	learn: 0.7377205	total: 2.49s	remaining: 7.59s
# 247:	learn: 0.7370925	total: 2.5s	remaining: 7.58s
# 248:	learn: 0.7366387	total: 2.51s	remaining: 7.57s
# 249:	learn: 0.7361918	total: 2.52s	remaining: 7.56s
# 250:	learn: 0.7356612	total: 2.53s	remaining: 7.55s
# 251:	learn: 0.7352676	total: 2.54s	remaining: 7.54s
# 252:	learn: 0.7346611	total: 2.55s	remaining: 7.53s
# 253:	learn: 0.7340927	total: 2.56s	remaining: 7.52s
# 254:	learn: 0.7334884	total: 2.57s	remaining: 7.51s
# 255:	learn: 0.7328588	total: 2.58s	remaining: 7.5s
# 256:	learn: 0.7321944	total: 2.59s	remaining: 7.49s
# 257:	learn: 0.7315877	total: 2.6s	remaining: 7.48s
# 258:	learn: 0.7311445	total: 2.61s	remaining: 7.47s
# 259:	learn: 0.7306230	total: 2.62s	remaining: 7.47s
# 260:	learn: 0.7301237	total: 2.63s	remaining: 7.46s
# 261:	learn: 0.7295056	total: 2.64s	remaining: 7.45s
# 262:	learn: 0.7288185	total: 2.65s	remaining: 7.44s
# 263:	learn: 0.7285097	total: 2.66s	remaining: 7.43s
# 264:	learn: 0.7280060	total: 2.67s	remaining: 7.42s
# 265:	learn: 0.7275373	total: 2.68s	remaining: 7.41s
# 266:	learn: 0.7270395	total: 2.69s	remaining: 7.39s
# 267:	learn: 0.7263651	total: 2.7s	remaining: 7.38s
# 268:	learn: 0.7258223	total: 2.71s	remaining: 7.37s
# 269:	learn: 0.7253067	total: 2.72s	remaining: 7.36s
# 270:	learn: 0.7246018	total: 2.73s	remaining: 7.35s
# 271:	learn: 0.7239944	total: 2.74s	remaining: 7.34s
# 272:	learn: 0.7235785	total: 2.75s	remaining: 7.33s
# 273:	learn: 0.7231923	total: 2.76s	remaining: 7.32s
# 274:	learn: 0.7226830	total: 2.77s	remaining: 7.31s
# 275:	learn: 0.7221015	total: 2.78s	remaining: 7.3s
# 276:	learn: 0.7214697	total: 2.79s	remaining: 7.29s
# 277:	learn: 0.7210535	total: 2.8s	remaining: 7.28s
# 278:	learn: 0.7205675	total: 2.81s	remaining: 7.27s
# 279:	learn: 0.7197526	total: 2.82s	remaining: 7.26s
# 280:	learn: 0.7191990	total: 2.83s	remaining: 7.25s
# 281:	learn: 0.7184968	total: 2.84s	remaining: 7.24s
# 282:	learn: 0.7180801	total: 2.85s	remaining: 7.22s
# 283:	learn: 0.7176304	total: 2.86s	remaining: 7.21s
# 284:	learn: 0.7171614	total: 2.87s	remaining: 7.2s
# 285:	learn: 0.7167172	total: 2.88s	remaining: 7.19s
# 286:	learn: 0.7162405	total: 2.89s	remaining: 7.18s
# 287:	learn: 0.7157645	total: 2.9s	remaining: 7.17s
# 288:	learn: 0.7154976	total: 2.91s	remaining: 7.16s
# 289:	learn: 0.7150077	total: 2.92s	remaining: 7.14s
# 290:	learn: 0.7145714	total: 2.93s	remaining: 7.13s
# 291:	learn: 0.7140676	total: 2.94s	remaining: 7.12s
# 292:	learn: 0.7136264	total: 2.95s	remaining: 7.11s
# 293:	learn: 0.7130953	total: 2.96s	remaining: 7.1s
# 294:	learn: 0.7126306	total: 2.97s	remaining: 7.09s
# 295:	learn: 0.7122486	total: 2.98s	remaining: 7.08s
# 296:	learn: 0.7118875	total: 2.99s	remaining: 7.07s
# 297:	learn: 0.7114463	total: 3s	remaining: 7.06s
# 298:	learn: 0.7108035	total: 3.01s	remaining: 7.05s
# 299:	learn: 0.7103244	total: 3.02s	remaining: 7.04s
# 300:	learn: 0.7094977	total: 3.03s	remaining: 7.03s
# 301:	learn: 0.7088892	total: 3.04s	remaining: 7.02s
# 302:	learn: 0.7082467	total: 3.05s	remaining: 7.01s
# 303:	learn: 0.7079210	total: 3.06s	remaining: 7s
# 304:	learn: 0.7075843	total: 3.07s	remaining: 6.99s
# 305:	learn: 0.7071430	total: 3.08s	remaining: 6.98s
# 306:	learn: 0.7065351	total: 3.09s	remaining: 6.97s
# 307:	learn: 0.7060828	total: 3.1s	remaining: 6.96s
# 308:	learn: 0.7055088	total: 3.11s	remaining: 6.95s
# 309:	learn: 0.7049837	total: 3.12s	remaining: 6.94s
# 310:	learn: 0.7043199	total: 3.13s	remaining: 6.93s
# 311:	learn: 0.7037951	total: 3.14s	remaining: 6.92s
# 312:	learn: 0.7031242	total: 3.15s	remaining: 6.92s
# 313:	learn: 0.7026643	total: 3.16s	remaining: 6.91s
# 314:	learn: 0.7022075	total: 3.17s	remaining: 6.9s
# 315:	learn: 0.7016968	total: 3.18s	remaining: 6.89s
# 316:	learn: 0.7010838	total: 3.19s	remaining: 6.88s
# 317:	learn: 0.7006053	total: 3.2s	remaining: 6.87s
# 318:	learn: 0.7001559	total: 3.21s	remaining: 6.86s
# 319:	learn: 0.6995623	total: 3.22s	remaining: 6.84s
# 320:	learn: 0.6990384	total: 3.23s	remaining: 6.83s
# 321:	learn: 0.6984070	total: 3.24s	remaining: 6.83s
# 322:	learn: 0.6977585	total: 3.25s	remaining: 6.82s
# 323:	learn: 0.6973898	total: 3.26s	remaining: 6.81s
# 324:	learn: 0.6969350	total: 3.27s	remaining: 6.8s
# 325:	learn: 0.6965446	total: 3.28s	remaining: 6.79s
# 326:	learn: 0.6959912	total: 3.29s	remaining: 6.78s
# 327:	learn: 0.6957925	total: 3.3s	remaining: 6.77s
# 328:	learn: 0.6952323	total: 3.31s	remaining: 6.76s
# 329:	learn: 0.6947781	total: 3.32s	remaining: 6.75s
# 330:	learn: 0.6942747	total: 3.33s	remaining: 6.74s
# 331:	learn: 0.6938100	total: 3.34s	remaining: 6.73s
# 332:	learn: 0.6932510	total: 3.35s	remaining: 6.72s
# 333:	learn: 0.6927894	total: 3.36s	remaining: 6.71s
# 334:	learn: 0.6922042	total: 3.38s	remaining: 6.7s
# 335:	learn: 0.6918230	total: 3.38s	remaining: 6.69s
# 336:	learn: 0.6914612	total: 3.39s	remaining: 6.68s
# 337:	learn: 0.6907284	total: 3.4s	remaining: 6.67s
# 338:	learn: 0.6904191	total: 3.42s	remaining: 6.66s
# 339:	learn: 0.6899463	total: 3.42s	remaining: 6.65s
# 340:	learn: 0.6894930	total: 3.44s	remaining: 6.64s
# 341:	learn: 0.6889928	total: 3.45s	remaining: 6.63s
# 342:	learn: 0.6884614	total: 3.46s	remaining: 6.62s
# 343:	learn: 0.6879984	total: 3.47s	remaining: 6.61s
# 344:	learn: 0.6875204	total: 3.48s	remaining: 6.6s
# 345:	learn: 0.6869484	total: 3.49s	remaining: 6.59s
# 346:	learn: 0.6864804	total: 3.5s	remaining: 6.58s
# 347:	learn: 0.6860029	total: 3.51s	remaining: 6.57s
# 348:	learn: 0.6856403	total: 3.52s	remaining: 6.56s
# 349:	learn: 0.6850718	total: 3.53s	remaining: 6.55s
# 350:	learn: 0.6846352	total: 3.54s	remaining: 6.54s
# 351:	learn: 0.6842356	total: 3.55s	remaining: 6.53s
# 352:	learn: 0.6839373	total: 3.56s	remaining: 6.52s
# 353:	learn: 0.6832635	total: 3.57s	remaining: 6.51s
# 354:	learn: 0.6826502	total: 3.58s	remaining: 6.51s
# 355:	learn: 0.6820370	total: 3.59s	remaining: 6.5s
# 356:	learn: 0.6815443	total: 3.6s	remaining: 6.49s
# 357:	learn: 0.6811166	total: 3.61s	remaining: 6.48s
# 358:	learn: 0.6804986	total: 3.62s	remaining: 6.47s
# 359:	learn: 0.6799242	total: 3.63s	remaining: 6.46s
# 360:	learn: 0.6795196	total: 3.64s	remaining: 6.45s
# 361:	learn: 0.6790920	total: 3.65s	remaining: 6.44s
# 362:	learn: 0.6786953	total: 3.66s	remaining: 6.43s
# 363:	learn: 0.6781457	total: 3.67s	remaining: 6.42s
# 364:	learn: 0.6776795	total: 3.68s	remaining: 6.41s
# 365:	learn: 0.6770001	total: 3.69s	remaining: 6.4s
# 366:	learn: 0.6763764	total: 3.71s	remaining: 6.39s
# 367:	learn: 0.6759273	total: 3.71s	remaining: 6.38s
# 368:	learn: 0.6753315	total: 3.73s	remaining: 6.37s
# 369:	learn: 0.6750662	total: 3.73s	remaining: 6.36s
# 370:	learn: 0.6746193	total: 3.75s	remaining: 6.35s
# 371:	learn: 0.6741515	total: 3.75s	remaining: 6.34s
# 372:	learn: 0.6737364	total: 3.77s	remaining: 6.33s
# 373:	learn: 0.6732114	total: 3.78s	remaining: 6.32s
# 374:	learn: 0.6727620	total: 3.79s	remaining: 6.31s
# 375:	learn: 0.6722730	total: 3.8s	remaining: 6.3s
# 376:	learn: 0.6717244	total: 3.81s	remaining: 6.29s
# 377:	learn: 0.6712190	total: 3.82s	remaining: 6.28s
# 378:	learn: 0.6707880	total: 3.83s	remaining: 6.27s
# 379:	learn: 0.6702180	total: 3.84s	remaining: 6.26s
# 380:	learn: 0.6695367	total: 3.85s	remaining: 6.25s
# 381:	learn: 0.6690971	total: 3.86s	remaining: 6.24s
# 382:	learn: 0.6687917	total: 3.87s	remaining: 6.23s
# 383:	learn: 0.6682303	total: 3.88s	remaining: 6.22s
# 384:	learn: 0.6676539	total: 3.89s	remaining: 6.21s
# 385:	learn: 0.6671574	total: 3.9s	remaining: 6.2s
# 386:	learn: 0.6667317	total: 3.91s	remaining: 6.19s
# 387:	learn: 0.6662729	total: 3.92s	remaining: 6.18s
# 388:	learn: 0.6658425	total: 3.93s	remaining: 6.17s
# 389:	learn: 0.6652718	total: 3.94s	remaining: 6.16s
# 390:	learn: 0.6647163	total: 3.95s	remaining: 6.15s
# 391:	learn: 0.6642545	total: 3.96s	remaining: 6.14s
# 392:	learn: 0.6636918	total: 3.97s	remaining: 6.13s
# 393:	learn: 0.6633044	total: 3.98s	remaining: 6.12s
# 394:	learn: 0.6627357	total: 3.99s	remaining: 6.12s
# 395:	learn: 0.6621682	total: 4s	remaining: 6.1s
# 396:	learn: 0.6616926	total: 4.01s	remaining: 6.09s
# 397:	learn: 0.6610952	total: 4.02s	remaining: 6.08s
# 398:	learn: 0.6606009	total: 4.03s	remaining: 6.07s
# 399:	learn: 0.6602595	total: 4.04s	remaining: 6.06s
# 400:	learn: 0.6595544	total: 4.05s	remaining: 6.05s
# 401:	learn: 0.6591962	total: 4.06s	remaining: 6.04s
# 402:	learn: 0.6588862	total: 4.07s	remaining: 6.03s
# 403:	learn: 0.6584947	total: 4.08s	remaining: 6.02s
# 404:	learn: 0.6579446	total: 4.09s	remaining: 6.01s
# 405:	learn: 0.6575533	total: 4.1s	remaining: 6s
# 406:	learn: 0.6570575	total: 4.11s	remaining: 5.99s
# 407:	learn: 0.6567018	total: 4.12s	remaining: 5.98s
# 408:	learn: 0.6561727	total: 4.13s	remaining: 5.97s
# 409:	learn: 0.6556571	total: 4.14s	remaining: 5.96s
# 410:	learn: 0.6553831	total: 4.15s	remaining: 5.95s
# 411:	learn: 0.6551034	total: 4.16s	remaining: 5.94s
# 412:	learn: 0.6547187	total: 4.17s	remaining: 5.92s
# 413:	learn: 0.6543398	total: 4.18s	remaining: 5.91s
# 414:	learn: 0.6536738	total: 4.19s	remaining: 5.9s
# 415:	learn: 0.6532151	total: 4.2s	remaining: 5.89s
# 416:	learn: 0.6526770	total: 4.21s	remaining: 5.88s
# 417:	learn: 0.6523105	total: 4.22s	remaining: 5.87s
# 418:	learn: 0.6519083	total: 4.23s	remaining: 5.86s
# 419:	learn: 0.6516423	total: 4.24s	remaining: 5.85s
# 420:	learn: 0.6510061	total: 4.25s	remaining: 5.84s
# 421:	learn: 0.6506571	total: 4.26s	remaining: 5.83s
# 422:	learn: 0.6500725	total: 4.27s	remaining: 5.82s
# 423:	learn: 0.6495528	total: 4.28s	remaining: 5.81s
# 424:	learn: 0.6490880	total: 4.29s	remaining: 5.8s
# 425:	learn: 0.6484939	total: 4.3s	remaining: 5.79s
# 426:	learn: 0.6480342	total: 4.31s	remaining: 5.78s
# 427:	learn: 0.6475156	total: 4.32s	remaining: 5.77s
# 428:	learn: 0.6470587	total: 4.33s	remaining: 5.76s
# 429:	learn: 0.6465960	total: 4.34s	remaining: 5.75s
# 430:	learn: 0.6462564	total: 4.35s	remaining: 5.74s
# 431:	learn: 0.6459089	total: 4.36s	remaining: 5.73s
# 432:	learn: 0.6455567	total: 4.37s	remaining: 5.72s
# 433:	learn: 0.6450847	total: 4.38s	remaining: 5.71s
# 434:	learn: 0.6447260	total: 4.39s	remaining: 5.7s
# 435:	learn: 0.6443129	total: 4.4s	remaining: 5.69s
# 436:	learn: 0.6440277	total: 4.41s	remaining: 5.68s
# 437:	learn: 0.6435598	total: 4.42s	remaining: 5.67s
# 438:	learn: 0.6432059	total: 4.43s	remaining: 5.66s
# 439:	learn: 0.6426694	total: 4.44s	remaining: 5.65s
# 440:	learn: 0.6421937	total: 4.45s	remaining: 5.64s
# 441:	learn: 0.6418931	total: 4.46s	remaining: 5.63s
# 442:	learn: 0.6412948	total: 4.47s	remaining: 5.62s
# 443:	learn: 0.6409639	total: 4.48s	remaining: 5.61s
# 444:	learn: 0.6402694	total: 4.49s	remaining: 5.6s
# 445:	learn: 0.6397862	total: 4.5s	remaining: 5.59s
# 446:	learn: 0.6393561	total: 4.51s	remaining: 5.58s
# 447:	learn: 0.6389102	total: 4.52s	remaining: 5.58s
# 448:	learn: 0.6386725	total: 4.53s	remaining: 5.56s
# 449:	learn: 0.6382718	total: 4.54s	remaining: 5.55s
# 450:	learn: 0.6380265	total: 4.55s	remaining: 5.54s
# 451:	learn: 0.6378169	total: 4.56s	remaining: 5.53s
# 452:	learn: 0.6375318	total: 4.57s	remaining: 5.52s
# 453:	learn: 0.6371948	total: 4.58s	remaining: 5.51s
# 454:	learn: 0.6368274	total: 4.59s	remaining: 5.5s
# 455:	learn: 0.6362747	total: 4.6s	remaining: 5.49s
# 456:	learn: 0.6360425	total: 4.61s	remaining: 5.48s
# 457:	learn: 0.6356161	total: 4.62s	remaining: 5.47s
# 458:	learn: 0.6352067	total: 4.63s	remaining: 5.46s
# 459:	learn: 0.6348558	total: 4.64s	remaining: 5.45s
# 460:	learn: 0.6342987	total: 4.65s	remaining: 5.44s
# 461:	learn: 0.6340048	total: 4.66s	remaining: 5.43s
# 462:	learn: 0.6333928	total: 4.67s	remaining: 5.42s
# 463:	learn: 0.6331181	total: 4.68s	remaining: 5.41s
# 464:	learn: 0.6328216	total: 4.69s	remaining: 5.39s
# 465:	learn: 0.6324354	total: 4.7s	remaining: 5.38s
# 466:	learn: 0.6319962	total: 4.71s	remaining: 5.37s
# 467:	learn: 0.6315045	total: 4.72s	remaining: 5.36s
# 468:	learn: 0.6311343	total: 4.73s	remaining: 5.35s
# 469:	learn: 0.6306583	total: 4.74s	remaining: 5.34s
# 470:	learn: 0.6303058	total: 4.75s	remaining: 5.33s
# 471:	learn: 0.6296641	total: 4.76s	remaining: 5.32s
# 472:	learn: 0.6292786	total: 4.77s	remaining: 5.31s
# 473:	learn: 0.6289086	total: 4.78s	remaining: 5.3s
# 474:	learn: 0.6283580	total: 4.79s	remaining: 5.29s
# 475:	learn: 0.6278864	total: 4.8s	remaining: 5.28s
# 476:	learn: 0.6274685	total: 4.81s	remaining: 5.27s
# 477:	learn: 0.6269758	total: 4.82s	remaining: 5.26s
# 478:	learn: 0.6263988	total: 4.83s	remaining: 5.25s
# 479:	learn: 0.6259935	total: 4.84s	remaining: 5.24s
# 480:	learn: 0.6253678	total: 4.85s	remaining: 5.23s
# 481:	learn: 0.6249165	total: 4.86s	remaining: 5.22s
# 482:	learn: 0.6245112	total: 4.87s	remaining: 5.21s
# 483:	learn: 0.6240463	total: 4.88s	remaining: 5.2s
# 484:	learn: 0.6236006	total: 4.88s	remaining: 5.19s
# 485:	learn: 0.6231400	total: 4.9s	remaining: 5.18s
# 486:	learn: 0.6226957	total: 4.91s	remaining: 5.17s
# 487:	learn: 0.6223284	total: 4.92s	remaining: 5.16s
# 488:	learn: 0.6220698	total: 4.93s	remaining: 5.15s
# 489:	learn: 0.6217975	total: 4.94s	remaining: 5.14s
# 490:	learn: 0.6213955	total: 4.95s	remaining: 5.13s
# 491:	learn: 0.6211437	total: 4.96s	remaining: 5.12s
# 492:	learn: 0.6207041	total: 4.97s	remaining: 5.11s
# 493:	learn: 0.6204136	total: 4.98s	remaining: 5.1s
# 494:	learn: 0.6199787	total: 4.99s	remaining: 5.09s
# 495:	learn: 0.6194549	total: 5s	remaining: 5.08s
# 496:	learn: 0.6191356	total: 5.01s	remaining: 5.07s
# 497:	learn: 0.6188542	total: 5.02s	remaining: 5.06s
# 498:	learn: 0.6185221	total: 5.03s	remaining: 5.05s
# 499:	learn: 0.6181287	total: 5.04s	remaining: 5.04s
# 500:	learn: 0.6177127	total: 5.05s	remaining: 5.03s
# 501:	learn: 0.6172471	total: 5.06s	remaining: 5.02s
# 502:	learn: 0.6168792	total: 5.07s	remaining: 5.01s
# 503:	learn: 0.6163970	total: 5.08s	remaining: 5s
# 504:	learn: 0.6160705	total: 5.09s	remaining: 4.99s
# 505:	learn: 0.6157130	total: 5.1s	remaining: 4.98s
# 506:	learn: 0.6154622	total: 5.11s	remaining: 4.97s
# 507:	learn: 0.6151401	total: 5.12s	remaining: 4.96s
# 508:	learn: 0.6149050	total: 5.13s	remaining: 4.95s
# 509:	learn: 0.6144599	total: 5.14s	remaining: 4.93s
# 510:	learn: 0.6140684	total: 5.15s	remaining: 4.92s
# 511:	learn: 0.6136999	total: 5.16s	remaining: 4.91s
# 512:	learn: 0.6133265	total: 5.17s	remaining: 4.9s
# 513:	learn: 0.6128078	total: 5.18s	remaining: 4.89s
# 514:	learn: 0.6122844	total: 5.19s	remaining: 4.88s
# 515:	learn: 0.6120317	total: 5.2s	remaining: 4.87s
# 516:	learn: 0.6117575	total: 5.21s	remaining: 4.86s
# 517:	learn: 0.6113082	total: 5.22s	remaining: 4.85s
# 518:	learn: 0.6108275	total: 5.23s	remaining: 4.84s
# 519:	learn: 0.6103843	total: 5.24s	remaining: 4.83s
# 520:	learn: 0.6099902	total: 5.25s	remaining: 4.82s
# 521:	learn: 0.6093262	total: 5.26s	remaining: 4.81s
# 522:	learn: 0.6089588	total: 5.27s	remaining: 4.8s
# 523:	learn: 0.6086656	total: 5.28s	remaining: 4.79s
# 524:	learn: 0.6083432	total: 5.29s	remaining: 4.78s
# 525:	learn: 0.6079689	total: 5.3s	remaining: 4.77s
# 526:	learn: 0.6075858	total: 5.31s	remaining: 4.76s
# 527:	learn: 0.6072352	total: 5.32s	remaining: 4.75s
# 528:	learn: 0.6066957	total: 5.33s	remaining: 4.74s
# 529:	learn: 0.6063060	total: 5.34s	remaining: 4.73s
# 530:	learn: 0.6059395	total: 5.35s	remaining: 4.72s
# 531:	learn: 0.6054574	total: 5.36s	remaining: 4.71s
# 532:	learn: 0.6052024	total: 5.37s	remaining: 4.7s
# 533:	learn: 0.6047701	total: 5.38s	remaining: 4.69s
# 534:	learn: 0.6045637	total: 5.39s	remaining: 4.68s
# 535:	learn: 0.6042115	total: 5.4s	remaining: 4.67s
# 536:	learn: 0.6038094	total: 5.41s	remaining: 4.66s
# 537:	learn: 0.6031987	total: 5.42s	remaining: 4.65s
# 538:	learn: 0.6026939	total: 5.43s	remaining: 4.64s
# 539:	learn: 0.6020757	total: 5.44s	remaining: 4.63s
# 540:	learn: 0.6015265	total: 5.45s	remaining: 4.62s
# 541:	learn: 0.6012312	total: 5.46s	remaining: 4.61s
# 542:	learn: 0.6007782	total: 5.47s	remaining: 4.6s
# 543:	learn: 0.6003394	total: 5.48s	remaining: 4.59s
# 544:	learn: 0.6000224	total: 5.49s	remaining: 4.58s
# 545:	learn: 0.5997081	total: 5.5s	remaining: 4.57s
# 546:	learn: 0.5993120	total: 5.51s	remaining: 4.56s
# 547:	learn: 0.5988767	total: 5.52s	remaining: 4.55s
# 548:	learn: 0.5983833	total: 5.53s	remaining: 4.54s
# 549:	learn: 0.5978962	total: 5.54s	remaining: 4.53s
# 550:	learn: 0.5974343	total: 5.55s	remaining: 4.52s
# 551:	learn: 0.5970867	total: 5.56s	remaining: 4.51s
# 552:	learn: 0.5967594	total: 5.57s	remaining: 4.5s
# 553:	learn: 0.5963093	total: 5.58s	remaining: 4.49s
# 554:	learn: 0.5959269	total: 5.59s	remaining: 4.49s
# 555:	learn: 0.5955666	total: 5.6s	remaining: 4.47s
# 556:	learn: 0.5952219	total: 5.61s	remaining: 4.46s
# 557:	learn: 0.5947077	total: 5.62s	remaining: 4.45s
# 558:	learn: 0.5943115	total: 5.63s	remaining: 4.44s
# 559:	learn: 0.5938388	total: 5.64s	remaining: 4.43s
# 560:	learn: 0.5935645	total: 5.65s	remaining: 4.42s
# 561:	learn: 0.5931810	total: 5.66s	remaining: 4.41s
# 562:	learn: 0.5928751	total: 5.67s	remaining: 4.4s
# 563:	learn: 0.5925289	total: 5.68s	remaining: 4.39s
# 564:	learn: 0.5921487	total: 5.69s	remaining: 4.38s
# 565:	learn: 0.5918936	total: 5.7s	remaining: 4.37s
# 566:	learn: 0.5914168	total: 5.71s	remaining: 4.36s
# 567:	learn: 0.5909463	total: 5.72s	remaining: 4.35s
# 568:	learn: 0.5905624	total: 5.74s	remaining: 4.34s
# 569:	learn: 0.5900917	total: 5.75s	remaining: 4.33s
# 570:	learn: 0.5896881	total: 5.76s	remaining: 4.32s
# 571:	learn: 0.5893391	total: 5.77s	remaining: 4.32s
# 572:	learn: 0.5890394	total: 5.78s	remaining: 4.3s
# 573:	learn: 0.5887965	total: 5.79s	remaining: 4.29s
# 574:	learn: 0.5884419	total: 5.8s	remaining: 4.29s
# 575:	learn: 0.5878130	total: 5.81s	remaining: 4.28s
# 576:	learn: 0.5875609	total: 5.82s	remaining: 4.26s
# 577:	learn: 0.5872644	total: 5.83s	remaining: 4.26s
# 578:	learn: 0.5866359	total: 5.84s	remaining: 4.25s
# 579:	learn: 0.5863460	total: 5.85s	remaining: 4.24s
# 580:	learn: 0.5860932	total: 5.86s	remaining: 4.23s
# 581:	learn: 0.5856535	total: 5.87s	remaining: 4.21s
# 582:	learn: 0.5852695	total: 5.88s	remaining: 4.21s
# 583:	learn: 0.5848219	total: 5.89s	remaining: 4.2s
# 584:	learn: 0.5844423	total: 5.9s	remaining: 4.18s
# 585:	learn: 0.5840310	total: 5.91s	remaining: 4.17s
# 586:	learn: 0.5837485	total: 5.92s	remaining: 4.16s
# 587:	learn: 0.5832105	total: 5.93s	remaining: 4.15s
# 588:	learn: 0.5828427	total: 5.94s	remaining: 4.14s
# 589:	learn: 0.5825558	total: 5.95s	remaining: 4.13s
# 590:	learn: 0.5822733	total: 5.96s	remaining: 4.12s
# 591:	learn: 0.5818871	total: 5.97s	remaining: 4.11s
# 592:	learn: 0.5814183	total: 5.98s	remaining: 4.1s
# 593:	learn: 0.5808320	total: 5.99s	remaining: 4.09s
# 594:	learn: 0.5803823	total: 6s	remaining: 4.08s
# 595:	learn: 0.5800803	total: 6.01s	remaining: 4.07s
# 596:	learn: 0.5796987	total: 6.02s	remaining: 4.06s
# 597:	learn: 0.5791620	total: 6.03s	remaining: 4.05s
# 598:	learn: 0.5787983	total: 6.04s	remaining: 4.04s
# 599:	learn: 0.5783029	total: 6.04s	remaining: 4.03s
# 600:	learn: 0.5778241	total: 6.05s	remaining: 4.02s
# 601:	learn: 0.5773894	total: 6.07s	remaining: 4.01s
# 602:	learn: 0.5770249	total: 6.08s	remaining: 4s
# 603:	learn: 0.5766231	total: 6.08s	remaining: 3.99s
# 604:	learn: 0.5763394	total: 6.09s	remaining: 3.98s
# 605:	learn: 0.5757989	total: 6.1s	remaining: 3.97s
# 606:	learn: 0.5753990	total: 6.11s	remaining: 3.96s
# 607:	learn: 0.5750668	total: 6.12s	remaining: 3.95s
# 608:	learn: 0.5747258	total: 6.13s	remaining: 3.94s
# 609:	learn: 0.5741910	total: 6.14s	remaining: 3.93s
# 610:	learn: 0.5737386	total: 6.15s	remaining: 3.92s
# 611:	learn: 0.5733912	total: 6.16s	remaining: 3.91s
# 612:	learn: 0.5730753	total: 6.17s	remaining: 3.9s
# 613:	learn: 0.5726238	total: 6.18s	remaining: 3.89s
# 614:	learn: 0.5722747	total: 6.19s	remaining: 3.88s
# 615:	learn: 0.5719881	total: 6.2s	remaining: 3.87s
# 616:	learn: 0.5715594	total: 6.21s	remaining: 3.85s
# 617:	learn: 0.5711691	total: 6.22s	remaining: 3.84s
# 618:	learn: 0.5709126	total: 6.23s	remaining: 3.83s
# 619:	learn: 0.5705937	total: 6.24s	remaining: 3.82s
# 620:	learn: 0.5702076	total: 6.25s	remaining: 3.81s
# 621:	learn: 0.5699402	total: 6.26s	remaining: 3.8s
# 622:	learn: 0.5695357	total: 6.27s	remaining: 3.79s
# 623:	learn: 0.5689825	total: 6.28s	remaining: 3.78s
# 624:	learn: 0.5686990	total: 6.29s	remaining: 3.77s
# 625:	learn: 0.5683842	total: 6.29s	remaining: 3.76s
# 626:	learn: 0.5678506	total: 6.3s	remaining: 3.75s
# 627:	learn: 0.5673711	total: 6.31s	remaining: 3.74s
# 628:	learn: 0.5670750	total: 6.32s	remaining: 3.73s
# 629:	learn: 0.5666016	total: 6.33s	remaining: 3.72s
# 630:	learn: 0.5661150	total: 6.34s	remaining: 3.71s
# 631:	learn: 0.5658160	total: 6.35s	remaining: 3.7s
# 632:	learn: 0.5654856	total: 6.36s	remaining: 3.69s
# 633:	learn: 0.5649404	total: 6.37s	remaining: 3.68s
# 634:	learn: 0.5644338	total: 6.38s	remaining: 3.67s
# 635:	learn: 0.5640809	total: 6.39s	remaining: 3.66s
# 636:	learn: 0.5637060	total: 6.4s	remaining: 3.65s
# 637:	learn: 0.5634115	total: 6.41s	remaining: 3.64s
# 638:	learn: 0.5630185	total: 6.42s	remaining: 3.63s
# 639:	learn: 0.5626601	total: 6.43s	remaining: 3.62s
# 640:	learn: 0.5623608	total: 6.44s	remaining: 3.61s
# 641:	learn: 0.5619885	total: 6.45s	remaining: 3.6s
# 642:	learn: 0.5616858	total: 6.46s	remaining: 3.59s
# 643:	learn: 0.5612399	total: 6.47s	remaining: 3.58s
# 644:	learn: 0.5609394	total: 6.48s	remaining: 3.57s
# 645:	learn: 0.5606472	total: 6.49s	remaining: 3.56s
# 646:	learn: 0.5603841	total: 6.5s	remaining: 3.55s
# 647:	learn: 0.5599585	total: 6.51s	remaining: 3.54s
# 648:	learn: 0.5594907	total: 6.52s	remaining: 3.53s
# 649:	learn: 0.5590962	total: 6.53s	remaining: 3.52s
# 650:	learn: 0.5588166	total: 6.54s	remaining: 3.51s
# 651:	learn: 0.5584544	total: 6.55s	remaining: 3.5s
# 652:	learn: 0.5578942	total: 6.56s	remaining: 3.49s
# 653:	learn: 0.5576066	total: 6.57s	remaining: 3.48s
# 654:	learn: 0.5571487	total: 6.58s	remaining: 3.47s
# 655:	learn: 0.5567586	total: 6.6s	remaining: 3.46s
# 656:	learn: 0.5564757	total: 6.61s	remaining: 3.45s
# 657:	learn: 0.5562334	total: 6.62s	remaining: 3.44s
# 658:	learn: 0.5558406	total: 6.63s	remaining: 3.43s
# 659:	learn: 0.5555623	total: 6.63s	remaining: 3.42s
# 660:	learn: 0.5551914	total: 6.64s	remaining: 3.41s
# 661:	learn: 0.5548657	total: 6.65s	remaining: 3.4s
# 662:	learn: 0.5545660	total: 6.66s	remaining: 3.39s
# 663:	learn: 0.5542965	total: 6.67s	remaining: 3.38s
# 664:	learn: 0.5539417	total: 6.68s	remaining: 3.37s
# 665:	learn: 0.5537202	total: 6.69s	remaining: 3.36s
# 666:	learn: 0.5533186	total: 6.7s	remaining: 3.35s
# 667:	learn: 0.5527860	total: 6.71s	remaining: 3.34s
# 668:	learn: 0.5523858	total: 6.72s	remaining: 3.33s
# 669:	learn: 0.5518689	total: 6.73s	remaining: 3.32s
# 670:	learn: 0.5515732	total: 6.74s	remaining: 3.31s
# 671:	learn: 0.5511071	total: 6.75s	remaining: 3.3s
# 672:	learn: 0.5507538	total: 6.76s	remaining: 3.29s
# 673:	learn: 0.5505242	total: 6.77s	remaining: 3.27s
# 674:	learn: 0.5500658	total: 6.78s	remaining: 3.27s
# 675:	learn: 0.5498215	total: 6.79s	remaining: 3.25s
# 676:	learn: 0.5494877	total: 6.8s	remaining: 3.24s
# 677:	learn: 0.5491105	total: 6.81s	remaining: 3.23s
# 678:	learn: 0.5489180	total: 6.82s	remaining: 3.22s
# 679:	learn: 0.5485264	total: 6.83s	remaining: 3.21s
# 680:	learn: 0.5480348	total: 6.84s	remaining: 3.2s
# 681:	learn: 0.5476068	total: 6.85s	remaining: 3.19s
# 682:	learn: 0.5472412	total: 6.86s	remaining: 3.18s
# 683:	learn: 0.5468340	total: 6.87s	remaining: 3.17s
# 684:	learn: 0.5463468	total: 6.88s	remaining: 3.16s
# 685:	learn: 0.5460499	total: 6.89s	remaining: 3.15s
# 686:	learn: 0.5457592	total: 6.9s	remaining: 3.14s
# 687:	learn: 0.5452296	total: 6.91s	remaining: 3.13s
# 688:	learn: 0.5448307	total: 6.92s	remaining: 3.12s
# 689:	learn: 0.5442661	total: 6.93s	remaining: 3.11s
# 690:	learn: 0.5438675	total: 6.94s	remaining: 3.1s
# 691:	learn: 0.5435734	total: 6.95s	remaining: 3.09s
# 692:	learn: 0.5432627	total: 6.96s	remaining: 3.08s
# 693:	learn: 0.5428059	total: 6.97s	remaining: 3.07s
# 694:	learn: 0.5425075	total: 6.98s	remaining: 3.06s
# 695:	learn: 0.5419965	total: 6.99s	remaining: 3.05s
# 696:	learn: 0.5416535	total: 7s	remaining: 3.04s
# 697:	learn: 0.5412244	total: 7.01s	remaining: 3.03s
# 698:	learn: 0.5408503	total: 7.02s	remaining: 3.02s
# 699:	learn: 0.5404973	total: 7.03s	remaining: 3.01s
# 700:	learn: 0.5400401	total: 7.04s	remaining: 3s
# 701:	learn: 0.5398175	total: 7.04s	remaining: 2.99s
# 702:	learn: 0.5393956	total: 7.05s	remaining: 2.98s
# 703:	learn: 0.5390574	total: 7.06s	remaining: 2.97s
# 704:	learn: 0.5386294	total: 7.08s	remaining: 2.96s
# 705:	learn: 0.5382947	total: 7.08s	remaining: 2.95s
# 706:	learn: 0.5379302	total: 7.1s	remaining: 2.94s
# 707:	learn: 0.5376525	total: 7.11s	remaining: 2.93s
# 708:	learn: 0.5373282	total: 7.12s	remaining: 2.92s
# 709:	learn: 0.5369232	total: 7.13s	remaining: 2.91s
# 710:	learn: 0.5367150	total: 7.13s	remaining: 2.9s
# 711:	learn: 0.5361539	total: 7.14s	remaining: 2.89s
# 712:	learn: 0.5358324	total: 7.16s	remaining: 2.88s
# 713:	learn: 0.5356036	total: 7.16s	remaining: 2.87s
# 714:	learn: 0.5353577	total: 7.17s	remaining: 2.86s
# 715:	learn: 0.5351337	total: 7.18s	remaining: 2.85s
# 716:	learn: 0.5349147	total: 7.19s	remaining: 2.84s
# 717:	learn: 0.5344917	total: 7.2s	remaining: 2.83s
# 718:	learn: 0.5339907	total: 7.21s	remaining: 2.82s
# 719:	learn: 0.5337425	total: 7.22s	remaining: 2.81s
# 720:	learn: 0.5333498	total: 7.23s	remaining: 2.8s
# 721:	learn: 0.5330136	total: 7.25s	remaining: 2.79s
# 722:	learn: 0.5325754	total: 7.25s	remaining: 2.78s
# 723:	learn: 0.5322367	total: 7.26s	remaining: 2.77s
# 724:	learn: 0.5320473	total: 7.28s	remaining: 2.76s
# 725:	learn: 0.5317452	total: 7.29s	remaining: 2.75s
# 726:	learn: 0.5312230	total: 7.29s	remaining: 2.74s
# 727:	learn: 0.5309138	total: 7.31s	remaining: 2.73s
# 728:	learn: 0.5305749	total: 7.32s	remaining: 2.72s
# 729:	learn: 0.5301109	total: 7.33s	remaining: 2.71s
# 730:	learn: 0.5298124	total: 7.34s	remaining: 2.7s
# 731:	learn: 0.5293800	total: 7.35s	remaining: 2.69s
# 732:	learn: 0.5289932	total: 7.36s	remaining: 2.68s
# 733:	learn: 0.5287215	total: 7.37s	remaining: 2.67s
# 734:	learn: 0.5282810	total: 7.38s	remaining: 2.66s
# 735:	learn: 0.5280279	total: 7.39s	remaining: 2.65s
# 736:	learn: 0.5276904	total: 7.39s	remaining: 2.64s
# 737:	learn: 0.5274678	total: 7.4s	remaining: 2.63s
# 738:	learn: 0.5271758	total: 7.41s	remaining: 2.62s
# 739:	learn: 0.5268166	total: 7.42s	remaining: 2.61s
# 740:	learn: 0.5264601	total: 7.43s	remaining: 2.6s
# 741:	learn: 0.5261681	total: 7.44s	remaining: 2.59s
# 742:	learn: 0.5257537	total: 7.45s	remaining: 2.58s
# 743:	learn: 0.5254890	total: 7.46s	remaining: 2.57s
# 744:	learn: 0.5252491	total: 7.47s	remaining: 2.56s
# 745:	learn: 0.5248840	total: 7.48s	remaining: 2.55s
# 746:	learn: 0.5246964	total: 7.49s	remaining: 2.54s
# 747:	learn: 0.5244578	total: 7.5s	remaining: 2.53s
# 748:	learn: 0.5242462	total: 7.51s	remaining: 2.52s
# 749:	learn: 0.5238841	total: 7.53s	remaining: 2.51s
# 750:	learn: 0.5233700	total: 7.54s	remaining: 2.5s
# 751:	learn: 0.5230085	total: 7.55s	remaining: 2.49s
# 752:	learn: 0.5227112	total: 7.56s	remaining: 2.48s
# 753:	learn: 0.5222890	total: 7.57s	remaining: 2.47s
# 754:	learn: 0.5220649	total: 7.58s	remaining: 2.46s
# 755:	learn: 0.5218013	total: 7.59s	remaining: 2.45s
# 756:	learn: 0.5214991	total: 7.6s	remaining: 2.44s
# 757:	learn: 0.5211691	total: 7.61s	remaining: 2.43s
# 758:	learn: 0.5207389	total: 7.62s	remaining: 2.42s
# 759:	learn: 0.5204901	total: 7.63s	remaining: 2.41s
# 760:	learn: 0.5202191	total: 7.64s	remaining: 2.4s
# 761:	learn: 0.5199200	total: 7.65s	remaining: 2.39s
# 762:	learn: 0.5195658	total: 7.66s	remaining: 2.38s
# 763:	learn: 0.5192376	total: 7.67s	remaining: 2.37s
# 764:	learn: 0.5188178	total: 7.68s	remaining: 2.36s
# 765:	learn: 0.5185790	total: 7.69s	remaining: 2.35s
# 766:	learn: 0.5181254	total: 7.7s	remaining: 2.34s
# 767:	learn: 0.5176996	total: 7.71s	remaining: 2.33s
# 768:	learn: 0.5174075	total: 7.72s	remaining: 2.32s
# 769:	learn: 0.5171949	total: 7.73s	remaining: 2.31s
# 770:	learn: 0.5168955	total: 7.74s	remaining: 2.3s
# 771:	learn: 0.5165141	total: 7.75s	remaining: 2.29s
# 772:	learn: 0.5161796	total: 7.76s	remaining: 2.28s
# 773:	learn: 0.5159634	total: 7.77s	remaining: 2.27s
# 774:	learn: 0.5156731	total: 7.78s	remaining: 2.26s
# 775:	learn: 0.5153640	total: 7.79s	remaining: 2.25s
# 776:	learn: 0.5151053	total: 7.8s	remaining: 2.24s
# 777:	learn: 0.5147606	total: 7.81s	remaining: 2.23s
# 778:	learn: 0.5144535	total: 7.82s	remaining: 2.22s
# 779:	learn: 0.5140725	total: 7.83s	remaining: 2.21s
# 780:	learn: 0.5138795	total: 7.84s	remaining: 2.2s
# 781:	learn: 0.5136502	total: 7.85s	remaining: 2.19s
# 782:	learn: 0.5132276	total: 7.86s	remaining: 2.18s
# 783:	learn: 0.5129044	total: 7.88s	remaining: 2.17s
# 784:	learn: 0.5127068	total: 7.88s	remaining: 2.16s
# 785:	learn: 0.5123145	total: 7.89s	remaining: 2.15s
# 786:	learn: 0.5120057	total: 7.91s	remaining: 2.14s
# 787:	learn: 0.5116809	total: 7.92s	remaining: 2.13s
# 788:	learn: 0.5114648	total: 7.92s	remaining: 2.12s
# 789:	learn: 0.5111367	total: 7.93s	remaining: 2.11s
# 790:	learn: 0.5107869	total: 7.94s	remaining: 2.1s
# 791:	learn: 0.5104903	total: 7.95s	remaining: 2.09s
# 792:	learn: 0.5101474	total: 7.96s	remaining: 2.08s
# 793:	learn: 0.5099177	total: 7.97s	remaining: 2.07s
# 794:	learn: 0.5096004	total: 7.98s	remaining: 2.06s
# 795:	learn: 0.5090685	total: 8s	remaining: 2.05s
# 796:	learn: 0.5088331	total: 8s	remaining: 2.04s
# 797:	learn: 0.5083173	total: 8.02s	remaining: 2.03s
# 798:	learn: 0.5080272	total: 8.03s	remaining: 2.02s
# 799:	learn: 0.5077402	total: 8.04s	remaining: 2.01s
# 800:	learn: 0.5073615	total: 8.05s	remaining: 2s
# 801:	learn: 0.5069579	total: 8.06s	remaining: 1.99s
# 802:	learn: 0.5066328	total: 8.07s	remaining: 1.98s
# 803:	learn: 0.5063118	total: 8.08s	remaining: 1.97s
# 804:	learn: 0.5060898	total: 8.09s	remaining: 1.96s
# 805:	learn: 0.5057124	total: 8.1s	remaining: 1.95s
# 806:	learn: 0.5053884	total: 8.11s	remaining: 1.94s
# 807:	learn: 0.5051704	total: 8.12s	remaining: 1.93s
# 808:	learn: 0.5049395	total: 8.13s	remaining: 1.92s
# 809:	learn: 0.5046275	total: 8.14s	remaining: 1.91s
# 810:	learn: 0.5043515	total: 8.15s	remaining: 1.9s
# 811:	learn: 0.5040358	total: 8.16s	remaining: 1.89s
# 812:	learn: 0.5037720	total: 8.17s	remaining: 1.88s
# 813:	learn: 0.5032825	total: 8.18s	remaining: 1.87s
# 814:	learn: 0.5030603	total: 8.19s	remaining: 1.86s
# 815:	learn: 0.5028392	total: 8.2s	remaining: 1.85s
# 816:	learn: 0.5024074	total: 8.21s	remaining: 1.84s
# 817:	learn: 0.5021896	total: 8.22s	remaining: 1.83s
# 818:	learn: 0.5019071	total: 8.23s	remaining: 1.82s
# 819:	learn: 0.5016163	total: 8.24s	remaining: 1.81s
# 820:	learn: 0.5013334	total: 8.25s	remaining: 1.8s
# 821:	learn: 0.5011719	total: 8.26s	remaining: 1.79s
# 822:	learn: 0.5008514	total: 8.27s	remaining: 1.78s
# 823:	learn: 0.5004655	total: 8.28s	remaining: 1.77s
# 824:	learn: 0.5001752	total: 8.3s	remaining: 1.76s
# 825:	learn: 0.4998240	total: 8.31s	remaining: 1.75s
# 826:	learn: 0.4994861	total: 8.32s	remaining: 1.74s
# 827:	learn: 0.4992331	total: 8.34s	remaining: 1.73s
# 828:	learn: 0.4988845	total: 8.35s	remaining: 1.72s
# 829:	learn: 0.4984764	total: 8.36s	remaining: 1.71s
# 830:	learn: 0.4981127	total: 8.37s	remaining: 1.7s
# 831:	learn: 0.4977455	total: 8.38s	remaining: 1.69s
# 832:	learn: 0.4973409	total: 8.39s	remaining: 1.68s
# 833:	learn: 0.4968968	total: 8.4s	remaining: 1.67s
# 834:	learn: 0.4966947	total: 8.41s	remaining: 1.66s
# 835:	learn: 0.4964983	total: 8.42s	remaining: 1.65s
# 836:	learn: 0.4960740	total: 8.43s	remaining: 1.64s
# 837:	learn: 0.4956932	total: 8.44s	remaining: 1.63s
# 838:	learn: 0.4953833	total: 8.45s	remaining: 1.62s
# 839:	learn: 0.4949701	total: 8.46s	remaining: 1.61s
# 840:	learn: 0.4944661	total: 8.47s	remaining: 1.6s
# 841:	learn: 0.4941634	total: 8.48s	remaining: 1.59s
# 842:	learn: 0.4938826	total: 8.49s	remaining: 1.58s
# 843:	learn: 0.4937070	total: 8.5s	remaining: 1.57s
# 844:	learn: 0.4934209	total: 8.51s	remaining: 1.56s
# 845:	learn: 0.4930879	total: 8.52s	remaining: 1.55s
# 846:	learn: 0.4926713	total: 8.53s	remaining: 1.54s
# 847:	learn: 0.4924329	total: 8.54s	remaining: 1.53s
# 848:	learn: 0.4919739	total: 8.55s	remaining: 1.52s
# 849:	learn: 0.4916840	total: 8.56s	remaining: 1.51s
# 850:	learn: 0.4913651	total: 8.57s	remaining: 1.5s
# 851:	learn: 0.4911215	total: 8.58s	remaining: 1.49s
# 852:	learn: 0.4908668	total: 8.59s	remaining: 1.48s
# 853:	learn: 0.4905983	total: 8.6s	remaining: 1.47s
# 854:	learn: 0.4902440	total: 8.61s	remaining: 1.46s
# 855:	learn: 0.4900386	total: 8.62s	remaining: 1.45s
# 856:	learn: 0.4897773	total: 8.63s	remaining: 1.44s
# 857:	learn: 0.4895332	total: 8.64s	remaining: 1.43s
# 858:	learn: 0.4892565	total: 8.65s	remaining: 1.42s
# 859:	learn: 0.4888372	total: 8.66s	remaining: 1.41s
# 860:	learn: 0.4884742	total: 8.67s	remaining: 1.4s
# 861:	learn: 0.4881212	total: 8.68s	remaining: 1.39s
# 862:	learn: 0.4877875	total: 8.69s	remaining: 1.38s
# 863:	learn: 0.4875402	total: 8.7s	remaining: 1.37s
# 864:	learn: 0.4871450	total: 8.71s	remaining: 1.36s
# 865:	learn: 0.4867460	total: 8.72s	remaining: 1.35s
# 866:	learn: 0.4863233	total: 8.73s	remaining: 1.34s
# 867:	learn: 0.4859460	total: 8.74s	remaining: 1.33s
# 868:	learn: 0.4857104	total: 8.75s	remaining: 1.32s
# 869:	learn: 0.4853805	total: 8.76s	remaining: 1.31s
# 870:	learn: 0.4849945	total: 8.77s	remaining: 1.3s
# 871:	learn: 0.4847217	total: 8.78s	remaining: 1.29s
# 872:	learn: 0.4844679	total: 8.79s	remaining: 1.28s
# 873:	learn: 0.4843210	total: 8.8s	remaining: 1.27s
# 874:	learn: 0.4840484	total: 8.81s	remaining: 1.26s
# 875:	learn: 0.4836902	total: 8.82s	remaining: 1.25s
# 876:	learn: 0.4835923	total: 8.83s	remaining: 1.24s
# 877:	learn: 0.4832211	total: 8.84s	remaining: 1.23s
# 878:	learn: 0.4829033	total: 8.85s	remaining: 1.22s
# 879:	learn: 0.4823877	total: 8.86s	remaining: 1.21s
# 880:	learn: 0.4821469	total: 8.87s	remaining: 1.2s
# 881:	learn: 0.4819286	total: 8.88s	remaining: 1.19s
# 882:	learn: 0.4816957	total: 8.89s	remaining: 1.18s
# 883:	learn: 0.4813146	total: 8.9s	remaining: 1.17s
# 884:	learn: 0.4810812	total: 8.91s	remaining: 1.16s
# 885:	learn: 0.4807992	total: 8.93s	remaining: 1.15s
# 886:	learn: 0.4806235	total: 8.93s	remaining: 1.14s
# 887:	learn: 0.4801686	total: 8.94s	remaining: 1.13s
# 888:	learn: 0.4799164	total: 8.95s	remaining: 1.12s
# 889:	learn: 0.4796234	total: 8.96s	remaining: 1.11s
# 890:	learn: 0.4791264	total: 8.97s	remaining: 1.1s
# 891:	learn: 0.4787999	total: 8.99s	remaining: 1.09s
# 892:	learn: 0.4785605	total: 9s	remaining: 1.08s
# 893:	learn: 0.4783210	total: 9.01s	remaining: 1.07s
# 894:	learn: 0.4780770	total: 9.02s	remaining: 1.06s
# 895:	learn: 0.4776533	total: 9.03s	remaining: 1.05s
# 896:	learn: 0.4773584	total: 9.04s	remaining: 1.04s
# 897:	learn: 0.4770689	total: 9.05s	remaining: 1.03s
# 898:	learn: 0.4768533	total: 9.06s	remaining: 1.02s
# 899:	learn: 0.4764955	total: 9.07s	remaining: 1.01s
# 900:	learn: 0.4762016	total: 9.08s	remaining: 998ms
# 901:	learn: 0.4758626	total: 9.09s	remaining: 988ms
# 902:	learn: 0.4756168	total: 9.1s	remaining: 978ms
# 903:	learn: 0.4752306	total: 9.11s	remaining: 968ms
# 904:	learn: 0.4748836	total: 9.12s	remaining: 958ms
# 905:	learn: 0.4745451	total: 9.13s	remaining: 947ms
# 906:	learn: 0.4743022	total: 9.14s	remaining: 937ms
# 907:	learn: 0.4740488	total: 9.15s	remaining: 927ms
# 908:	learn: 0.4738774	total: 9.16s	remaining: 917ms
# 909:	learn: 0.4734843	total: 9.17s	remaining: 907ms
# 910:	learn: 0.4731619	total: 9.18s	remaining: 897ms
# 911:	learn: 0.4729559	total: 9.19s	remaining: 887ms
# 912:	learn: 0.4726627	total: 9.2s	remaining: 877ms
# 913:	learn: 0.4722764	total: 9.21s	remaining: 867ms
# 914:	learn: 0.4719632	total: 9.22s	remaining: 857ms
# 915:	learn: 0.4717784	total: 9.23s	remaining: 847ms
# 916:	learn: 0.4714251	total: 9.24s	remaining: 837ms
# 917:	learn: 0.4711240	total: 9.26s	remaining: 827ms
# 918:	learn: 0.4708680	total: 9.27s	remaining: 817ms
# 919:	learn: 0.4704457	total: 9.28s	remaining: 807ms
# 920:	learn: 0.4702861	total: 9.29s	remaining: 796ms
# 921:	learn: 0.4700027	total: 9.29s	remaining: 786ms
# 922:	learn: 0.4697373	total: 9.31s	remaining: 776ms
# 923:	learn: 0.4694997	total: 9.32s	remaining: 766ms
# 924:	learn: 0.4691215	total: 9.33s	remaining: 756ms
# 925:	learn: 0.4688064	total: 9.34s	remaining: 746ms
# 926:	learn: 0.4685226	total: 9.35s	remaining: 736ms
# 927:	learn: 0.4683102	total: 9.36s	remaining: 726ms
# 928:	learn: 0.4679749	total: 9.37s	remaining: 716ms
# 929:	learn: 0.4677126	total: 9.38s	remaining: 706ms
# 930:	learn: 0.4674298	total: 9.38s	remaining: 696ms
# 931:	learn: 0.4671862	total: 9.39s	remaining: 685ms
# 932:	learn: 0.4668317	total: 9.4s	remaining: 675ms
# 933:	learn: 0.4665486	total: 9.41s	remaining: 665ms
# 934:	learn: 0.4663002	total: 9.42s	remaining: 655ms
# 935:	learn: 0.4659752	total: 9.43s	remaining: 645ms
# 936:	learn: 0.4657037	total: 9.44s	remaining: 635ms
# 937:	learn: 0.4653742	total: 9.45s	remaining: 625ms
# 938:	learn: 0.4651816	total: 9.46s	remaining: 615ms
# 939:	learn: 0.4648737	total: 9.47s	remaining: 604ms
# 940:	learn: 0.4645956	total: 9.48s	remaining: 594ms
# 941:	learn: 0.4641994	total: 9.49s	remaining: 584ms
# 942:	learn: 0.4639161	total: 9.5s	remaining: 574ms
# 943:	learn: 0.4636123	total: 9.51s	remaining: 564ms
# 944:	learn: 0.4633375	total: 9.52s	remaining: 554ms
# 945:	learn: 0.4630618	total: 9.53s	remaining: 544ms
# 946:	learn: 0.4626487	total: 9.54s	remaining: 534ms
# 947:	learn: 0.4623632	total: 9.55s	remaining: 524ms
# 948:	learn: 0.4621131	total: 9.56s	remaining: 514ms
# 949:	learn: 0.4619788	total: 9.57s	remaining: 504ms
# 950:	learn: 0.4617219	total: 9.58s	remaining: 493ms
# 951:	learn: 0.4614887	total: 9.59s	remaining: 483ms
# 952:	learn: 0.4612928	total: 9.6s	remaining: 473ms
# 953:	learn: 0.4609936	total: 9.61s	remaining: 463ms
# 954:	learn: 0.4606651	total: 9.62s	remaining: 453ms
# 955:	learn: 0.4604097	total: 9.63s	remaining: 443ms
# 956:	learn: 0.4601903	total: 9.64s	remaining: 433ms
# 957:	learn: 0.4599584	total: 9.65s	remaining: 423ms
# 958:	learn: 0.4595620	total: 9.66s	remaining: 413ms
# 959:	learn: 0.4593110	total: 9.67s	remaining: 403ms
# 960:	learn: 0.4590368	total: 9.68s	remaining: 393ms
# 961:	learn: 0.4587477	total: 9.69s	remaining: 383ms
# 962:	learn: 0.4585337	total: 9.7s	remaining: 373ms
# 963:	learn: 0.4583508	total: 9.71s	remaining: 362ms
# 964:	learn: 0.4580906	total: 9.71s	remaining: 352ms
# 965:	learn: 0.4579013	total: 9.72s	remaining: 342ms
# 966:	learn: 0.4576177	total: 9.73s	remaining: 332ms
# 967:	learn: 0.4574301	total: 9.74s	remaining: 322ms
# 968:	learn: 0.4571291	total: 9.75s	remaining: 312ms
# 969:	learn: 0.4570073	total: 9.76s	remaining: 302ms
# 970:	learn: 0.4567413	total: 9.77s	remaining: 292ms
# 971:	learn: 0.4563297	total: 9.78s	remaining: 282ms
# 972:	learn: 0.4560839	total: 9.79s	remaining: 272ms
# 973:	learn: 0.4558583	total: 9.8s	remaining: 262ms
# 974:	learn: 0.4556211	total: 9.81s	remaining: 252ms
# 975:	learn: 0.4551991	total: 9.82s	remaining: 242ms
# 976:	learn: 0.4549435	total: 9.83s	remaining: 232ms
# 977:	learn: 0.4545957	total: 9.84s	remaining: 221ms
# 978:	learn: 0.4543044	total: 9.85s	remaining: 211ms
# 979:	learn: 0.4540950	total: 9.86s	remaining: 201ms
# 980:	learn: 0.4538839	total: 9.87s	remaining: 191ms
# 981:	learn: 0.4535337	total: 9.88s	remaining: 181ms
# 982:	learn: 0.4532780	total: 9.89s	remaining: 171ms
# 983:	learn: 0.4529223	total: 9.9s	remaining: 161ms
# 984:	learn: 0.4526466	total: 9.91s	remaining: 151ms
# 985:	learn: 0.4523319	total: 9.92s	remaining: 141ms
# 986:	learn: 0.4520843	total: 9.93s	remaining: 131ms
# 987:	learn: 0.4516370	total: 9.94s	remaining: 121ms
# 988:	learn: 0.4512735	total: 9.95s	remaining: 111ms
# 989:	learn: 0.4509362	total: 9.96s	remaining: 101ms
# 990:	learn: 0.4506455	total: 9.97s	remaining: 90.6ms
# 991:	learn: 0.4504520	total: 9.98s	remaining: 80.5ms
# 992:	learn: 0.4502059	total: 9.99s	remaining: 70.5ms
# 993:	learn: 0.4499380	total: 10s	remaining: 60.4ms
# 994:	learn: 0.4496288	total: 10s	remaining: 50.3ms
# 995:	learn: 0.4495156	total: 10s	remaining: 40.3ms
# 996:	learn: 0.4493417	total: 10s	remaining: 30.2ms
# 997:	learn: 0.4492123	total: 10s	remaining: 20.1ms
# 998:	learn: 0.4488211	total: 10.1s	remaining: 10.1ms
# 999:	learn: 0.4484559	total: 10.1s	remaining: 0us

# %%
test_pred = clf.predict(test_embeds)
test_proba = clf.predict_proba(test_embeds)

# %%
print("Accuracy:", accuracy_score(target_test, test_pred))
print("ROC-AUC:", roc_auc_score(target_test, test_proba, average="weighted", multi_class="ovr"))
# Out:
# Accuracy: 0.591
# ROC-AUC: 0.8412818485451155

# %%
arr = np.array([0.8374069458382453, 0.8371004593414186, 0.8348023797489404])

arr.mean(), arr.std()
# Out:
# (0.8364365949762015, 0.0011623189607972097)

# %% [markdown]
# - COLES embeds + Catboost:
#   - `Accuracy: 0.6133333333333333`, `0.606`, `0.5933333333333334`, avg: `0.6042 +- 0.0083`
#   -  `ROC-AUC: 0.8490542004456147`, `0.848260886697585`, `0.8472952867923927`, avg: `0.8482 +- 0.0007`
#
# ---
#
# - COLES embeds (w/ Aggregation by Days, 1 day) + Catboost:
#   - `Accuracy: 0.5903333333333334`, `0.5976666666666667`, `0.5976666666666667`, avg: `0.5952 +- 0.0035`
#   - `ROC-AUC: 0.8359934171032082`, `0.8401389801353204`, `0.8431170146372144`, avg: `0.8397 +- 0.0029`
#
# ---
#
# - COLES embeds (w/ Aggregation by Days, 2 days) + Catboost:
#   - `Accuracy: 0.5796666666666667`, `0.5846666666666667`, `0.5756666666666667`, avg: `0.58 +- 0.0037`
#   - `ROC-AUC: 0.8374069458382453`, `0.8371004593414186`, `0.8348023797489404`, avg: `0.8364 +- 0.0012`
#
# ---
#
# - COLES embeds (w/ Aggregation by Days, 1 day; w/ 'No Trx' Indicators) + Catboost:
#   - `Accuracy: 0.6`, `0.591`, `0.5986666666666667`, avg: `0.5966 +- 0.004`
#   - `ROC-AUC: 0.8440655920805434`, `0.8412818485451155`, `0.8421997227414773`, avg: `0.8425 +- 0.0012`
#
# ---
#
# **Логика + Вывод:** для CoLES агрегация по времени приводит к худшему, чем в случае бейзлайна, качеству. При этом с увеличением периода времени, учитываемого при агрегации, качество лишь ухудшается.
#
# Так как для агрегации по одному дню результаты лучше, чем для агрегации по двум дням, будем далее экспериментировать с этой конфигурацией (агрегация по одному дню). В частности, попробуем добавить в дни, в которые не было ни одной транзакции специальные транзакции-индикаторы, означающие отсутствие в этот день транзакций.
#
# Неожиданно (во всех остальных случаях - иначе) для конфигурации c транзакциями-индикаторами результаты оказались несколько лучше, чем для обычной агрегации по 1 дню, как по accuracy, так и по ROC-AUC, хотя эта конфигурация всё ещё хуже, чем бейзлайн.
#
# **Лучший по метрикам результат:**
#
# - COLES embeds (w/ Aggregation by Days, 1 day; w/ 'No Trx' Indicators) + Catboost:
#   - `Accuracy: 0.6`, `0.591`, `0.5986666666666667`, avg: `0.5966 +- 0.004`
#   - `ROC-AUC: 0.8440655920805434`, `0.8412818485451155`, `0.8421997227414773`, avg: `0.8425 +- 0.0012`

# %% [markdown]
# ---

# %% [markdown]
# **Train sequences lengths check:**

# %%
agg_encoder_params = dict(
    embeddings_noise=0.003,
    numeric_values={"amount_rur": "log"},
    embeddings={
        "trans_date": {"in": 800, "out": 16},
        "small_group": {"in": 250, "out": 16},
    },
    n_days=2, # 1, 2
    use_window_attention=False
)

trx_encoder = TimeAggregator(**agg_encoder_params)
trx_encoder.to("cuda")
# Out:
# TimeAggregator(
#   (embeddings): ModuleDict(
#     (trans_date): NoisyEmbedding(
#       800, 16, padding_idx=0
#       (dropout): Dropout(p=0, inplace=False)
#     )
#     (small_group): NoisyEmbedding(
#       250, 16, padding_idx=0
#       (dropout): Dropout(p=0, inplace=False)
#     )
#   )
#   (custom_embeddings): ModuleDict(
#     (amount_rur): LogScaler()
#   )
# )

# %%
train_loader = inference_data_loader(data_train, num_workers=0, batch_size=128)

trx_encoder.eval()

seq_lens = []

for batch in tqdm(train_loader):
    embeds_batch = trx_encoder(batch.to("cuda"))
    seq_lens += [embeds_batch.seq_lens.detach().cpu().numpy()]

seq_lens = np.concatenate(seq_lens)

threshold = int(np.quantile(seq_lens, 0.6))

print("Max Length:", threshold)
# Out:
# 211it [00:13, 15.17it/s]
# Max Length: 315

# %% [markdown]
# ---

# %% [markdown]
# - **CPC modeling:**

# %%
seed_everything(42)

# %% [markdown]
# **DataLoaders:**

# %%
data = PtlsDataModule(
    train_data=CpcDataset(
        MemoryMapDataset(
            data=data_train,
            i_filters=[AddNulls(null_cat=1000, numeric_values=['amount_rur'], col_time='trans_date', col_id='client_id')]
        ),
        min_len=309,             
        max_len=315
    ),
    train_num_workers=4,
    train_batch_size=64,
    valid_data=CpcDataset(
        MemoryMapDataset(
            data=data_test,
            i_filters=[AddNulls(null_cat=1000, numeric_values=['amount_rur'], col_time='trans_date', col_id='client_id')]
        ),
        min_len=309,
        max_len=315
    ),
    valid_num_workers=4,
    valid_batch_size=64
)

# %% [markdown]
# **Модель:**

# %%
N_EPOCHS = 20

# %%
agg_encoder_params = dict(
    embeddings_noise=0.003,
    numeric_values={"amount_rur": "log"},
    embeddings={
        "trans_date": {"in": 1001, "out": 128},
        "small_group": {"in": 1001, "out": 128},
        # "trans_date": {"in": 800, "out": 128},
        # "small_group": {"in": 250, "out": 128},
    },
    n_days=2, # 1, 2
    use_window_attention=False
)

trx_encoder = TimeAggregator(**agg_encoder_params)

seq_encoder = RnnSeqEncoder(
    trx_encoder=trx_encoder,
    hidden_size=512,
    type="gru"
)

cpc = CpcModule(
    seq_encoder=seq_encoder,
    n_forward_steps=6, 
    n_negatives=40,
    optimizer_partial=partial(torch.optim.Adam, lr=2e-3),
    lr_scheduler_partial=partial(torch.optim.lr_scheduler.StepLR, step_size=5, gamma=0.5)
)

# %% [markdown]
# **Обучение:**

# %%
logger = CometLogger(project_name="EvS_SSL", experiment_name="CPC_modeling_AggByDays (2 days, w/ AddNulls)")

trainer = pl.Trainer(
    logger=logger,
    max_epochs=N_EPOCHS,
    accelerator="gpu",
    devices=1,
    enable_progress_bar=True
)

# %%
trainer.fit(cpc, data)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Couldn't find a Git repository in '/kaggle/working' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/askoro/evs-ssl/f716dea771964e42a1fc562fbc4b37fc
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : CPC_modeling_AggByDays (2 days, w/ AddNulls)
# COMET INFO:     url                   : https://www.comet.com/askoro/evs-ssl/f716dea771964e42a1fc562fbc4b37fc
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [1012]             : (0.7066872119903564, 4.526556491851807)
# COMET INFO:     seq_len [168]           : (311.4375, 312.53125)
# COMET INFO:     valid/cpc_accuracy [20] : (0.8983393907546997, 0.929221510887146)
# COMET INFO:   Others:
# COMET INFO:     Name : CPC_modeling_AggByDays (2 days, w/ AddNulls)
# COMET INFO:   Parameters:
# COMET INFO:     test_batch_size   : None
# COMET INFO:     test_drop_last    : False
# COMET INFO:     test_num_workers  : None
# COMET INFO:     train_batch_size  : 64
# COMET INFO:     train_drop_last   : False
# COMET INFO:     train_num_workers : 4
# COMET INFO:     valid_batch_size  : 64
# COMET INFO:     valid_drop_last   : False
# COMET INFO:     valid_num_workers : 4
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:

# %%
trainer.logged_metrics
# Out:
# {'loss': tensor(0.9989),
#  'seq_len': tensor(311.6964),
#  'valid/cpc_accuracy': tensor(0.9291)}

# %%
# torch.save(seq_encoder.state_dict(), "cpc_enc_win_agg_trx20.pt")

# %% [markdown]
# **Измерим качество на тесте (catboost поверх эмбеддингов):**

# %%
encoder = cpc.seq_encoder

device = "cuda:0"

encoder.to(device)
# Out:
# RnnSeqEncoder(
#   (trx_encoder): TimeAggregator(
#     (embeddings): ModuleDict(
#       (trans_date): NoisyEmbedding(
#         1001, 128, padding_idx=0
#         (dropout): Dropout(p=0, inplace=False)
#       )
#       (small_group): NoisyEmbedding(
#         1001, 128, padding_idx=0
#         (dropout): Dropout(p=0, inplace=False)
#       )
#     )
#     (custom_embeddings): ModuleDict(
#       (amount_rur): LogScaler()
#     )
#   )
#   (seq_encoder): RnnEncoder(
#     (rnn): GRU(257, 512, batch_first=True)
#     (reducer): LastStepEncoder()
#   )
# )

# %%
encoder.seq_encoder.is_reduce_sequence = True

# %%
from tqdm import tqdm

seed_everything(42)

# %%
train_loader = inference_data_loader(data_train, num_workers=0, batch_size=128)
encoder.eval()
train_embeds = None

for i, batch in tqdm(enumerate(train_loader)):
    train_embeds_batch = encoder(batch.to(device))
    if i == 0:
        train_embeds = train_embeds_batch.detach().cpu().numpy()
    else:
        train_embeds = np.concatenate([train_embeds, train_embeds_batch.detach().cpu().numpy()], axis=0)
    
train_embeds
# Out:
# 211it [00:28,  7.48it/s]
# array([[ 9.0661354e-02, -1.7940442e-04,  1.6187808e-01, ...,
#         -2.0322989e-01,  1.5438804e-01, -2.1484785e-01],
#        [-1.2730356e-01,  5.7423402e-02,  7.5044572e-02, ...,
#         -1.6158232e-01,  1.1380931e-01, -3.0741990e-01],
#        [ 6.1412532e-02,  2.1402998e-01,  1.4462718e-01, ...,
#         -3.4001883e-02, -4.6531048e-02, -1.4534314e-01],
#        ...,
#        [ 2.3595154e-01,  6.6408962e-02,  2.1761590e-01, ...,
#         -1.2518129e-01,  1.5884288e-01, -3.3319229e-01],
#        [-5.9891578e-02, -1.4634946e-02,  2.2151016e-01, ...,
#         -2.3773111e-01,  2.8775817e-02, -2.1939257e-01],
#        [-1.8175900e-01, -1.3543776e-01,  1.9350383e-01, ...,
#         -3.6563453e-01,  1.4757746e-01, -2.3649485e-01]], dtype=float32)

# %%
test_loader = inference_data_loader(data_test, num_workers=0, batch_size=128)
encoder.eval()
test_embeds = None

for i, batch in tqdm(enumerate(test_loader)):
    test_embeds_batch = encoder(batch.to(device))
    if i == 0:
        test_embeds = test_embeds_batch.detach().cpu().numpy()
    else:
        test_embeds = np.concatenate([test_embeds, test_embeds_batch.detach().cpu().numpy()], axis=0)
    
test_embeds
# Out:
# 24it [00:02,  8.03it/s]
# array([[-0.09716944, -0.06535138,  0.10782406, ..., -0.15078679,
#          0.18098472, -0.3724438 ],
#        [ 0.19423717,  0.15957253,  0.08630638, ..., -0.05126814,
#         -0.01902957,  0.07876328],
#        [ 0.00109657,  0.05739365,  0.18357062, ..., -0.15846033,
#          0.08779249, -0.1989849 ],
#        ...,
#        [-0.05791983,  0.05395125,  0.19589399, ..., -0.07685129,
#          0.11897571, -0.18030733],
#        [-0.03931396,  0.08975551,  0.12729435, ..., -0.01959309,
#          0.17313237, -0.34923705],
#        [ 0.06401593,  0.14231046,  0.16555986, ..., -0.08124476,
#          0.24138758, -0.16685297]], dtype=float32)

# %%
clf = CatBoostClassifier(loss_function='MultiClass', task_type="GPU", devices='0', random_state=42)

clf.fit(train_embeds, target_train, plot_file="catboost_log.html")
# Out:
# Learning rate set to 0.12714
# 0:	learn: 1.3205184	total: 13.9ms	remaining: 13.9s
# 1:	learn: 1.2692111	total: 24.3ms	remaining: 12.1s
# 2:	learn: 1.2302591	total: 34.5ms	remaining: 11.5s
# 3:	learn: 1.1976002	total: 44.6ms	remaining: 11.1s
# 4:	learn: 1.1706399	total: 54.7ms	remaining: 10.9s
# 5:	learn: 1.1489706	total: 64.7ms	remaining: 10.7s
# 6:	learn: 1.1286913	total: 75.4ms	remaining: 10.7s
# 7:	learn: 1.1114361	total: 85.8ms	remaining: 10.6s
# 8:	learn: 1.0972407	total: 96.7ms	remaining: 10.7s
# 9:	learn: 1.0851062	total: 107ms	remaining: 10.6s
# 10:	learn: 1.0738839	total: 117ms	remaining: 10.5s
# 11:	learn: 1.0641899	total: 127ms	remaining: 10.5s
# 12:	learn: 1.0551678	total: 138ms	remaining: 10.5s
# 13:	learn: 1.0479664	total: 148ms	remaining: 10.4s
# 14:	learn: 1.0412188	total: 158ms	remaining: 10.4s
# 15:	learn: 1.0347198	total: 167ms	remaining: 10.3s
# 16:	learn: 1.0292612	total: 176ms	remaining: 10.2s
# 17:	learn: 1.0240231	total: 187ms	remaining: 10.2s
# 18:	learn: 1.0189375	total: 198ms	remaining: 10.2s
# 19:	learn: 1.0148749	total: 208ms	remaining: 10.2s
# 20:	learn: 1.0115841	total: 218ms	remaining: 10.1s
# 21:	learn: 1.0080042	total: 228ms	remaining: 10.1s
# 22:	learn: 1.0046484	total: 238ms	remaining: 10.1s
# 23:	learn: 1.0019339	total: 247ms	remaining: 10s
# 24:	learn: 0.9987687	total: 257ms	remaining: 10s
# 25:	learn: 0.9964012	total: 268ms	remaining: 10s
# 26:	learn: 0.9938925	total: 279ms	remaining: 10.1s
# 27:	learn: 0.9914638	total: 290ms	remaining: 10.1s
# 28:	learn: 0.9890582	total: 301ms	remaining: 10.1s
# 29:	learn: 0.9869845	total: 311ms	remaining: 10.1s
# 30:	learn: 0.9852233	total: 321ms	remaining: 10s
# 31:	learn: 0.9831013	total: 332ms	remaining: 10s
# 32:	learn: 0.9811955	total: 343ms	remaining: 10.1s
# 33:	learn: 0.9796771	total: 354ms	remaining: 10.1s
# 34:	learn: 0.9779421	total: 365ms	remaining: 10.1s
# 35:	learn: 0.9762908	total: 375ms	remaining: 10s
# 36:	learn: 0.9747124	total: 386ms	remaining: 10s
# 37:	learn: 0.9734136	total: 396ms	remaining: 10s
# 38:	learn: 0.9717084	total: 407ms	remaining: 10s
# 39:	learn: 0.9706857	total: 418ms	remaining: 10s
# 40:	learn: 0.9689747	total: 429ms	remaining: 10s
# 41:	learn: 0.9677524	total: 440ms	remaining: 10s
# 42:	learn: 0.9664418	total: 451ms	remaining: 10s
# 43:	learn: 0.9648642	total: 462ms	remaining: 10s
# 44:	learn: 0.9636127	total: 473ms	remaining: 10s
# 45:	learn: 0.9628231	total: 483ms	remaining: 10s
# 46:	learn: 0.9614706	total: 493ms	remaining: 9.99s
# 47:	learn: 0.9601918	total: 503ms	remaining: 9.98s
# 48:	learn: 0.9590106	total: 513ms	remaining: 9.96s
# 49:	learn: 0.9577037	total: 524ms	remaining: 9.95s
# 50:	learn: 0.9563082	total: 534ms	remaining: 9.94s
# 51:	learn: 0.9552279	total: 545ms	remaining: 9.93s
# 52:	learn: 0.9539937	total: 555ms	remaining: 9.91s
# 53:	learn: 0.9523562	total: 565ms	remaining: 9.9s
# 54:	learn: 0.9511003	total: 576ms	remaining: 9.89s
# 55:	learn: 0.9498505	total: 586ms	remaining: 9.87s
# 56:	learn: 0.9489721	total: 596ms	remaining: 9.86s
# 57:	learn: 0.9477101	total: 606ms	remaining: 9.85s
# 58:	learn: 0.9464469	total: 616ms	remaining: 9.83s
# 59:	learn: 0.9451474	total: 626ms	remaining: 9.81s
# 60:	learn: 0.9444576	total: 636ms	remaining: 9.79s
# 61:	learn: 0.9430863	total: 646ms	remaining: 9.77s
# 62:	learn: 0.9418726	total: 656ms	remaining: 9.75s
# 63:	learn: 0.9407496	total: 666ms	remaining: 9.74s
# 64:	learn: 0.9398591	total: 676ms	remaining: 9.72s
# 65:	learn: 0.9391617	total: 685ms	remaining: 9.7s
# 66:	learn: 0.9382679	total: 695ms	remaining: 9.68s
# 67:	learn: 0.9374347	total: 705ms	remaining: 9.66s
# 68:	learn: 0.9363297	total: 714ms	remaining: 9.64s
# 69:	learn: 0.9353968	total: 724ms	remaining: 9.62s
# 70:	learn: 0.9345493	total: 734ms	remaining: 9.6s
# 71:	learn: 0.9337364	total: 743ms	remaining: 9.58s
# 72:	learn: 0.9326379	total: 754ms	remaining: 9.57s
# 73:	learn: 0.9317009	total: 763ms	remaining: 9.55s
# 74:	learn: 0.9307488	total: 774ms	remaining: 9.55s
# 75:	learn: 0.9298004	total: 785ms	remaining: 9.54s
# 76:	learn: 0.9288095	total: 795ms	remaining: 9.53s
# 77:	learn: 0.9278488	total: 806ms	remaining: 9.53s
# 78:	learn: 0.9269141	total: 816ms	remaining: 9.52s
# 79:	learn: 0.9259297	total: 826ms	remaining: 9.5s
# 80:	learn: 0.9250177	total: 836ms	remaining: 9.49s
# 81:	learn: 0.9239196	total: 847ms	remaining: 9.48s
# 82:	learn: 0.9229811	total: 856ms	remaining: 9.46s
# 83:	learn: 0.9218843	total: 867ms	remaining: 9.45s
# 84:	learn: 0.9209356	total: 877ms	remaining: 9.44s
# 85:	learn: 0.9199195	total: 887ms	remaining: 9.42s
# 86:	learn: 0.9190647	total: 897ms	remaining: 9.41s
# 87:	learn: 0.9179887	total: 907ms	remaining: 9.4s
# 88:	learn: 0.9170226	total: 917ms	remaining: 9.38s
# 89:	learn: 0.9162951	total: 926ms	remaining: 9.37s
# 90:	learn: 0.9153380	total: 936ms	remaining: 9.35s
# 91:	learn: 0.9145443	total: 946ms	remaining: 9.34s
# 92:	learn: 0.9136969	total: 956ms	remaining: 9.32s
# 93:	learn: 0.9127776	total: 966ms	remaining: 9.31s
# 94:	learn: 0.9119890	total: 976ms	remaining: 9.3s
# 95:	learn: 0.9112463	total: 985ms	remaining: 9.28s
# 96:	learn: 0.9103701	total: 995ms	remaining: 9.27s
# 97:	learn: 0.9095242	total: 1s	remaining: 9.25s
# 98:	learn: 0.9085920	total: 1.01s	remaining: 9.24s
# 99:	learn: 0.9076840	total: 1.02s	remaining: 9.23s
# 100:	learn: 0.9070351	total: 1.03s	remaining: 9.21s
# 101:	learn: 0.9063435	total: 1.04s	remaining: 9.2s
# 102:	learn: 0.9054368	total: 1.05s	remaining: 9.19s
# 103:	learn: 0.9045553	total: 1.06s	remaining: 9.17s
# 104:	learn: 0.9037637	total: 1.07s	remaining: 9.16s
# 105:	learn: 0.9029267	total: 1.08s	remaining: 9.14s
# 106:	learn: 0.9024063	total: 1.09s	remaining: 9.12s
# 107:	learn: 0.9015748	total: 1.1s	remaining: 9.11s
# 108:	learn: 0.9007143	total: 1.11s	remaining: 9.1s
# 109:	learn: 0.9001228	total: 1.12s	remaining: 9.08s
# 110:	learn: 0.8993401	total: 1.13s	remaining: 9.07s
# 111:	learn: 0.8987359	total: 1.14s	remaining: 9.05s
# 112:	learn: 0.8980145	total: 1.15s	remaining: 9.04s
# 113:	learn: 0.8974398	total: 1.16s	remaining: 9.03s
# 114:	learn: 0.8967401	total: 1.17s	remaining: 9.02s
# 115:	learn: 0.8960231	total: 1.18s	remaining: 9.01s
# 116:	learn: 0.8953500	total: 1.19s	remaining: 9s
# 117:	learn: 0.8947703	total: 1.2s	remaining: 8.99s
# 118:	learn: 0.8938858	total: 1.21s	remaining: 8.98s
# 119:	learn: 0.8927684	total: 1.22s	remaining: 8.97s
# 120:	learn: 0.8919598	total: 1.23s	remaining: 8.97s
# 121:	learn: 0.8910140	total: 1.24s	remaining: 8.96s
# 122:	learn: 0.8903950	total: 1.25s	remaining: 8.95s
# 123:	learn: 0.8896765	total: 1.26s	remaining: 8.94s
# 124:	learn: 0.8889325	total: 1.27s	remaining: 8.93s
# 125:	learn: 0.8883237	total: 1.28s	remaining: 8.92s
# 126:	learn: 0.8876806	total: 1.29s	remaining: 8.91s
# 127:	learn: 0.8867899	total: 1.31s	remaining: 8.9s
# 128:	learn: 0.8860301	total: 1.32s	remaining: 8.89s
# 129:	learn: 0.8851993	total: 1.33s	remaining: 8.88s
# 130:	learn: 0.8841530	total: 1.34s	remaining: 8.88s
# 131:	learn: 0.8833275	total: 1.35s	remaining: 8.87s
# 132:	learn: 0.8824880	total: 1.36s	remaining: 8.86s
# 133:	learn: 0.8818244	total: 1.37s	remaining: 8.85s
# 134:	learn: 0.8809018	total: 1.38s	remaining: 8.84s
# 135:	learn: 0.8802930	total: 1.39s	remaining: 8.83s
# 136:	learn: 0.8795143	total: 1.4s	remaining: 8.81s
# 137:	learn: 0.8788762	total: 1.41s	remaining: 8.8s
# 138:	learn: 0.8783343	total: 1.42s	remaining: 8.79s
# 139:	learn: 0.8777125	total: 1.43s	remaining: 8.78s
# 140:	learn: 0.8767343	total: 1.44s	remaining: 8.77s
# 141:	learn: 0.8760268	total: 1.45s	remaining: 8.76s
# 142:	learn: 0.8752682	total: 1.46s	remaining: 8.75s
# 143:	learn: 0.8743161	total: 1.47s	remaining: 8.74s
# 144:	learn: 0.8738420	total: 1.48s	remaining: 8.73s
# 145:	learn: 0.8731084	total: 1.49s	remaining: 8.72s
# 146:	learn: 0.8722125	total: 1.5s	remaining: 8.71s
# 147:	learn: 0.8717100	total: 1.51s	remaining: 8.7s
# 148:	learn: 0.8710056	total: 1.52s	remaining: 8.69s
# 149:	learn: 0.8702925	total: 1.53s	remaining: 8.68s
# 150:	learn: 0.8695136	total: 1.54s	remaining: 8.67s
# 151:	learn: 0.8691305	total: 1.55s	remaining: 8.65s
# 152:	learn: 0.8685718	total: 1.56s	remaining: 8.64s
# 153:	learn: 0.8681529	total: 1.57s	remaining: 8.63s
# 154:	learn: 0.8673972	total: 1.58s	remaining: 8.63s
# 155:	learn: 0.8665409	total: 1.59s	remaining: 8.62s
# 156:	learn: 0.8660286	total: 1.6s	remaining: 8.61s
# 157:	learn: 0.8653134	total: 1.61s	remaining: 8.59s
# 158:	learn: 0.8646250	total: 1.62s	remaining: 8.58s
# 159:	learn: 0.8638919	total: 1.63s	remaining: 8.57s
# 160:	learn: 0.8634028	total: 1.64s	remaining: 8.56s
# 161:	learn: 0.8627294	total: 1.65s	remaining: 8.55s
# 162:	learn: 0.8619487	total: 1.66s	remaining: 8.54s
# 163:	learn: 0.8614535	total: 1.67s	remaining: 8.53s
# 164:	learn: 0.8605506	total: 1.68s	remaining: 8.52s
# 165:	learn: 0.8598395	total: 1.69s	remaining: 8.51s
# 166:	learn: 0.8592282	total: 1.7s	remaining: 8.49s
# 167:	learn: 0.8586248	total: 1.71s	remaining: 8.48s
# 168:	learn: 0.8578730	total: 1.72s	remaining: 8.47s
# 169:	learn: 0.8571188	total: 1.73s	remaining: 8.46s
# 170:	learn: 0.8564366	total: 1.74s	remaining: 8.45s
# 171:	learn: 0.8557446	total: 1.75s	remaining: 8.43s
# 172:	learn: 0.8551355	total: 1.76s	remaining: 8.42s
# 173:	learn: 0.8543605	total: 1.77s	remaining: 8.41s
# 174:	learn: 0.8535560	total: 1.78s	remaining: 8.4s
# 175:	learn: 0.8528651	total: 1.79s	remaining: 8.4s
# 176:	learn: 0.8521370	total: 1.8s	remaining: 8.39s
# 177:	learn: 0.8512598	total: 1.81s	remaining: 8.38s
# 178:	learn: 0.8507823	total: 1.82s	remaining: 8.37s
# 179:	learn: 0.8499564	total: 1.83s	remaining: 8.36s
# 180:	learn: 0.8492388	total: 1.84s	remaining: 8.35s
# 181:	learn: 0.8484503	total: 1.86s	remaining: 8.34s
# 182:	learn: 0.8476599	total: 1.87s	remaining: 8.33s
# 183:	learn: 0.8468821	total: 1.88s	remaining: 8.32s
# 184:	learn: 0.8463159	total: 1.89s	remaining: 8.31s
# 185:	learn: 0.8456740	total: 1.9s	remaining: 8.3s
# 186:	learn: 0.8451136	total: 1.91s	remaining: 8.3s
# 187:	learn: 0.8444577	total: 1.92s	remaining: 8.29s
# 188:	learn: 0.8435331	total: 1.93s	remaining: 8.28s
# 189:	learn: 0.8427398	total: 1.94s	remaining: 8.27s
# 190:	learn: 0.8419630	total: 1.95s	remaining: 8.26s
# 191:	learn: 0.8411583	total: 1.96s	remaining: 8.25s
# 192:	learn: 0.8401508	total: 1.97s	remaining: 8.24s
# 193:	learn: 0.8395755	total: 1.98s	remaining: 8.23s
# 194:	learn: 0.8390904	total: 1.99s	remaining: 8.22s
# 195:	learn: 0.8385042	total: 2s	remaining: 8.21s
# 196:	learn: 0.8377484	total: 2.01s	remaining: 8.21s
# 197:	learn: 0.8369698	total: 2.02s	remaining: 8.2s
# 198:	learn: 0.8362866	total: 2.04s	remaining: 8.19s
# 199:	learn: 0.8357435	total: 2.04s	remaining: 8.18s
# 200:	learn: 0.8350021	total: 2.06s	remaining: 8.18s
# 201:	learn: 0.8345286	total: 2.07s	remaining: 8.16s
# 202:	learn: 0.8338901	total: 2.08s	remaining: 8.15s
# 203:	learn: 0.8331879	total: 2.09s	remaining: 8.14s
# 204:	learn: 0.8326500	total: 2.1s	remaining: 8.13s
# 205:	learn: 0.8321416	total: 2.1s	remaining: 8.12s
# 206:	learn: 0.8312846	total: 2.12s	remaining: 8.11s
# 207:	learn: 0.8305748	total: 2.13s	remaining: 8.1s
# 208:	learn: 0.8300907	total: 2.14s	remaining: 8.09s
# 209:	learn: 0.8293621	total: 2.15s	remaining: 8.07s
# 210:	learn: 0.8287723	total: 2.16s	remaining: 8.06s
# 211:	learn: 0.8281825	total: 2.17s	remaining: 8.05s
# 212:	learn: 0.8274502	total: 2.18s	remaining: 8.04s
# 213:	learn: 0.8264853	total: 2.19s	remaining: 8.04s
# 214:	learn: 0.8259083	total: 2.2s	remaining: 8.03s
# 215:	learn: 0.8253218	total: 2.21s	remaining: 8.01s
# 216:	learn: 0.8248335	total: 2.22s	remaining: 8s
# 217:	learn: 0.8241303	total: 2.23s	remaining: 7.99s
# 218:	learn: 0.8235118	total: 2.24s	remaining: 7.98s
# 219:	learn: 0.8229348	total: 2.25s	remaining: 7.97s
# 220:	learn: 0.8223197	total: 2.26s	remaining: 7.96s
# 221:	learn: 0.8217877	total: 2.27s	remaining: 7.95s
# 222:	learn: 0.8211107	total: 2.28s	remaining: 7.94s
# 223:	learn: 0.8206436	total: 2.29s	remaining: 7.93s
# 224:	learn: 0.8200386	total: 2.3s	remaining: 7.92s
# 225:	learn: 0.8191730	total: 2.31s	remaining: 7.91s
# 226:	learn: 0.8183973	total: 2.32s	remaining: 7.9s
# 227:	learn: 0.8176341	total: 2.33s	remaining: 7.88s
# 228:	learn: 0.8172600	total: 2.34s	remaining: 7.87s
# 229:	learn: 0.8166630	total: 2.35s	remaining: 7.86s
# 230:	learn: 0.8157501	total: 2.36s	remaining: 7.85s
# 231:	learn: 0.8149695	total: 2.37s	remaining: 7.84s
# 232:	learn: 0.8144920	total: 2.38s	remaining: 7.82s
# 233:	learn: 0.8139391	total: 2.39s	remaining: 7.81s
# 234:	learn: 0.8132245	total: 2.4s	remaining: 7.8s
# 235:	learn: 0.8125705	total: 2.41s	remaining: 7.79s
# 236:	learn: 0.8119894	total: 2.42s	remaining: 7.78s
# 237:	learn: 0.8112898	total: 2.42s	remaining: 7.77s
# 238:	learn: 0.8107658	total: 2.44s	remaining: 7.75s
# 239:	learn: 0.8100734	total: 2.44s	remaining: 7.74s
# 240:	learn: 0.8095706	total: 2.45s	remaining: 7.73s
# 241:	learn: 0.8090187	total: 2.46s	remaining: 7.72s
# 242:	learn: 0.8082859	total: 2.47s	remaining: 7.71s
# 243:	learn: 0.8077813	total: 2.48s	remaining: 7.7s
# 244:	learn: 0.8072401	total: 2.49s	remaining: 7.68s
# 245:	learn: 0.8065230	total: 2.5s	remaining: 7.67s
# 246:	learn: 0.8060206	total: 2.51s	remaining: 7.66s
# 247:	learn: 0.8054436	total: 2.52s	remaining: 7.65s
# 248:	learn: 0.8045203	total: 2.53s	remaining: 7.64s
# 249:	learn: 0.8038396	total: 2.54s	remaining: 7.63s
# 250:	learn: 0.8032663	total: 2.55s	remaining: 7.62s
# 251:	learn: 0.8027539	total: 2.56s	remaining: 7.61s
# 252:	learn: 0.8020212	total: 2.57s	remaining: 7.59s
# 253:	learn: 0.8013681	total: 2.58s	remaining: 7.58s
# 254:	learn: 0.8008198	total: 2.59s	remaining: 7.57s
# 255:	learn: 0.7999988	total: 2.6s	remaining: 7.56s
# 256:	learn: 0.7996090	total: 2.61s	remaining: 7.55s
# 257:	learn: 0.7989464	total: 2.62s	remaining: 7.54s
# 258:	learn: 0.7981392	total: 2.63s	remaining: 7.53s
# 259:	learn: 0.7976134	total: 2.64s	remaining: 7.52s
# 260:	learn: 0.7968454	total: 2.65s	remaining: 7.51s
# 261:	learn: 0.7962308	total: 2.66s	remaining: 7.5s
# 262:	learn: 0.7956839	total: 2.67s	remaining: 7.49s
# 263:	learn: 0.7950589	total: 2.68s	remaining: 7.47s
# 264:	learn: 0.7944256	total: 2.69s	remaining: 7.46s
# 265:	learn: 0.7939047	total: 2.7s	remaining: 7.45s
# 266:	learn: 0.7932775	total: 2.71s	remaining: 7.44s
# 267:	learn: 0.7927229	total: 2.72s	remaining: 7.43s
# 268:	learn: 0.7920516	total: 2.73s	remaining: 7.42s
# 269:	learn: 0.7913870	total: 2.74s	remaining: 7.41s
# 270:	learn: 0.7909541	total: 2.75s	remaining: 7.4s
# 271:	learn: 0.7900375	total: 2.76s	remaining: 7.39s
# 272:	learn: 0.7892795	total: 2.77s	remaining: 7.38s
# 273:	learn: 0.7888130	total: 2.78s	remaining: 7.37s
# 274:	learn: 0.7883123	total: 2.79s	remaining: 7.35s
# 275:	learn: 0.7875243	total: 2.8s	remaining: 7.34s
# 276:	learn: 0.7870643	total: 2.81s	remaining: 7.33s
# 277:	learn: 0.7863011	total: 2.82s	remaining: 7.32s
# 278:	learn: 0.7858827	total: 2.83s	remaining: 7.31s
# 279:	learn: 0.7853759	total: 2.84s	remaining: 7.3s
# 280:	learn: 0.7849531	total: 2.85s	remaining: 7.29s
# 281:	learn: 0.7843379	total: 2.86s	remaining: 7.28s
# 282:	learn: 0.7835245	total: 2.87s	remaining: 7.28s
# 283:	learn: 0.7828978	total: 2.88s	remaining: 7.27s
# 284:	learn: 0.7821816	total: 2.89s	remaining: 7.26s
# 285:	learn: 0.7814419	total: 2.9s	remaining: 7.25s
# 286:	learn: 0.7809120	total: 2.91s	remaining: 7.24s
# 287:	learn: 0.7804251	total: 2.92s	remaining: 7.23s
# 288:	learn: 0.7796878	total: 2.93s	remaining: 7.22s
# 289:	learn: 0.7790126	total: 2.94s	remaining: 7.21s
# 290:	learn: 0.7783696	total: 2.96s	remaining: 7.2s
# 291:	learn: 0.7776196	total: 2.96s	remaining: 7.19s
# 292:	learn: 0.7770413	total: 2.98s	remaining: 7.18s
# 293:	learn: 0.7765303	total: 2.99s	remaining: 7.17s
# 294:	learn: 0.7759850	total: 3s	remaining: 7.16s
# 295:	learn: 0.7753239	total: 3.01s	remaining: 7.15s
# 296:	learn: 0.7745705	total: 3.02s	remaining: 7.14s
# 297:	learn: 0.7740167	total: 3.03s	remaining: 7.13s
# 298:	learn: 0.7734986	total: 3.04s	remaining: 7.12s
# 299:	learn: 0.7729616	total: 3.05s	remaining: 7.11s
# 300:	learn: 0.7723045	total: 3.06s	remaining: 7.1s
# 301:	learn: 0.7717896	total: 3.07s	remaining: 7.09s
# 302:	learn: 0.7712713	total: 3.08s	remaining: 7.08s
# 303:	learn: 0.7707031	total: 3.09s	remaining: 7.07s
# 304:	learn: 0.7700050	total: 3.1s	remaining: 7.06s
# 305:	learn: 0.7693606	total: 3.11s	remaining: 7.05s
# 306:	learn: 0.7686508	total: 3.12s	remaining: 7.04s
# 307:	learn: 0.7679600	total: 3.13s	remaining: 7.03s
# 308:	learn: 0.7673236	total: 3.14s	remaining: 7.02s
# 309:	learn: 0.7668617	total: 3.15s	remaining: 7s
# 310:	learn: 0.7662635	total: 3.16s	remaining: 6.99s
# 311:	learn: 0.7656769	total: 3.17s	remaining: 6.98s
# 312:	learn: 0.7650700	total: 3.18s	remaining: 6.97s
# 313:	learn: 0.7645874	total: 3.19s	remaining: 6.96s
# 314:	learn: 0.7642033	total: 3.2s	remaining: 6.95s
# 315:	learn: 0.7636879	total: 3.21s	remaining: 6.94s
# 316:	learn: 0.7628023	total: 3.22s	remaining: 6.93s
# 317:	learn: 0.7622946	total: 3.23s	remaining: 6.92s
# 318:	learn: 0.7618367	total: 3.24s	remaining: 6.91s
# 319:	learn: 0.7612713	total: 3.25s	remaining: 6.9s
# 320:	learn: 0.7608115	total: 3.25s	remaining: 6.89s
# 321:	learn: 0.7603994	total: 3.27s	remaining: 6.87s
# 322:	learn: 0.7598121	total: 3.27s	remaining: 6.86s
# 323:	learn: 0.7589327	total: 3.29s	remaining: 6.86s
# 324:	learn: 0.7583640	total: 3.29s	remaining: 6.84s
# 325:	learn: 0.7578277	total: 3.31s	remaining: 6.83s
# 326:	learn: 0.7571351	total: 3.31s	remaining: 6.82s
# 327:	learn: 0.7566102	total: 3.33s	remaining: 6.81s
# 328:	learn: 0.7558312	total: 3.33s	remaining: 6.8s
# 329:	learn: 0.7553189	total: 3.34s	remaining: 6.79s
# 330:	learn: 0.7547078	total: 3.35s	remaining: 6.78s
# 331:	learn: 0.7541291	total: 3.37s	remaining: 6.77s
# 332:	learn: 0.7536653	total: 3.38s	remaining: 6.76s
# 333:	learn: 0.7528016	total: 3.39s	remaining: 6.75s
# 334:	learn: 0.7520957	total: 3.4s	remaining: 6.74s
# 335:	learn: 0.7514772	total: 3.41s	remaining: 6.73s
# 336:	learn: 0.7509072	total: 3.42s	remaining: 6.72s
# 337:	learn: 0.7503886	total: 3.43s	remaining: 6.71s
# 338:	learn: 0.7498393	total: 3.44s	remaining: 6.7s
# 339:	learn: 0.7492172	total: 3.45s	remaining: 6.69s
# 340:	learn: 0.7487304	total: 3.46s	remaining: 6.68s
# 341:	learn: 0.7481165	total: 3.47s	remaining: 6.67s
# 342:	learn: 0.7474775	total: 3.48s	remaining: 6.66s
# 343:	learn: 0.7469542	total: 3.49s	remaining: 6.65s
# 344:	learn: 0.7464146	total: 3.5s	remaining: 6.64s
# 345:	learn: 0.7458491	total: 3.51s	remaining: 6.63s
# 346:	learn: 0.7452922	total: 3.52s	remaining: 6.62s
# 347:	learn: 0.7446589	total: 3.53s	remaining: 6.61s
# 348:	learn: 0.7439482	total: 3.54s	remaining: 6.6s
# 349:	learn: 0.7434198	total: 3.55s	remaining: 6.59s
# 350:	learn: 0.7429663	total: 3.56s	remaining: 6.58s
# 351:	learn: 0.7422289	total: 3.57s	remaining: 6.57s
# 352:	learn: 0.7416806	total: 3.58s	remaining: 6.56s
# 353:	learn: 0.7409200	total: 3.59s	remaining: 6.55s
# 354:	learn: 0.7402386	total: 3.6s	remaining: 6.54s
# 355:	learn: 0.7398785	total: 3.61s	remaining: 6.53s
# 356:	learn: 0.7392909	total: 3.62s	remaining: 6.52s
# 357:	learn: 0.7386442	total: 3.63s	remaining: 6.51s
# 358:	learn: 0.7380356	total: 3.64s	remaining: 6.5s
# 359:	learn: 0.7374183	total: 3.65s	remaining: 6.49s
# 360:	learn: 0.7368282	total: 3.66s	remaining: 6.48s
# 361:	learn: 0.7365009	total: 3.67s	remaining: 6.47s
# 362:	learn: 0.7357700	total: 3.68s	remaining: 6.46s
# 363:	learn: 0.7353604	total: 3.69s	remaining: 6.45s
# 364:	learn: 0.7347357	total: 3.7s	remaining: 6.44s
# 365:	learn: 0.7341899	total: 3.71s	remaining: 6.43s
# 366:	learn: 0.7336844	total: 3.72s	remaining: 6.42s
# 367:	learn: 0.7330514	total: 3.73s	remaining: 6.41s
# 368:	learn: 0.7323509	total: 3.74s	remaining: 6.4s
# 369:	learn: 0.7315759	total: 3.75s	remaining: 6.39s
# 370:	learn: 0.7310950	total: 3.76s	remaining: 6.38s
# 371:	learn: 0.7306212	total: 3.77s	remaining: 6.36s
# 372:	learn: 0.7301223	total: 3.78s	remaining: 6.35s
# 373:	learn: 0.7296214	total: 3.79s	remaining: 6.34s
# 374:	learn: 0.7291827	total: 3.8s	remaining: 6.33s
# 375:	learn: 0.7287601	total: 3.81s	remaining: 6.32s
# 376:	learn: 0.7282284	total: 3.82s	remaining: 6.31s
# 377:	learn: 0.7277762	total: 3.83s	remaining: 6.3s
# 378:	learn: 0.7273833	total: 3.84s	remaining: 6.29s
# 379:	learn: 0.7268751	total: 3.85s	remaining: 6.28s
# 380:	learn: 0.7261864	total: 3.86s	remaining: 6.26s
# 381:	learn: 0.7255380	total: 3.87s	remaining: 6.25s
# 382:	learn: 0.7248709	total: 3.88s	remaining: 6.24s
# 383:	learn: 0.7243639	total: 3.89s	remaining: 6.23s
# 384:	learn: 0.7237381	total: 3.9s	remaining: 6.22s
# 385:	learn: 0.7234818	total: 3.9s	remaining: 6.21s
# 386:	learn: 0.7229923	total: 3.91s	remaining: 6.2s
# 387:	learn: 0.7224450	total: 3.92s	remaining: 6.19s
# 388:	learn: 0.7221004	total: 3.93s	remaining: 6.18s
# 389:	learn: 0.7216020	total: 3.94s	remaining: 6.17s
# 390:	learn: 0.7211914	total: 3.95s	remaining: 6.16s
# 391:	learn: 0.7206259	total: 3.96s	remaining: 6.15s
# 392:	learn: 0.7200105	total: 3.97s	remaining: 6.14s
# 393:	learn: 0.7196133	total: 3.98s	remaining: 6.13s
# 394:	learn: 0.7189128	total: 3.99s	remaining: 6.11s
# 395:	learn: 0.7182966	total: 4s	remaining: 6.1s
# 396:	learn: 0.7177822	total: 4.01s	remaining: 6.09s
# 397:	learn: 0.7173140	total: 4.02s	remaining: 6.08s
# 398:	learn: 0.7170213	total: 4.03s	remaining: 6.07s
# 399:	learn: 0.7165841	total: 4.04s	remaining: 6.06s
# 400:	learn: 0.7159091	total: 4.05s	remaining: 6.05s
# 401:	learn: 0.7153457	total: 4.06s	remaining: 6.04s
# 402:	learn: 0.7146719	total: 4.07s	remaining: 6.03s
# 403:	learn: 0.7140377	total: 4.08s	remaining: 6.02s
# 404:	learn: 0.7134638	total: 4.09s	remaining: 6.01s
# 405:	learn: 0.7130523	total: 4.1s	remaining: 6s
# 406:	learn: 0.7123088	total: 4.11s	remaining: 5.99s
# 407:	learn: 0.7117114	total: 4.12s	remaining: 5.98s
# 408:	learn: 0.7109341	total: 4.13s	remaining: 5.97s
# 409:	learn: 0.7102926	total: 4.14s	remaining: 5.96s
# 410:	learn: 0.7096136	total: 4.15s	remaining: 5.95s
# 411:	learn: 0.7090018	total: 4.16s	remaining: 5.94s
# 412:	learn: 0.7082412	total: 4.17s	remaining: 5.93s
# 413:	learn: 0.7077413	total: 4.18s	remaining: 5.92s
# 414:	learn: 0.7073077	total: 4.2s	remaining: 5.92s
# 415:	learn: 0.7068233	total: 4.21s	remaining: 5.91s
# 416:	learn: 0.7063845	total: 4.22s	remaining: 5.9s
# 417:	learn: 0.7058202	total: 4.23s	remaining: 5.89s
# 418:	learn: 0.7051073	total: 4.24s	remaining: 5.88s
# 419:	learn: 0.7045619	total: 4.25s	remaining: 5.87s
# 420:	learn: 0.7041236	total: 4.26s	remaining: 5.86s
# 421:	learn: 0.7034842	total: 4.27s	remaining: 5.85s
# 422:	learn: 0.7028687	total: 4.28s	remaining: 5.84s
# 423:	learn: 0.7022693	total: 4.29s	remaining: 5.83s
# 424:	learn: 0.7017518	total: 4.3s	remaining: 5.82s
# 425:	learn: 0.7012925	total: 4.31s	remaining: 5.81s
# 426:	learn: 0.7009499	total: 4.32s	remaining: 5.8s
# 427:	learn: 0.7003014	total: 4.33s	remaining: 5.79s
# 428:	learn: 0.6996307	total: 4.34s	remaining: 5.78s
# 429:	learn: 0.6992698	total: 4.35s	remaining: 5.77s
# 430:	learn: 0.6988486	total: 4.36s	remaining: 5.76s
# 431:	learn: 0.6985456	total: 4.37s	remaining: 5.75s
# 432:	learn: 0.6979721	total: 4.38s	remaining: 5.74s
# 433:	learn: 0.6973804	total: 4.39s	remaining: 5.73s
# 434:	learn: 0.6968466	total: 4.41s	remaining: 5.72s
# 435:	learn: 0.6963286	total: 4.42s	remaining: 5.71s
# 436:	learn: 0.6958213	total: 4.43s	remaining: 5.7s
# 437:	learn: 0.6951625	total: 4.44s	remaining: 5.69s
# 438:	learn: 0.6946997	total: 4.45s	remaining: 5.68s
# 439:	learn: 0.6940967	total: 4.46s	remaining: 5.67s
# 440:	learn: 0.6937018	total: 4.47s	remaining: 5.66s
# 441:	learn: 0.6932766	total: 4.48s	remaining: 5.65s
# 442:	learn: 0.6929373	total: 4.49s	remaining: 5.64s
# 443:	learn: 0.6924783	total: 4.5s	remaining: 5.63s
# 444:	learn: 0.6920042	total: 4.51s	remaining: 5.62s
# 445:	learn: 0.6913297	total: 4.52s	remaining: 5.61s
# 446:	learn: 0.6907133	total: 4.53s	remaining: 5.6s
# 447:	learn: 0.6901589	total: 4.54s	remaining: 5.59s
# 448:	learn: 0.6896052	total: 4.55s	remaining: 5.58s
# 449:	learn: 0.6891638	total: 4.56s	remaining: 5.57s
# 450:	learn: 0.6887088	total: 4.57s	remaining: 5.56s
# 451:	learn: 0.6881806	total: 4.58s	remaining: 5.55s
# 452:	learn: 0.6878171	total: 4.59s	remaining: 5.54s
# 453:	learn: 0.6871910	total: 4.6s	remaining: 5.53s
# 454:	learn: 0.6866708	total: 4.61s	remaining: 5.52s
# 455:	learn: 0.6860659	total: 4.62s	remaining: 5.51s
# 456:	learn: 0.6857235	total: 4.63s	remaining: 5.5s
# 457:	learn: 0.6852062	total: 4.64s	remaining: 5.49s
# 458:	learn: 0.6846484	total: 4.65s	remaining: 5.48s
# 459:	learn: 0.6838895	total: 4.66s	remaining: 5.47s
# 460:	learn: 0.6835178	total: 4.67s	remaining: 5.46s
# 461:	learn: 0.6830805	total: 4.68s	remaining: 5.45s
# 462:	learn: 0.6827871	total: 4.69s	remaining: 5.44s
# 463:	learn: 0.6822978	total: 4.7s	remaining: 5.43s
# 464:	learn: 0.6819380	total: 4.71s	remaining: 5.42s
# 465:	learn: 0.6813979	total: 4.72s	remaining: 5.41s
# 466:	learn: 0.6809154	total: 4.73s	remaining: 5.39s
# 467:	learn: 0.6802676	total: 4.74s	remaining: 5.38s
# 468:	learn: 0.6799708	total: 4.75s	remaining: 5.37s
# 469:	learn: 0.6793558	total: 4.76s	remaining: 5.36s
# 470:	learn: 0.6789735	total: 4.77s	remaining: 5.35s
# 471:	learn: 0.6784434	total: 4.78s	remaining: 5.34s
# 472:	learn: 0.6778884	total: 4.79s	remaining: 5.33s
# 473:	learn: 0.6774913	total: 4.8s	remaining: 5.32s
# 474:	learn: 0.6768906	total: 4.81s	remaining: 5.31s
# 475:	learn: 0.6763593	total: 4.82s	remaining: 5.3s
# 476:	learn: 0.6756611	total: 4.83s	remaining: 5.29s
# 477:	learn: 0.6751761	total: 4.84s	remaining: 5.28s
# 478:	learn: 0.6748243	total: 4.85s	remaining: 5.27s
# 479:	learn: 0.6743539	total: 4.86s	remaining: 5.26s
# 480:	learn: 0.6737143	total: 4.87s	remaining: 5.25s
# 481:	learn: 0.6731782	total: 4.88s	remaining: 5.24s
# 482:	learn: 0.6728338	total: 4.89s	remaining: 5.23s
# 483:	learn: 0.6725524	total: 4.9s	remaining: 5.22s
# 484:	learn: 0.6721727	total: 4.91s	remaining: 5.21s
# 485:	learn: 0.6716270	total: 4.92s	remaining: 5.2s
# 486:	learn: 0.6710351	total: 4.93s	remaining: 5.19s
# 487:	learn: 0.6705540	total: 4.94s	remaining: 5.18s
# 488:	learn: 0.6700901	total: 4.95s	remaining: 5.17s
# 489:	learn: 0.6696369	total: 4.96s	remaining: 5.16s
# 490:	learn: 0.6693576	total: 4.97s	remaining: 5.15s
# 491:	learn: 0.6687515	total: 4.98s	remaining: 5.14s
# 492:	learn: 0.6681628	total: 4.99s	remaining: 5.13s
# 493:	learn: 0.6677252	total: 5s	remaining: 5.12s
# 494:	learn: 0.6673093	total: 5.01s	remaining: 5.11s
# 495:	learn: 0.6666761	total: 5.02s	remaining: 5.1s
# 496:	learn: 0.6662277	total: 5.03s	remaining: 5.09s
# 497:	learn: 0.6657067	total: 5.04s	remaining: 5.08s
# 498:	learn: 0.6652342	total: 5.05s	remaining: 5.07s
# 499:	learn: 0.6647466	total: 5.06s	remaining: 5.06s
# 500:	learn: 0.6643769	total: 5.07s	remaining: 5.05s
# 501:	learn: 0.6639422	total: 5.08s	remaining: 5.04s
# 502:	learn: 0.6634789	total: 5.09s	remaining: 5.03s
# 503:	learn: 0.6631077	total: 5.1s	remaining: 5.02s
# 504:	learn: 0.6627762	total: 5.11s	remaining: 5.01s
# 505:	learn: 0.6622453	total: 5.12s	remaining: 5s
# 506:	learn: 0.6617208	total: 5.13s	remaining: 4.99s
# 507:	learn: 0.6611767	total: 5.14s	remaining: 4.98s
# 508:	learn: 0.6608137	total: 5.15s	remaining: 4.97s
# 509:	learn: 0.6603665	total: 5.16s	remaining: 4.96s
# 510:	learn: 0.6600230	total: 5.17s	remaining: 4.95s
# 511:	learn: 0.6596929	total: 5.18s	remaining: 4.94s
# 512:	learn: 0.6593320	total: 5.19s	remaining: 4.93s
# 513:	learn: 0.6589632	total: 5.2s	remaining: 4.92s
# 514:	learn: 0.6585718	total: 5.21s	remaining: 4.91s
# 515:	learn: 0.6581783	total: 5.22s	remaining: 4.9s
# 516:	learn: 0.6577531	total: 5.23s	remaining: 4.89s
# 517:	learn: 0.6573158	total: 5.24s	remaining: 4.88s
# 518:	learn: 0.6567329	total: 5.25s	remaining: 4.87s
# 519:	learn: 0.6560084	total: 5.26s	remaining: 4.86s
# 520:	learn: 0.6555347	total: 5.27s	remaining: 4.85s
# 521:	learn: 0.6550365	total: 5.29s	remaining: 4.84s
# 522:	learn: 0.6545722	total: 5.29s	remaining: 4.83s
# 523:	learn: 0.6540788	total: 5.3s	remaining: 4.82s
# 524:	learn: 0.6536506	total: 5.32s	remaining: 4.81s
# 525:	learn: 0.6531209	total: 5.33s	remaining: 4.8s
# 526:	learn: 0.6526144	total: 5.34s	remaining: 4.79s
# 527:	learn: 0.6522696	total: 5.35s	remaining: 4.78s
# 528:	learn: 0.6518293	total: 5.36s	remaining: 4.77s
# 529:	learn: 0.6514721	total: 5.37s	remaining: 4.76s
# 530:	learn: 0.6509771	total: 5.38s	remaining: 4.75s
# 531:	learn: 0.6503814	total: 5.39s	remaining: 4.74s
# 532:	learn: 0.6498111	total: 5.4s	remaining: 4.73s
# 533:	learn: 0.6495204	total: 5.41s	remaining: 4.72s
# 534:	learn: 0.6490590	total: 5.42s	remaining: 4.71s
# 535:	learn: 0.6485891	total: 5.43s	remaining: 4.7s
# 536:	learn: 0.6481282	total: 5.44s	remaining: 4.69s
# 537:	learn: 0.6477479	total: 5.45s	remaining: 4.68s
# 538:	learn: 0.6473811	total: 5.46s	remaining: 4.67s
# 539:	learn: 0.6467889	total: 5.47s	remaining: 4.66s
# 540:	learn: 0.6463372	total: 5.48s	remaining: 4.65s
# 541:	learn: 0.6459207	total: 5.49s	remaining: 4.64s
# 542:	learn: 0.6454646	total: 5.5s	remaining: 4.63s
# 543:	learn: 0.6449528	total: 5.51s	remaining: 4.62s
# 544:	learn: 0.6445250	total: 5.52s	remaining: 4.61s
# 545:	learn: 0.6440498	total: 5.53s	remaining: 4.6s
# 546:	learn: 0.6435306	total: 5.54s	remaining: 4.59s
# 547:	learn: 0.6431130	total: 5.55s	remaining: 4.58s
# 548:	learn: 0.6424819	total: 5.56s	remaining: 4.57s
# 549:	learn: 0.6420077	total: 5.57s	remaining: 4.56s
# 550:	learn: 0.6416912	total: 5.58s	remaining: 4.55s
# 551:	learn: 0.6413676	total: 5.59s	remaining: 4.54s
# 552:	learn: 0.6406736	total: 5.6s	remaining: 4.53s
# 553:	learn: 0.6401942	total: 5.61s	remaining: 4.52s
# 554:	learn: 0.6397854	total: 5.62s	remaining: 4.51s
# 555:	learn: 0.6393446	total: 5.63s	remaining: 4.5s
# 556:	learn: 0.6388420	total: 5.64s	remaining: 4.49s
# 557:	learn: 0.6385951	total: 5.65s	remaining: 4.47s
# 558:	learn: 0.6380258	total: 5.66s	remaining: 4.46s
# 559:	learn: 0.6375383	total: 5.67s	remaining: 4.46s
# 560:	learn: 0.6369928	total: 5.68s	remaining: 4.45s
# 561:	learn: 0.6367435	total: 5.69s	remaining: 4.44s
# 562:	learn: 0.6363590	total: 5.71s	remaining: 4.43s
# 563:	learn: 0.6358295	total: 5.72s	remaining: 4.42s
# 564:	learn: 0.6354061	total: 5.73s	remaining: 4.41s
# 565:	learn: 0.6348226	total: 5.74s	remaining: 4.4s
# 566:	learn: 0.6343479	total: 5.75s	remaining: 4.39s
# 567:	learn: 0.6338759	total: 5.76s	remaining: 4.38s
# 568:	learn: 0.6335808	total: 5.77s	remaining: 4.37s
# 569:	learn: 0.6331333	total: 5.78s	remaining: 4.36s
# 570:	learn: 0.6327862	total: 5.79s	remaining: 4.35s
# 571:	learn: 0.6321280	total: 5.8s	remaining: 4.34s
# 572:	learn: 0.6315293	total: 5.81s	remaining: 4.33s
# 573:	learn: 0.6312044	total: 5.82s	remaining: 4.32s
# 574:	learn: 0.6307122	total: 5.83s	remaining: 4.31s
# 575:	learn: 0.6303033	total: 5.84s	remaining: 4.3s
# 576:	learn: 0.6298830	total: 5.85s	remaining: 4.29s
# 577:	learn: 0.6292575	total: 5.86s	remaining: 4.28s
# 578:	learn: 0.6289408	total: 5.87s	remaining: 4.27s
# 579:	learn: 0.6281955	total: 5.88s	remaining: 4.26s
# 580:	learn: 0.6277112	total: 5.89s	remaining: 4.25s
# 581:	learn: 0.6273172	total: 5.9s	remaining: 4.24s
# 582:	learn: 0.6268973	total: 5.91s	remaining: 4.23s
# 583:	learn: 0.6265070	total: 5.92s	remaining: 4.22s
# 584:	learn: 0.6262493	total: 5.93s	remaining: 4.21s
# 585:	learn: 0.6259689	total: 5.94s	remaining: 4.2s
# 586:	learn: 0.6256311	total: 5.95s	remaining: 4.18s
# 587:	learn: 0.6251623	total: 5.96s	remaining: 4.17s
# 588:	learn: 0.6247530	total: 5.97s	remaining: 4.16s
# 589:	learn: 0.6241553	total: 5.98s	remaining: 4.15s
# 590:	learn: 0.6238196	total: 5.99s	remaining: 4.14s
# 591:	learn: 0.6234567	total: 6s	remaining: 4.13s
# 592:	learn: 0.6231406	total: 6.01s	remaining: 4.12s
# 593:	learn: 0.6228297	total: 6.02s	remaining: 4.11s
# 594:	learn: 0.6225072	total: 6.03s	remaining: 4.1s
# 595:	learn: 0.6221731	total: 6.04s	remaining: 4.09s
# 596:	learn: 0.6216901	total: 6.05s	remaining: 4.08s
# 597:	learn: 0.6212833	total: 6.06s	remaining: 4.07s
# 598:	learn: 0.6206147	total: 6.07s	remaining: 4.06s
# 599:	learn: 0.6202402	total: 6.08s	remaining: 4.05s
# 600:	learn: 0.6198754	total: 6.08s	remaining: 4.04s
# 601:	learn: 0.6193092	total: 6.09s	remaining: 4.03s
# 602:	learn: 0.6189434	total: 6.11s	remaining: 4.02s
# 603:	learn: 0.6185931	total: 6.12s	remaining: 4.01s
# 604:	learn: 0.6181250	total: 6.13s	remaining: 4s
# 605:	learn: 0.6176645	total: 6.13s	remaining: 3.99s
# 606:	learn: 0.6173670	total: 6.14s	remaining: 3.98s
# 607:	learn: 0.6170808	total: 6.15s	remaining: 3.97s
# 608:	learn: 0.6166751	total: 6.16s	remaining: 3.96s
# 609:	learn: 0.6162187	total: 6.17s	remaining: 3.95s
# 610:	learn: 0.6157553	total: 6.18s	remaining: 3.94s
# 611:	learn: 0.6153258	total: 6.19s	remaining: 3.93s
# 612:	learn: 0.6148966	total: 6.2s	remaining: 3.92s
# 613:	learn: 0.6144990	total: 6.21s	remaining: 3.91s
# 614:	learn: 0.6141519	total: 6.22s	remaining: 3.9s
# 615:	learn: 0.6134952	total: 6.23s	remaining: 3.88s
# 616:	learn: 0.6129805	total: 6.24s	remaining: 3.88s
# 617:	learn: 0.6124674	total: 6.25s	remaining: 3.86s
# 618:	learn: 0.6118192	total: 6.26s	remaining: 3.85s
# 619:	learn: 0.6112056	total: 6.27s	remaining: 3.85s
# 620:	learn: 0.6107965	total: 6.28s	remaining: 3.83s
# 621:	learn: 0.6103776	total: 6.29s	remaining: 3.82s
# 622:	learn: 0.6098921	total: 6.3s	remaining: 3.81s
# 623:	learn: 0.6094814	total: 6.31s	remaining: 3.8s
# 624:	learn: 0.6089358	total: 6.32s	remaining: 3.79s
# 625:	learn: 0.6084120	total: 6.33s	remaining: 3.78s
# 626:	learn: 0.6078306	total: 6.34s	remaining: 3.77s
# 627:	learn: 0.6075296	total: 6.35s	remaining: 3.76s
# 628:	learn: 0.6071445	total: 6.36s	remaining: 3.75s
# 629:	learn: 0.6065776	total: 6.37s	remaining: 3.74s
# 630:	learn: 0.6061230	total: 6.38s	remaining: 3.73s
# 631:	learn: 0.6056398	total: 6.39s	remaining: 3.72s
# 632:	learn: 0.6052077	total: 6.4s	remaining: 3.71s
# 633:	learn: 0.6048856	total: 6.41s	remaining: 3.7s
# 634:	learn: 0.6045605	total: 6.42s	remaining: 3.69s
# 635:	learn: 0.6042607	total: 6.43s	remaining: 3.68s
# 636:	learn: 0.6038411	total: 6.44s	remaining: 3.67s
# 637:	learn: 0.6034430	total: 6.45s	remaining: 3.66s
# 638:	learn: 0.6031978	total: 6.46s	remaining: 3.65s
# 639:	learn: 0.6026961	total: 6.47s	remaining: 3.64s
# 640:	learn: 0.6022501	total: 6.48s	remaining: 3.63s
# 641:	learn: 0.6018997	total: 6.49s	remaining: 3.62s
# 642:	learn: 0.6013882	total: 6.5s	remaining: 3.61s
# 643:	learn: 0.6008594	total: 6.51s	remaining: 3.6s
# 644:	learn: 0.6005130	total: 6.52s	remaining: 3.59s
# 645:	learn: 0.6000341	total: 6.53s	remaining: 3.58s
# 646:	learn: 0.5995388	total: 6.54s	remaining: 3.57s
# 647:	learn: 0.5990868	total: 6.55s	remaining: 3.56s
# 648:	learn: 0.5985741	total: 6.56s	remaining: 3.55s
# 649:	learn: 0.5981972	total: 6.57s	remaining: 3.54s
# 650:	learn: 0.5976695	total: 6.58s	remaining: 3.53s
# 651:	learn: 0.5972503	total: 6.59s	remaining: 3.52s
# 652:	learn: 0.5966994	total: 6.6s	remaining: 3.51s
# 653:	learn: 0.5963714	total: 6.61s	remaining: 3.5s
# 654:	learn: 0.5959374	total: 6.62s	remaining: 3.48s
# 655:	learn: 0.5955115	total: 6.63s	remaining: 3.48s
# 656:	learn: 0.5951217	total: 6.64s	remaining: 3.46s
# 657:	learn: 0.5946556	total: 6.65s	remaining: 3.46s
# 658:	learn: 0.5941705	total: 6.66s	remaining: 3.44s
# 659:	learn: 0.5935924	total: 6.67s	remaining: 3.44s
# 660:	learn: 0.5933070	total: 6.68s	remaining: 3.42s
# 661:	learn: 0.5928670	total: 6.69s	remaining: 3.41s
# 662:	learn: 0.5924668	total: 6.7s	remaining: 3.4s
# 663:	learn: 0.5919566	total: 6.71s	remaining: 3.39s
# 664:	learn: 0.5915242	total: 6.72s	remaining: 3.38s
# 665:	learn: 0.5911370	total: 6.73s	remaining: 3.37s
# 666:	learn: 0.5907283	total: 6.74s	remaining: 3.36s
# 667:	learn: 0.5901802	total: 6.75s	remaining: 3.35s
# 668:	learn: 0.5898458	total: 6.76s	remaining: 3.34s
# 669:	learn: 0.5893427	total: 6.77s	remaining: 3.33s
# 670:	learn: 0.5888805	total: 6.78s	remaining: 3.32s
# 671:	learn: 0.5885024	total: 6.79s	remaining: 3.31s
# 672:	learn: 0.5881537	total: 6.8s	remaining: 3.3s
# 673:	learn: 0.5876675	total: 6.81s	remaining: 3.29s
# 674:	learn: 0.5873890	total: 6.82s	remaining: 3.28s
# 675:	learn: 0.5868848	total: 6.83s	remaining: 3.27s
# 676:	learn: 0.5866115	total: 6.84s	remaining: 3.26s
# 677:	learn: 0.5861558	total: 6.85s	remaining: 3.25s
# 678:	learn: 0.5856517	total: 6.86s	remaining: 3.24s
# 679:	learn: 0.5851276	total: 6.87s	remaining: 3.23s
# 680:	learn: 0.5847220	total: 6.88s	remaining: 3.22s
# 681:	learn: 0.5841941	total: 6.89s	remaining: 3.21s
# 682:	learn: 0.5836050	total: 6.9s	remaining: 3.2s
# 683:	learn: 0.5831372	total: 6.91s	remaining: 3.19s
# 684:	learn: 0.5827018	total: 6.92s	remaining: 3.18s
# 685:	learn: 0.5822822	total: 6.93s	remaining: 3.17s
# 686:	learn: 0.5818819	total: 6.94s	remaining: 3.16s
# 687:	learn: 0.5812616	total: 6.95s	remaining: 3.15s
# 688:	learn: 0.5808065	total: 6.96s	remaining: 3.14s
# 689:	learn: 0.5803543	total: 6.97s	remaining: 3.13s
# 690:	learn: 0.5800266	total: 6.99s	remaining: 3.12s
# 691:	learn: 0.5794882	total: 7s	remaining: 3.11s
# 692:	learn: 0.5789202	total: 7.01s	remaining: 3.1s
# 693:	learn: 0.5783285	total: 7.02s	remaining: 3.09s
# 694:	learn: 0.5778695	total: 7.03s	remaining: 3.08s
# 695:	learn: 0.5774368	total: 7.04s	remaining: 3.07s
# 696:	learn: 0.5770403	total: 7.05s	remaining: 3.06s
# 697:	learn: 0.5764845	total: 7.06s	remaining: 3.05s
# 698:	learn: 0.5760766	total: 7.07s	remaining: 3.04s
# 699:	learn: 0.5757117	total: 7.08s	remaining: 3.03s
# 700:	learn: 0.5754702	total: 7.09s	remaining: 3.02s
# 701:	learn: 0.5750834	total: 7.1s	remaining: 3.01s
# 702:	learn: 0.5744503	total: 7.11s	remaining: 3s
# 703:	learn: 0.5740307	total: 7.12s	remaining: 2.99s
# 704:	learn: 0.5736402	total: 7.13s	remaining: 2.98s
# 705:	learn: 0.5733316	total: 7.14s	remaining: 2.97s
# 706:	learn: 0.5728466	total: 7.15s	remaining: 2.96s
# 707:	learn: 0.5724539	total: 7.16s	remaining: 2.95s
# 708:	learn: 0.5719980	total: 7.17s	remaining: 2.94s
# 709:	learn: 0.5713850	total: 7.18s	remaining: 2.93s
# 710:	learn: 0.5707781	total: 7.19s	remaining: 2.92s
# 711:	learn: 0.5704525	total: 7.2s	remaining: 2.91s
# 712:	learn: 0.5701533	total: 7.21s	remaining: 2.9s
# 713:	learn: 0.5697656	total: 7.22s	remaining: 2.89s
# 714:	learn: 0.5693009	total: 7.23s	remaining: 2.88s
# 715:	learn: 0.5689652	total: 7.24s	remaining: 2.87s
# 716:	learn: 0.5685887	total: 7.25s	remaining: 2.86s
# 717:	learn: 0.5681935	total: 7.26s	remaining: 2.85s
# 718:	learn: 0.5677682	total: 7.28s	remaining: 2.84s
# 719:	learn: 0.5674391	total: 7.29s	remaining: 2.83s
# 720:	learn: 0.5669922	total: 7.3s	remaining: 2.82s
# 721:	learn: 0.5666746	total: 7.31s	remaining: 2.81s
# 722:	learn: 0.5662224	total: 7.32s	remaining: 2.8s
# 723:	learn: 0.5657499	total: 7.33s	remaining: 2.79s
# 724:	learn: 0.5653127	total: 7.34s	remaining: 2.78s
# 725:	learn: 0.5650124	total: 7.35s	remaining: 2.77s
# 726:	learn: 0.5645390	total: 7.36s	remaining: 2.76s
# 727:	learn: 0.5640990	total: 7.37s	remaining: 2.75s
# 728:	learn: 0.5636449	total: 7.38s	remaining: 2.74s
# 729:	learn: 0.5631907	total: 7.39s	remaining: 2.73s
# 730:	learn: 0.5627099	total: 7.4s	remaining: 2.72s
# 731:	learn: 0.5623682	total: 7.42s	remaining: 2.71s
# 732:	learn: 0.5620370	total: 7.42s	remaining: 2.7s
# 733:	learn: 0.5616785	total: 7.43s	remaining: 2.69s
# 734:	learn: 0.5612945	total: 7.44s	remaining: 2.68s
# 735:	learn: 0.5610774	total: 7.45s	remaining: 2.67s
# 736:	learn: 0.5606617	total: 7.46s	remaining: 2.66s
# 737:	learn: 0.5603091	total: 7.47s	remaining: 2.65s
# 738:	learn: 0.5600314	total: 7.48s	remaining: 2.64s
# 739:	learn: 0.5597802	total: 7.49s	remaining: 2.63s
# 740:	learn: 0.5593957	total: 7.5s	remaining: 2.62s
# 741:	learn: 0.5589478	total: 7.51s	remaining: 2.61s
# 742:	learn: 0.5585237	total: 7.52s	remaining: 2.6s
# 743:	learn: 0.5580935	total: 7.53s	remaining: 2.59s
# 744:	learn: 0.5577354	total: 7.54s	remaining: 2.58s
# 745:	learn: 0.5573068	total: 7.55s	remaining: 2.57s
# 746:	learn: 0.5569357	total: 7.56s	remaining: 2.56s
# 747:	learn: 0.5565979	total: 7.57s	remaining: 2.55s
# 748:	learn: 0.5562135	total: 7.58s	remaining: 2.54s
# 749:	learn: 0.5558322	total: 7.59s	remaining: 2.53s
# 750:	learn: 0.5554399	total: 7.6s	remaining: 2.52s
# 751:	learn: 0.5550415	total: 7.61s	remaining: 2.51s
# 752:	learn: 0.5546556	total: 7.62s	remaining: 2.5s
# 753:	learn: 0.5543158	total: 7.63s	remaining: 2.49s
# 754:	learn: 0.5537943	total: 7.64s	remaining: 2.48s
# 755:	learn: 0.5534648	total: 7.66s	remaining: 2.47s
# 756:	learn: 0.5530755	total: 7.67s	remaining: 2.46s
# 757:	learn: 0.5527065	total: 7.68s	remaining: 2.45s
# 758:	learn: 0.5522922	total: 7.69s	remaining: 2.44s
# 759:	learn: 0.5519645	total: 7.7s	remaining: 2.43s
# 760:	learn: 0.5514878	total: 7.71s	remaining: 2.42s
# 761:	learn: 0.5509360	total: 7.72s	remaining: 2.41s
# 762:	learn: 0.5504816	total: 7.73s	remaining: 2.4s
# 763:	learn: 0.5501119	total: 7.74s	remaining: 2.39s
# 764:	learn: 0.5497764	total: 7.75s	remaining: 2.38s
# 765:	learn: 0.5492433	total: 7.76s	remaining: 2.37s
# 766:	learn: 0.5488189	total: 7.77s	remaining: 2.36s
# 767:	learn: 0.5482725	total: 7.78s	remaining: 2.35s
# 768:	learn: 0.5478699	total: 7.79s	remaining: 2.34s
# 769:	learn: 0.5475402	total: 7.8s	remaining: 2.33s
# 770:	learn: 0.5472988	total: 7.81s	remaining: 2.32s
# 771:	learn: 0.5468987	total: 7.82s	remaining: 2.31s
# 772:	learn: 0.5463279	total: 7.83s	remaining: 2.3s
# 773:	learn: 0.5460311	total: 7.84s	remaining: 2.29s
# 774:	learn: 0.5456929	total: 7.85s	remaining: 2.28s
# 775:	learn: 0.5452216	total: 7.86s	remaining: 2.27s
# 776:	learn: 0.5448907	total: 7.87s	remaining: 2.26s
# 777:	learn: 0.5444200	total: 7.88s	remaining: 2.25s
# 778:	learn: 0.5438577	total: 7.89s	remaining: 2.24s
# 779:	learn: 0.5434415	total: 7.9s	remaining: 2.23s
# 780:	learn: 0.5431027	total: 7.91s	remaining: 2.22s
# 781:	learn: 0.5426387	total: 7.92s	remaining: 2.21s
# 782:	learn: 0.5423833	total: 7.93s	remaining: 2.2s
# 783:	learn: 0.5420037	total: 7.94s	remaining: 2.19s
# 784:	learn: 0.5416169	total: 7.95s	remaining: 2.18s
# 785:	learn: 0.5413499	total: 7.96s	remaining: 2.17s
# 786:	learn: 0.5409405	total: 7.97s	remaining: 2.16s
# 787:	learn: 0.5405723	total: 7.98s	remaining: 2.15s
# 788:	learn: 0.5402457	total: 7.99s	remaining: 2.14s
# 789:	learn: 0.5399646	total: 8.01s	remaining: 2.13s
# 790:	learn: 0.5395624	total: 8.02s	remaining: 2.12s
# 791:	learn: 0.5392901	total: 8.03s	remaining: 2.11s
# 792:	learn: 0.5390068	total: 8.04s	remaining: 2.1s
# 793:	learn: 0.5386740	total: 8.05s	remaining: 2.09s
# 794:	learn: 0.5383203	total: 8.06s	remaining: 2.08s
# 795:	learn: 0.5378889	total: 8.07s	remaining: 2.07s
# 796:	learn: 0.5373983	total: 8.08s	remaining: 2.06s
# 797:	learn: 0.5368713	total: 8.09s	remaining: 2.05s
# 798:	learn: 0.5362652	total: 8.1s	remaining: 2.04s
# 799:	learn: 0.5358041	total: 8.11s	remaining: 2.03s
# 800:	learn: 0.5355139	total: 8.12s	remaining: 2.02s
# 801:	learn: 0.5350190	total: 8.13s	remaining: 2.01s
# 802:	learn: 0.5345033	total: 8.14s	remaining: 2s
# 803:	learn: 0.5342339	total: 8.15s	remaining: 1.99s
# 804:	learn: 0.5337779	total: 8.16s	remaining: 1.98s
# 805:	learn: 0.5333766	total: 8.17s	remaining: 1.97s
# 806:	learn: 0.5329717	total: 8.18s	remaining: 1.96s
# 807:	learn: 0.5324308	total: 8.19s	remaining: 1.95s
# 808:	learn: 0.5321118	total: 8.2s	remaining: 1.94s
# 809:	learn: 0.5317887	total: 8.21s	remaining: 1.93s
# 810:	learn: 0.5314816	total: 8.22s	remaining: 1.92s
# 811:	learn: 0.5310610	total: 8.23s	remaining: 1.91s
# 812:	learn: 0.5306785	total: 8.24s	remaining: 1.9s
# 813:	learn: 0.5302585	total: 8.25s	remaining: 1.89s
# 814:	learn: 0.5298611	total: 8.26s	remaining: 1.88s
# 815:	learn: 0.5295561	total: 8.27s	remaining: 1.86s
# 816:	learn: 0.5289996	total: 8.28s	remaining: 1.85s
# 817:	learn: 0.5286854	total: 8.29s	remaining: 1.84s
# 818:	learn: 0.5282522	total: 8.3s	remaining: 1.83s
# 819:	learn: 0.5278669	total: 8.31s	remaining: 1.82s
# 820:	learn: 0.5275315	total: 8.32s	remaining: 1.81s
# 821:	learn: 0.5270509	total: 8.34s	remaining: 1.8s
# 822:	learn: 0.5268129	total: 8.35s	remaining: 1.79s
# 823:	learn: 0.5265421	total: 8.36s	remaining: 1.78s
# 824:	learn: 0.5260774	total: 8.37s	remaining: 1.77s
# 825:	learn: 0.5256543	total: 8.38s	remaining: 1.76s
# 826:	learn: 0.5253662	total: 8.39s	remaining: 1.75s
# 827:	learn: 0.5249304	total: 8.4s	remaining: 1.74s
# 828:	learn: 0.5245734	total: 8.41s	remaining: 1.73s
# 829:	learn: 0.5242482	total: 8.42s	remaining: 1.72s
# 830:	learn: 0.5238844	total: 8.43s	remaining: 1.71s
# 831:	learn: 0.5233707	total: 8.44s	remaining: 1.7s
# 832:	learn: 0.5230945	total: 8.45s	remaining: 1.69s
# 833:	learn: 0.5227481	total: 8.46s	remaining: 1.68s
# 834:	learn: 0.5222517	total: 8.47s	remaining: 1.67s
# 835:	learn: 0.5218790	total: 8.48s	remaining: 1.66s
# 836:	learn: 0.5214520	total: 8.49s	remaining: 1.65s
# 837:	learn: 0.5210067	total: 8.5s	remaining: 1.64s
# 838:	learn: 0.5204641	total: 8.51s	remaining: 1.63s
# 839:	learn: 0.5201589	total: 8.52s	remaining: 1.62s
# 840:	learn: 0.5196564	total: 8.53s	remaining: 1.61s
# 841:	learn: 0.5193938	total: 8.54s	remaining: 1.6s
# 842:	learn: 0.5190216	total: 8.55s	remaining: 1.59s
# 843:	learn: 0.5187162	total: 8.56s	remaining: 1.58s
# 844:	learn: 0.5183549	total: 8.57s	remaining: 1.57s
# 845:	learn: 0.5180547	total: 8.58s	remaining: 1.56s
# 846:	learn: 0.5177505	total: 8.59s	remaining: 1.55s
# 847:	learn: 0.5173542	total: 8.6s	remaining: 1.54s
# 848:	learn: 0.5170075	total: 8.61s	remaining: 1.53s
# 849:	learn: 0.5166371	total: 8.62s	remaining: 1.52s
# 850:	learn: 0.5162811	total: 8.63s	remaining: 1.51s
# 851:	learn: 0.5158575	total: 8.64s	remaining: 1.5s
# 852:	learn: 0.5156035	total: 8.65s	remaining: 1.49s
# 853:	learn: 0.5151118	total: 8.66s	remaining: 1.48s
# 854:	learn: 0.5146366	total: 8.67s	remaining: 1.47s
# 855:	learn: 0.5141951	total: 8.68s	remaining: 1.46s
# 856:	learn: 0.5139268	total: 8.69s	remaining: 1.45s
# 857:	learn: 0.5137067	total: 8.7s	remaining: 1.44s
# 858:	learn: 0.5133773	total: 8.71s	remaining: 1.43s
# 859:	learn: 0.5130917	total: 8.72s	remaining: 1.42s
# 860:	learn: 0.5128210	total: 8.73s	remaining: 1.41s
# 861:	learn: 0.5123007	total: 8.74s	remaining: 1.4s
# 862:	learn: 0.5118332	total: 8.75s	remaining: 1.39s
# 863:	learn: 0.5113849	total: 8.76s	remaining: 1.38s
# 864:	learn: 0.5111019	total: 8.77s	remaining: 1.37s
# 865:	learn: 0.5108246	total: 8.78s	remaining: 1.36s
# 866:	learn: 0.5106172	total: 8.79s	remaining: 1.35s
# 867:	learn: 0.5101863	total: 8.8s	remaining: 1.34s
# 868:	learn: 0.5097324	total: 8.81s	remaining: 1.33s
# 869:	learn: 0.5094713	total: 8.82s	remaining: 1.32s
# 870:	learn: 0.5091186	total: 8.83s	remaining: 1.31s
# 871:	learn: 0.5087452	total: 8.84s	remaining: 1.3s
# 872:	learn: 0.5084605	total: 8.85s	remaining: 1.29s
# 873:	learn: 0.5080663	total: 8.86s	remaining: 1.28s
# 874:	learn: 0.5076836	total: 8.87s	remaining: 1.27s
# 875:	learn: 0.5073587	total: 8.88s	remaining: 1.26s
# 876:	learn: 0.5070198	total: 8.89s	remaining: 1.25s
# 877:	learn: 0.5066784	total: 8.9s	remaining: 1.24s
# 878:	learn: 0.5061504	total: 8.91s	remaining: 1.23s
# 879:	learn: 0.5057271	total: 8.92s	remaining: 1.22s
# 880:	learn: 0.5053690	total: 8.93s	remaining: 1.21s
# 881:	learn: 0.5049143	total: 8.94s	remaining: 1.2s
# 882:	learn: 0.5043845	total: 8.95s	remaining: 1.19s
# 883:	learn: 0.5040295	total: 8.96s	remaining: 1.18s
# 884:	learn: 0.5035590	total: 8.97s	remaining: 1.17s
# 885:	learn: 0.5032381	total: 8.98s	remaining: 1.16s
# 886:	learn: 0.5028589	total: 8.99s	remaining: 1.15s
# 887:	learn: 0.5025545	total: 9s	remaining: 1.14s
# 888:	learn: 0.5022080	total: 9.01s	remaining: 1.12s
# 889:	learn: 0.5018916	total: 9.02s	remaining: 1.11s
# 890:	learn: 0.5014655	total: 9.03s	remaining: 1.1s
# 891:	learn: 0.5011106	total: 9.04s	remaining: 1.09s
# 892:	learn: 0.5008442	total: 9.05s	remaining: 1.08s
# 893:	learn: 0.5003621	total: 9.06s	remaining: 1.07s
# 894:	learn: 0.4999764	total: 9.07s	remaining: 1.06s
# 895:	learn: 0.4995407	total: 9.08s	remaining: 1.05s
# 896:	learn: 0.4992042	total: 9.09s	remaining: 1.04s
# 897:	learn: 0.4988626	total: 9.1s	remaining: 1.03s
# 898:	learn: 0.4984136	total: 9.11s	remaining: 1.02s
# 899:	learn: 0.4980420	total: 9.12s	remaining: 1.01s
# 900:	learn: 0.4978223	total: 9.13s	remaining: 1s
# 901:	learn: 0.4974507	total: 9.14s	remaining: 993ms
# 902:	learn: 0.4972448	total: 9.15s	remaining: 983ms
# 903:	learn: 0.4969063	total: 9.16s	remaining: 973ms
# 904:	learn: 0.4965976	total: 9.17s	remaining: 963ms
# 905:	learn: 0.4962651	total: 9.18s	remaining: 953ms
# 906:	learn: 0.4959423	total: 9.19s	remaining: 943ms
# 907:	learn: 0.4954638	total: 9.21s	remaining: 933ms
# 908:	learn: 0.4951411	total: 9.21s	remaining: 923ms
# 909:	learn: 0.4948278	total: 9.23s	remaining: 912ms
# 910:	learn: 0.4945277	total: 9.24s	remaining: 902ms
# 911:	learn: 0.4940221	total: 9.25s	remaining: 892ms
# 912:	learn: 0.4934696	total: 9.26s	remaining: 882ms
# 913:	learn: 0.4930885	total: 9.27s	remaining: 872ms
# 914:	learn: 0.4927761	total: 9.28s	remaining: 862ms
# 915:	learn: 0.4924957	total: 9.29s	remaining: 852ms
# 916:	learn: 0.4921444	total: 9.3s	remaining: 842ms
# 917:	learn: 0.4918951	total: 9.31s	remaining: 831ms
# 918:	learn: 0.4914740	total: 9.32s	remaining: 821ms
# 919:	learn: 0.4910192	total: 9.33s	remaining: 811ms
# 920:	learn: 0.4906063	total: 9.34s	remaining: 801ms
# 921:	learn: 0.4903136	total: 9.35s	remaining: 791ms
# 922:	learn: 0.4900396	total: 9.36s	remaining: 781ms
# 923:	learn: 0.4897037	total: 9.37s	remaining: 771ms
# 924:	learn: 0.4894273	total: 9.38s	remaining: 761ms
# 925:	learn: 0.4891171	total: 9.39s	remaining: 750ms
# 926:	learn: 0.4887061	total: 9.4s	remaining: 740ms
# 927:	learn: 0.4882295	total: 9.41s	remaining: 730ms
# 928:	learn: 0.4879024	total: 9.42s	remaining: 720ms
# 929:	learn: 0.4875299	total: 9.43s	remaining: 710ms
# 930:	learn: 0.4871292	total: 9.44s	remaining: 700ms
# 931:	learn: 0.4868007	total: 9.45s	remaining: 689ms
# 932:	learn: 0.4863606	total: 9.46s	remaining: 679ms
# 933:	learn: 0.4859446	total: 9.47s	remaining: 669ms
# 934:	learn: 0.4855978	total: 9.48s	remaining: 659ms
# 935:	learn: 0.4852646	total: 9.49s	remaining: 649ms
# 936:	learn: 0.4849181	total: 9.5s	remaining: 639ms
# 937:	learn: 0.4845332	total: 9.51s	remaining: 629ms
# 938:	learn: 0.4843164	total: 9.52s	remaining: 619ms
# 939:	learn: 0.4838887	total: 9.53s	remaining: 608ms
# 940:	learn: 0.4835040	total: 9.54s	remaining: 598ms
# 941:	learn: 0.4830664	total: 9.55s	remaining: 588ms
# 942:	learn: 0.4825285	total: 9.56s	remaining: 578ms
# 943:	learn: 0.4821532	total: 9.57s	remaining: 568ms
# 944:	learn: 0.4818008	total: 9.59s	remaining: 558ms
# 945:	learn: 0.4814643	total: 9.6s	remaining: 548ms
# 946:	learn: 0.4812098	total: 9.6s	remaining: 538ms
# 947:	learn: 0.4808097	total: 9.61s	remaining: 527ms
# 948:	learn: 0.4804057	total: 9.63s	remaining: 517ms
# 949:	learn: 0.4801491	total: 9.63s	remaining: 507ms
# 950:	learn: 0.4798275	total: 9.64s	remaining: 497ms
# 951:	learn: 0.4794225	total: 9.65s	remaining: 487ms
# 952:	learn: 0.4790976	total: 9.66s	remaining: 477ms
# 953:	learn: 0.4787496	total: 9.68s	remaining: 467ms
# 954:	learn: 0.4785099	total: 9.69s	remaining: 456ms
# 955:	learn: 0.4781598	total: 9.7s	remaining: 446ms
# 956:	learn: 0.4776765	total: 9.71s	remaining: 436ms
# 957:	learn: 0.4771595	total: 9.72s	remaining: 426ms
# 958:	learn: 0.4769032	total: 9.73s	remaining: 416ms
# 959:	learn: 0.4765930	total: 9.74s	remaining: 406ms
# 960:	learn: 0.4761800	total: 9.75s	remaining: 396ms
# 961:	learn: 0.4759797	total: 9.76s	remaining: 385ms
# 962:	learn: 0.4755890	total: 9.77s	remaining: 375ms
# 963:	learn: 0.4752155	total: 9.78s	remaining: 365ms
# 964:	learn: 0.4747121	total: 9.79s	remaining: 355ms
# 965:	learn: 0.4742495	total: 9.79s	remaining: 345ms
# 966:	learn: 0.4739843	total: 9.81s	remaining: 335ms
# 967:	learn: 0.4735646	total: 9.82s	remaining: 325ms
# 968:	learn: 0.4733443	total: 9.82s	remaining: 314ms
# 969:	learn: 0.4731389	total: 9.83s	remaining: 304ms
# 970:	learn: 0.4727941	total: 9.84s	remaining: 294ms
# 971:	learn: 0.4724644	total: 9.85s	remaining: 284ms
# 972:	learn: 0.4720999	total: 9.87s	remaining: 274ms
# 973:	learn: 0.4718791	total: 9.88s	remaining: 264ms
# 974:	learn: 0.4714762	total: 9.89s	remaining: 253ms
# 975:	learn: 0.4710111	total: 9.9s	remaining: 243ms
# 976:	learn: 0.4706711	total: 9.91s	remaining: 233ms
# 977:	learn: 0.4703211	total: 9.92s	remaining: 223ms
# 978:	learn: 0.4700259	total: 9.93s	remaining: 213ms
# 979:	learn: 0.4696137	total: 9.94s	remaining: 203ms
# 980:	learn: 0.4693119	total: 9.95s	remaining: 193ms
# 981:	learn: 0.4690099	total: 9.96s	remaining: 183ms
# 982:	learn: 0.4687452	total: 9.97s	remaining: 172ms
# 983:	learn: 0.4683945	total: 9.98s	remaining: 162ms
# 984:	learn: 0.4680210	total: 9.99s	remaining: 152ms
# 985:	learn: 0.4677142	total: 10s	remaining: 142ms
# 986:	learn: 0.4673250	total: 10s	remaining: 132ms
# 987:	learn: 0.4670395	total: 10s	remaining: 122ms
# 988:	learn: 0.4665630	total: 10s	remaining: 112ms
# 989:	learn: 0.4663336	total: 10s	remaining: 101ms
# 990:	learn: 0.4657924	total: 10s	remaining: 91.3ms
# 991:	learn: 0.4656053	total: 10.1s	remaining: 81.1ms
# 992:	learn: 0.4650617	total: 10.1s	remaining: 71ms
# 993:	learn: 0.4647500	total: 10.1s	remaining: 60.8ms
# 994:	learn: 0.4643375	total: 10.1s	remaining: 50.7ms
# 995:	learn: 0.4640336	total: 10.1s	remaining: 40.6ms
# 996:	learn: 0.4637516	total: 10.1s	remaining: 30.4ms
# 997:	learn: 0.4634000	total: 10.1s	remaining: 20.3ms
# 998:	learn: 0.4631237	total: 10.1s	remaining: 10.1ms
# 999:	learn: 0.4627610	total: 10.1s	remaining: 0us

# %%
test_pred = clf.predict(test_embeds)
test_proba = clf.predict_proba(test_embeds)

# %%
print("Accuracy:", accuracy_score(target_test, test_pred))
print("ROC-AUC:", roc_auc_score(target_test, test_proba, average="weighted", multi_class="ovr"))
# Out:
# Accuracy: 0.5526666666666666
# ROC-AUC: 0.8083604141160274

# %%
arr = np.array([0.8119719125015539, 0.8194989765156216, 0.8083604141160274])

arr.mean(), arr.std()
# Out:
# (0.813277101044401, 0.004640009406003254)

# %% [markdown]
# - CPC context embeds + Catboost:
#    - `Accuracy: 0.5773333333333334`, `0.5686666666666667`, `0.5826666666666667`, avg: `0.5762 +- 0.0058`
#    - ` ROC-AUC: 0.830123007110738`, `0.8271157616313021`, `0.8343491131233265`, avg: `0.8305 +- 0.003`
#
# ---
#
# - CPC context embeds (w/ Aggregation by Days, 1 day) + Catboost:
#   - `Accuracy: 0.5566666666666666`, `0.5633333333333334`, `0.5666666666666667`, avg: `0.5622 +- 0.0042`
#   - `ROC-AUC: 0.8170450532014047`, `0.8193299016595438`, `0.8193262261512632`, avg: `0.8186 +- 0.0011`
#
# ---
#
# - CPC context embeds (w/ Aggregation by Days, 2 days) + Catboost:
#   - `Accuracy: 0.561`, `0.571`, `0.5726666666666667`, avg: `0.5682 +- 0.0052`
#   - `ROC-AUC: 0.8206436640112535`, `0.8229407334548793`, `0.8270720554974593`, avg: `0.8236 +- 0.0027`
#
# ---
#
# - CPC context embeds (w/ Aggregation by Days, 2 days; w/ 'No Trx' Indicators) + Catboost:
#   - `Accuracy: 0.5573333333333333`, `0.5723333333333334`, `0.5526666666666666`, avg: `0.5608 +- 0.0084`
#   - `ROC-AUC: 0.8119719125015539`, `0.8194989765156216`, `0.8083604141160274`, avg: `0.8133 +- 0.0046`
#
# ---
#
# **Логика + Вывод:** для CPC агрегация по времени также приводит к худшему, чем в случае бейзлайна, качеству. При этом, в отличие от CoLES, с увеличением периода времени, учитываемого при агрегации, качество становится лучше (хотя далее эксперименты не проводились, предполагается, что с увеличением учитываемого при агрегации периода времени значения метрик в итоге выйдут на плато, а затем начнут ухудшаться - из-за слишком сильного сжатия информации).
#
# Так как для агрегации по двум дням результаты значительно лучше, чем для агрегации по одному дню, будем далее экспериментировать с этой конфигурацией (агрегация по двум дням). В частности, попробуем добавить в дни, в которые не было ни одной транзакции специальные транзакции-индикаторы, означающие отсутствие в этот день транзакций.
#
# Получили, что для конфигурации c транзакциями-индикаторами результаты оказались значительно хуже, чем для обычной агрегации по 2 дням, как по accuracy, так и по ROC-AUC.
#
# **Лучший по метрикам результат:**
#
# - CPC context embeds (w/ Aggregation by Days, 2 days) + Catboost:
#   - `Accuracy: 0.561`, `0.571`, `0.5726666666666667`, avg: `0.5682 +- 0.0052`
#   - `ROC-AUC: 0.8206436640112535`, `0.8229407334548793`, `0.8270720554974593`, avg: `0.8236 +- 0.0027`

# %% [markdown]
# ---

# %% [markdown]
# # Итоги.

# %% [markdown]
# | Method|Accuracy|ROC-AUC|
# | --- |:---:|:---:|
# | **Flattened Sequences**                   | 0.4921 ± 0.005        | 0.76 ± 0.0012   |
# | **GRU (+ MLP)**                           | 0.6066 ± 0.0019       | 0.8479 ± 0.0013 |
# | **CoLES**                                 | 0.6042 ± 0.0083       | 0.8482 ± 0.0007 |
# | **CoLES embeds + AggByDays (1 day, w/ Null Tokens)** | 0.5966 ± 0.004       | 0.8425 ± 0.0012 |
# | **CPC Modeling**                          | 0.5762 ± 0.0058       | 0.8305 ± 0.003  |
# | **CPC Modeling + AggByDays (2 days)**     | 0.5682 ± 0.0052       | 0.8236 ± 0.0027 |
# | **GPT2**                                  | 0.6146 ± 0.0075       | 0.852 ± 0.0029  |
# | **GPT2 + AggByDays**                      | -                     | -               |
