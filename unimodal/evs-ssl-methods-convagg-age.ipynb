# %% [markdown]
# # Импортируем необходимые библиотеки

# %%
# !pip install pytorch-lifestream
# !pip install comet_ml
# Out:
# Collecting pytorch-lifestream
#   Downloading pytorch-lifestream-0.6.0.tar.gz (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.4/163.4 kB 10.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: duckdb in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (1.1.3)
# Collecting hydra-core>=1.1.2 (from pytorch-lifestream)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: numpy>=1.21.5 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (1.26.4)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (2.3.0)
# Requirement already satisfied: pandas>=1.3.5 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (2.2.3)
# Requirement already satisfied: pyarrow>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (19.0.1)
# Requirement already satisfied: pytorch-lightning>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (2.5.0.post0)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (1.2.2)
# Requirement already satisfied: torch>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (2.5.1+cu121)
# Requirement already satisfied: torchmetrics>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (1.6.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (4.47.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from hydra-core>=1.1.2->pytorch-lifestream) (4.9.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from hydra-core>=1.1.2->pytorch-lifestream) (24.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.5->pytorch-lifestream) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.5->pytorch-lifestream) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.5->pytorch-lifestream) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.5->pytorch-lifestream) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.5->pytorch-lifestream) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.5->pytorch-lifestream) (2.4.1)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.10/dist-packages (from omegaconf->pytorch-lifestream) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->pytorch-lifestream) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->pytorch-lifestream) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->pytorch-lifestream) (2025.1)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.6.0->pytorch-lifestream) (4.67.1)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (2024.12.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.6.0->pytorch-lifestream) (4.12.2)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.6.0->pytorch-lifestream) (0.12.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->pytorch-lifestream) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->pytorch-lifestream) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->pytorch-lifestream) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch-lifestream) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch-lifestream) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch-lifestream) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch-lifestream) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.12.0->pytorch-lifestream) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers->pytorch-lifestream) (0.29.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->pytorch-lifestream) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->pytorch-lifestream) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers->pytorch-lifestream) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->pytorch-lifestream) (0.4.5)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (3.11.12)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.10.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (75.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.5->pytorch-lifestream) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.12.0->pytorch-lifestream) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.21.5->pytorch-lifestream) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.21.5->pytorch-lifestream) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.5->pytorch-lifestream) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.21.5->pytorch-lifestream) (2024.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->pytorch-lifestream) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->pytorch-lifestream) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->pytorch-lifestream) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->pytorch-lifestream) (2025.1.31)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (1.18.3)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.21.5->pytorch-lifestream) (2024.2.0)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 11.6 MB/s eta 0:00:00
# Building wheels for collected packages: pytorch-lifestream
#   Building wheel for pytorch-lifestream (pyproject.toml) ... done
#   Created wheel for pytorch-lifestream: filename=pytorch_lifestream-0.6.0-py3-none-any.whl size=274670 sha256=5b73d792ebb2d5ec1f9c3ff03737fbe21eddc10a5da1d15941352c105c6e7b11
#   Stored in directory: /root/.cache/pip/wheels/90/76/b4/0a944bc7c5a69201e4d757cc54886971117a2a581740e7f11d
# Successfully built pytorch-lifestream
# Installing collected packages: hydra-core, pytorch-lifestream
# Successfully installed hydra-core-1.3.2 pytorch-lifestream-0.6.0
# Collecting comet_ml
#   Downloading comet_ml-3.49.8-py3-none-any.whl.metadata (4.1 kB)
# Collecting dulwich!=0.20.33,>=0.20.6 (from comet_ml)
#   Downloading dulwich-0.22.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting everett<3.2.0,>=1.0.1 (from everett[ini]<3.2.0,>=1.0.1->comet_ml)
#   Downloading everett-3.1.0-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (4.23.0)
# Requirement already satisfied: psutil>=5.6.3 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (5.9.5)
# Collecting python-box<7.0.0 (from comet_ml)
#   Downloading python_box-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.8 kB)
# Requirement already satisfied: requests-toolbelt>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (1.0.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (2.32.3)
# Requirement already satisfied: rich>=13.3.2 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (13.9.4)
# Collecting semantic-version>=2.8.0 (from comet_ml)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: sentry-sdk>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (2.19.2)
# Collecting simplejson (from comet_ml)
#   Downloading simplejson-3.20.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (2.3.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (1.17.0)
# Requirement already satisfied: wurlitzer>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (3.1.1)
# Collecting configobj (from everett[ini]<3.2.0,>=1.0.1->comet_ml)
#   Downloading configobj-5.0.9-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (0.22.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet_ml) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet_ml) (2.19.1)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet_ml) (4.12.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=13.3.2->comet_ml) (0.1.2)
# Downloading comet_ml-3.49.8-py3-none-any.whl (726 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 726.7/726.7 kB 36.5 MB/s eta 0:00:00
# Downloading dulwich-0.22.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 54.2 MB/s eta 0:00:00
# Downloading everett-3.1.0-py2.py3-none-any.whl (35 kB)
# Downloading python_box-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 86.3 MB/s eta 0:00:00:00:01
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading simplejson-3.20.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 11.1 MB/s eta 0:00:00
# Downloading configobj-5.0.9-py2.py3-none-any.whl (35 kB)
# Installing collected packages: everett, simplejson, semantic-version, python-box, dulwich, configobj, comet_ml
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.3.0
#     Uninstalling python-box-7.3.0:
#       Successfully uninstalled python-box-7.3.0
# Successfully installed comet_ml-3.49.8 configobj-5.0.9 dulwich-0.22.8 everett-3.1.0 python-box-6.1.0 semantic-version-2.10.0 simplejson-3.20.1

# %%
# data preprocessing
import os
import numpy as np
import pandas as pd
import pickle

# misc
from tqdm import tqdm
from functools import partial

# logging
import comet_ml

# classical ML
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score
from catboost import CatBoostClassifier

# basic deep learning libs
import torch
import pytorch_lightning as pl
import torchmetrics

# ptls
from ptls.nn import TrxEncoder, RnnSeqEncoder, TransformerEncoder, GptEncoder, Head
from ptls.frames import PtlsDataModule
from ptls.frames.coles import CoLESModule
from ptls.frames.coles import ColesDataset
from ptls.frames.coles.split_strategy import SampleSlices
from ptls.frames.cpc import CpcModule
from ptls.frames.cpc import CpcDataset
from ptls.frames.gpt import GptDataset
from ptls.frames.supervised import SeqToTargetDataset, SequenceToTarget
from ptls.data_load.datasets import MemoryMapDataset
from ptls.data_load.datasets import inference_data_loader
from ptls.frames.inference_module import InferenceModule
from ptls.data_load.iterable_processing import SeqLenFilter
from ptls.preprocessing import PandasDataPreprocessor
from ptls.data_load.utils import collate_feature_dict
from ptls.frames.inference_module import InferenceModule

# %%
def seed_everything(seed):
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
comet_ml.login()

# %%
from pytorch_lightning.loggers import CometLogger

# %% [markdown]
# # Эксперименты.

# %% [markdown]
# **Данные:**

# %%
path_data = "https://huggingface.co/datasets/dllllb/age-group-prediction/resolve/main/transactions_train.csv.gz?download=true"
data = pd.read_csv(path_data, compression="gzip")
data
# Out:
#           client_id  trans_date  small_group  amount_rur
# 0             33172           6            4      71.463
# 1             33172           6           35      45.017
# 2             33172           8           11      13.887
# 3             33172           9           11      15.983
# 4             33172          10           11      21.341
# ...             ...         ...          ...         ...
# 26450572      43300         727           25       7.602
# 26450573      43300         727           15       3.709
# 26450574      43300         727            1       6.448
# 26450575      43300         727           11      24.669
# 26450576      43300         729            3      19.408
#
# [26450577 rows x 4 columns]

# %%
path_target = "https://huggingface.co/datasets/dllllb/age-group-prediction/resolve/main/train_target.csv?download=true"
target = pd.read_csv(path_target)
target
# Out:
#        client_id  bins
# 0          24662     2
# 1           1046     0
# 2          34089     2
# 3          34848     1
# 4          47076     3
# ...          ...   ...
# 29995      14303     1
# 29996      22301     2
# 29997      25731     0
# 29998      16820     3
# 29999       5265     0
#
# [30000 rows x 2 columns]

# %%
target_train, target_test = train_test_split(target, test_size=0.1, stratify=target["bins"], random_state=42)

# %%
trx_data_train = pd.merge(data, target_train["client_id"], on="client_id", how="inner")
trx_data_test = pd.merge(data, target_test["client_id"], on="client_id", how="inner")

# %% [markdown]
# ---

# %% [markdown]
# **Квантизация непрерывных признаков (опциональный шаг, нужен только для GPT):**

# %%
def digitize(input_array: np.array, q_count: int = 1, bins: np.array = None):
    """Quantile-based discretization function.

    Parameters:
    -------
    input_array (np.array): Input array.
    q_count (int): Amount of quantiles. Used only if input parameter `bins` is None.
    bins (np.array):
        If None, then calculate bins as quantiles of input array,
        otherwise only apply bins to input_array. Default: None

    Returns
    -------
    out_array (np.array of ints): discretized input_array
    bins (np.array of floats):
        Returned only if input parameter `bins` is None.
    """

    if bins is None:
        return_bins = True
        bins = np.quantile(input_array, q=[i / q_count for i in range(1, q_count)], axis=0)
    else:
        return_bins = False

    out_array = np.digitize(input_array, bins)

    if return_bins:
        return out_array, bins
    else:
        return out_array

# %%
BINS_NUM = 128

# %%
numeric_features = ["amount_rur"]

for feat in numeric_features:
    trx_data_train[feat], bins = digitize(trx_data_train[feat], q_count=BINS_NUM)
    trx_data_test[feat] = digitize(trx_data_test[feat], bins=bins)

# %%
import gc

gc.collect()
# Out:
# 147

# %% [markdown]
# ---

# %%
preprocessor = PandasDataPreprocessor(
    col_id="client_id",
    col_event_time="trans_date",
    event_time_transformation="none",
    cols_category=["small_group"],
    cols_numerical=["amount_rur"],
    return_records=False,
)

# %%
data_train = preprocessor.fit_transform(trx_data_train)
data_test = preprocessor.transform(trx_data_test)

# %%
target_train.rename(columns={"bins": "target"}, inplace=True)
target_test.rename(columns={"bins": "target"}, inplace=True)
target_train.sort_values(by="client_id", inplace=True)
target_test.sort_values(by="client_id", inplace=True)
target_train = target_train["target"]
target_test = target_test["target"]
target_train.reset_index(drop=True, inplace=True)
target_test.reset_index(drop=True, inplace=True)

# %%
data_train = data_train.to_dict(orient="records")
data_test = data_test.to_dict(orient="records")

# %% [markdown]
# ---

# %% [markdown]
# **Convolution Aggregator Class:**

# %%
from ptls.data_load.padded_batch import PaddedBatch
import torch.nn as nn


class ConvAggregator(TrxEncoder):
    """The NN layer, a combination of TrxEncoder and Conv Layer (a window of #`agg_samples` transactions) 
       (works like nn.Sequential([TrxEncoder, Conv Window Aggregation])).
       
       The types of the input and output are `PaddedBatch` of shapes (B, L, T) and (B, L', T) respectively, where 
       B means batch_size,
       L/L' means the max length of a sequence of transactions in a batch (the length is the same as #trx)
       T means the dimension of a single transaction.

       Parameters
        agg_samples (int):
            The number of transactions in a sliding aggregation window (conv layer).

        use_window_attention (bool):
            If True, the attention layer will be applied to transactions in a sliding window before pooling.
            
        embeddings:
            You can find info about this param in TrxEncoder desc.
        
        numeric_values:
            You can find info about this param in TrxEncoder desc.

        embeddings_noise:
            You can find info about this param in TrxEncoder desc.
            
        emb_dropout:
            You can find info about this param in TrxEncoder desc.
            
        spatial_dropout:
            You can find info about this param in TrxEncoder desc.

        use_batch_norm:
            You can find info about this param in TrxEncoder desc.

        orthogonal_init:
            You can find info about this param in TrxEncoder desc.
            
        linear_projection_size:
            You can find info about this param in TrxEncoder desc.

        out_of_index:
            You can find info about this param in TrxEncoder desc.

        norm_embeddings:
            Keep default value for this parameter
        
        clip_replace_value:
            Not used. Keep default value for this parameter
        
        positions: 
            Not used. Keep default value for this parameter
       """

    def __init__(self,
                 agg_samples=3,
                 use_window_attention=False,
                 embeddings=None,
                 numeric_values=None,
                 custom_embeddings=None,
                 time_values=None,
                 embeddings_noise: float = 0,
                 norm_embeddings=None,
                 use_batch_norm=False,
                 use_batch_norm_with_lens=False,
                 clip_replace_value=None,
                 positions=None,
                 emb_dropout=0,
                 spatial_dropout=False,
                 orthogonal_init=False,
                 linear_projection_size=0,
                 out_of_index: str = 'clip',
                ):
        
        super().__init__(
            embeddings=embeddings,
            numeric_values=numeric_values,
            custom_embeddings=custom_embeddings,
            embeddings_noise=embeddings_noise,
            norm_embeddings=norm_embeddings,
            use_batch_norm=use_batch_norm,
            use_batch_norm_with_lens=use_batch_norm_with_lens,
            clip_replace_value=clip_replace_value,
            positions=positions,
            emb_dropout=emb_dropout,
            spatial_dropout=spatial_dropout,
            orthogonal_init=orthogonal_init,
            linear_projection_size=linear_projection_size,
            out_of_index=out_of_index,
        )

        self.agg_samples = agg_samples

        channels = super().output_size

        self.conv = nn.Conv1d(in_channels=channels, out_channels=channels, kernel_size=self.agg_samples, padding=(self.agg_samples - 1), bias=False) # (B, T, L)

        self.use_window_attention = use_window_attention
        if self.use_window_attention:
            pass # Not Implemented

    def forward(self, pb: PaddedBatch):
        embeds = super().forward(pb)

        mask = torch.arange(embeds.payload.shape[1], device=embeds.device)[None, :] + torch.ones((embeds.seq_lens.shape[0], embeds.payload.shape[1]), device=embeds.device)
        mask[mask > embeds.seq_lens[:, None]] = 0.
        mask[mask > 0.] = 1.
        mask = mask[:, :, None]
    
        masked_embeds = embeds.payload * mask
    
        if self.use_window_attention:
            pass # Not Implemented
    
        agg_embeds = torch.transpose(self.conv(torch.transpose(masked_embeds, 1, 2)), 1, 2)

        new_seq_lens = embeds.seq_lens + self.agg_samples - 1

        return PaddedBatch(agg_embeds, new_seq_lens)

# %%
# seed_everything(0)

# %%
# device = "cuda:0"

# %%
# agg_encoder_params = dict(
#     embeddings_noise=0.003,
#     numeric_values={"amount_rur": "log"},
#     embeddings={
#         "trans_date": {"in": 800, "out": 16},
#         "small_group": {"in": 250, "out": 16},
#     },
#     agg_samples=5,
#     use_window_attention=False
# )

# trx_encoder = ConvAggregator(**agg_encoder_params).to(device)

# %%
# trx_encoder.eval()

# train_loader = inference_data_loader(data_train, num_workers=0, batch_size=128)

# for i, batch in tqdm(enumerate(train_loader)):
#     batch = batch.to(device)
#     embeds_batch = trx_encoder(batch)

#     # if i == 0:
#     #     # print(batch.payload)
#     #     print(batch.seq_lens)
#     #     print()
#     #     print(embeds_batch.payload[31, 2])
#     #     print()
#     #     print(embeds_batch.payload.shape)
#     #     print()
#     #     print(embeds_batch.seq_lens)
# Out:
# 211it [00:02, 84.69it/s]

# %% [markdown]
# ---

# %% [markdown]
# **Train sequences lengths check:**

# %%
agg_encoder_params = dict(
    embeddings_noise=0.003,
    numeric_values={"amount_rur": "log"},
    embeddings={
        "trans_date": {"in": 800, "out": 16},
        "small_group": {"in": 250, "out": 16},
    }
)

trx_encoder = TrxEncoder(**agg_encoder_params)
trx_encoder.to("cuda")
# Out:
# TrxEncoder(
#   (embeddings): ModuleDict(
#     (trans_date): NoisyEmbedding(
#       800, 16, padding_idx=0
#       (dropout): Dropout(p=0, inplace=False)
#     )
#     (small_group): NoisyEmbedding(
#       250, 16, padding_idx=0
#       (dropout): Dropout(p=0, inplace=False)
#     )
#   )
#   (custom_embeddings): ModuleDict(
#     (amount_rur): LogScaler()
#   )
#   (custom_embedding_batch_norm): RBatchNorm(
#     (bn): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )

# %%
train_loader = inference_data_loader(data_train, num_workers=0, batch_size=128)

trx_encoder.eval()

seq_lens = []

for batch in tqdm(train_loader):
    embeds_batch = trx_encoder(batch.to("cuda"))
    seq_lens += [embeds_batch.seq_lens.detach().cpu().numpy()]

seq_lens = np.concatenate(seq_lens)

threshold = int(np.quantile(seq_lens, 0.75) * 0.7)

print("Max Length:", threshold)
# Out:
# 211it [00:01, 116.47it/s]
# Max Length: 683

# %% [markdown]
# ---

# %% [markdown]
# # Sliding Window Aggregation (Mean Pooling)

# %% [markdown]
# - **COLES:**

# %%
seed_everything(42)

# %% [markdown]
# **DataLoaders:**

# %%
data = PtlsDataModule(
    train_data=ColesDataset(
        MemoryMapDataset(
            data=data_train,
            i_filters=[SeqLenFilter(min_seq_len=30)],
        ),
        splitter=SampleSlices(
            split_count=5,
            cnt_min=30,
            cnt_max=560,
        ),
    ),
    train_num_workers=4,
    train_batch_size=128,
    valid_data=ColesDataset(
        MemoryMapDataset(
            data=data_test,
            i_filters=[SeqLenFilter(min_seq_len=30)],
        ),
        splitter=SampleSlices(
            split_count=5,
            cnt_min=30,
            cnt_max=560,
        ),
    ),
    valid_num_workers=4,
    valid_batch_size=128
)

# %% [markdown]
# **Модель:**

# %%
N_EPOCHS = 20

# %%
agg_encoder_params = dict(
    embeddings_noise=0.003,
    numeric_values={"amount_rur": "log"},
    embeddings={
        "trans_date": {"in": 800, "out": 16},
        "small_group": {"in": 250, "out": 16},
    },
    agg_samples=7, # 3, 5, 7, 9
    use_window_attention=False
)

trx_encoder = ConvAggregator(**agg_encoder_params)

seq_encoder = RnnSeqEncoder(
    trx_encoder=trx_encoder,
    hidden_size=512,
    type="gru"
)

coles = CoLESModule(
    seq_encoder=seq_encoder,
    optimizer_partial=partial(torch.optim.Adam, lr=3e-3, weight_decay=5e-4),
    lr_scheduler_partial=partial(torch.optim.lr_scheduler.CosineAnnealingLR, T_max=N_EPOCHS, eta_min=1e-6)
)

# %% [markdown]
# **Обучение:**

# %%
logger = CometLogger(project_name="EvS_SSL", experiment_name="CoLES_ConvAgg (7 trx)")

trainer = pl.Trainer(
    logger=logger,
    max_epochs=N_EPOCHS,
    accelerator="gpu",
    devices=1,
    enable_progress_bar=True
)

# %%
trainer.fit(coles, data)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/askoro/evs-ssl/9e9f1e636f4a4d7492e7ef540fd63afa
#
# COMET INFO: Couldn't find a Git repository in '/kaggle/working' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : CoLES_ConvAgg (7 trx)
# COMET INFO:     url                   : https://www.comet.com/askoro/evs-ssl/9e9f1e636f4a4d7492e7ef540fd63afa
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [506]              : (81.32427215576172, 759.7018432617188)
# COMET INFO:     seq_len [84]            : (281.6890563964844, 307.6047058105469)
# COMET INFO:     valid/recall_top_k [20] : (0.7845447659492493, 0.9423479437828064)
# COMET INFO:   Others:
# COMET INFO:     Name : CoLES_ConvAgg (7 trx)
# COMET INFO:   Parameters:
# COMET INFO:     test_batch_size   : None
# COMET INFO:     test_drop_last    : False
# COMET INFO:     test_num_workers  : None
# COMET INFO:     train_batch_size  : 128
# COMET INFO:     train_drop_last   : False
# COMET INFO:     train_num_workers : 4
# COMET INFO:     valid_batch_size  : 128
# COMET INFO:     valid_drop_last   : False
# COMET INFO:     valid_num_workers : 4
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET INFO: Please wait for metadata to finish uploading (timeout is 3600 seconds)
# COMET INFO: Uploading 33 metrics, params and output messages

# %%
trainer.logged_metrics
# Out:
# {'loss': tensor(86.9931),
#  'seq_len': tensor(297.0533),
#  'valid/recall_top_k': tensor(0.9423)}

# %%
torch.save(seq_encoder.state_dict(), "coles_enc_win_agg.pt")

# %% [markdown]
# **Измерим качество на тесте (catboost поверх эмбеддингов):**

# %%
encoder = coles.seq_encoder

device = "cuda:0"

encoder.to(device)
# Out:
# RnnSeqEncoder(
#   (trx_encoder): ConvAggregator(
#     (embeddings): ModuleDict(
#       (trans_date): NoisyEmbedding(
#         800, 16, padding_idx=0
#         (dropout): Dropout(p=0, inplace=False)
#       )
#       (small_group): NoisyEmbedding(
#         250, 16, padding_idx=0
#         (dropout): Dropout(p=0, inplace=False)
#       )
#     )
#     (custom_embeddings): ModuleDict(
#       (amount_rur): LogScaler()
#     )
#     (conv): Conv1d(33, 33, kernel_size=(7,), stride=(1,), padding=(6,), bias=False)
#   )
#   (seq_encoder): RnnEncoder(
#     (rnn): GRU(33, 512, batch_first=True)
#     (reducer): LastStepEncoder()
#   )
# )

# %%
from tqdm import tqdm

seed_everything(42)

# %%
train_loader = inference_data_loader(data_train, num_workers=0, batch_size=128)
encoder.eval()
train_embeds = None

for i, batch in tqdm(enumerate(train_loader)):
    train_embeds_batch = encoder(batch.to(device))
    if i == 0:
        train_embeds = train_embeds_batch.detach().cpu().numpy()
    else:
        train_embeds = np.concatenate([train_embeds, train_embeds_batch.detach().cpu().numpy()], axis=0)
    
train_embeds
# Out:
# 211it [00:24,  8.75it/s]
# array([[ 0.03698849,  0.0065549 ,  0.03586466, ..., -0.07524633,
#          0.3811207 , -0.249045  ],
#        [ 0.68024206,  0.133578  ,  0.02426561, ..., -0.08792991,
#          0.33768442, -0.3966271 ],
#        [ 0.01316545, -0.02980805,  0.03586124, ..., -0.13590482,
#          0.59702384,  0.00281469],
#        ...,
#        [-0.08812407, -0.05642426,  0.0234392 , ..., -0.01974014,
#          0.44292927, -0.37987572],
#        [-0.5504547 , -0.10151711,  0.04181264, ..., -0.08819497,
#          0.25297815,  0.11250492],
#        [-0.1457776 , -0.10500189,  0.02579749, ..., -0.11508597,
#          0.19503188, -0.1200649 ]], dtype=float32)

# %%
test_loader = inference_data_loader(data_test, num_workers=0, batch_size=128)
encoder.eval()
test_embeds = None

for i, batch in tqdm(enumerate(test_loader)):
    test_embeds_batch = encoder(batch.to(device))
    if i == 0:
        test_embeds = test_embeds_batch.detach().cpu().numpy()
    else:
        test_embeds = np.concatenate([test_embeds, test_embeds_batch.detach().cpu().numpy()], axis=0)
    
test_embeds
# Out:
# 24it [00:02,  9.69it/s]
# array([[-0.89095265,  0.04210023,  0.026358  , ..., -0.07034364,
#          0.5044866 , -0.32076114],
#        [ 0.13615598,  0.214713  ,  0.0209006 , ..., -0.12813726,
#          0.26064026,  0.0152501 ],
#        [ 0.69760936,  0.06759962,  0.01733929, ..., -0.18130785,
#          0.44097042, -0.49486622],
#        ...,
#        [ 0.4669804 , -0.06284533,  0.02873191, ..., -0.02277629,
#          0.26693788, -0.1816809 ],
#        [ 0.15836863, -0.01949545,  0.02283837, ..., -0.08913588,
#          0.5751037 , -0.36161187],
#        [ 0.2480348 , -0.00120775,  0.02129856, ..., -0.14086127,
#          0.702488  , -0.4512518 ]], dtype=float32)

# %%
clf = CatBoostClassifier(loss_function='MultiClass', task_type="GPU", devices='0', random_state=42)

clf.fit(train_embeds, target_train, plot_file="catboost_log.html")
# Out:
# Learning rate set to 0.12714
# 0:	learn: 1.2991978	total: 14.1s	remaining: 3h 54m 29s
# 1:	learn: 1.2348466	total: 14.1s	remaining: 1h 57m 12s
# 2:	learn: 1.1850406	total: 14.1s	remaining: 1h 18m 7s
# 3:	learn: 1.1441941	total: 14.1s	remaining: 58m 34s
# 4:	learn: 1.1101088	total: 14.1s	remaining: 46m 50s
# 5:	learn: 1.0825827	total: 14.1s	remaining: 39m 1s
# 6:	learn: 1.0593864	total: 14.1s	remaining: 33m 26s
# 7:	learn: 1.0387410	total: 14.2s	remaining: 29m 15s
# 8:	learn: 1.0216364	total: 14.2s	remaining: 25m 59s
# 9:	learn: 1.0063884	total: 14.2s	remaining: 23m 23s
# 10:	learn: 0.9938767	total: 14.2s	remaining: 21m 15s
# 11:	learn: 0.9825193	total: 14.2s	remaining: 19m 28s
# 12:	learn: 0.9728731	total: 14.2s	remaining: 17m 58s
# 13:	learn: 0.9638458	total: 14.2s	remaining: 16m 41s
# 14:	learn: 0.9552195	total: 14.2s	remaining: 15m 34s
# 15:	learn: 0.9481326	total: 14.2s	remaining: 14m 35s
# 16:	learn: 0.9413106	total: 14.2s	remaining: 13m 43s
# 17:	learn: 0.9353958	total: 14.3s	remaining: 12m 57s
# 18:	learn: 0.9304108	total: 14.3s	remaining: 12m 16s
# 19:	learn: 0.9260802	total: 14.3s	remaining: 11m 39s
# 20:	learn: 0.9214512	total: 14.3s	remaining: 11m 5s
# 21:	learn: 0.9176260	total: 14.3s	remaining: 10m 35s
# 22:	learn: 0.9141584	total: 14.3s	remaining: 10m 7s
# 23:	learn: 0.9104531	total: 14.3s	remaining: 9m 42s
# 24:	learn: 0.9071848	total: 14.3s	remaining: 9m 18s
# 25:	learn: 0.9039257	total: 14.3s	remaining: 8m 57s
# 26:	learn: 0.9011513	total: 14.3s	remaining: 8m 36s
# 27:	learn: 0.8988751	total: 14.4s	remaining: 8m 18s
# 28:	learn: 0.8964913	total: 14.4s	remaining: 8m
# 29:	learn: 0.8941020	total: 14.4s	remaining: 7m 44s
# 30:	learn: 0.8920584	total: 14.4s	remaining: 7m 29s
# 31:	learn: 0.8895001	total: 14.4s	remaining: 7m 15s
# 32:	learn: 0.8875784	total: 14.4s	remaining: 7m 2s
# 33:	learn: 0.8855428	total: 14.4s	remaining: 6m 49s
# 34:	learn: 0.8835461	total: 14.4s	remaining: 6m 37s
# 35:	learn: 0.8818682	total: 14.4s	remaining: 6m 26s
# 36:	learn: 0.8799975	total: 14.4s	remaining: 6m 15s
# 37:	learn: 0.8786543	total: 14.5s	remaining: 6m 5s
# 38:	learn: 0.8771142	total: 14.5s	remaining: 5m 56s
# 39:	learn: 0.8754272	total: 14.5s	remaining: 5m 47s
# 40:	learn: 0.8737079	total: 14.5s	remaining: 5m 38s
# 41:	learn: 0.8720384	total: 14.5s	remaining: 5m 30s
# 42:	learn: 0.8703150	total: 14.5s	remaining: 5m 22s
# 43:	learn: 0.8687961	total: 14.5s	remaining: 5m 15s
# 44:	learn: 0.8676562	total: 14.5s	remaining: 5m 8s
# 45:	learn: 0.8664470	total: 14.5s	remaining: 5m 1s
# 46:	learn: 0.8649154	total: 14.5s	remaining: 4m 54s
# 47:	learn: 0.8634572	total: 14.6s	remaining: 4m 48s
# 48:	learn: 0.8624202	total: 14.6s	remaining: 4m 42s
# 49:	learn: 0.8615309	total: 14.6s	remaining: 4m 36s
# 50:	learn: 0.8600164	total: 14.6s	remaining: 4m 31s
# 51:	learn: 0.8588485	total: 14.6s	remaining: 4m 26s
# 52:	learn: 0.8575805	total: 14.6s	remaining: 4m 20s
# 53:	learn: 0.8565323	total: 14.6s	remaining: 4m 15s
# 54:	learn: 0.8556562	total: 14.6s	remaining: 4m 11s
# 55:	learn: 0.8546219	total: 14.6s	remaining: 4m 6s
# 56:	learn: 0.8534010	total: 14.6s	remaining: 4m 2s
# 57:	learn: 0.8521858	total: 14.7s	remaining: 3m 57s
# 58:	learn: 0.8509295	total: 14.7s	remaining: 3m 53s
# 59:	learn: 0.8501644	total: 14.7s	remaining: 3m 49s
# 60:	learn: 0.8491809	total: 14.7s	remaining: 3m 46s
# 61:	learn: 0.8480247	total: 14.7s	remaining: 3m 42s
# 62:	learn: 0.8467663	total: 14.7s	remaining: 3m 38s
# 63:	learn: 0.8459348	total: 14.7s	remaining: 3m 35s
# 64:	learn: 0.8450556	total: 14.7s	remaining: 3m 31s
# 155:	learn: 0.7752151	total: 15.6s	remaining: 1m 24s
# 156:	learn: 0.7746398	total: 15.6s	remaining: 1m 23s
# 157:	learn: 0.7737271	total: 15.6s	remaining: 1m 23s
# 158:	learn: 0.7733699	total: 15.7s	remaining: 1m 22s
# 159:	learn: 0.7728728	total: 15.7s	remaining: 1m 22s
# 160:	learn: 0.7721622	total: 15.7s	remaining: 1m 21s
# 161:	learn: 0.7715004	total: 15.7s	remaining: 1m 21s
# 162:	learn: 0.7705902	total: 15.7s	remaining: 1m 20s
# 163:	learn: 0.7698500	total: 15.7s	remaining: 1m 20s
# 164:	learn: 0.7691792	total: 15.7s	remaining: 1m 19s
# 165:	learn: 0.7686231	total: 15.7s	remaining: 1m 19s
# 166:	learn: 0.7680454	total: 15.7s	remaining: 1m 18s
# 167:	learn: 0.7674967	total: 15.7s	remaining: 1m 17s
# 168:	learn: 0.7667600	total: 15.8s	remaining: 1m 17s
# 169:	learn: 0.7662492	total: 15.8s	remaining: 1m 16s
# 170:	learn: 0.7656292	total: 15.8s	remaining: 1m 16s
# 171:	learn: 0.7650812	total: 15.8s	remaining: 1m 15s
# 172:	learn: 0.7641628	total: 15.8s	remaining: 1m 15s
# 173:	learn: 0.7637720	total: 15.8s	remaining: 1m 15s
# 174:	learn: 0.7630135	total: 15.8s	remaining: 1m 14s
# 175:	learn: 0.7624591	total: 15.8s	remaining: 1m 14s
# 176:	learn: 0.7618791	total: 15.8s	remaining: 1m 13s
# 177:	learn: 0.7613488	total: 15.8s	remaining: 1m 13s
# 178:	learn: 0.7608273	total: 15.8s	remaining: 1m 12s
# 179:	learn: 0.7602990	total: 15.9s	remaining: 1m 12s
# 180:	learn: 0.7597661	total: 15.9s	remaining: 1m 11s
# 181:	learn: 0.7589096	total: 15.9s	remaining: 1m 11s
# 182:	learn: 0.7581533	total: 15.9s	remaining: 1m 10s
# 183:	learn: 0.7575815	total: 15.9s	remaining: 1m 10s
# 184:	learn: 0.7568487	total: 15.9s	remaining: 1m 10s
# 185:	learn: 0.7563733	total: 15.9s	remaining: 1m 9s
# 186:	learn: 0.7558320	total: 15.9s	remaining: 1m 9s
# 187:	learn: 0.7551753	total: 15.9s	remaining: 1m 8s
# 188:	learn: 0.7544303	total: 15.9s	remaining: 1m 8s
# 189:	learn: 0.7539765	total: 16s	remaining: 1m 8s
# 190:	learn: 0.7535192	total: 16s	remaining: 1m 7s
# 191:	learn: 0.7530217	total: 16s	remaining: 1m 7s
# 192:	learn: 0.7525242	total: 16s	remaining: 1m 6s
# 193:	learn: 0.7519667	total: 16s	remaining: 1m 6s
# 194:	learn: 0.7513308	total: 16s	remaining: 1m 6s
# 195:	learn: 0.7508837	total: 16s	remaining: 1m 5s
# 196:	learn: 0.7502567	total: 16s	remaining: 1m 5s
# 197:	learn: 0.7495694	total: 16s	remaining: 1m 4s
# 198:	learn: 0.7487890	total: 16s	remaining: 1m 4s
# 199:	learn: 0.7480268	total: 16.1s	remaining: 1m 4s
# 200:	learn: 0.7474046	total: 16.1s	remaining: 1m 3s
# 201:	learn: 0.7466738	total: 16.1s	remaining: 1m 3s
# 202:	learn: 0.7461320	total: 16.1s	remaining: 1m 3s
# 203:	learn: 0.7453851	total: 16.1s	remaining: 1m 2s
# 204:	learn: 0.7448560	total: 16.1s	remaining: 1m 2s
# 205:	learn: 0.7443992	total: 16.1s	remaining: 1m 2s
# 206:	learn: 0.7438885	total: 16.1s	remaining: 1m 1s
# 207:	learn: 0.7434850	total: 16.1s	remaining: 1m 1s
# 208:	learn: 0.7428795	total: 16.1s	remaining: 1m 1s
# 209:	learn: 0.7422158	total: 16.1s	remaining: 1m
# 210:	learn: 0.7415974	total: 16.2s	remaining: 1m
# 211:	learn: 0.7409499	total: 16.2s	remaining: 1m
# 212:	learn: 0.7404183	total: 16.2s	remaining: 59.8s
# 213:	learn: 0.7398011	total: 16.2s	remaining: 59.5s
# 214:	learn: 0.7392187	total: 16.2s	remaining: 59.1s
# 215:	learn: 0.7387574	total: 16.2s	remaining: 58.8s
# 216:	learn: 0.7381217	total: 16.2s	remaining: 58.5s
# 217:	learn: 0.7375777	total: 16.2s	remaining: 58.2s
# 218:	learn: 0.7370779	total: 16.2s	remaining: 57.9s
# 219:	learn: 0.7365431	total: 16.2s	remaining: 57.6s
# 220:	learn: 0.7358191	total: 16.3s	remaining: 57.3s
# 221:	learn: 0.7352952	total: 16.3s	remaining: 57s
# 222:	learn: 0.7345892	total: 16.3s	remaining: 56.7s
# 223:	learn: 0.7340971	total: 16.3s	remaining: 56.4s
# 224:	learn: 0.7334406	total: 16.3s	remaining: 56.1s
# 225:	learn: 0.7327899	total: 16.3s	remaining: 55.8s
# 226:	learn: 0.7322763	total: 16.3s	remaining: 55.6s
# 227:	learn: 0.7316524	total: 16.3s	remaining: 55.3s
# 228:	learn: 0.7309635	total: 16.3s	remaining: 55s
# 229:	learn: 0.7304967	total: 16.3s	remaining: 54.7s
# 230:	learn: 0.7298417	total: 16.4s	remaining: 54.4s
# 231:	learn: 0.7291975	total: 16.4s	remaining: 54.2s
# 232:	learn: 0.7286660	total: 16.4s	remaining: 53.9s
# 233:	learn: 0.7280161	total: 16.4s	remaining: 53.6s
# 234:	learn: 0.7275359	total: 16.4s	remaining: 53.4s
# 235:	learn: 0.7270070	total: 16.4s	remaining: 53.1s
# 236:	learn: 0.7266494	total: 16.4s	remaining: 52.8s
# 237:	learn: 0.7260672	total: 16.4s	remaining: 52.6s
# 238:	learn: 0.7255268	total: 16.4s	remaining: 52.3s
# 239:	learn: 0.7248075	total: 16.4s	remaining: 52.1s
# 240:	learn: 0.7240693	total: 16.5s	remaining: 51.8s
# 241:	learn: 0.7234005	total: 16.5s	remaining: 51.6s
# 242:	learn: 0.7228338	total: 16.5s	remaining: 51.3s
# 243:	learn: 0.7223172	total: 16.5s	remaining: 51.1s
# 244:	learn: 0.7217441	total: 16.5s	remaining: 50.8s
# 245:	learn: 0.7212820	total: 16.5s	remaining: 50.6s
# 246:	learn: 0.7206353	total: 16.5s	remaining: 50.3s
# 294:	learn: 0.6957341	total: 17s	remaining: 40.6s
# 295:	learn: 0.6953607	total: 17s	remaining: 40.4s
# 296:	learn: 0.6947657	total: 17s	remaining: 40.2s
# 297:	learn: 0.6943622	total: 17s	remaining: 40.1s
# 298:	learn: 0.6938863	total: 17s	remaining: 39.9s
# 299:	learn: 0.6933848	total: 17s	remaining: 39.7s
# 300:	learn: 0.6928885	total: 17s	remaining: 39.6s
# 301:	learn: 0.6923234	total: 17s	remaining: 39.4s
# 302:	learn: 0.6918485	total: 17.1s	remaining: 39.2s
# 303:	learn: 0.6913394	total: 17.1s	remaining: 39.1s
# 304:	learn: 0.6908987	total: 17.1s	remaining: 38.9s
# 305:	learn: 0.6905584	total: 17.1s	remaining: 38.8s
# 306:	learn: 0.6900337	total: 17.1s	remaining: 38.6s
# 307:	learn: 0.6896699	total: 17.1s	remaining: 38.4s
# 308:	learn: 0.6891643	total: 17.1s	remaining: 38.3s
# 309:	learn: 0.6887683	total: 17.1s	remaining: 38.1s
# 310:	learn: 0.6881466	total: 17.1s	remaining: 38s
# 311:	learn: 0.6876646	total: 17.1s	remaining: 37.8s
# 312:	learn: 0.6871556	total: 17.2s	remaining: 37.6s
# 313:	learn: 0.6868563	total: 17.2s	remaining: 37.5s
# 314:	learn: 0.6863691	total: 17.2s	remaining: 37.3s
# 315:	learn: 0.6860129	total: 17.2s	remaining: 37.2s
# 316:	learn: 0.6855245	total: 17.2s	remaining: 37s
# 317:	learn: 0.6850910	total: 17.2s	remaining: 36.9s
# 318:	learn: 0.6848009	total: 17.2s	remaining: 36.7s
# 319:	learn: 0.6844447	total: 17.2s	remaining: 36.6s
# 320:	learn: 0.6837102	total: 17.2s	remaining: 36.4s
# 321:	learn: 0.6831892	total: 17.2s	remaining: 36.3s
# 322:	learn: 0.6827655	total: 17.2s	remaining: 36.1s
# 323:	learn: 0.6824486	total: 17.3s	remaining: 36s
# 324:	learn: 0.6817018	total: 17.3s	remaining: 35.9s
# 325:	learn: 0.6813025	total: 17.3s	remaining: 35.7s
# 326:	learn: 0.6806499	total: 17.3s	remaining: 35.6s
# 327:	learn: 0.6804342	total: 17.3s	remaining: 35.4s
# 328:	learn: 0.6799185	total: 17.3s	remaining: 35.3s
# 329:	learn: 0.6794183	total: 17.3s	remaining: 35.2s
# 330:	learn: 0.6789631	total: 17.3s	remaining: 35s
# 331:	learn: 0.6786396	total: 17.3s	remaining: 34.9s
# 332:	learn: 0.6781560	total: 17.3s	remaining: 34.7s
# 333:	learn: 0.6776131	total: 17.4s	remaining: 34.6s
# 334:	learn: 0.6769948	total: 17.4s	remaining: 34.5s
# 335:	learn: 0.6766637	total: 17.4s	remaining: 34.3s
# 336:	learn: 0.6761070	total: 17.4s	remaining: 34.2s
# 337:	learn: 0.6756960	total: 17.4s	remaining: 34.1s
# 338:	learn: 0.6753162	total: 17.4s	remaining: 33.9s
# 339:	learn: 0.6748798	total: 17.4s	remaining: 33.8s
# 340:	learn: 0.6744191	total: 17.4s	remaining: 33.7s
# 341:	learn: 0.6738102	total: 17.4s	remaining: 33.5s
# 342:	learn: 0.6734144	total: 17.4s	remaining: 33.4s
# 343:	learn: 0.6729467	total: 17.4s	remaining: 33.3s
# 344:	learn: 0.6725396	total: 17.5s	remaining: 33.1s
# 345:	learn: 0.6718642	total: 17.5s	remaining: 33s
# 346:	learn: 0.6713061	total: 17.5s	remaining: 32.9s
# 347:	learn: 0.6708859	total: 17.5s	remaining: 32.8s
# 348:	learn: 0.6701780	total: 17.5s	remaining: 32.6s
# 349:	learn: 0.6697386	total: 17.5s	remaining: 32.5s
# 350:	learn: 0.6691143	total: 17.5s	remaining: 32.4s
# 351:	learn: 0.6686871	total: 17.5s	remaining: 32.3s
# 352:	learn: 0.6683840	total: 17.5s	remaining: 32.1s
# 353:	learn: 0.6680012	total: 17.5s	remaining: 32s
# 354:	learn: 0.6673871	total: 17.6s	remaining: 31.9s
# 355:	learn: 0.6668207	total: 17.6s	remaining: 31.8s
# 356:	learn: 0.6661116	total: 17.6s	remaining: 31.7s
# 357:	learn: 0.6655530	total: 17.6s	remaining: 31.5s
# 358:	learn: 0.6649614	total: 17.6s	remaining: 31.4s
# 359:	learn: 0.6645867	total: 17.6s	remaining: 31.3s
# 360:	learn: 0.6641216	total: 17.6s	remaining: 31.2s
# 361:	learn: 0.6636855	total: 17.6s	remaining: 31.1s
# 362:	learn: 0.6632525	total: 17.6s	remaining: 31s
# 363:	learn: 0.6627624	total: 17.6s	remaining: 30.8s
# 364:	learn: 0.6622445	total: 17.7s	remaining: 30.7s
# 365:	learn: 0.6618136	total: 17.7s	remaining: 30.6s
# 366:	learn: 0.6613840	total: 17.7s	remaining: 30.5s
# 367:	learn: 0.6609012	total: 17.7s	remaining: 30.4s
# 368:	learn: 0.6603958	total: 17.7s	remaining: 30.3s
# 369:	learn: 0.6598265	total: 17.7s	remaining: 30.2s
# 370:	learn: 0.6594280	total: 17.7s	remaining: 30s
# 371:	learn: 0.6590908	total: 17.7s	remaining: 29.9s
# 372:	learn: 0.6586112	total: 17.7s	remaining: 29.8s
# 373:	learn: 0.6581916	total: 17.7s	remaining: 29.7s
# 374:	learn: 0.6577812	total: 17.8s	remaining: 29.6s
# 375:	learn: 0.6572934	total: 17.8s	remaining: 29.5s
# 376:	learn: 0.6567465	total: 17.8s	remaining: 29.4s
# 377:	learn: 0.6562303	total: 17.8s	remaining: 29.3s
# 378:	learn: 0.6559263	total: 17.8s	remaining: 29.2s
# 379:	learn: 0.6553341	total: 17.8s	remaining: 29.1s
# 380:	learn: 0.6548814	total: 17.8s	remaining: 28.9s
# 381:	learn: 0.6543259	total: 17.8s	remaining: 28.8s
# 382:	learn: 0.6536892	total: 17.8s	remaining: 28.7s
# 383:	learn: 0.6532248	total: 17.8s	remaining: 28.6s
# 384:	learn: 0.6527478	total: 17.9s	remaining: 28.5s
# 385:	learn: 0.6524901	total: 17.9s	remaining: 28.4s
# 386:	learn: 0.6520825	total: 17.9s	remaining: 28.3s
# 387:	learn: 0.6517368	total: 17.9s	remaining: 28.2s
# 388:	learn: 0.6513165	total: 17.9s	remaining: 28.1s
# 389:	learn: 0.6508971	total: 17.9s	remaining: 28s
# 390:	learn: 0.6504288	total: 17.9s	remaining: 27.9s
# 391:	learn: 0.6499621	total: 17.9s	remaining: 27.8s
# 392:	learn: 0.6495618	total: 17.9s	remaining: 27.7s
# 393:	learn: 0.6492846	total: 17.9s	remaining: 27.6s
# 394:	learn: 0.6488979	total: 18s	remaining: 27.5s
# 395:	learn: 0.6482839	total: 18s	remaining: 27.4s
# 396:	learn: 0.6479541	total: 18s	remaining: 27.3s
# 397:	learn: 0.6474777	total: 18s	remaining: 27.2s
# 398:	learn: 0.6469593	total: 18s	remaining: 27.1s
# 399:	learn: 0.6464122	total: 18s	remaining: 27s
# 400:	learn: 0.6459017	total: 18s	remaining: 26.9s
# 401:	learn: 0.6455650	total: 18s	remaining: 26.8s
# 402:	learn: 0.6450271	total: 18s	remaining: 26.7s
# 403:	learn: 0.6445082	total: 18s	remaining: 26.6s
# 404:	learn: 0.6439905	total: 18s	remaining: 26.5s
# 405:	learn: 0.6435450	total: 18.1s	remaining: 26.4s
# 406:	learn: 0.6430704	total: 18.1s	remaining: 26.3s
# 407:	learn: 0.6425389	total: 18.1s	remaining: 26.2s
# 408:	learn: 0.6421866	total: 18.1s	remaining: 26.1s
# 409:	learn: 0.6416509	total: 18.1s	remaining: 26s
# 410:	learn: 0.6411724	total: 18.1s	remaining: 26s
# 411:	learn: 0.6407032	total: 18.1s	remaining: 25.9s
# 412:	learn: 0.6403284	total: 18.1s	remaining: 25.8s
# 413:	learn: 0.6397945	total: 18.1s	remaining: 25.7s
# 414:	learn: 0.6393906	total: 18.1s	remaining: 25.6s
# 415:	learn: 0.6390422	total: 18.2s	remaining: 25.5s
# 416:	learn: 0.6386057	total: 18.2s	remaining: 25.4s
# 417:	learn: 0.6383120	total: 18.2s	remaining: 25.3s
# 418:	learn: 0.6377395	total: 18.2s	remaining: 25.2s
# 419:	learn: 0.6370605	total: 18.2s	remaining: 25.1s
# 420:	learn: 0.6367033	total: 18.2s	remaining: 25s
# 421:	learn: 0.6363942	total: 18.2s	remaining: 25s
# 422:	learn: 0.6358518	total: 18.2s	remaining: 24.9s
# 423:	learn: 0.6353647	total: 18.2s	remaining: 24.8s
# 424:	learn: 0.6347697	total: 18.2s	remaining: 24.7s
# 425:	learn: 0.6343425	total: 18.3s	remaining: 24.6s
# 426:	learn: 0.6339188	total: 18.3s	remaining: 24.5s
# 427:	learn: 0.6336162	total: 18.3s	remaining: 24.4s
# 428:	learn: 0.6332485	total: 18.3s	remaining: 24.3s
# 429:	learn: 0.6328135	total: 18.3s	remaining: 24.3s
# 430:	learn: 0.6325525	total: 18.3s	remaining: 24.2s
# 431:	learn: 0.6321682	total: 18.3s	remaining: 24.1s
# 432:	learn: 0.6316492	total: 18.3s	remaining: 24s
# 433:	learn: 0.6309425	total: 18.3s	remaining: 23.9s
# 434:	learn: 0.6304476	total: 18.4s	remaining: 23.8s
# 529:	learn: 0.5923045	total: 19.3s	remaining: 17.1s
# 530:	learn: 0.5919484	total: 19.3s	remaining: 17.1s
# 531:	learn: 0.5915026	total: 19.3s	remaining: 17s
# 532:	learn: 0.5912065	total: 19.3s	remaining: 16.9s
# 533:	learn: 0.5908019	total: 19.3s	remaining: 16.9s
# 534:	learn: 0.5903460	total: 19.4s	remaining: 16.8s
# 535:	learn: 0.5898577	total: 19.4s	remaining: 16.8s
# 536:	learn: 0.5895622	total: 19.4s	remaining: 16.7s
# 537:	learn: 0.5892305	total: 19.4s	remaining: 16.6s
# 538:	learn: 0.5887543	total: 19.4s	remaining: 16.6s
# 539:	learn: 0.5883618	total: 19.4s	remaining: 16.5s
# 540:	learn: 0.5880591	total: 19.4s	remaining: 16.5s
# 541:	learn: 0.5876901	total: 19.4s	remaining: 16.4s
# 542:	learn: 0.5871966	total: 19.4s	remaining: 16.4s
# 543:	learn: 0.5868023	total: 19.4s	remaining: 16.3s
# 544:	learn: 0.5863321	total: 19.5s	remaining: 16.2s
# 545:	learn: 0.5859179	total: 19.5s	remaining: 16.2s
# 546:	learn: 0.5854792	total: 19.5s	remaining: 16.1s
# 547:	learn: 0.5850615	total: 19.5s	remaining: 16.1s
# 548:	learn: 0.5847111	total: 19.5s	remaining: 16s
# 549:	learn: 0.5843224	total: 19.5s	remaining: 16s
# 550:	learn: 0.5840148	total: 19.5s	remaining: 15.9s
# 551:	learn: 0.5836016	total: 19.5s	remaining: 15.8s
# 552:	learn: 0.5831924	total: 19.5s	remaining: 15.8s
# 553:	learn: 0.5828259	total: 19.5s	remaining: 15.7s
# 554:	learn: 0.5823978	total: 19.6s	remaining: 15.7s
# 555:	learn: 0.5820840	total: 19.6s	remaining: 15.6s
# 556:	learn: 0.5817258	total: 19.6s	remaining: 15.6s
# 557:	learn: 0.5813403	total: 19.6s	remaining: 15.5s
# 558:	learn: 0.5808790	total: 19.6s	remaining: 15.5s
# 559:	learn: 0.5804591	total: 19.6s	remaining: 15.4s
# 560:	learn: 0.5800163	total: 19.6s	remaining: 15.3s
# 561:	learn: 0.5795450	total: 19.6s	remaining: 15.3s
# 562:	learn: 0.5791251	total: 19.6s	remaining: 15.2s
# 563:	learn: 0.5787270	total: 19.6s	remaining: 15.2s
# 564:	learn: 0.5782134	total: 19.7s	remaining: 15.1s
# 565:	learn: 0.5779456	total: 19.7s	remaining: 15.1s
# 566:	learn: 0.5776902	total: 19.7s	remaining: 15s
# 567:	learn: 0.5773792	total: 19.7s	remaining: 15s
# 568:	learn: 0.5770757	total: 19.7s	remaining: 14.9s
# 569:	learn: 0.5767529	total: 19.7s	remaining: 14.9s
# 570:	learn: 0.5763694	total: 19.7s	remaining: 14.8s
# 571:	learn: 0.5758763	total: 19.7s	remaining: 14.8s
# 572:	learn: 0.5754521	total: 19.7s	remaining: 14.7s
# 573:	learn: 0.5749689	total: 19.7s	remaining: 14.7s
# 574:	learn: 0.5745888	total: 19.8s	remaining: 14.6s
# 575:	learn: 0.5743269	total: 19.8s	remaining: 14.5s
# 623:	learn: 0.5561709	total: 20.2s	remaining: 12.2s
# 624:	learn: 0.5557327	total: 20.2s	remaining: 12.1s
# 625:	learn: 0.5553271	total: 20.2s	remaining: 12.1s
# 626:	learn: 0.5549536	total: 20.3s	remaining: 12.1s
# 627:	learn: 0.5546732	total: 20.3s	remaining: 12s
# 628:	learn: 0.5542814	total: 20.3s	remaining: 12s
# 629:	learn: 0.5537955	total: 20.3s	remaining: 11.9s
# 630:	learn: 0.5535041	total: 20.3s	remaining: 11.9s
# 631:	learn: 0.5530848	total: 20.3s	remaining: 11.8s
# 632:	learn: 0.5527522	total: 20.3s	remaining: 11.8s
# 633:	learn: 0.5522873	total: 20.3s	remaining: 11.7s
# 634:	learn: 0.5519196	total: 20.3s	remaining: 11.7s
# 635:	learn: 0.5516101	total: 20.3s	remaining: 11.6s
# 636:	learn: 0.5514634	total: 20.4s	remaining: 11.6s
# 637:	learn: 0.5512135	total: 20.4s	remaining: 11.6s
# 638:	learn: 0.5508298	total: 20.4s	remaining: 11.5s
# 639:	learn: 0.5505218	total: 20.4s	remaining: 11.5s
# 640:	learn: 0.5501783	total: 20.4s	remaining: 11.4s
# 641:	learn: 0.5497219	total: 20.4s	remaining: 11.4s
# 642:	learn: 0.5493116	total: 20.4s	remaining: 11.3s
# 643:	learn: 0.5488367	total: 20.4s	remaining: 11.3s
# 644:	learn: 0.5484155	total: 20.4s	remaining: 11.2s
# 645:	learn: 0.5480652	total: 20.4s	remaining: 11.2s
# 646:	learn: 0.5478747	total: 20.5s	remaining: 11.2s
# 647:	learn: 0.5475026	total: 20.5s	remaining: 11.1s
# 648:	learn: 0.5471857	total: 20.5s	remaining: 11.1s
# 649:	learn: 0.5468810	total: 20.5s	remaining: 11s
# 650:	learn: 0.5464132	total: 20.5s	remaining: 11s
# 651:	learn: 0.5460420	total: 20.5s	remaining: 10.9s
# 652:	learn: 0.5456537	total: 20.5s	remaining: 10.9s
# 653:	learn: 0.5453269	total: 20.5s	remaining: 10.9s
# 654:	learn: 0.5450609	total: 20.5s	remaining: 10.8s
# 655:	learn: 0.5448536	total: 20.5s	remaining: 10.8s
# 656:	learn: 0.5444537	total: 20.6s	remaining: 10.7s
# 657:	learn: 0.5440916	total: 20.6s	remaining: 10.7s
# 658:	learn: 0.5437259	total: 20.6s	remaining: 10.6s
# 659:	learn: 0.5434525	total: 20.6s	remaining: 10.6s
# 660:	learn: 0.5430843	total: 20.6s	remaining: 10.6s
# 661:	learn: 0.5428013	total: 20.6s	remaining: 10.5s
# 662:	learn: 0.5424806	total: 20.6s	remaining: 10.5s
# 663:	learn: 0.5421161	total: 20.6s	remaining: 10.4s
# 664:	learn: 0.5417409	total: 20.6s	remaining: 10.4s
# 665:	learn: 0.5411743	total: 20.6s	remaining: 10.4s
# 666:	learn: 0.5408984	total: 20.7s	remaining: 10.3s
# 667:	learn: 0.5405363	total: 20.7s	remaining: 10.3s
# 668:	learn: 0.5402749	total: 20.7s	remaining: 10.2s
# 669:	learn: 0.5399553	total: 20.7s	remaining: 10.2s
# 670:	learn: 0.5394919	total: 20.7s	remaining: 10.1s
# 671:	learn: 0.5391650	total: 20.7s	remaining: 10.1s
# 672:	learn: 0.5389450	total: 20.7s	remaining: 10.1s
# 673:	learn: 0.5384516	total: 20.7s	remaining: 10s
# 674:	learn: 0.5381370	total: 20.7s	remaining: 9.98s
# 675:	learn: 0.5377621	total: 20.7s	remaining: 9.94s
# 676:	learn: 0.5374772	total: 20.8s	remaining: 9.9s
# 677:	learn: 0.5371647	total: 20.8s	remaining: 9.86s
# 678:	learn: 0.5367731	total: 20.8s	remaining: 9.82s
# 679:	learn: 0.5364885	total: 20.8s	remaining: 9.78s
# 680:	learn: 0.5363373	total: 20.8s	remaining: 9.74s
# 681:	learn: 0.5359368	total: 20.8s	remaining: 9.7s
# 682:	learn: 0.5355166	total: 20.8s	remaining: 9.66s
# 683:	learn: 0.5351869	total: 20.8s	remaining: 9.62s
# 684:	learn: 0.5348284	total: 20.8s	remaining: 9.58s
# 685:	learn: 0.5344142	total: 20.8s	remaining: 9.54s
# 686:	learn: 0.5339430	total: 20.9s	remaining: 9.5s
# 687:	learn: 0.5333289	total: 20.9s	remaining: 9.46s
# 688:	learn: 0.5329260	total: 20.9s	remaining: 9.42s
# 689:	learn: 0.5324567	total: 20.9s	remaining: 9.38s
# 690:	learn: 0.5322038	total: 20.9s	remaining: 9.34s
# 691:	learn: 0.5319406	total: 20.9s	remaining: 9.3s
# 692:	learn: 0.5315293	total: 20.9s	remaining: 9.27s
# 693:	learn: 0.5312035	total: 20.9s	remaining: 9.23s
# 694:	learn: 0.5307341	total: 20.9s	remaining: 9.19s
# 695:	learn: 0.5304511	total: 20.9s	remaining: 9.15s
# 696:	learn: 0.5301024	total: 21s	remaining: 9.11s
# 697:	learn: 0.5298406	total: 21s	remaining: 9.07s
# 698:	learn: 0.5294919	total: 21s	remaining: 9.03s
# 699:	learn: 0.5291072	total: 21s	remaining: 8.99s
# 700:	learn: 0.5288829	total: 21s	remaining: 8.96s
# 701:	learn: 0.5285557	total: 21s	remaining: 8.92s
# 702:	learn: 0.5281810	total: 21s	remaining: 8.88s
# 703:	learn: 0.5278798	total: 21s	remaining: 8.84s
# 704:	learn: 0.5275696	total: 21s	remaining: 8.8s
# 705:	learn: 0.5272172	total: 21s	remaining: 8.76s
# 706:	learn: 0.5270360	total: 21.1s	remaining: 8.73s
# 707:	learn: 0.5266700	total: 21.1s	remaining: 8.69s
# 708:	learn: 0.5263110	total: 21.1s	remaining: 8.65s
# 709:	learn: 0.5259546	total: 21.1s	remaining: 8.61s
# 710:	learn: 0.5254489	total: 21.1s	remaining: 8.57s
# 711:	learn: 0.5249619	total: 21.1s	remaining: 8.54s
# 712:	learn: 0.5246843	total: 21.1s	remaining: 8.5s
# 713:	learn: 0.5243849	total: 21.1s	remaining: 8.46s
# 714:	learn: 0.5241116	total: 21.1s	remaining: 8.43s
# 715:	learn: 0.5236465	total: 21.1s	remaining: 8.39s
# 716:	learn: 0.5232226	total: 21.2s	remaining: 8.35s
# 717:	learn: 0.5229109	total: 21.2s	remaining: 8.31s
# 718:	learn: 0.5227515	total: 21.2s	remaining: 8.28s
# 719:	learn: 0.5222818	total: 21.2s	remaining: 8.24s
# 720:	learn: 0.5220570	total: 21.2s	remaining: 8.2s
# 721:	learn: 0.5218125	total: 21.2s	remaining: 8.16s
# 722:	learn: 0.5215176	total: 21.2s	remaining: 8.13s
# 723:	learn: 0.5211674	total: 21.2s	remaining: 8.09s
# 724:	learn: 0.5209253	total: 21.2s	remaining: 8.05s
# 725:	learn: 0.5206906	total: 21.2s	remaining: 8.02s
# 726:	learn: 0.5202074	total: 21.3s	remaining: 7.98s
# 727:	learn: 0.5198986	total: 21.3s	remaining: 7.94s
# 728:	learn: 0.5196497	total: 21.3s	remaining: 7.91s
# 729:	learn: 0.5194368	total: 21.3s	remaining: 7.87s
# 730:	learn: 0.5191001	total: 21.3s	remaining: 7.83s
# 731:	learn: 0.5188373	total: 21.3s	remaining: 7.8s
# 732:	learn: 0.5185598	total: 21.3s	remaining: 7.76s
# 733:	learn: 0.5181186	total: 21.3s	remaining: 7.73s
# 734:	learn: 0.5178896	total: 21.3s	remaining: 7.69s
# 735:	learn: 0.5175928	total: 21.3s	remaining: 7.65s
# 736:	learn: 0.5172879	total: 21.3s	remaining: 7.62s
# 737:	learn: 0.5170189	total: 21.4s	remaining: 7.58s
# 738:	learn: 0.5168301	total: 21.4s	remaining: 7.55s
# 739:	learn: 0.5163788	total: 21.4s	remaining: 7.51s
# 740:	learn: 0.5160101	total: 21.4s	remaining: 7.47s
# 741:	learn: 0.5157597	total: 21.4s	remaining: 7.44s
# 742:	learn: 0.5153744	total: 21.4s	remaining: 7.4s
# 743:	learn: 0.5150969	total: 21.4s	remaining: 7.37s
# 744:	learn: 0.5147822	total: 21.4s	remaining: 7.33s
# 745:	learn: 0.5143112	total: 21.4s	remaining: 7.3s
# 746:	learn: 0.5137929	total: 21.4s	remaining: 7.26s
# 747:	learn: 0.5134272	total: 21.5s	remaining: 7.23s
# 748:	learn: 0.5130270	total: 21.5s	remaining: 7.19s
# 749:	learn: 0.5126300	total: 21.5s	remaining: 7.16s
# 750:	learn: 0.5122538	total: 21.5s	remaining: 7.12s
# 751:	learn: 0.5119150	total: 21.5s	remaining: 7.09s
# 752:	learn: 0.5115323	total: 21.5s	remaining: 7.05s
# 753:	learn: 0.5112202	total: 21.5s	remaining: 7.02s
# 754:	learn: 0.5109697	total: 21.5s	remaining: 6.98s
# 755:	learn: 0.5106789	total: 21.5s	remaining: 6.95s
# 756:	learn: 0.5103298	total: 21.5s	remaining: 6.91s
# 757:	learn: 0.5100504	total: 21.6s	remaining: 6.88s
# 758:	learn: 0.5097527	total: 21.6s	remaining: 6.85s
# 759:	learn: 0.5094400	total: 21.6s	remaining: 6.81s
# 760:	learn: 0.5091110	total: 21.6s	remaining: 6.78s
# 761:	learn: 0.5086689	total: 21.6s	remaining: 6.74s
# 762:	learn: 0.5083542	total: 21.6s	remaining: 6.71s
	remaining: 0us

# %%
test_pred = clf.predict(test_embeds)
test_proba = clf.predict_proba(test_embeds)

# %%
print("Accuracy:", accuracy_score(target_test, test_pred))
print("ROC-AUC:", roc_auc_score(target_test, test_proba, average="weighted", multi_class="ovr"))
# Out:
# Accuracy: 0.5996666666666667
# ROC-AUC: 0.8462534406315487

# %%
arr = np.array([0.8459122462737779, 0.8483154534047637, 0.8462534406315487])

arr.mean(), arr.std()
# Out:
# (0.8468270467700302, 0.0010616399672779273)

# %% [markdown]
# - COLES embeds + Catboost:
#   - `Accuracy: 0.6133333333333333`, `0.606`, `0.5933333333333334`, avg: `0.6042 +- 0.0083`
#   -  `ROC-AUC: 0.8490542004456147`, `0.848260886697585`, `0.8472952867923927`, avg: `0.8482 +- 0.0007`
#
# ---
#
# - COLES embeds + ConvAgg (3 trx) + Catboost:
#   - Accuracy: `0.6`, `0.6023333333333334`, `0.6056666666666667`, avg: `0.6027 +- 0.0023`
#   - ROC-AUC: `0.8449018451080985`, `0.8453518001645437`, `0.8479308377093546`, avg: `0.8461 +- 0.0013`
#
# ---
#
# - COLES embeds + ConvAgg (5 trx) + Catboost:
#   - Accuracy: `0.5963333333333334`, `0.6053333333333333`, `0.605`, avg: `0.6022 +- 0.0042`
#   - ROC-AUC: `0.8435980298247711`, `0.8489526718533573`, `0.8445515887986031`, avg: `0.8457 +- 0.0023`
#
# ---
#
# - COLES embeds + ConvAgg (7 trx) + Catboost:
#   - Accuracy: `0.5996666666666667`, `0.6013333333333334`, `0.5996666666666667`, avg: `0.6002 +- 0.0008`
#   - ROC-AUC: `0.8459122462737779`, `0.8483154534047637`, `0.8462534406315487`, avg: `0.8468 +- 0.0011`
#
# ---
#
# **Вывод:** для CoLES качество при свёрточной агрегации несколько хуже, чем у бейзлайна. С увеличением размера ядра свёртки в целом убывает, при этом при наибольшем размере ядра (7 транзакций) ROC-AUC выше, чем в остальных случаях.
#
# **Конфигурация, лучшая по метрикам:**
#
# - COLES embeds + ConvAgg (3 trx) + Catboost:
#   - Accuracy: `0.6`, `0.6023333333333334`, `0.6056666666666667`, avg: `0.6027 +- 0.0023`
#   - ROC-AUC: `0.8449018451080985`, `0.8453518001645437`, `0.8479308377093546`, avg: `0.8461 +- 0.0013`

# %% [markdown]
# ---

# %% [markdown]
# **Train sequences lengths check:**

# %%
agg_encoder_params = dict(
    embeddings_noise=0.003,
    numeric_values={"amount_rur": "log"},
    embeddings={
        "trans_date": {"in": 800, "out": 16},
        "small_group": {"in": 250, "out": 16},
    }
)

trx_encoder = TrxEncoder(**agg_encoder_params)
trx_encoder.to("cuda")
# Out:
# TrxEncoder(
#   (embeddings): ModuleDict(
#     (trans_date): NoisyEmbedding(
#       800, 16, padding_idx=0
#       (dropout): Dropout(p=0, inplace=False)
#     )
#     (small_group): NoisyEmbedding(
#       250, 16, padding_idx=0
#       (dropout): Dropout(p=0, inplace=False)
#     )
#   )
#   (custom_embeddings): ModuleDict(
#     (amount_rur): LogScaler()
#   )
#   (custom_embedding_batch_norm): RBatchNorm(
#     (bn): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )

# %%
train_loader = inference_data_loader(data_train, num_workers=0, batch_size=128)

trx_encoder.eval()

seq_lens = []

for batch in tqdm(train_loader):
    embeds_batch = trx_encoder(batch.to("cuda"))
    seq_lens += [embeds_batch.seq_lens.detach().cpu().numpy()]

seq_lens = np.concatenate(seq_lens)

threshold = int(np.quantile(seq_lens, 0.6))

print("Max Length:", threshold)
# Out:
# 211it [00:01, 109.70it/s]
# Max Length: 904

# %% [markdown]
# ---

# %% [markdown]
# - **CPC modeling:**

# %% [markdown]
# ---

# %% [markdown]
# **Скорректируем класс CpcModule так, чтобы при работе CPC не было даталиков:**

# %%
import torch
from torch import nn as nn
from torch.nn import functional as F


class CPC_ShiftedLoss(nn.Module):
    def __init__(self, n_negatives=None, n_forward_steps=None, shift=None):
        super().__init__()
        self.n_negatives = n_negatives
        self.n_forward_steps = n_forward_steps
        self.shift = shift

    def _get_preds(self, base_embeddings, mapped_ctx_embeddings):
        batch_size, max_seq_len, emb_size = base_embeddings.payload.shape
        _, _, _, n_forward_steps = mapped_ctx_embeddings.payload.shape
        seq_lens = mapped_ctx_embeddings.seq_lens
        device = mapped_ctx_embeddings.payload.device

        len_mask = torch.arange(max_seq_len).unsqueeze(0).expand(batch_size, -1).to(device)
        len_mask = (len_mask < seq_lens.unsqueeze(1).expand(-1, max_seq_len)).float()
        
        possible_negatives = base_embeddings.payload.reshape(batch_size * max_seq_len, emb_size)

        mask = len_mask.unsqueeze(0).expand(batch_size, *len_mask.shape).clone()

        mask = mask.reshape(batch_size, -1)
        sample_ids = torch.multinomial(mask, self.n_negatives)
        neg_samples = possible_negatives[sample_ids]

        positive_preds, neg_preds = [], []
        len_mask_exp = len_mask.unsqueeze(-1).unsqueeze(-1).to(device).expand(-1, -1, emb_size, n_forward_steps)
        trimmed_mce = mapped_ctx_embeddings.payload.mul(len_mask_exp)  # zero context vectors by sequence lengths
        for i in range(1, n_forward_steps + 1):
            ce_i = trimmed_mce[:, 0:(max_seq_len - i - self.shift), :, i - 1]
            be_i = base_embeddings.payload[:, (i + self.shift):max_seq_len]

            positive_pred_i = ce_i.mul(be_i).sum(axis=-1)
            positive_preds.append(positive_pred_i)

            neg_pred_i = ce_i.matmul(neg_samples.transpose(-2, -1))
            neg_preds.append(neg_pred_i)

        return positive_preds, neg_preds

    def forward(self, embeddings, _):
        base_embeddings, _, mapped_ctx_embeddings = embeddings
        device = mapped_ctx_embeddings.payload.device
        positive_preds, neg_preds = self._get_preds(base_embeddings, mapped_ctx_embeddings)

        step_losses = []
        for positive_pred_i, neg_pred_i in zip(positive_preds, neg_preds):
            step_loss = -F.log_softmax(torch.cat([positive_pred_i.unsqueeze(-1), neg_pred_i], dim=-1), dim=-1)[:, :, 0].mean()
            step_losses.append(step_loss)

        loss = torch.stack(step_losses).mean()
        return loss

    def cpc_accuracy(self, embeddings, _):
        base_embeddings, _, mapped_ctx_embeddings = embeddings
        positive_preds, neg_preds = self._get_preds(base_embeddings, mapped_ctx_embeddings)

        batch_size, max_seq_len, emb_size = base_embeddings.payload.shape
        seq_lens = mapped_ctx_embeddings.seq_lens
        device = mapped_ctx_embeddings.payload.device

        len_mask = torch.arange(max_seq_len).unsqueeze(0).expand(batch_size, -1).to(device)
        len_mask = (len_mask < seq_lens.unsqueeze(1).expand(-1, max_seq_len)).float()

        total, accurate = 0, 0
        
        for i, (positive_pred_i, neg_pred_i) in enumerate(zip(positive_preds, neg_preds)):
            i_mask = len_mask[:, (self.shift + i + 1):max_seq_len].to(device)
            total += i_mask.sum().item()
            accurate += (((positive_pred_i.unsqueeze(-1).expand(*neg_pred_i.shape) > neg_pred_i) \
                          .sum(dim=-1) == self.n_negatives) * i_mask).sum().item()
        return accurate / total

# %%
import torch

from ptls.frames.abs_module import ABSModule
from ptls.frames.cpc.metrics.cpc_accuracy import CpcAccuracy
from ptls.nn.seq_encoder import RnnSeqEncoder
from ptls.data_load.padded_batch import PaddedBatch


class CpcModule(ABSModule):
    """Contrastive Predictive Coding ([CPC](https://arxiv.org/abs/1807.03748))

    Original sequence are encoded by `TrxEncoder`.
    Hidden representation `z` is an embedding for each individual transaction.
    Next `RnnEncoder` used for `context` calculation from `z`.
    Linear predictors are used to predict next trx embedding by context.
    The loss function tends to make future trx embedding and they predict closer.
    Negative sampling are used to avoid trivial solution.

    Parameters
        seq_encoder:
            Model which calculate embeddings for original raw transaction sequences
            `seq_encoder` is trained by `CoLESModule` to get better representations of input sequences
        head:
            Not used
        loss:
            Keep None. CPCLoss used by default
        validation_metric:
            Keep None. CPCAccuracy used by default
        optimizer_partial:
            optimizer init partial. Network parameters are missed.
        lr_scheduler_partial:
            scheduler init partial. Optimizer are missed.

    """
    def __init__(self, validation_metric=None,
                       seq_encoder=None,
                       head=None,
                       n_negatives=40, n_forward_steps=6,
                       optimizer_partial=None,
                       lr_scheduler_partial=None):

        self.save_hyperparameters('n_negatives', 'n_forward_steps')

        loss = CPC_ShiftedLoss(n_negatives=n_negatives, n_forward_steps=n_forward_steps, shift=(seq_encoder.trx_encoder.agg_samples - 1))

        if validation_metric is None:
            validation_metric = CpcAccuracy(loss)

        if seq_encoder is not None and not isinstance(seq_encoder, RnnSeqEncoder):
            raise NotImplementedError(f'Only rnn encoder supported in CpcModule. Found {type(seq_encoder)}')

        seq_encoder.seq_encoder.is_reduce_sequence = False

        super().__init__(validation_metric,
                         seq_encoder,
                         loss,
                         optimizer_partial,
                         lr_scheduler_partial)

        linear_size = self.seq_encoder.trx_encoder.output_size
        embedding_size = self.seq_encoder.embedding_size
        self._linears = torch.nn.ModuleList([torch.nn.Linear(embedding_size, linear_size)
                                             for _ in range(loss.n_forward_steps)])

    @property
    def metric_name(self):
        return 'cpc_accuracy'

    @property
    def is_requires_reduced_sequence(self):
        return False

    def shared_step(self, x, y):
        trx_encoder = self._seq_encoder.trx_encoder
        seq_encoder = self._seq_encoder.seq_encoder

        base_embeddings = trx_encoder(x)
        context_embeddings = seq_encoder(base_embeddings)

        me = []
        for l in self._linears:
            me.append(l(context_embeddings.payload))
        mapped_ctx_embeddings = PaddedBatch(torch.stack(me, dim=3), context_embeddings.seq_lens)

        return (base_embeddings, context_embeddings, mapped_ctx_embeddings), y

# %% [markdown]
# ---

# %%
seed_everything(17)

# %% [markdown]
# **DataLoaders:**

# %%
data = PtlsDataModule(
    train_data=CpcDataset(
        MemoryMapDataset(data=data_train),
        min_len=863,
        max_len=904
    ),
    train_num_workers=4,
    train_batch_size=64,
    valid_data=CpcDataset(
        MemoryMapDataset(data=data_test),
        min_len=863,
        max_len=904
    ),
    valid_num_workers=4,
    valid_batch_size=64
)

# %% [markdown]
# **Модель:**

# %%
N_EPOCHS = 20

# %%
agg_encoder_params = dict(
    embeddings_noise=0.003,
    numeric_values={"amount_rur": "log"},
    embeddings={
        "trans_date": {"in": 800, "out": 128},
        "small_group": {"in": 250, "out": 128},
    },
    agg_samples=7, # 3, 5, 7
    use_window_attention=False
)

trx_encoder = ConvAggregator(**agg_encoder_params)

seq_encoder = RnnSeqEncoder(
    trx_encoder=trx_encoder,
    hidden_size=512,
    type="gru"
)

cpc = CpcModule(
    seq_encoder=seq_encoder,
    n_forward_steps=6,
    n_negatives=40,
    optimizer_partial=partial(torch.optim.Adam, lr=2e-3),
    lr_scheduler_partial=partial(torch.optim.lr_scheduler.StepLR, step_size=5, gamma=0.5)
)

# %% [markdown]
# **Обучение:**

# %%
logger = CometLogger(project_name="EvS_SSL", experiment_name="CPC_modeling_ConvAgg (7 trx)")

trainer = pl.Trainer(
    logger=logger,
    max_epochs=N_EPOCHS,
    accelerator="gpu",
    devices=1,
    enable_progress_bar=True
)

# %%
trainer.fit(cpc, data)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Couldn't find a Git repository in '/kaggle/working' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/askoro/evs-ssl/073b670595a44e61bd27efc51efaad91
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : CPC_modeling_ConvAgg (7 trx)
# COMET INFO:     url                   : https://www.comet.com/askoro/evs-ssl/073b670595a44e61bd27efc51efaad91
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [1012]             : (0.265452116727829, 4.289204120635986)
# COMET INFO:     seq_len [168]           : (808.203125, 848.625)
# COMET INFO:     valid/cpc_accuracy [20] : (0.9208076000213623, 0.9663130044937134)
# COMET INFO:   Others:
# COMET INFO:     Name : CPC_modeling_ConvAgg (7 trx)
# COMET INFO:   Parameters:
# COMET INFO:     test_batch_size   : None
# COMET INFO:     test_drop_last    : False
# COMET INFO:     test_num_workers  : None
# COMET INFO:     train_batch_size  : 64
# COMET INFO:     train_drop_last   : False
# COMET INFO:     train_num_workers : 4
# COMET INFO:     valid_batch_size  : 64
# COMET INFO:     valid_drop_last   : False
# COMET INFO:     valid_num_workers : 4
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:

# %%
trainer.logged_metrics
# Out:
# {'loss': tensor(0.3818),
#  'seq_len': tensor(819.3751),
#  'valid/cpc_accuracy': tensor(0.9662)}

# %%
# torch.save(seq_encoder.state_dict(), "cpc_enc_win_agg_trx20.pt")

# %% [markdown]
# **Измерим качество на тесте (catboost поверх эмбеддингов):**

# %%
encoder = cpc.seq_encoder

device = "cuda:0"

encoder.to(device)
# Out:
# RnnSeqEncoder(
#   (trx_encoder): ConvAggregator(
#     (embeddings): ModuleDict(
#       (trans_date): NoisyEmbedding(
#         800, 128, padding_idx=0
#         (dropout): Dropout(p=0, inplace=False)
#       )
#       (small_group): NoisyEmbedding(
#         250, 128, padding_idx=0
#         (dropout): Dropout(p=0, inplace=False)
#       )
#     )
#     (custom_embeddings): ModuleDict(
#       (amount_rur): LogScaler()
#     )
#     (conv): Conv1d(257, 257, kernel_size=(7,), stride=(1,), padding=(6,), bias=False)
#   )
#   (seq_encoder): RnnEncoder(
#     (rnn): GRU(257, 512, batch_first=True)
#     (reducer): LastStepEncoder()
#   )
# )

# %%
encoder.seq_encoder.is_reduce_sequence = True

# %%
from tqdm import tqdm

seed_everything(17)

# %%
train_loader = inference_data_loader(data_train, num_workers=0, batch_size=128)
encoder.eval()
train_embeds = None

for i, batch in tqdm(enumerate(train_loader)):
    train_embeds_batch = encoder(batch.to(device))
    if i == 0:
        train_embeds = train_embeds_batch.detach().cpu().numpy()
    else:
        train_embeds = np.concatenate([train_embeds, train_embeds_batch.detach().cpu().numpy()], axis=0)
    
train_embeds
# Out:
# 211it [00:30,  7.03it/s]
# array([[-0.05324957,  0.11450856, -0.12086479, ..., -0.07501061,
#          0.03365382, -0.09520902],
#        [-0.09045979,  0.07325636, -0.15996777, ..., -0.0804252 ,
#          0.02945825, -0.09366222],
#        [ 0.03150362,  0.14453615, -0.05120659, ..., -0.24039234,
#          0.13753735, -0.20452476],
#        ...,
#        [-0.04467927,  0.11737393, -0.11436034, ..., -0.1464082 ,
#          0.13431565, -0.12178652],
#        [-0.0121008 ,  0.0200711 , -0.14695942, ..., -0.1723734 ,
#          0.07244273, -0.1261596 ],
#        [ 0.02000915,  0.01037849, -0.06434368, ...,  0.04906905,
#          0.16014408, -0.07977976]], dtype=float32)

# %%
test_loader = inference_data_loader(data_test, num_workers=0, batch_size=128)
encoder.eval()
test_embeds = None

for i, batch in tqdm(enumerate(test_loader)):
    test_embeds_batch = encoder(batch.to(device))
    if i == 0:
        test_embeds = test_embeds_batch.detach().cpu().numpy()
    else:
        test_embeds = np.concatenate([test_embeds, test_embeds_batch.detach().cpu().numpy()], axis=0)
    
test_embeds
# Out:
# 24it [00:03,  7.57it/s]
# array([[-0.00633594,  0.01500798, -0.09645905, ..., -0.10396656,
#          0.16359031, -0.0927169 ],
#        [ 0.02070122,  0.06364661, -0.16149746, ..., -0.15697472,
#          0.03835281, -0.17137945],
#        [ 0.08664538,  0.1276432 , -0.16208892, ..., -0.04973625,
#          0.1019806 , -0.16285062],
#        ...,
#        [-0.06901073,  0.01682798,  0.02728134, ..., -0.07610157,
#          0.04936444, -0.09541061],
#        [ 0.00699887,  0.04263111, -0.00087967, ..., -0.15079468,
#          0.05048765, -0.21230198],
#        [ 0.02064326,  0.10989095, -0.13404979, ...,  0.0484121 ,
#          0.01480115, -0.18523376]], dtype=float32)

# %%
clf = CatBoostClassifier(loss_function='MultiClass', task_type="GPU", devices='0', random_state=17)

clf.fit(train_embeds, target_train, plot_file="catboost_log.html")
# Out:
# Warning: less than 75% GPU memory available for training. Free: 11869.125 Total: 16269.25
# Learning rate set to 0.12714
# 0:	learn: 1.3094333	total: 17.3ms	remaining: 17.3s
# 1:	learn: 1.2535525	total: 28.7ms	remaining: 14.3s
# 2:	learn: 1.2096732	total: 40ms	remaining: 13.3s
# 3:	learn: 1.1749940	total: 51.1ms	remaining: 12.7s
# 4:	learn: 1.1472119	total: 62.4ms	remaining: 12.4s
# 5:	learn: 1.1205456	total: 74.1ms	remaining: 12.3s
# 987:	learn: 0.4351720	total: 9.83s	remaining: 119ms
# 988:	learn: 0.4348200	total: 9.84s	remaining: 109ms
# 989:	learn: 0.4345265	total: 9.85s	remaining: 99.5ms
# 990:	learn: 0.4342781	total: 9.86s	remaining: 89.5ms
# 991:	learn: 0.4339559	total: 9.87s	remaining: 79.6ms
# 992:	learn: 0.4335471	total: 9.88s	remaining: 69.6ms
# 993:	learn: 0.4332436	total: 9.89s	remaining: 59.7ms
# 994:	learn: 0.4329212	total: 9.9s	remaining: 49.7ms
# 995:	learn: 0.4325388	total: 9.91s	remaining: 39.8ms
# 996:	learn: 0.4322419	total: 9.92s	remaining: 29.8ms
# 997:	learn: 0.4319505	total: 9.93s	remaining: 19.9ms
# 998:	learn: 0.4316913	total: 9.94s	remaining: 9.95ms
# 999:	learn: 0.4314319	total: 9.95s	remaining: 0us

# %%
test_pred = clf.predict(test_embeds)
test_proba = clf.predict_proba(test_embeds)

# %%
print("Accuracy:", accuracy_score(target_test, test_pred))
print("ROC-AUC:", roc_auc_score(target_test, test_proba, average="weighted", multi_class="ovr"))
# Out:
# Accuracy: 0.5816666666666667
# ROC-AUC: 0.8337874711769329

# %%
arr = np.array([0.8346637198543245, 0.8337874711769329, 0.829962629518911])

arr.mean(), arr.std()
# Out:
# (0.8328046068500562, 0.0020411727510126487)

# %% [markdown]
# - CPC context embeds + Catboost:
#    - `Accuracy: 0.5773333333333334`, `0.5686666666666667`, `0.5826666666666667`, avg: `0.5762 +- 0.0058`
#    - ` ROC-AUC: 0.830123007110738`, `0.8271157616313021`, `0.8343491131233265`, avg: `0.8305 +- 0.003`
#
# ---
#
# - CPC context embeds + ConvAgg (3 trx) + Catboost:
#   - Accuracy: `0.5813333333333334`, `0.5816666666666667`, `0.5723333333333334`, avg: `0.5784 +- 0.0043`
#   - ROC-AUC: `0.8281683346974047`, `0.8303942706365449`, `0.8299126513367255`, avg: `0.8295 +- 0.001`
#
# ---
#
# - CPC context embeds + ConvAgg (5 trx) + Catboost:
#   - `Accuracy: 0.579`, `0.587`, `0.589`, avg: `0.585 +- 0.0043`
#   - `ROC-AUC: 0.8304985732068079`, `0.8342778789187919`, `0.8303966161955582`, avg: `0.8317 +- 0.0018`
#
# ---
#
# - CPC context embeds + ConvAgg (7 trx) + Catboost:
#   - `Accuracy: 0.5843333333333334`, `0.5816666666666667`, `0.5826666666666667`, avg: `0.5829 +- 0.0011`
#   - `ROC-AUC: 0.8346637198543245`, `0.8337874711769329`, `0.829962629518911`, avg: `0.8328 +- 0.002`
#
# ---
#
# **Вывод:** Свёрточная агрегация значительно улучшает качество для CPC. С увеличением размера ядра свёртки качество улучшается (далее - предполагается, что оно выйдет на плато, а затем будет лишь ухудшаться).
#
#
# **Конфигурация, лучшая по метрикам:**
#
# - CPC context embeds + ConvAgg (5 trx) + Catboost:
#   - `Accuracy: 0.579`, `0.587`, `0.589`, avg: `0.585 +- 0.0043`
#   - `ROC-AUC: 0.8304985732068079`, `0.8342778789187919`, `0.8303966161955582`, avg: `0.8317 +- 0.0018`

# %% [markdown]
# ---

# %% [markdown]
# - **GPT:**

# %%
seed_everything(17)

# %% [markdown]
# **DataLoaders:**

# %%
data = PtlsDataModule(
    train_data=GptDataset(
        MemoryMapDataset(data=data_train),
        min_len=1000,
        max_len=1200
    ),
    train_num_workers=4,
    train_batch_size=16,
    valid_data=GptDataset(
        MemoryMapDataset(data=data_test),
        min_len=1000,
        max_len=1200
    ),
    valid_num_workers=4,
    valid_batch_size=16
)

# %% [markdown]
# **Модель:**

# %%
from torchmetrics import MeanMetric
from typing import Tuple, Dict, List, Union
from torch import nn
import torch.nn.functional as F 
from ptls.nn.seq_encoder.abs_seq_encoder import AbsSeqEncoder
from ptls.nn import PBL2Norm
from ptls.data_load.padded_batch import PaddedBatch


class MeanPooling(torch.nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, pb: PaddedBatch):
        payload = pb.payload # (B, T, H)
        mask = pb.seq_len_mask.bool()
        pb_mean = payload.sum(dim=1) / mask.float().sum(dim=1, keepdim=True)
        return pb_mean


class StatPooling(torch.nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, pb: PaddedBatch):
        payload = pb.payload # (B, T, H)
        mask = pb.seq_len_mask.bool()
        inf_mask = torch.zeros_like(mask, device=mask.device).float()
        inf_mask[~mask] = -torch.inf
        
        pb_mean = payload.sum(dim=1) / mask.float().sum(dim=1, keepdim=True)
        pb_max = torch.max(payload + inf_mask.unsqueeze(-1), dim=1)[0]
        pb_stat = torch.cat((pb_mean, pb_max), dim=1)
        return pb_stat


class GPTHead(torch.nn.Module):   
    def __init__(self, input_size, n_classes, hidden_size=64, drop_p=0.1):
        super().__init__()
        self.head = nn.Sequential(
            nn.Linear(input_size, hidden_size, bias=True),
            nn.GELU(),
            nn.Dropout(drop_p),
            nn.Linear(hidden_size, n_classes)
        )
    def forward(self, x):
        x = self.head(x)
        return x


class ConvAgg_GPT_PretrainModule(pl.LightningModule):
    def __init__(self,
                 trx_encoder: torch.nn.Module,
                 seq_encoder: AbsSeqEncoder,
                 head_hidden_size: int = 64,
                 total_steps: int = 64000,
                 seed_seq_len: int = 16,
                 max_lr: float = 0.00005,
                 weight_decay: float = 0.0,
                 pct_start: float = 0.1,
                 norm_predict: bool = False
                 ):

        super().__init__()
        self.save_hyperparameters(ignore=['trx_encoder', 'seq_encoder'])

        self.trx_encoder = trx_encoder
        self._seq_encoder = seq_encoder
        self._seq_encoder.is_reduce_sequence = False

        self.head = nn.ModuleDict()
        for col_name, noisy_emb in self.trx_encoder.embeddings.items():
            self.head[col_name] = GPTHead(input_size=self._seq_encoder.embedding_size, hidden_size=head_hidden_size, n_classes=noisy_emb.num_embeddings)

        if self.hparams.norm_predict:
            self.fn_norm_predict = PBL2Norm()

        self.loss = nn.CrossEntropyLoss(ignore_index=0)

        self.train_gpt_loss = MeanMetric()
        self.valid_gpt_loss = MeanMetric()

        self.shift = trx_encoder.agg_samples

    def forward(self, batch: PaddedBatch):
        z_trx = self.trx_encoder(batch) 
        out = self._seq_encoder(z_trx)
        if self.hparams.norm_predict:
            out = self.fn_norm_predict(out)
        return out

    def loss_gpt(self, logits, labels):
        loss = 0
        for col_name, head in self.head.items():
            y_pred = head(logits[:, self.hparams.seed_seq_len:-self.shift, :])
            y_pred = y_pred.view(-1, y_pred.size(-1))

            y_true = labels[col_name][:, self.hparams.seed_seq_len+1:]
            y_true = torch.flatten(y_true.long())
            
            loss += self.loss(y_pred, y_true)
            
        return loss

    def training_step(self, batch, batch_idx):
        out = self.forward(batch)  # PB: B, T, H
        out = out.payload if isinstance(out, PaddedBatch) else out
        labels = batch.payload

        loss_gpt = self.loss_gpt(out, labels)
        self.train_gpt_loss(loss_gpt)
        self.log(f'loss', loss_gpt, sync_dist=True)
        return loss_gpt

    def validation_step(self, batch, batch_idx):
        out = self.forward(batch)  # PB: B, T, H
        out = out.payload if isinstance(out, PaddedBatch) else out
        labels = batch.payload

        loss_gpt = self.loss_gpt(out, labels)
        self.valid_gpt_loss(loss_gpt)

    def on_training_epoch_end(self):
        self.log('train loss (by epochs)', self.train_gpt_loss, prog_bar=True, logger=True, sync_dist=True, rank_zero_only=True)

    def on_validation_epoch_end(self):
        self.log('val loss (by epochs)', self.valid_gpt_loss, prog_bar=True, logger=True, sync_dist=True, rank_zero_only=True)

    def configure_optimizers(self):
        optim = torch.optim.NAdam(self.parameters(),
                                  lr=self.hparams.max_lr,
                                  weight_decay=self.hparams.weight_decay
                                 )
        
        scheduler = torch.optim.lr_scheduler.OneCycleLR(
            optimizer=optim,
            max_lr=self.hparams.max_lr,
            total_steps=self.hparams.total_steps,
            pct_start=self.hparams.pct_start,
            anneal_strategy='cos',
            cycle_momentum=False,
            div_factor=25.0,
            final_div_factor=10000.0,
            three_phase=False
        )
        
        scheduler = {'scheduler': scheduler, 'interval': 'step'}
        return [optim], [scheduler]
    
    @property
    def seq_encoder(self):
        return GPTInferenceModule(pretrained_model=self)


class GPTInferenceModule(torch.nn.Module):
    def __init__(self, pretrained_model):
        super().__init__()
        self.model = pretrained_model
        self.model.is_reduce_sequence = False
        self.mean_pooling = MeanPooling()
        self.stat_pooling = StatPooling()

    def forward(self, batch, eval_strategy="mean"):
        z_trx = self.model.trx_encoder(batch)
        out = self.model._seq_encoder(z_trx)
        out = out if isinstance(out, PaddedBatch) else PaddedBatch(out, batch.seq_lens)

        if eval_strategy == "mean":
            out = self.mean_pooling(out)
        elif eval_strategy == "stat":
            out = self.stat_pooling(out)

        if self.model.hparams.norm_predict:
            out = out / (out.pow(2).sum(dim=-1, keepdim=True) + 1e-9).pow(0.5)
        return out

# %% [markdown]
# Multilabel-подход для обучения здесь не применим, так как окна транзакций пересекаются.

# %%
# class WinAgg_GPT_MultiLabelPretrainModule(GptPretrainModule):
#     def __init__(self,
#                  trx_encoder: torch.nn.Module,
#                  seq_encoder: AbsSeqEncoder,
#                  head_hidden_size: int = 64,
#                  total_steps: int = 64000,
#                  seed_seq_len: int = 16,
#                  max_lr: float = 0.00005,
#                  weight_decay: float = 0.0,
#                  pct_start: float = 0.1,
#                  norm_predict: bool = False
#                  ):
#         super().__init__(
#             trx_encoder=trx_encoder,
#             seq_encoder=seq_encoder,
#             head_hidden_size=head_hidden_size,
#             total_steps=total_steps,
#             seed_seq_len=seed_seq_len,
#             max_lr=max_lr,
#             weight_decay=weight_decay,
#             pct_start=pct_start,
#             norm_predict=norm_predict
#         )
#         self.agg_samples = trx_encoder.agg_samples
#         self.loss = nn.MultiLabelSoftMarginLoss()

#     def loss_gpt(self, logits, labels):
#         loss = 0
        
#         for col_name, head in self.head.items():
#             pred = head(logits[:, (self.hparams.seed_seq_len // self.agg_samples):-1, :])

#             ohe_labels = torch.zeros((pred.shape[0] * pred.shape[1], pred.shape[2]), device=pred.device)
            
#             for shift in range(self.agg_samples):
#                 y_true = labels[col_name][:, (self.hparams.seed_seq_len + self.agg_samples + shift)::self.agg_samples]
#                 y_true = torch.flatten(y_true.long())
#                 ohe_labels_part = F.one_hot(y_true, num_classes=pred.shape[2])
                
#                 if ohe_labels_part.shape[0] < pred.shape[0] * pred.shape[1]:
#                     padding = torch.zeros((pred.shape[0], 1, pred.shape[2]), device=ohe_labels_part.device)
#                     ohe_labels_part = torch.cat((ohe_labels_part.reshape(pred.shape[0], pred.shape[1] - 1, pred.shape[2]), padding), dim=1).reshape(pred.shape[0] * pred.shape[1], pred.shape[2])
                
#                 ohe_labels += ohe_labels_part

#             ohe_labels[ohe_labels > 1] = 1
            
#             pred = pred.reshape(-1, pred.size(-1))

#             loss += self.loss(pred, ohe_labels)
                
#         return loss

# %%
N_EPOCHS = 20

# %%
agg_encoder_params = dict(
    embeddings_noise=0.003,
    embeddings={
        "trans_date": {"in": 730, "out": 64},
        "small_group": {"in": 204, "out": 64},
        "amount_rur": {"in": BINS_NUM, "out": 64}
    },
    agg_samples=5, # 3, 5, 7
    use_window_attention=False
)

trx_encoder = ConvAggregator(**agg_encoder_params)

seq_encoder = GptEncoder(
    n_embd=trx_encoder.output_size,
    n_layer=6,
    n_head=6,
    n_inner=256,
    activation_function="gelu_new",
    resid_pdrop=0.1,
    embd_pdrop=0.1,
    attn_pdrop=0.1,
    n_positions=2048,
    use_positional_encoding=True,
    use_start_random_shift=True,
    is_reduce_sequence=False
)

gpt = ConvAgg_GPT_PretrainModule(
    trx_encoder=trx_encoder,
    seq_encoder=seq_encoder,
    head_hidden_size=256,
    total_steps=(N_EPOCHS * 1688), # num_epochs * num_steps_per_epoch
    seed_seq_len=16,
    max_lr=1e-3,
    weight_decay=0.,
    pct_start=0.1,
    norm_predict=False
)

# %% [markdown]
# **Обучение:**

# %%
logger = CometLogger(project_name="EvS_SSL", experiment_name="GPT_modeling_ConvAgg (5 trx)")

trainer = pl.Trainer(
    logger=logger,
    max_epochs=N_EPOCHS,
    accelerator="gpu",
    devices=1,
    enable_progress_bar=True
)

# %%
trainer.fit(gpt, data)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/askoro/evs-ssl/6a2fa98b88d0452ead57b955d067f4be
#
# COMET INFO: Couldn't find a Git repository in '/kaggle/working' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : GPT_modeling_ConvAgg (5 trx)
# COMET INFO:     url                   : https://www.comet.com/askoro/evs-ssl/6a2fa98b88d0452ead57b955d067f4be
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [4051]               : (7.1974592208862305, 16.79559326171875)
# COMET INFO:     val loss (by epochs) [20] : (7.706978797912598, 8.111540794372559)
# COMET INFO:   Others:
# COMET INFO:     Name : GPT_modeling_ConvAgg (5 trx)
# COMET INFO:   Parameters:
# COMET INFO:     head_hidden_size  : 256
# COMET INFO:     max_lr            : 0.001
# COMET INFO:     norm_predict      : False
# COMET INFO:     pct_start         : 0.1
# COMET INFO:     seed_seq_len      : 16
# COMET INFO:     test_batch_size   : None
# COMET INFO:     test_drop_last    : False
# COMET INFO:     test_num_workers  : None
# COMET INFO:     total_steps       : 33760
# COMET INFO:     train_batch_size  : 16
# COMET INFO:     train_drop_last   : False
# COMET INFO:     train_num_workers : 4
# COMET INFO:     valid_batch_size  : 16
# COMET INFO:     valid_drop_last   : False
# COMET INFO:     valid_num_workers : 4
# COMET INFO:     weight_decay      : 0.0
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:

# %%
trainer.logged_metrics
# Out:
# {'loss': tensor(7.4389), 'val loss (by epochs)': tensor(7.7070)}

# %%
encoder = gpt.seq_encoder

# %%
#torch.save(encoder.state_dict(), "gpt_WinAgg_trx10_multilabel.pt")

# %% [markdown]
# **Измерим качество на тесте (catboost поверх эмбеддингов):**

# %%
# import gdown

# gdown.download("https://drive.google.com/uc?export=download&id=1YBstN7hpEIREo7zORmPoEZ_0NyBgfjm6", "gpt_baseline_NAdam.pt")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1YBstN7hpEIREo7zORmPoEZ_0NyBgfjm6
# From (redirected): https://drive.google.com/uc?export=download&id=1YBstN7hpEIREo7zORmPoEZ_0NyBgfjm6&confirm=t&uuid=be4debcd-1d0b-4619-a15e-892431777c63
# To: /kaggle/working/gpt_baseline_NAdam.pt
# 100%|██████████| 34.7M/34.7M [00:00<00:00, 156MB/s]
# 'gpt_baseline_NAdam.pt'

# %%
# state_dict = torch.load("./gpt_baseline_NAdam.pt")
# encoder.load_state_dict(state_dict)

device = "cuda:0"

encoder.to(device)
# Out:
# GPTInferenceModule(
#   (model): ConvAgg_GPT_PretrainModule(
#     (trx_encoder): ConvAggregator(
#       (embeddings): ModuleDict(
#         (trans_date): NoisyEmbedding(
#           730, 64, padding_idx=0
#           (dropout): Dropout(p=0, inplace=False)
#         )
#         (small_group): NoisyEmbedding(
#           204, 64, padding_idx=0
#           (dropout): Dropout(p=0, inplace=False)
#         )
#         (amount_rur): NoisyEmbedding(
#           128, 64, padding_idx=0
#           (dropout): Dropout(p=0, inplace=False)
#         )
#       )
#       (custom_embeddings): ModuleDict()
#       (conv): Conv1d(192, 192, kernel_size=(5,), stride=(1,), padding=(4,), bias=False)
#     )
#     (_seq_encoder): GptEncoder(
#       (transf): GPT2Model(
#         (wte): Embedding(4, 192)
#         (wpe): Embedding(2048, 192)
#         (drop): Dropout(p=0.1, inplace=False)
#         (h): ModuleList(
#           (0-5): 6 x GPT2Block(
#             (ln_1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#             (attn): GPT2SdpaAttention(
#               (c_attn): Conv1D(nf=576, nx=192)
#               (c_proj): Conv1D(nf=192, nx=192)
#               (attn_dropout): Dropout(p=0.1, inplace=False)
#               (resid_dropout): Dropout(p=0.1, inplace=False)
#             )
#             (ln_2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#             (mlp): GPT2MLP(
#               (c_fc): Conv1D(nf=256, nx=192)
#               (c_proj): Conv1D(nf=192, nx=256)
#               (act): NewGELUActivation()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (ln_f): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (head): ModuleDict(
#       (trans_date): GPTHead(
#         (head): Sequential(
#           (0): Linear(in_features=192, out_features=256, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.1, inplace=False)
#           (3): Linear(in_features=256, out_features=730, bias=True)
#         )
#       )
#       (small_group): GPTHead(
#         (head): Sequential(
#           (0): Linear(in_features=192, out_features=256, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.1, inplace=False)
#           (3): Linear(in_features=256, out_features=204, bias=True)
#         )
#       )
#       (amount_rur): GPTHead(
#         (head): Sequential(
#           (0): Linear(in_features=192, out_features=256, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.1, inplace=False)
#           (3): Linear(in_features=256, out_features=128, bias=True)
#         )
#       )
#     )
#     (loss): CrossEntropyLoss()
#     (train_gpt_loss): MeanMetric()
#     (valid_gpt_loss): MeanMetric()
#   )
#   (mean_pooling): MeanPooling()
#   (stat_pooling): StatPooling()
# )

# %%
from tqdm import tqdm

seed_everything(17)

# %%
train_loader = inference_data_loader(data_train, num_workers=0, batch_size=8)
encoder.eval()
train_embeds = None

for i, batch in tqdm(enumerate(train_loader)):
    train_embeds_batch = encoder(batch.to(device), eval_strategy="mean")
    if i == 0:
        train_embeds = train_embeds_batch.detach().cpu().numpy()
    else:
        train_embeds = np.concatenate([train_embeds, train_embeds_batch.detach().cpu().numpy()], axis=0)
    
train_embeds
# Out:
# 3375it [01:50, 30.49it/s]
# array([[-0.33462667, -0.8954681 , -0.4302902 , ...,  0.31755188,
#         -0.4282316 ,  1.0043997 ],
#        [-0.62445164, -0.64348966,  0.17183866, ...,  0.47483826,
#         -0.06584188,  0.09253756],
#        [ 0.03645117, -0.00585962,  0.4776758 , ...,  0.4745791 ,
#          0.22592434,  0.12130009],
#        ...,
#        [-0.14497751, -0.92623764, -0.20247638, ..., -0.3186678 ,
#         -0.12830502,  0.71001214],
#        [-0.22208676,  0.13177368,  0.2472424 , ...,  0.06017498,
#         -0.2755309 ,  0.05550779],
#        [-0.81465566, -0.3648326 ,  0.8156164 , ..., -0.1697784 ,
#         -0.53425485,  0.56683344]], dtype=float32)

# %%
test_loader = inference_data_loader(data_test, num_workers=0, batch_size=1)
encoder.eval()
test_embeds = None

for i, batch in tqdm(enumerate(test_loader)):
    test_embeds_batch = encoder(batch.to(device), eval_strategy="mean")
    if i == 0:
        test_embeds = test_embeds_batch.detach().cpu().numpy()
    else:
        test_embeds = np.concatenate([test_embeds, test_embeds_batch.detach().cpu().numpy()], axis=0)
    
test_embeds
# Out:
# 3000it [00:19, 154.49it/s]
# array([[-0.44947675, -0.19581969,  0.40659872, ..., -0.04312054,
#         -0.03518488,  0.30500835],
#        [-0.67480373, -0.03185154,  0.14559251, ...,  0.16728781,
#         -0.35244393, -0.0491464 ],
#        [-0.33507663,  0.25592807,  0.40558302, ..., -0.05884036,
#         -0.02490208, -0.23148002],
#        ...,
#        [-0.21486415, -0.59190446, -0.16830519, ...,  0.19163302,
#         -0.27041575,  0.18258   ],
#        [ 0.05898442, -0.06531187,  0.39572296, ...,  0.27670342,
#          0.09850958,  0.25114918],
#        [-0.38886726, -0.30049315,  0.40989238, ..., -0.29424664,
#         -0.15515497, -0.21075957]], dtype=float32)

# %%
clf = CatBoostClassifier(loss_function='MultiClass', task_type="GPU", devices='0', random_state=17)

clf.fit(train_embeds, target_train, plot_file="catboost_log.html")
# Out:
# Learning rate set to 0.12714
# 0:	learn: 1.3193835	total: 10.2ms	remaining: 10.2s
# 1:	learn: 1.2685855	total: 17.5ms	remaining: 8.73s
# 2:	learn: 1.2270816	total: 24.6ms	remaining: 8.18s
# 3:	learn: 1.1948241	total: 31.9ms	remaining: 7.94s
# 4:	learn: 1.1667674	total: 38.5ms	remaining: 7.66s
# 5:	learn: 1.1408816	total: 45ms	remaining: 7.46s
# 6:	learn: 1.1177070	total: 51.7ms	remaining: 7.33s
# 7:	learn: 1.0991144	total: 58.2ms	remaining: 7.22s
# 8:	learn: 1.0831135	total: 65ms	remaining: 7.16s
# 991:	learn: 0.3764670	total: 6.73s	remaining: 54.3ms
# 992:	learn: 0.3762270	total: 6.74s	remaining: 47.5ms
# 993:	learn: 0.3760000	total: 6.74s	remaining: 40.7ms
# 994:	learn: 0.3756493	total: 6.75s	remaining: 33.9ms
# 995:	learn: 0.3752691	total: 6.76s	remaining: 27.1ms
# 996:	learn: 0.3748071	total: 6.76s	remaining: 20.4ms
# 997:	learn: 0.3744388	total: 6.77s	remaining: 13.6ms
# 998:	learn: 0.3741234	total: 6.78s	remaining: 6.79ms
# 999:	learn: 0.3738542	total: 6.79s	remaining: 0us

# %%
test_pred = clf.predict(test_embeds)
test_proba = clf.predict_proba(test_embeds)

# %%
print("Accuracy:", accuracy_score(target_test, test_pred))
print("ROC-AUC:", roc_auc_score(target_test, test_proba, average="weighted", multi_class="ovr"))
# Out:
# Accuracy: 0.6153333333333333
# ROC-AUC: 0.852413120169623

# %%
arr = np.array([0.8490318453772406, 0.852413120169623, 0.8524314150724707])

arr.mean(), arr.std()
# Out:
# (0.8512921268731115, 0.0015982778244722268)

# %% [markdown]
# - GPT embeds + Catboost:
#     - `Accuracy: 0.6066666666666667`, `0.6246666666666667`, `0.6123333333333333`, avg: `0.6146 +- 0.0075`
#     - `ROC-AUC: 0.8479316455892264`, `0.8544376474342738`, `0.8537725354907774`, avg: `0.852 +- 0.0029`
#
# ---
#
# - GPT embeds + ConvAgg (3 trx) + Catboost:
#   - `Accuracy: 0.613`, `0.6103333333333333`, `0.615`, avg: `0.6128 +- 0.0019`
#   - `ROC-AUC: 0.8506448682792362`, `0.8542724256159796`, `0.8518455633248265`, avg: `0.8523 +- 0.0015`
#
# ---
#
# - GPT embeds + ConvAgg (5 trx) + Catboost:
#   - `Accuracy: 0.5976666666666667`, `0.6153333333333333`, `0.61`, avg: `0.6077 +- 0.0074`
#   - `ROC-AUC: 0.8490318453772406`, `0.852413120169623`, `0.8524314150724707`, avg: `0.8513 +- 0.0016`
#
# ---
#
# **Вывод:** При свёрточной агрегации метрики качества становятся хуже, чем у бейзлайна. С увеличением размера ядра свёртки качество становится лишь хуже.
#
# **Лучший результат - из всех рассмотренных конфигураций:**
#
# - GPT embeds + ConvAgg (3 trx) + Catboost:
#   - `Accuracy: 0.613`, `0.6103333333333333`, `0.615`, avg: `0.6128 +- 0.0019`
#   - `ROC-AUC: 0.8506448682792362`, `0.8542724256159796`, `0.8518455633248265`, avg: `0.8523 +- 0.0015`

# %% [markdown]
# # Итоги.

# %% [markdown]
# | Method|Accuracy|ROC-AUC|
# | --- |:---:|:---:|
# | **Flattened Sequences**                   | 0.4921 ± 0.005        | 0.76 ± 0.0012   |
# | **GRU (+ MLP)**                           | 0.6066 ± 0.0019       | 0.8479 ± 0.0013 |
# | **CoLES**                                 | 0.6042 ± 0.0083       | 0.8482 ± 0.0007 |
# | **COLES embeds + ConvAgg (3 trx)**        | 0.6027 ± 0.0023       | 0.8461 ± 0.0013 |
# | **CPC Modeling**                          | 0.5762 ± 0.0058       | 0.8305 ± 0.003  |
# | **CPC Modeling + ConvAgg (5 trx)**        | 0.585 ± 0.0043        | 0.8317 ± 0.0018 |
# | **GPT2**                                  | 0.6146 ± 0.0075       | 0.852 ± 0.0029  |
# | **GPT2 + ConvAgg ()**                     | 0.6128 ± 0.0019       | 0.8523 ± 0.0015 |
