# %% [markdown]
# # Импортируем необходимые библиотеки

# %%
# !pip install pytorch-lifestream
# !pip install comet_ml
# Out:
# Collecting pytorch-lifestream
#   Downloading pytorch-lifestream-0.6.0.tar.gz (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.4/163.4 kB 6.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: duckdb in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (1.1.3)
# Collecting hydra-core>=1.1.2 (from pytorch-lifestream)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: numpy>=1.21.5 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (1.26.4)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (2.3.0)
# Requirement already satisfied: pandas>=1.3.5 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (2.2.3)
# Requirement already satisfied: pyarrow>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (19.0.1)
# Requirement already satisfied: pytorch-lightning>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (2.5.0.post0)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (1.2.2)
# Requirement already satisfied: torch>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (2.5.1+cu121)
# Requirement already satisfied: torchmetrics>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (1.6.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from pytorch-lifestream) (4.47.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from hydra-core>=1.1.2->pytorch-lifestream) (4.9.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from hydra-core>=1.1.2->pytorch-lifestream) (24.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.5->pytorch-lifestream) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.5->pytorch-lifestream) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.5->pytorch-lifestream) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.5->pytorch-lifestream) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.5->pytorch-lifestream) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.5->pytorch-lifestream) (2.4.1)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.10/dist-packages (from omegaconf->pytorch-lifestream) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->pytorch-lifestream) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->pytorch-lifestream) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->pytorch-lifestream) (2025.1)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.6.0->pytorch-lifestream) (4.67.1)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (2024.12.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.6.0->pytorch-lifestream) (4.12.2)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.6.0->pytorch-lifestream) (0.12.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->pytorch-lifestream) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->pytorch-lifestream) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->pytorch-lifestream) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch-lifestream) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch-lifestream) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch-lifestream) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch-lifestream) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.12.0->pytorch-lifestream) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers->pytorch-lifestream) (0.29.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->pytorch-lifestream) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->pytorch-lifestream) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers->pytorch-lifestream) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->pytorch-lifestream) (0.4.5)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (3.11.12)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.10.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (75.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.5->pytorch-lifestream) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.12.0->pytorch-lifestream) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.21.5->pytorch-lifestream) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.21.5->pytorch-lifestream) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.5->pytorch-lifestream) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.21.5->pytorch-lifestream) (2024.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->pytorch-lifestream) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->pytorch-lifestream) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->pytorch-lifestream) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->pytorch-lifestream) (2025.1.31)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.6.0->pytorch-lifestream) (1.18.3)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.21.5->pytorch-lifestream) (2024.2.0)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 9.6 MB/s eta 0:00:00
# Building wheels for collected packages: pytorch-lifestream
#   Building wheel for pytorch-lifestream (pyproject.toml) ... done
#   Created wheel for pytorch-lifestream: filename=pytorch_lifestream-0.6.0-py3-none-any.whl size=274639 sha256=1211f32cbe41dcd8ca89176b9020cd993a314bb5e399958166eef797396063ca
#   Stored in directory: /root/.cache/pip/wheels/90/76/b4/0a944bc7c5a69201e4d757cc54886971117a2a581740e7f11d
# Successfully built pytorch-lifestream
# Installing collected packages: hydra-core, pytorch-lifestream
# Successfully installed hydra-core-1.3.2 pytorch-lifestream-0.6.0
# Collecting comet_ml
#   Downloading comet_ml-3.49.5-py3-none-any.whl.metadata (4.1 kB)
# Collecting dulwich!=0.20.33,>=0.20.6 (from comet_ml)
#   Downloading dulwich-0.22.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting everett<3.2.0,>=1.0.1 (from everett[ini]<3.2.0,>=1.0.1->comet_ml)
#   Downloading everett-3.1.0-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (4.23.0)
# Requirement already satisfied: psutil>=5.6.3 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (5.9.5)
# Collecting python-box<7.0.0 (from comet_ml)
#   Downloading python_box-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.8 kB)
# Requirement already satisfied: requests-toolbelt>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (1.0.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (2.32.3)
# Requirement already satisfied: rich>=13.3.2 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (13.9.4)
# Collecting semantic-version>=2.8.0 (from comet_ml)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: sentry-sdk>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (2.19.2)
# Collecting simplejson (from comet_ml)
#   Downloading simplejson-3.20.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (2.3.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (1.17.0)
# Requirement already satisfied: wurlitzer>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (3.1.1)
# Collecting configobj (from everett[ini]<3.2.0,>=1.0.1->comet_ml)
#   Downloading configobj-5.0.9-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (0.22.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet_ml) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet_ml) (2.19.1)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet_ml) (4.12.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=13.3.2->comet_ml) (0.1.2)
# Downloading comet_ml-3.49.5-py3-none-any.whl (725 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 725.8/725.8 kB 15.5 MB/s eta 0:00:0000:01
# Downloading dulwich-0.22.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 42.3 MB/s eta 0:00:00
# Downloading everett-3.1.0-py2.py3-none-any.whl (35 kB)
# Downloading python_box-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 84.4 MB/s eta 0:00:00:00:01
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading simplejson-3.20.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 9.6 MB/s eta 0:00:00
# Downloading configobj-5.0.9-py2.py3-none-any.whl (35 kB)
# Installing collected packages: everett, simplejson, semantic-version, python-box, dulwich, configobj, comet_ml
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.3.0
#     Uninstalling python-box-7.3.0:
#       Successfully uninstalled python-box-7.3.0
# Successfully installed comet_ml-3.49.5 configobj-5.0.9 dulwich-0.22.8 everett-3.1.0 python-box-6.1.0 semantic-version-2.10.0 simplejson-3.20.1

# %%
# data preprocessing
import os
import numpy as np
import pandas as pd
import pickle

# misc
from tqdm import tqdm
from functools import partial

# logging
import comet_ml

# classical ML
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score
from catboost import CatBoostClassifier

# basic deep learning libs
import torch
import pytorch_lightning as pl
import torchmetrics

# ptls
from ptls.nn import TrxEncoder, RnnSeqEncoder, TransformerEncoder, GptEncoder, Head
from ptls.frames import PtlsDataModule
from ptls.frames.coles import CoLESModule
from ptls.frames.coles import ColesDataset
from ptls.frames.coles.split_strategy import SampleSlices
from ptls.frames.cpc import CpcModule
from ptls.frames.cpc import CpcDataset
from ptls.frames.gpt import GptDataset
from ptls.frames.supervised import SeqToTargetDataset, SequenceToTarget
from ptls.data_load.datasets import MemoryMapDataset
from ptls.data_load.datasets import inference_data_loader
from ptls.frames.inference_module import InferenceModule
from ptls.data_load.iterable_processing import SeqLenFilter
from ptls.preprocessing import PandasDataPreprocessor
from ptls.data_load.utils import collate_feature_dict
from ptls.frames.inference_module import InferenceModule

# %%
def seed_everything(seed):
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
comet_ml.login()

# %%
from pytorch_lightning.loggers import CometLogger

# %% [markdown]
# ---

# %% [markdown]
# **Time2Vec:**

# %%
import torch
from ptls.data_load.padded_batch import PaddedBatch
from ptls.nn.trx_encoder.batch_norm import RBatchNorm, RBatchNormWithLens
from ptls.nn.trx_encoder.noisy_embedding import NoisyEmbedding
from ptls.nn.trx_encoder.trx_encoder_base import TrxEncoderBase
import torch.nn as nn


class Time2Vec(nn.Module):
    def __init__(self, k, interval=86400):
        super(Time2Vec, self).__init__()
        self.k = k
        self.w = nn.Parameter(torch.randn(k))
        self.b = nn.Parameter(torch.randn(k))
        self.w0 = nn.Parameter(torch.randn(1))
        self.b0 = nn.Parameter(torch.randn(1))
        self.interval = interval
        
    def forward(self, event_time, t0):
        t0_ = torch.zeros_like(event_time)
        time_diff=None
        if type(t0)!=int:
            first_column = t0[:, 0].unsqueeze(1)
            t0_ = first_column.expand(-1, t0.size(1))
        time_diff = (event_time - t0_)/self.interval
        v1 = self.w0 * time_diff.unsqueeze(-1) + self.b0
        v2 = torch.cos(self.w * time_diff.unsqueeze(-1) + self.b)
        
        return torch.cat([v1, v2], -1)

        
class TrxEncoderT2V(TrxEncoderBase):
    def __init__(self,
                 embeddings=None,
                 numeric_values=None,
                 custom_embeddings=None,
                 time_values=None,
                 embeddings_noise: float = 0,
                 norm_embeddings=None,
                 use_batch_norm=True,
                 use_batch_norm_with_lens=False,
                 clip_replace_value=None,
                 positions=None,
                 emb_dropout=0,
                 spatial_dropout=False,
                 orthogonal_init=False,
                 linear_projection_size=0,
                 out_of_index: str = 'clip',
                 k=2,
                 time_col='event_time'
                 ):
        if clip_replace_value is not None:
            warnings.warn('`clip_replace_value` attribute is deprecated. Always "clip to max" used. '
                          'Use `out_of_index="assert"` to avoid categorical values clip', DeprecationWarning)

        if positions is not None:
            warnings.warn('`positions` is deprecated. positions is not used', UserWarning)

        if embeddings is None:
            embeddings = {}
        if custom_embeddings is None:
            custom_embeddings = {}
        if time_values is None:
            time_values = {}

        noisy_embeddings = {}
        for emb_name, emb_props in embeddings.items():
            if emb_props.get('disabled', False):
                continue
            if emb_props['in'] == 0 or emb_props['out'] == 0:
                continue
            noisy_embeddings[emb_name] = NoisyEmbedding(
                num_embeddings=emb_props['in'],
                embedding_dim=emb_props['out'],
                padding_idx=0,
                max_norm=1 if norm_embeddings else None,
                noise_scale=embeddings_noise,
                dropout=emb_dropout,
                spatial_dropout=spatial_dropout,
            )

        super().__init__(
            embeddings=noisy_embeddings,
            numeric_values=numeric_values,
            custom_embeddings=custom_embeddings,
            out_of_index=out_of_index,
        )

        custom_embedding_size = self.custom_embedding_size
        if use_batch_norm and custom_embedding_size > 0:
            # :TODO: Should we use Batch norm with not-numerical custom embeddings?
            if use_batch_norm_with_lens:
                self.custom_embedding_batch_norm = RBatchNormWithLens(custom_embedding_size)
            else:
                self.custom_embedding_batch_norm = RBatchNorm(custom_embedding_size)
        else:
            self.custom_embedding_batch_norm = None
        
        self.k = k
        self.time2vec_days = Time2Vec(k=self.k)
        self.time_col = time_col
        
        if linear_projection_size > 0:
            self.linear_projection_head = torch.nn.Linear(super().output_size+k+1, linear_projection_size)
        else:
            self.linear_projection_head = None
            

        if orthogonal_init:
            for n, p in self.named_parameters():
                if n.startswith('embeddings.') and n.endswith('.weight'):
                    torch.nn.init.orthogonal_(p.data[1:])
                if n == 'linear_projection_head.weight':
                    torch.nn.init.orthogonal_(p.data)

    def forward(self, x: PaddedBatch):
        processed_embeddings = []
        processed_custom_embeddings = []

        for field_name in self.embeddings.keys():
            processed_embeddings.append(self.get_category_embeddings(x, field_name))
        
        for field_name in self.custom_embeddings.keys():
            processed_custom_embeddings.append(self.get_custom_embeddings(x, field_name))

        if len(processed_custom_embeddings):
            processed_custom_embeddings = torch.cat(processed_custom_embeddings, dim=2)
            if self.custom_embedding_batch_norm is not None:
                processed_custom_embeddings = PaddedBatch(processed_custom_embeddings, x.seq_lens)
                processed_custom_embeddings = self.custom_embedding_batch_norm(processed_custom_embeddings)
                processed_custom_embeddings = processed_custom_embeddings.payload
            processed_embeddings.append(processed_custom_embeddings)

        out = torch.cat(processed_embeddings, dim=2)

        time_encoded_days = self.time2vec_days(x.payload[self.time_col], x.payload[self.time_col])
        out = torch.cat((out, time_encoded_days), dim=2)

        if self.linear_projection_head is not None:
            out = self.linear_projection_head(out)
        return PaddedBatch(out, x.seq_lens)

    @property
    def output_size(self):
        """Returns hidden size of output representation
        """
        if self.linear_projection_head is not None:
            return self.linear_projection_head.out_features
        return super().output_size + self.k + 1

# %% [markdown]
# # Эксперименты.

# %% [markdown]
# **Данные:**

# %%
path_data = "https://huggingface.co/datasets/dllllb/rosbank-churn/resolve/main/train.csv.gz?download=true"
data = pd.read_csv(path_data, compression="gzip")
data
# Out:
#             PERIOD  cl_id   MCC channel_type  currency        TRDATETIME  \
# 0       01/10/2017      0  5200          NaN       810  21OCT17:00:00:00
# 1       01/10/2017      0  6011          NaN       810  12OCT17:12:24:07
# 2       01/12/2017      0  5921          NaN       810  05DEC17:00:00:00
# 3       01/10/2017      0  5411          NaN       810  21OCT17:00:00:00
# 4       01/10/2017      0  6012          NaN       810  24OCT17:13:14:24
# ...            ...    ...   ...          ...       ...               ...
# 490508  01/04/2017  10176  6011        type1       810  24APR17:14:05:26
# 490509  01/06/2017  10171  5411        type1       810  06JUN17:00:00:00
# 490510  01/02/2017  10167  5541        type1       810  03FEB17:00:00:00
# 490511  01/06/2017  10163  5941        type1       810  08JUN17:00:00:00
# 490512  01/06/2017  10162  5411        type1       810  15JUN17:00:00:00
#
#           amount trx_category  target_flag  target_sum
# 0        5023.00          POS            0         0.0
# 1       20000.00      DEPOSIT            0         0.0
# 2         767.00          POS            0         0.0
# 3        2031.00          POS            0         0.0
# 4       36562.00      C2C_OUT            0         0.0
# ...          ...          ...          ...         ...
# 490508    600.00   WD_ATM_ROS            1       405.0
# 490509    132.00          POS            0         0.0
# 490510   1000.00          POS            1    280428.2
# 490511    100.00          POS            0         0.0
# 490512    441.33          POS            1       253.0
#
# [490513 rows x 10 columns]

# %%
target = data.groupby(by="cl_id").first().reset_index()[["cl_id", "target_flag"]]
target
# Out:
#       cl_id  target_flag
# 0         0            0
# 1         1            0
# 2         5            1
# 3         9            0
# 4        10            0
# ...     ...          ...
# 4995  10210            1
# 4996  10212            0
# 4997  10213            0
# 4998  10214            0
# 4999  10215            0
#
# [5000 rows x 2 columns]

# %%
data.drop(columns=["PERIOD", "target_flag", "target_sum"], inplace=True)

# %%
target_train, target_test = train_test_split(target, test_size=0.1, stratify=target["target_flag"], random_state=42)

# %%
trx_data_train = pd.merge(data, target_train["cl_id"], on="cl_id", how="inner")
trx_data_test = pd.merge(data, target_test["cl_id"], on="cl_id", how="inner")

# %%
trx_data_train["channel_type"] = trx_data_train["channel_type"].fillna("none")
trx_data_test["channel_type"] = trx_data_test["channel_type"].fillna("none")

# %%
month2num = {"JAN": "/01/", "FEB": "/02/", "MAR": "/03/", "APR": "/04/", "MAY": "/05/", "JUN": "/06/",
             "JUL": "/07/", "AUG": "/08/", "SEP": "/09/", "OCT": "/10/", "NOV": "/11/", "DEC": "/12/"}

trx_data_train["TRDATETIME"] = trx_data_train["TRDATETIME"].map(lambda x: x[0:2] + month2num[x[2:5]] + x[5:7] + " " + x[8:])
trx_data_test["TRDATETIME"] = trx_data_test["TRDATETIME"].map(lambda x: x[0:2] + month2num[x[2:5]] + x[5:7] + " " + x[8:])

trx_data_train["TRDATETIME"] = pd.to_datetime(trx_data_train["TRDATETIME"],format='%d/%m/%y %H:%M:%S')
trx_data_test["TRDATETIME"] = pd.to_datetime(trx_data_test["TRDATETIME"],format='%d/%m/%y %H:%M:%S')

# %%
chtype2num = {"none": 0, "type1": 1, "type2": 2, "type3": 3, "type4": 4, "type5": 5}

trx_data_train["channel_type"] = trx_data_train["channel_type"].map(lambda x: chtype2num[x])
trx_data_test["channel_type"] = trx_data_test["channel_type"].map(lambda x: chtype2num[x])

# %%
trxcat2num = {"POS": 0, "DEPOSIT": 1, "WD_ATM_ROS": 2, "WD_ATM_PARTNER": 3, 
              "C2C_IN": 4, "WD_ATM_OTHER": 5, "C2C_OUT": 6, "BACK_TRX": 7,
              "CAT": 8, "CASH_ADV": 9}

trx_data_train["trx_category"] = trx_data_train["trx_category"].map(lambda x: trxcat2num[x])
trx_data_test["trx_category"] = trx_data_test["trx_category"].map(lambda x: trxcat2num[x])

# %% [markdown]
# ---

# %% [markdown]
# **Квантизация непрерывных признаков (опциональный шаг, нужен только для GPT):**

# %%
def digitize(input_array: np.array, q_count: int = 1, bins: np.array = None):
    """Quantile-based discretization function.

    Parameters:
    -------
    input_array (np.array): Input array.
    q_count (int): Amount of quantiles. Used only if input parameter `bins` is None.
    bins (np.array):
        If None, then calculate bins as quantiles of input array,
        otherwise only apply bins to input_array. Default: None

    Returns
    -------
    out_array (np.array of ints): discretized input_array
    bins (np.array of floats):
        Returned only if input parameter `bins` is None.
    """

    if bins is None:
        return_bins = True
        bins = np.quantile(input_array, q=[i / q_count for i in range(1, q_count)], axis=0)
    else:
        return_bins = False

    out_array = np.digitize(input_array, bins)

    if return_bins:
        return out_array, bins
    else:
        return out_array

# %%
BINS_NUM = 128

# %%
numeric_features = ["amount"]

for feat in numeric_features:
    trx_data_train[feat], bins = digitize(trx_data_train[feat], q_count=BINS_NUM)
    trx_data_test[feat] = digitize(trx_data_test[feat], bins=bins)

# %%
import gc

gc.collect()
# Out:
# 147

# %% [markdown]
# ---

# %%
preprocessor = PandasDataPreprocessor(
    col_id="cl_id",
    col_event_time="TRDATETIME",
    event_time_transformation="dt_to_timestamp",
    cols_category=["MCC", "channel_type", "currency", "trx_category"],
    cols_numerical=["amount"],
    return_records=False,
)

# %%
data_train = preprocessor.fit_transform(trx_data_train)
data_test = preprocessor.transform(trx_data_test)

# %%
target_train.rename(columns={"target_flag": "target"}, inplace=True)
target_test.rename(columns={"target_flag": "target"}, inplace=True)
target_train.sort_values(by="cl_id", inplace=True)
target_test.sort_values(by="cl_id", inplace=True)
target_train = target_train["target"]
target_test = target_test["target"]
target_train.reset_index(drop=True, inplace=True)
target_test.reset_index(drop=True, inplace=True)

# %%
data_train = data_train.to_dict(orient="records")
data_test = data_test.to_dict(orient="records")

# %% [markdown]
# ---

# %% [markdown]
# **Window Aggregator Class:**

# %%
from ptls.data_load.padded_batch import PaddedBatch


class WinAggregator(TrxEncoderT2V):
    """The NN layer, a combination of TrxEncoder and Mean Aggregation within a window of #`agg_samples` transactions 
       (works like nn.Sequential([TrxEncoder, Mean Window Aggregation])).
       It is assumed that any two different windows do not overlap here.
       
       The types of the input and output are `PaddedBatch` of shapes (B, L, T) and (B, L', T) respectively, where 
       B means batch_size,
       L/L' means the max length of a sequence of transactions in a batch (the length is the same as #trx)
       T means the dimension of a single transaction.

       Parameters
        agg_samples (int):
            The number of transactions in a sliding aggregation window.

        use_window_attention (bool):
            If True, the attention layer will be applied to transactions in a sliding window before pooling.

        k (int):
            Number of periodic components in T2V time embeddings

        time_col (str):
            Name of the time column in data
            
        embeddings:
            You can find info about this param in TrxEncoder desc.
        
        numeric_values:
            You can find info about this param in TrxEncoder desc.

        embeddings_noise:
            You can find info about this param in TrxEncoder desc.
            
        emb_dropout:
            You can find info about this param in TrxEncoder desc.
            
        spatial_dropout:
            You can find info about this param in TrxEncoder desc.

        use_batch_norm:
            You can find info about this param in TrxEncoder desc.

        orthogonal_init:
            You can find info about this param in TrxEncoder desc.
            
        linear_projection_size:
            You can find info about this param in TrxEncoder desc.

        out_of_index:
            You can find info about this param in TrxEncoder desc.

        norm_embeddings:
            Keep default value for this parameter
        
        clip_replace_value:
            Not used. Keep default value for this parameter
        
        positions: 
            Not used. Keep default value for this parameter
       """

    def __init__(self,
                 agg_samples=3,
                 use_window_attention=False,
                 embeddings=None,
                 numeric_values=None,
                 custom_embeddings=None,
                 time_values=None,
                 embeddings_noise: float = 0,
                 norm_embeddings=None,
                 use_batch_norm=False,
                 use_batch_norm_with_lens=False,
                 clip_replace_value=None,
                 positions=None,
                 emb_dropout=0,
                 spatial_dropout=False,
                 orthogonal_init=False,
                 linear_projection_size=0,
                 out_of_index: str = 'clip',
                 k=2,
                 time_col='event_time'
                ):

        
        super().__init__(
            embeddings=embeddings,
            numeric_values=numeric_values,
            custom_embeddings=custom_embeddings,
            embeddings_noise=embeddings_noise,
            norm_embeddings=norm_embeddings,
            use_batch_norm=use_batch_norm,
            use_batch_norm_with_lens=use_batch_norm_with_lens,
            clip_replace_value=clip_replace_value,
            positions=positions,
            emb_dropout=emb_dropout,
            spatial_dropout=spatial_dropout,
            orthogonal_init=orthogonal_init,
            linear_projection_size=linear_projection_size,
            out_of_index=out_of_index,
            k=k,
            time_col=time_col
        )

        self.agg_samples = agg_samples

        self.use_window_attention = use_window_attention
        if self.use_window_attention:
            pass # Not Implemented

    def forward(self, pb: PaddedBatch):
        embeds = super().forward(pb)

        mask = torch.arange(embeds.payload.shape[1], device=embeds.device)[None, :] + torch.ones((embeds.seq_lens.shape[0], embeds.payload.shape[1]), device=embeds.device)
        mask[mask > embeds.seq_lens[:, None]] = 0.
        mask[mask > 0.] = 1.
        mask = mask[:, :, None]
    
        masked_embeds = embeds.payload * mask
    
        num_samples_to_add = self.agg_samples - (masked_embeds.shape[1] % self.agg_samples)  
        if num_samples_to_add > 0:
            additional_samples = torch.zeros((masked_embeds.shape[0], num_samples_to_add, masked_embeds.shape[2]), device=masked_embeds.device)
            masked_embeds = torch.cat((masked_embeds, additional_samples), dim=1)
            mask_additional_samples = torch.zeros((mask.shape[0], num_samples_to_add, mask.shape[2]), device=mask.device)
            mask = torch.cat((mask, mask_additional_samples), dim=1)
    
        masked_embeds = torch.reshape(masked_embeds, (masked_embeds.shape[0], masked_embeds.shape[1] // self.agg_samples, self.agg_samples, masked_embeds.shape[2]))
        mask = torch.reshape(mask, (mask.shape[0], mask.shape[1] // self.agg_samples, self.agg_samples, mask.shape[2]))

        if self.use_window_attention:
            pass # Not Implemented
        
        mask = torch.sum(mask, dim=2)
        mask[mask == 0.] = 1.
    
        mean_embeds = torch.sum(masked_embeds, dim=2) / mask

        new_seq_lens = embeds.seq_lens // self.agg_samples
        div_mod_seq_lens = ((embeds.seq_lens % self.agg_samples) > 0).int()
        new_seq_lens += div_mod_seq_lens

        return PaddedBatch(mean_embeds, new_seq_lens)

# %% [markdown]
# ---

# %% [markdown]
# # Sliding Window Aggregation (Mean Pooling)

# %% [markdown]
# - **COLES:**

# %%
seed_everything(30)

# %% [markdown]
# **DataLoaders:**

# %%
data = PtlsDataModule(
    train_data=ColesDataset(
        MemoryMapDataset(
            data=data_train,
            i_filters=[SeqLenFilter(min_seq_len=10)],
        ),
        splitter=SampleSlices(
            split_count=5,
            cnt_min=15,
            cnt_max=150,
        ),
    ),
    train_num_workers=4,
    train_batch_size=128,
    valid_data=ColesDataset(
        MemoryMapDataset(
            data=data_test,
            i_filters=[SeqLenFilter(min_seq_len=10)],
        ),
        splitter=SampleSlices(
            split_count=5,
            cnt_min=15,
            cnt_max=150,
        ),
    ),
    valid_num_workers=4,
    valid_batch_size=128
)

# %% [markdown]
# **Модель:**

# %%
N_EPOCHS = 20

# %%
agg_encoder_params = dict(
    embeddings={
        "MCC": {"in": 342, "out": 8},
        "channel_type": {"in": 7, "out": 8},
        "currency": {"in": 60, "out": 8},
        "trx_category": {"in": 11, "out": 8}            
    },
    numeric_values={"amount": "log"},
    embeddings_noise=0.003,
    k=7,
    time_col="event_time",
    agg_samples=10, # 3, 5, 10
    use_window_attention=False
)

trx_encoder = WinAggregator(**agg_encoder_params)

seq_encoder = RnnSeqEncoder(
    trx_encoder=trx_encoder,
    hidden_size=512,
    type="gru"
)

coles = CoLESModule(
    seq_encoder=seq_encoder,
    optimizer_partial=partial(torch.optim.Adam, lr=1e-3, weight_decay=0),
    lr_scheduler_partial=partial(torch.optim.lr_scheduler.CosineAnnealingLR, T_max=N_EPOCHS, eta_min=5e-6)
)

# %% [markdown]
# **Обучение:**

# %%
logger = CometLogger(project_name="evs-ssl-rb", experiment_name="CoLES_WinAgg (10 trx)")

trainer = pl.Trainer(
    logger=logger,
    max_epochs=N_EPOCHS,
    accelerator="gpu",
    devices=1,
    enable_progress_bar=True
)

# %%
trainer.fit(coles, data)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/askoro/evs-ssl-rb/c3ebf667bfd14c72a9245f7772d3df8e
#
# COMET INFO: Couldn't find a Git repository in '/kaggle/working' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loops/fit_loop.py:310: PossibleUserWarning:
#
# The number of training batches (33) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : CoLES_WinAgg (10 trx)
# COMET INFO:     url                   : https://www.comet.com/askoro/evs-ssl-rb/c3ebf667bfd14c72a9245f7772d3df8e
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [79]               : (56.88361358642578, 728.8323974609375)
# COMET INFO:     seq_len [13]            : (48.70624923706055, 56.78750228881836)
# COMET INFO:     valid/recall_top_k [20] : (0.4856342673301697, 0.8206671476364136)
# COMET INFO:   Others:
# COMET INFO:     Name : CoLES_WinAgg (10 trx)
# COMET INFO:   Parameters:
# COMET INFO:     test_batch_size   : None
# COMET INFO:     test_drop_last    : False
# COMET INFO:     test_num_workers  : None
# COMET INFO:     train_batch_size  : 128
# COMET INFO:     train_drop_last   : False
# COMET INFO:     train_num_workers : 4
# COMET INFO:     valid_batch_size  : 128
# COMET INFO:     valid_drop_last   : False
# COMET INFO:     valid_num_workers : 4
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:

# %%
trainer.logged_metrics
# Out:
# {'loss': tensor(59.2878),
#  'seq_len': tensor(55.1967),
#  'valid/recall_top_k': tensor(0.8122)}

# %%
torch.save(seq_encoder.state_dict(), "coles_enc_baseline_rosbank.pt")

# %% [markdown]
# **Измерим качество на тесте (catboost поверх эмбеддингов):**

# %%
# !wget "https://drive.google.com/uc?export=download&id=1Mn8o9IPT4Zzg3946orbw1MVZwpkrBoNb" -O "coles_enc_baseline.pt"

# %%
encoder = coles.seq_encoder

# state_dict = torch.load("./coles_enc_baseline.pt")
# encoder.load_state_dict(state_dict)

device = "cuda:0"

encoder.to(device)
# Out:
# RnnSeqEncoder(
#   (trx_encoder): WinAggregator(
#     (embeddings): ModuleDict(
#       (MCC): NoisyEmbedding(
#         342, 8, padding_idx=0
#         (dropout): Dropout(p=0, inplace=False)
#       )
#       (channel_type): NoisyEmbedding(
#         7, 8, padding_idx=0
#         (dropout): Dropout(p=0, inplace=False)
#       )
#       (currency): NoisyEmbedding(
#         60, 8, padding_idx=0
#         (dropout): Dropout(p=0, inplace=False)
#       )
#       (trx_category): NoisyEmbedding(
#         11, 8, padding_idx=0
#         (dropout): Dropout(p=0, inplace=False)
#       )
#     )
#     (custom_embeddings): ModuleDict(
#       (amount): LogScaler()
#     )
#     (time2vec_days): Time2Vec()
#   )
#   (seq_encoder): RnnEncoder(
#     (rnn): GRU(41, 512, batch_first=True)
#     (reducer): LastStepEncoder()
#   )
# )

# %%
from tqdm import tqdm

seed_everything(30)

# %%
train_loader = inference_data_loader(data_train, num_workers=0, batch_size=128)
encoder.eval()
train_embeds = None

for i, batch in tqdm(enumerate(train_loader)):
    train_embeds_batch = encoder(batch.to(device))
    if i == 0:
        train_embeds = train_embeds_batch.detach().cpu().numpy()
    else:
        train_embeds = np.concatenate([train_embeds, train_embeds_batch.detach().cpu().numpy()], axis=0)
    
train_embeds
# Out:
# 36it [00:00, 59.31it/s]
# array([[-0.60833985, -0.511413  , -0.09896265, ...,  0.1076753 ,
#         -0.01422375, -0.28425995],
#        [-0.9892348 , -0.56318617,  0.9520664 , ...,  0.9001066 ,
#          0.12255293,  0.33234027],
#        [-0.84397465, -0.40318084,  0.5685012 , ...,  0.8353386 ,
#          0.04327878,  0.6504765 ],
#        ...,
#        [-0.88698775, -0.22863524,  0.8202358 , ...,  0.12695561,
#          0.01108486, -0.2747371 ],
#        [-0.92584634,  0.4159664 , -0.33733493, ..., -0.76366967,
#          0.03447534, -0.6255679 ],
#        [-0.57684284,  0.01687094, -0.26798904, ...,  0.11736609,
#          0.01469811, -0.43869486]], dtype=float32)

# %%
test_loader = inference_data_loader(data_test, num_workers=0, batch_size=128)
encoder.eval()
test_embeds = None

for i, batch in tqdm(enumerate(test_loader)):
    test_embeds_batch = encoder(batch.to(device))
    if i == 0:
        test_embeds = test_embeds_batch.detach().cpu().numpy()
    else:
        test_embeds = np.concatenate([test_embeds, test_embeds_batch.detach().cpu().numpy()], axis=0)
    
test_embeds
# Out:
# 4it [00:00, 58.76it/s]
# array([[-0.960636  , -0.23163263,  0.9502865 , ...,  0.91831595,
#          0.0973716 ,  0.34862608],
#        [-0.74289703, -0.552289  ,  0.6497263 , ...,  0.36723498,
#         -0.03615671,  0.7167583 ],
#        [-0.9683374 , -0.57284385,  0.98294455, ...,  0.89663374,
#          0.082857  ,  0.21520062],
#        ...,
#        [-0.6565343 ,  0.09395197, -0.7778541 , ...,  0.14457308,
#         -0.03706352, -0.54188603],
#        [-0.85760665,  0.02938094, -0.46376103, ..., -0.17878065,
#         -0.0320862 , -0.47163618],
#        [-0.99402833,  0.10789418, -0.38567895, ..., -0.6211662 ,
#          0.10599243, -0.3955111 ]], dtype=float32)

# %%
clf = CatBoostClassifier(loss_function='MultiClass', task_type="GPU", devices='0', random_state=30)

clf.fit(train_embeds, target_train, plot_file="catboost_log.html")
# Out:
# Learning rate set to 0.088214
# 0:	learn: 0.6696746	total: 9.13ms	remaining: 9.12s
# 1:	learn: 0.6490142	total: 15.4ms	remaining: 7.67s
# 2:	learn: 0.6323775	total: 21.7ms	remaining: 7.21s
# 3:	learn: 0.6176477	total: 28.2ms	remaining: 7.01s
# 4:	learn: 0.6037361	total: 34.9ms	remaining: 6.93s
# 5:	learn: 0.5919549	total: 41.7ms	remaining: 6.9s
# 6:	learn: 0.5811617	total: 48.6ms	remaining: 6.89s
# 7:	learn: 0.5718378	total: 55.3ms	remaining: 6.85s
# 8:	learn: 0.5627696	total: 61.2ms	remaining: 6.74s
# 9:	learn: 0.5550774	total: 67.3ms	remaining: 6.66s
# 10:	learn: 0.5481952	total: 73.8ms	remaining: 6.64s
# 11:	learn: 0.5420741	total: 80ms	remaining: 6.58s
# 12:	learn: 0.5358254	total: 86.2ms	remaining: 6.54s
# 13:	learn: 0.5303205	total: 92.4ms	remaining: 6.51s
# 14:	learn: 0.5252356	total: 98.6ms	remaining: 6.47s
# 15:	learn: 0.5212352	total: 105ms	remaining: 6.43s
# 16:	learn: 0.5170278	total: 111ms	remaining: 6.4s
# 17:	learn: 0.5131427	total: 117ms	remaining: 6.38s
# 18:	learn: 0.5097282	total: 123ms	remaining: 6.35s
# 19:	learn: 0.5057734	total: 130ms	remaining: 6.35s
# 20:	learn: 0.5028170	total: 137ms	remaining: 6.37s
# 21:	learn: 0.4995411	total: 143ms	remaining: 6.35s
# 22:	learn: 0.4967307	total: 149ms	remaining: 6.32s
# 23:	learn: 0.4935760	total: 155ms	remaining: 6.29s
# 24:	learn: 0.4910026	total: 160ms	remaining: 6.24s
# 25:	learn: 0.4892166	total: 166ms	remaining: 6.22s
# 26:	learn: 0.4863455	total: 172ms	remaining: 6.2s
# 27:	learn: 0.4836893	total: 178ms	remaining: 6.17s
# 28:	learn: 0.4816795	total: 184ms	remaining: 6.14s
# 29:	learn: 0.4792650	total: 189ms	remaining: 6.12s
# 30:	learn: 0.4769344	total: 195ms	remaining: 6.1s
# 31:	learn: 0.4750031	total: 201ms	remaining: 6.08s
# 32:	learn: 0.4730730	total: 207ms	remaining: 6.07s
# 33:	learn: 0.4715815	total: 213ms	remaining: 6.05s
# 34:	learn: 0.4699169	total: 219ms	remaining: 6.03s
# 35:	learn: 0.4675129	total: 225ms	remaining: 6.01s
# 36:	learn: 0.4656423	total: 231ms	remaining: 6.01s
# 37:	learn: 0.4640404	total: 237ms	remaining: 6.01s
# 38:	learn: 0.4626956	total: 243ms	remaining: 5.98s
# 39:	learn: 0.4613871	total: 249ms	remaining: 5.97s
# 40:	learn: 0.4593137	total: 255ms	remaining: 5.95s
# 41:	learn: 0.4574604	total: 260ms	remaining: 5.94s
# 42:	learn: 0.4556437	total: 266ms	remaining: 5.93s
# 43:	learn: 0.4540697	total: 272ms	remaining: 5.91s
# 44:	learn: 0.4521270	total: 278ms	remaining: 5.9s
# 45:	learn: 0.4508540	total: 284ms	remaining: 5.89s
# 46:	learn: 0.4498381	total: 290ms	remaining: 5.88s
# 47:	learn: 0.4487391	total: 296ms	remaining: 5.86s
# 48:	learn: 0.4471922	total: 302ms	remaining: 5.86s
# 49:	learn: 0.4461493	total: 307ms	remaining: 5.84s
# 50:	learn: 0.4444438	total: 313ms	remaining: 5.83s
# 51:	learn: 0.4428620	total: 319ms	remaining: 5.82s
# 52:	learn: 0.4414753	total: 325ms	remaining: 5.81s
# 53:	learn: 0.4400368	total: 331ms	remaining: 5.81s
# 54:	learn: 0.4389941	total: 338ms	remaining: 5.8s
# 55:	learn: 0.4379594	total: 344ms	remaining: 5.8s
# 56:	learn: 0.4368123	total: 350ms	remaining: 5.79s
# 57:	learn: 0.4361150	total: 355ms	remaining: 5.77s
# 58:	learn: 0.4347815	total: 361ms	remaining: 5.76s
# 59:	learn: 0.4335062	total: 367ms	remaining: 5.74s
# 60:	learn: 0.4325231	total: 373ms	remaining: 5.74s
# 61:	learn: 0.4313915	total: 378ms	remaining: 5.72s
# 62:	learn: 0.4304390	total: 384ms	remaining: 5.71s
# 63:	learn: 0.4295524	total: 390ms	remaining: 5.7s
# 64:	learn: 0.4284626	total: 396ms	remaining: 5.69s
# 65:	learn: 0.4270999	total: 402ms	remaining: 5.68s
# 66:	learn: 0.4259460	total: 407ms	remaining: 5.67s
# 67:	learn: 0.4245217	total: 413ms	remaining: 5.66s
# 68:	learn: 0.4236937	total: 418ms	remaining: 5.64s
# 69:	learn: 0.4231332	total: 424ms	remaining: 5.63s
# 70:	learn: 0.4222026	total: 430ms	remaining: 5.63s
# 71:	learn: 0.4212683	total: 437ms	remaining: 5.63s
# 72:	learn: 0.4200388	total: 443ms	remaining: 5.63s
# 73:	learn: 0.4189575	total: 449ms	remaining: 5.62s
# 74:	learn: 0.4183264	total: 455ms	remaining: 5.62s
# 75:	learn: 0.4172042	total: 462ms	remaining: 5.61s
# 76:	learn: 0.4164612	total: 468ms	remaining: 5.61s
# 77:	learn: 0.4151191	total: 474ms	remaining: 5.6s
# 78:	learn: 0.4146638	total: 480ms	remaining: 5.6s
# 79:	learn: 0.4136730	total: 486ms	remaining: 5.59s
# 80:	learn: 0.4131060	total: 492ms	remaining: 5.58s
# 81:	learn: 0.4121683	total: 497ms	remaining: 5.57s
# 82:	learn: 0.4114596	total: 503ms	remaining: 5.55s
# 83:	learn: 0.4107068	total: 509ms	remaining: 5.55s
# 84:	learn: 0.4101182	total: 514ms	remaining: 5.54s
# 85:	learn: 0.4094328	total: 520ms	remaining: 5.53s
# 86:	learn: 0.4084973	total: 526ms	remaining: 5.52s
# 87:	learn: 0.4077996	total: 532ms	remaining: 5.51s
# 88:	learn: 0.4069293	total: 537ms	remaining: 5.5s
# 89:	learn: 0.4060471	total: 543ms	remaining: 5.49s
# 90:	learn: 0.4049336	total: 549ms	remaining: 5.48s
# 91:	learn: 0.4039363	total: 555ms	remaining: 5.48s
# 92:	learn: 0.4029708	total: 561ms	remaining: 5.47s
# 93:	learn: 0.4023909	total: 566ms	remaining: 5.46s
# 94:	learn: 0.4011785	total: 572ms	remaining: 5.45s
# 95:	learn: 0.4004555	total: 578ms	remaining: 5.44s
# 96:	learn: 0.3996899	total: 584ms	remaining: 5.43s
# 97:	learn: 0.3987310	total: 590ms	remaining: 5.43s
# 98:	learn: 0.3982807	total: 596ms	remaining: 5.42s
# 99:	learn: 0.3976460	total: 601ms	remaining: 5.41s
# 100:	learn: 0.3971350	total: 607ms	remaining: 5.4s
# 101:	learn: 0.3963405	total: 612ms	remaining: 5.39s
# 102:	learn: 0.3955535	total: 618ms	remaining: 5.38s
# 103:	learn: 0.3946135	total: 624ms	remaining: 5.37s
# 104:	learn: 0.3938565	total: 629ms	remaining: 5.36s
# 105:	learn: 0.3928539	total: 635ms	remaining: 5.36s
# 106:	learn: 0.3918729	total: 641ms	remaining: 5.35s
# 107:	learn: 0.3908558	total: 647ms	remaining: 5.34s
# 108:	learn: 0.3900053	total: 652ms	remaining: 5.33s
# 109:	learn: 0.3891969	total: 658ms	remaining: 5.33s
# 110:	learn: 0.3882485	total: 664ms	remaining: 5.32s
# 111:	learn: 0.3875085	total: 670ms	remaining: 5.31s
# 112:	learn: 0.3868150	total: 676ms	remaining: 5.3s
# 113:	learn: 0.3858498	total: 681ms	remaining: 5.3s
# 114:	learn: 0.3851038	total: 687ms	remaining: 5.29s
# 115:	learn: 0.3842253	total: 693ms	remaining: 5.28s
# 116:	learn: 0.3833915	total: 699ms	remaining: 5.28s
# 117:	learn: 0.3828070	total: 704ms	remaining: 5.26s
# 118:	learn: 0.3814948	total: 710ms	remaining: 5.26s
# 119:	learn: 0.3807763	total: 716ms	remaining: 5.25s
# 120:	learn: 0.3802884	total: 722ms	remaining: 5.24s
# 121:	learn: 0.3796660	total: 727ms	remaining: 5.23s
# 122:	learn: 0.3786839	total: 733ms	remaining: 5.23s
# 123:	learn: 0.3779316	total: 739ms	remaining: 5.22s
# 124:	learn: 0.3773944	total: 745ms	remaining: 5.21s
# 125:	learn: 0.3767770	total: 750ms	remaining: 5.2s
# 126:	learn: 0.3760619	total: 756ms	remaining: 5.19s
# 127:	learn: 0.3751002	total: 762ms	remaining: 5.19s
# 128:	learn: 0.3746822	total: 767ms	remaining: 5.18s
# 129:	learn: 0.3738239	total: 773ms	remaining: 5.17s
# 130:	learn: 0.3730520	total: 779ms	remaining: 5.17s
# 131:	learn: 0.3725352	total: 784ms	remaining: 5.16s
# 132:	learn: 0.3715218	total: 790ms	remaining: 5.15s
# 133:	learn: 0.3706948	total: 796ms	remaining: 5.14s
# 134:	learn: 0.3699825	total: 802ms	remaining: 5.14s
# 135:	learn: 0.3691736	total: 808ms	remaining: 5.13s
# 136:	learn: 0.3684200	total: 814ms	remaining: 5.13s
# 137:	learn: 0.3676707	total: 819ms	remaining: 5.12s
# 138:	learn: 0.3672699	total: 825ms	remaining: 5.11s
# 139:	learn: 0.3664751	total: 831ms	remaining: 5.1s
# 140:	learn: 0.3656537	total: 837ms	remaining: 5.1s
# 141:	learn: 0.3652821	total: 842ms	remaining: 5.09s
# 142:	learn: 0.3645685	total: 848ms	remaining: 5.08s
# 143:	learn: 0.3637747	total: 854ms	remaining: 5.08s
# 144:	learn: 0.3633952	total: 859ms	remaining: 5.07s
# 145:	learn: 0.3628438	total: 865ms	remaining: 5.06s
# 146:	learn: 0.3622060	total: 871ms	remaining: 5.05s
# 147:	learn: 0.3616853	total: 876ms	remaining: 5.04s
# 148:	learn: 0.3608426	total: 882ms	remaining: 5.04s
# 149:	learn: 0.3598417	total: 888ms	remaining: 5.03s
# 150:	learn: 0.3592959	total: 894ms	remaining: 5.03s
# 151:	learn: 0.3582310	total: 900ms	remaining: 5.02s
# 152:	learn: 0.3574216	total: 906ms	remaining: 5.01s
# 153:	learn: 0.3567219	total: 912ms	remaining: 5.01s
# 154:	learn: 0.3561427	total: 918ms	remaining: 5s
# 155:	learn: 0.3555873	total: 924ms	remaining: 5s
# 156:	learn: 0.3550106	total: 930ms	remaining: 4.99s
# 157:	learn: 0.3541238	total: 936ms	remaining: 4.99s
# 158:	learn: 0.3533941	total: 942ms	remaining: 4.98s
# 159:	learn: 0.3526286	total: 948ms	remaining: 4.98s
# 160:	learn: 0.3516508	total: 954ms	remaining: 4.97s
# 161:	learn: 0.3511305	total: 960ms	remaining: 4.96s
# 162:	learn: 0.3504461	total: 965ms	remaining: 4.96s
# 163:	learn: 0.3497850	total: 971ms	remaining: 4.95s
# 164:	learn: 0.3491903	total: 977ms	remaining: 4.94s
# 165:	learn: 0.3484918	total: 983ms	remaining: 4.94s
# 166:	learn: 0.3477441	total: 988ms	remaining: 4.93s
# 167:	learn: 0.3470816	total: 994ms	remaining: 4.92s
# 168:	learn: 0.3464731	total: 1000ms	remaining: 4.92s
# 169:	learn: 0.3458113	total: 1s	remaining: 4.91s
# 170:	learn: 0.3448509	total: 1.01s	remaining: 4.9s
# 171:	learn: 0.3439867	total: 1.02s	remaining: 4.9s
# 172:	learn: 0.3433683	total: 1.02s	remaining: 4.89s
# 173:	learn: 0.3426998	total: 1.03s	remaining: 4.89s
# 174:	learn: 0.3419565	total: 1.04s	remaining: 4.89s
# 175:	learn: 0.3414296	total: 1.04s	remaining: 4.88s
# 176:	learn: 0.3406199	total: 1.05s	remaining: 4.88s
# 177:	learn: 0.3400036	total: 1.05s	remaining: 4.87s
# 178:	learn: 0.3394034	total: 1.06s	remaining: 4.87s
# 179:	learn: 0.3384462	total: 1.07s	remaining: 4.86s
# 180:	learn: 0.3378369	total: 1.07s	remaining: 4.85s
# 181:	learn: 0.3371509	total: 1.08s	remaining: 4.85s
# 182:	learn: 0.3363868	total: 1.08s	remaining: 4.84s
# 183:	learn: 0.3357748	total: 1.09s	remaining: 4.83s
# 184:	learn: 0.3352568	total: 1.1s	remaining: 4.83s
# 185:	learn: 0.3343382	total: 1.1s	remaining: 4.82s
# 186:	learn: 0.3336202	total: 1.11s	remaining: 4.82s
# 187:	learn: 0.3327916	total: 1.11s	remaining: 4.81s
# 188:	learn: 0.3322866	total: 1.12s	remaining: 4.81s
# 189:	learn: 0.3315508	total: 1.13s	remaining: 4.8s
# 190:	learn: 0.3310301	total: 1.13s	remaining: 4.8s
# 191:	learn: 0.3303133	total: 1.14s	remaining: 4.79s
# 192:	learn: 0.3295401	total: 1.14s	remaining: 4.79s
# 193:	learn: 0.3289578	total: 1.15s	remaining: 4.78s
# 194:	learn: 0.3284382	total: 1.16s	remaining: 4.78s
# 195:	learn: 0.3280017	total: 1.16s	remaining: 4.77s
# 196:	learn: 0.3274954	total: 1.17s	remaining: 4.76s
# 197:	learn: 0.3269646	total: 1.18s	remaining: 4.76s
# 198:	learn: 0.3266249	total: 1.18s	remaining: 4.75s
# 199:	learn: 0.3259331	total: 1.19s	remaining: 4.75s
# 200:	learn: 0.3253247	total: 1.19s	remaining: 4.74s
# 201:	learn: 0.3246485	total: 1.2s	remaining: 4.74s
# 202:	learn: 0.3242686	total: 1.21s	remaining: 4.73s
# 203:	learn: 0.3236837	total: 1.21s	remaining: 4.73s
# 204:	learn: 0.3232577	total: 1.22s	remaining: 4.72s
# 205:	learn: 0.3227777	total: 1.22s	remaining: 4.71s
# 206:	learn: 0.3223235	total: 1.23s	remaining: 4.71s
# 207:	learn: 0.3215446	total: 1.24s	remaining: 4.7s
# 208:	learn: 0.3208476	total: 1.24s	remaining: 4.7s
# 209:	learn: 0.3204840	total: 1.25s	remaining: 4.69s
# 210:	learn: 0.3198242	total: 1.25s	remaining: 4.69s
# 211:	learn: 0.3191898	total: 1.26s	remaining: 4.68s
# 212:	learn: 0.3188899	total: 1.26s	remaining: 4.68s
# 213:	learn: 0.3183247	total: 1.27s	remaining: 4.67s
# 214:	learn: 0.3174916	total: 1.28s	remaining: 4.67s
# 215:	learn: 0.3170799	total: 1.28s	remaining: 4.67s
# 216:	learn: 0.3164993	total: 1.29s	remaining: 4.66s
# 217:	learn: 0.3158372	total: 1.3s	remaining: 4.66s
# 218:	learn: 0.3150885	total: 1.3s	remaining: 4.66s
# 219:	learn: 0.3146530	total: 1.31s	remaining: 4.65s
# 220:	learn: 0.3142560	total: 1.32s	remaining: 4.65s
# 221:	learn: 0.3135747	total: 1.32s	remaining: 4.64s
# 222:	learn: 0.3130288	total: 1.33s	remaining: 4.64s
# 223:	learn: 0.3125461	total: 1.34s	remaining: 4.64s
# 224:	learn: 0.3117944	total: 1.35s	remaining: 4.64s
# 225:	learn: 0.3112194	total: 1.35s	remaining: 4.63s
# 226:	learn: 0.3106039	total: 1.36s	remaining: 4.63s
# 227:	learn: 0.3101506	total: 1.37s	remaining: 4.63s
# 228:	learn: 0.3095930	total: 1.37s	remaining: 4.62s
# 229:	learn: 0.3090521	total: 1.38s	remaining: 4.61s
# 230:	learn: 0.3082980	total: 1.38s	remaining: 4.61s
# 231:	learn: 0.3077859	total: 1.39s	remaining: 4.6s
# 232:	learn: 0.3074296	total: 1.4s	remaining: 4.6s
# 233:	learn: 0.3068469	total: 1.4s	remaining: 4.59s
# 234:	learn: 0.3062390	total: 1.41s	remaining: 4.59s
# 235:	learn: 0.3056055	total: 1.42s	remaining: 4.58s
# 236:	learn: 0.3051430	total: 1.42s	remaining: 4.58s
# 237:	learn: 0.3046311	total: 1.43s	remaining: 4.57s
# 238:	learn: 0.3041017	total: 1.44s	remaining: 4.57s
# 239:	learn: 0.3034292	total: 1.44s	remaining: 4.56s
# 240:	learn: 0.3030661	total: 1.45s	remaining: 4.56s
# 241:	learn: 0.3021141	total: 1.45s	remaining: 4.55s
# 242:	learn: 0.3013635	total: 1.46s	remaining: 4.54s
# 243:	learn: 0.3007221	total: 1.46s	remaining: 4.54s
# 244:	learn: 0.3003981	total: 1.47s	remaining: 4.53s
# 245:	learn: 0.2999864	total: 1.48s	remaining: 4.52s
# 246:	learn: 0.2996307	total: 1.48s	remaining: 4.52s
# 247:	learn: 0.2991241	total: 1.49s	remaining: 4.51s
# 248:	learn: 0.2984848	total: 1.49s	remaining: 4.5s
# 249:	learn: 0.2983212	total: 1.5s	remaining: 4.49s
# 250:	learn: 0.2976475	total: 1.5s	remaining: 4.49s
# 251:	learn: 0.2972414	total: 1.51s	remaining: 4.48s
# 252:	learn: 0.2969923	total: 1.51s	remaining: 4.47s
# 253:	learn: 0.2964334	total: 1.52s	remaining: 4.46s
# 254:	learn: 0.2959846	total: 1.52s	remaining: 4.46s
# 255:	learn: 0.2954782	total: 1.53s	remaining: 4.45s
# 256:	learn: 0.2951885	total: 1.54s	remaining: 4.44s
# 257:	learn: 0.2944483	total: 1.54s	remaining: 4.44s
# 258:	learn: 0.2937647	total: 1.55s	remaining: 4.43s
# 259:	learn: 0.2932466	total: 1.55s	remaining: 4.42s
# 260:	learn: 0.2923485	total: 1.56s	remaining: 4.42s
# 261:	learn: 0.2918182	total: 1.57s	remaining: 4.41s
# 262:	learn: 0.2914498	total: 1.57s	remaining: 4.4s
# 263:	learn: 0.2911140	total: 1.58s	remaining: 4.4s
# 264:	learn: 0.2903808	total: 1.58s	remaining: 4.39s
# 265:	learn: 0.2897726	total: 1.59s	remaining: 4.38s
# 266:	learn: 0.2893448	total: 1.59s	remaining: 4.38s
# 267:	learn: 0.2887430	total: 1.6s	remaining: 4.37s
# 268:	learn: 0.2883565	total: 1.6s	remaining: 4.36s
# 269:	learn: 0.2880217	total: 1.61s	remaining: 4.36s
# 270:	learn: 0.2874192	total: 1.62s	remaining: 4.35s
# 271:	learn: 0.2869638	total: 1.62s	remaining: 4.34s
# 272:	learn: 0.2865078	total: 1.63s	remaining: 4.34s
# 273:	learn: 0.2858588	total: 1.64s	remaining: 4.33s
# 274:	learn: 0.2852774	total: 1.64s	remaining: 4.33s
# 275:	learn: 0.2845202	total: 1.65s	remaining: 4.32s
# 276:	learn: 0.2840253	total: 1.65s	remaining: 4.31s
# 277:	learn: 0.2834811	total: 1.66s	remaining: 4.31s
# 278:	learn: 0.2831401	total: 1.66s	remaining: 4.3s
# 279:	learn: 0.2827328	total: 1.67s	remaining: 4.29s
# 280:	learn: 0.2821880	total: 1.68s	remaining: 4.29s
# 281:	learn: 0.2814923	total: 1.68s	remaining: 4.28s
# 282:	learn: 0.2810754	total: 1.69s	remaining: 4.27s
# 283:	learn: 0.2804709	total: 1.69s	remaining: 4.26s
# 284:	learn: 0.2800228	total: 1.7s	remaining: 4.26s
# 285:	learn: 0.2794634	total: 1.7s	remaining: 4.25s
# 286:	learn: 0.2788677	total: 1.71s	remaining: 4.25s
# 287:	learn: 0.2786079	total: 1.72s	remaining: 4.24s
# 288:	learn: 0.2780829	total: 1.72s	remaining: 4.24s
# 289:	learn: 0.2778255	total: 1.73s	remaining: 4.23s
# 290:	learn: 0.2775151	total: 1.73s	remaining: 4.22s
# 291:	learn: 0.2769832	total: 1.74s	remaining: 4.22s
# 292:	learn: 0.2766330	total: 1.75s	remaining: 4.21s
# 293:	learn: 0.2762799	total: 1.75s	remaining: 4.21s
# 294:	learn: 0.2754636	total: 1.76s	remaining: 4.21s
# 295:	learn: 0.2751676	total: 1.76s	remaining: 4.2s
# 296:	learn: 0.2748092	total: 1.77s	remaining: 4.19s
# 297:	learn: 0.2743555	total: 1.78s	remaining: 4.19s
# 298:	learn: 0.2737628	total: 1.78s	remaining: 4.18s
# 299:	learn: 0.2733248	total: 1.79s	remaining: 4.17s
# 300:	learn: 0.2728381	total: 1.79s	remaining: 4.17s
# 301:	learn: 0.2722292	total: 1.8s	remaining: 4.16s
# 302:	learn: 0.2716198	total: 1.81s	remaining: 4.16s
# 303:	learn: 0.2711826	total: 1.81s	remaining: 4.15s
# 304:	learn: 0.2706870	total: 1.82s	remaining: 4.14s
# 305:	learn: 0.2702766	total: 1.82s	remaining: 4.14s
# 306:	learn: 0.2697032	total: 1.83s	remaining: 4.13s
# 307:	learn: 0.2691154	total: 1.83s	remaining: 4.12s
# 308:	learn: 0.2687119	total: 1.84s	remaining: 4.12s
# 309:	learn: 0.2681128	total: 1.85s	remaining: 4.11s
# 310:	learn: 0.2675890	total: 1.85s	remaining: 4.1s
# 311:	learn: 0.2671785	total: 1.86s	remaining: 4.1s
# 312:	learn: 0.2666172	total: 1.86s	remaining: 4.09s
# 313:	learn: 0.2661984	total: 1.87s	remaining: 4.08s
# 314:	learn: 0.2658142	total: 1.88s	remaining: 4.08s
# 315:	learn: 0.2656469	total: 1.88s	remaining: 4.07s
# 316:	learn: 0.2650756	total: 1.89s	remaining: 4.07s
# 317:	learn: 0.2647837	total: 1.89s	remaining: 4.06s
# 318:	learn: 0.2644618	total: 1.9s	remaining: 4.05s
# 319:	learn: 0.2641649	total: 1.9s	remaining: 4.04s
# 320:	learn: 0.2636412	total: 1.91s	remaining: 4.04s
# 321:	learn: 0.2629365	total: 1.92s	remaining: 4.04s
# 322:	learn: 0.2625222	total: 1.92s	remaining: 4.03s
# 323:	learn: 0.2621432	total: 1.93s	remaining: 4.02s
# 324:	learn: 0.2618020	total: 1.93s	remaining: 4.02s
# 325:	learn: 0.2611186	total: 1.94s	remaining: 4.01s
# 326:	learn: 0.2608086	total: 1.95s	remaining: 4.01s
# 327:	learn: 0.2604134	total: 1.95s	remaining: 4s
# 328:	learn: 0.2600837	total: 1.96s	remaining: 4s
# 329:	learn: 0.2596261	total: 1.97s	remaining: 3.99s
# 330:	learn: 0.2592171	total: 1.97s	remaining: 3.98s
# 331:	learn: 0.2588988	total: 1.98s	remaining: 3.98s
# 332:	learn: 0.2585316	total: 1.98s	remaining: 3.97s
# 333:	learn: 0.2579920	total: 1.99s	remaining: 3.97s
# 334:	learn: 0.2575364	total: 2s	remaining: 3.96s
# 335:	learn: 0.2568718	total: 2s	remaining: 3.96s
# 336:	learn: 0.2564460	total: 2.01s	remaining: 3.95s
# 337:	learn: 0.2558653	total: 2.02s	remaining: 3.95s
# 338:	learn: 0.2553546	total: 2.02s	remaining: 3.94s
# 339:	learn: 0.2549096	total: 2.03s	remaining: 3.94s
# 340:	learn: 0.2543188	total: 2.03s	remaining: 3.93s
# 341:	learn: 0.2540061	total: 2.04s	remaining: 3.92s
# 342:	learn: 0.2536802	total: 2.05s	remaining: 3.92s
# 343:	learn: 0.2533148	total: 2.05s	remaining: 3.91s
# 344:	learn: 0.2528400	total: 2.06s	remaining: 3.91s
# 345:	learn: 0.2524737	total: 2.06s	remaining: 3.9s
# 346:	learn: 0.2521214	total: 2.07s	remaining: 3.9s
# 347:	learn: 0.2516307	total: 2.08s	remaining: 3.89s
# 348:	learn: 0.2510768	total: 2.08s	remaining: 3.89s
# 349:	learn: 0.2508265	total: 2.09s	remaining: 3.88s
# 350:	learn: 0.2504017	total: 2.1s	remaining: 3.88s
# 351:	learn: 0.2498737	total: 2.1s	remaining: 3.87s
# 352:	learn: 0.2495087	total: 2.11s	remaining: 3.86s
# 353:	learn: 0.2490366	total: 2.11s	remaining: 3.86s
# 354:	learn: 0.2486587	total: 2.12s	remaining: 3.85s
# 355:	learn: 0.2479083	total: 2.13s	remaining: 3.85s
# 356:	learn: 0.2475276	total: 2.13s	remaining: 3.84s
# 357:	learn: 0.2471437	total: 2.14s	remaining: 3.83s
# 358:	learn: 0.2468121	total: 2.14s	remaining: 3.83s
# 359:	learn: 0.2464408	total: 2.15s	remaining: 3.82s
# 360:	learn: 0.2459354	total: 2.16s	remaining: 3.82s
# 361:	learn: 0.2454100	total: 2.16s	remaining: 3.81s
# 362:	learn: 0.2452208	total: 2.17s	remaining: 3.81s
# 363:	learn: 0.2449772	total: 2.17s	remaining: 3.8s
# 364:	learn: 0.2443867	total: 2.18s	remaining: 3.79s
# 365:	learn: 0.2439688	total: 2.19s	remaining: 3.79s
# 366:	learn: 0.2436952	total: 2.19s	remaining: 3.78s
# 367:	learn: 0.2432084	total: 2.2s	remaining: 3.78s
# 368:	learn: 0.2426435	total: 2.21s	remaining: 3.77s
# 369:	learn: 0.2424304	total: 2.21s	remaining: 3.77s
# 370:	learn: 0.2422096	total: 2.22s	remaining: 3.76s
# 371:	learn: 0.2417190	total: 2.22s	remaining: 3.75s
# 372:	learn: 0.2411159	total: 2.23s	remaining: 3.75s
# 373:	learn: 0.2407405	total: 2.23s	remaining: 3.74s
# 374:	learn: 0.2403930	total: 2.24s	remaining: 3.73s
# 375:	learn: 0.2399202	total: 2.25s	remaining: 3.73s
# 376:	learn: 0.2396177	total: 2.25s	remaining: 3.72s
# 377:	learn: 0.2394013	total: 2.26s	remaining: 3.72s
# 378:	learn: 0.2390197	total: 2.26s	remaining: 3.71s
# 379:	learn: 0.2385708	total: 2.27s	remaining: 3.7s
# 380:	learn: 0.2380633	total: 2.27s	remaining: 3.7s
# 381:	learn: 0.2376476	total: 2.28s	remaining: 3.69s
# 382:	learn: 0.2373210	total: 2.29s	remaining: 3.69s
# 383:	learn: 0.2368838	total: 2.29s	remaining: 3.68s
# 384:	learn: 0.2363709	total: 2.3s	remaining: 3.67s
# 385:	learn: 0.2358619	total: 2.31s	remaining: 3.67s
# 386:	learn: 0.2353791	total: 2.31s	remaining: 3.66s
# 387:	learn: 0.2350304	total: 2.32s	remaining: 3.65s
# 388:	learn: 0.2344083	total: 2.32s	remaining: 3.65s
# 389:	learn: 0.2340601	total: 2.33s	remaining: 3.64s
# 390:	learn: 0.2336302	total: 2.33s	remaining: 3.64s
# 391:	learn: 0.2332680	total: 2.34s	remaining: 3.63s
# 392:	learn: 0.2326957	total: 2.35s	remaining: 3.63s
# 393:	learn: 0.2322163	total: 2.35s	remaining: 3.62s
# 394:	learn: 0.2319206	total: 2.36s	remaining: 3.61s
# 395:	learn: 0.2315886	total: 2.36s	remaining: 3.61s
# 396:	learn: 0.2312772	total: 2.37s	remaining: 3.6s
# 397:	learn: 0.2308585	total: 2.38s	remaining: 3.59s
# 398:	learn: 0.2304487	total: 2.38s	remaining: 3.59s
# 399:	learn: 0.2299012	total: 2.39s	remaining: 3.58s
# 400:	learn: 0.2295663	total: 2.39s	remaining: 3.58s
# 401:	learn: 0.2290954	total: 2.4s	remaining: 3.57s
# 402:	learn: 0.2288055	total: 2.4s	remaining: 3.56s
# 403:	learn: 0.2286171	total: 2.41s	remaining: 3.56s
# 404:	learn: 0.2283951	total: 2.42s	remaining: 3.55s
# 405:	learn: 0.2278788	total: 2.42s	remaining: 3.54s
# 406:	learn: 0.2274783	total: 2.43s	remaining: 3.54s
# 407:	learn: 0.2271178	total: 2.44s	remaining: 3.53s
# 408:	learn: 0.2267362	total: 2.44s	remaining: 3.53s
# 409:	learn: 0.2264350	total: 2.45s	remaining: 3.52s
# 410:	learn: 0.2259966	total: 2.45s	remaining: 3.52s
# 411:	learn: 0.2255326	total: 2.46s	remaining: 3.51s
# 412:	learn: 0.2253220	total: 2.46s	remaining: 3.5s
# 413:	learn: 0.2250424	total: 2.47s	remaining: 3.5s
# 414:	learn: 0.2246416	total: 2.48s	remaining: 3.49s
# 415:	learn: 0.2242903	total: 2.48s	remaining: 3.48s
# 416:	learn: 0.2238714	total: 2.49s	remaining: 3.48s
# 417:	learn: 0.2235672	total: 2.49s	remaining: 3.47s
# 418:	learn: 0.2233208	total: 2.5s	remaining: 3.47s
# 419:	learn: 0.2230515	total: 2.5s	remaining: 3.46s
# 420:	learn: 0.2228000	total: 2.51s	remaining: 3.45s
# 421:	learn: 0.2224814	total: 2.52s	remaining: 3.45s
# 422:	learn: 0.2222465	total: 2.52s	remaining: 3.44s
# 423:	learn: 0.2219133	total: 2.53s	remaining: 3.43s
# 424:	learn: 0.2217433	total: 2.53s	remaining: 3.43s
# 425:	learn: 0.2213657	total: 2.54s	remaining: 3.42s
# 426:	learn: 0.2209324	total: 2.55s	remaining: 3.42s
# 427:	learn: 0.2204515	total: 2.55s	remaining: 3.41s
# 428:	learn: 0.2202674	total: 2.56s	remaining: 3.41s
# 429:	learn: 0.2199284	total: 2.57s	remaining: 3.4s
# 430:	learn: 0.2194056	total: 2.57s	remaining: 3.4s
# 431:	learn: 0.2189642	total: 2.58s	remaining: 3.39s
# 432:	learn: 0.2186833	total: 2.58s	remaining: 3.38s
# 433:	learn: 0.2182659	total: 2.59s	remaining: 3.38s
# 434:	learn: 0.2176684	total: 2.6s	remaining: 3.37s
# 435:	learn: 0.2173411	total: 2.6s	remaining: 3.37s
# 436:	learn: 0.2169721	total: 2.61s	remaining: 3.36s
# 437:	learn: 0.2165618	total: 2.62s	remaining: 3.36s
# 438:	learn: 0.2161657	total: 2.62s	remaining: 3.35s
# 439:	learn: 0.2157619	total: 2.63s	remaining: 3.34s
# 440:	learn: 0.2153402	total: 2.63s	remaining: 3.34s
# 441:	learn: 0.2149690	total: 2.64s	remaining: 3.33s
# 442:	learn: 0.2147663	total: 2.65s	remaining: 3.33s
# 443:	learn: 0.2144187	total: 2.65s	remaining: 3.32s
# 444:	learn: 0.2141175	total: 2.66s	remaining: 3.31s
# 445:	learn: 0.2138534	total: 2.66s	remaining: 3.31s
# 446:	learn: 0.2135449	total: 2.67s	remaining: 3.3s
# 447:	learn: 0.2132781	total: 2.67s	remaining: 3.29s
# 448:	learn: 0.2129642	total: 2.68s	remaining: 3.29s
# 449:	learn: 0.2126633	total: 2.69s	remaining: 3.28s
# 450:	learn: 0.2122990	total: 2.69s	remaining: 3.28s
# 451:	learn: 0.2119517	total: 2.7s	remaining: 3.27s
# 452:	learn: 0.2115960	total: 2.71s	remaining: 3.27s
# 453:	learn: 0.2113936	total: 2.71s	remaining: 3.26s
# 454:	learn: 0.2109948	total: 2.72s	remaining: 3.25s
# 455:	learn: 0.2105586	total: 2.72s	remaining: 3.25s
# 456:	learn: 0.2103115	total: 2.73s	remaining: 3.24s
# 457:	learn: 0.2101321	total: 2.73s	remaining: 3.24s
# 458:	learn: 0.2097696	total: 2.74s	remaining: 3.23s
# 459:	learn: 0.2094633	total: 2.75s	remaining: 3.23s
# 460:	learn: 0.2091327	total: 2.75s	remaining: 3.22s
# 461:	learn: 0.2089808	total: 2.76s	remaining: 3.21s
# 462:	learn: 0.2086471	total: 2.77s	remaining: 3.21s
# 463:	learn: 0.2082871	total: 2.77s	remaining: 3.2s
# 464:	learn: 0.2079049	total: 2.78s	remaining: 3.2s
# 465:	learn: 0.2074729	total: 2.79s	remaining: 3.19s
# 466:	learn: 0.2071608	total: 2.79s	remaining: 3.19s
# 467:	learn: 0.2066921	total: 2.8s	remaining: 3.18s
# 468:	learn: 0.2064037	total: 2.8s	remaining: 3.17s
# 469:	learn: 0.2059993	total: 2.81s	remaining: 3.17s
# 470:	learn: 0.2055774	total: 2.82s	remaining: 3.16s
# 471:	learn: 0.2051735	total: 2.82s	remaining: 3.16s
# 472:	learn: 0.2048135	total: 2.83s	remaining: 3.15s
# 473:	learn: 0.2045324	total: 2.83s	remaining: 3.14s
# 474:	learn: 0.2043209	total: 2.84s	remaining: 3.14s
# 475:	learn: 0.2038094	total: 2.85s	remaining: 3.13s
# 476:	learn: 0.2036085	total: 2.85s	remaining: 3.13s
# 477:	learn: 0.2033739	total: 2.86s	remaining: 3.12s
# 478:	learn: 0.2031337	total: 2.86s	remaining: 3.11s
# 479:	learn: 0.2028655	total: 2.87s	remaining: 3.11s
# 480:	learn: 0.2025349	total: 2.87s	remaining: 3.1s
# 481:	learn: 0.2019789	total: 2.88s	remaining: 3.09s
# 482:	learn: 0.2016847	total: 2.88s	remaining: 3.09s
# 483:	learn: 0.2014692	total: 2.89s	remaining: 3.08s
# 484:	learn: 0.2011476	total: 2.9s	remaining: 3.08s
# 485:	learn: 0.2007984	total: 2.9s	remaining: 3.07s
# 486:	learn: 0.2003522	total: 2.91s	remaining: 3.06s
# 487:	learn: 0.1998635	total: 2.92s	remaining: 3.06s
# 488:	learn: 0.1997299	total: 2.92s	remaining: 3.05s
# 489:	learn: 0.1995352	total: 2.93s	remaining: 3.05s
# 490:	learn: 0.1991687	total: 2.93s	remaining: 3.04s
# 491:	learn: 0.1988356	total: 2.94s	remaining: 3.04s
# 492:	learn: 0.1984971	total: 2.95s	remaining: 3.03s
# 493:	learn: 0.1980287	total: 2.95s	remaining: 3.02s
# 494:	learn: 0.1975460	total: 2.96s	remaining: 3.02s
# 495:	learn: 0.1971889	total: 2.97s	remaining: 3.02s
# 496:	learn: 0.1969022	total: 2.97s	remaining: 3.01s
# 497:	learn: 0.1965424	total: 2.98s	remaining: 3s
# 498:	learn: 0.1963643	total: 2.98s	remaining: 3s
# 499:	learn: 0.1960253	total: 2.99s	remaining: 2.99s
# 500:	learn: 0.1956802	total: 3s	remaining: 2.98s
# 501:	learn: 0.1953700	total: 3s	remaining: 2.98s
# 502:	learn: 0.1951450	total: 3.01s	remaining: 2.97s
# 503:	learn: 0.1949481	total: 3.02s	remaining: 2.97s
# 504:	learn: 0.1945580	total: 3.02s	remaining: 2.96s
# 505:	learn: 0.1942593	total: 3.03s	remaining: 2.96s
# 506:	learn: 0.1938285	total: 3.04s	remaining: 2.95s
# 507:	learn: 0.1935752	total: 3.04s	remaining: 2.95s
# 508:	learn: 0.1931865	total: 3.05s	remaining: 2.94s
# 509:	learn: 0.1928005	total: 3.05s	remaining: 2.94s
# 510:	learn: 0.1925383	total: 3.06s	remaining: 2.93s
# 511:	learn: 0.1922453	total: 3.07s	remaining: 2.92s
# 512:	learn: 0.1921017	total: 3.07s	remaining: 2.92s
# 513:	learn: 0.1917696	total: 3.08s	remaining: 2.91s
# 514:	learn: 0.1915930	total: 3.09s	remaining: 2.91s
# 515:	learn: 0.1913693	total: 3.09s	remaining: 2.9s
# 516:	learn: 0.1910960	total: 3.1s	remaining: 2.89s
# 517:	learn: 0.1906678	total: 3.1s	remaining: 2.89s
# 518:	learn: 0.1905202	total: 3.11s	remaining: 2.88s
# 519:	learn: 0.1901546	total: 3.12s	remaining: 2.88s
# 520:	learn: 0.1899578	total: 3.12s	remaining: 2.87s
# 521:	learn: 0.1897207	total: 3.13s	remaining: 2.86s
# 522:	learn: 0.1893743	total: 3.13s	remaining: 2.86s
# 523:	learn: 0.1890204	total: 3.14s	remaining: 2.85s
# 524:	learn: 0.1887210	total: 3.15s	remaining: 2.85s
# 525:	learn: 0.1883898	total: 3.15s	remaining: 2.84s
# 526:	learn: 0.1881998	total: 3.16s	remaining: 2.83s
# 527:	learn: 0.1878458	total: 3.16s	remaining: 2.83s
# 528:	learn: 0.1874323	total: 3.17s	remaining: 2.82s
# 529:	learn: 0.1871082	total: 3.17s	remaining: 2.81s
# 530:	learn: 0.1869107	total: 3.18s	remaining: 2.81s
# 531:	learn: 0.1866688	total: 3.19s	remaining: 2.8s
# 532:	learn: 0.1863923	total: 3.19s	remaining: 2.8s
# 533:	learn: 0.1861624	total: 3.2s	remaining: 2.79s
# 534:	learn: 0.1858415	total: 3.2s	remaining: 2.78s
# 535:	learn: 0.1856143	total: 3.21s	remaining: 2.78s
# 536:	learn: 0.1853981	total: 3.21s	remaining: 2.77s
# 537:	learn: 0.1850635	total: 3.22s	remaining: 2.77s
# 538:	learn: 0.1848684	total: 3.23s	remaining: 2.76s
# 539:	learn: 0.1846277	total: 3.23s	remaining: 2.75s
# 540:	learn: 0.1843708	total: 3.24s	remaining: 2.75s
# 541:	learn: 0.1840374	total: 3.24s	remaining: 2.74s
# 542:	learn: 0.1838921	total: 3.25s	remaining: 2.73s
# 543:	learn: 0.1835902	total: 3.25s	remaining: 2.73s
# 544:	learn: 0.1832308	total: 3.26s	remaining: 2.72s
# 545:	learn: 0.1829998	total: 3.27s	remaining: 2.72s
# 546:	learn: 0.1827169	total: 3.27s	remaining: 2.71s
# 547:	learn: 0.1824385	total: 3.28s	remaining: 2.7s
# 548:	learn: 0.1820167	total: 3.28s	remaining: 2.7s
# 549:	learn: 0.1817242	total: 3.29s	remaining: 2.69s
# 550:	learn: 0.1813903	total: 3.29s	remaining: 2.69s
# 551:	learn: 0.1811034	total: 3.3s	remaining: 2.68s
# 552:	learn: 0.1807172	total: 3.31s	remaining: 2.67s
# 553:	learn: 0.1804389	total: 3.31s	remaining: 2.67s
# 554:	learn: 0.1801343	total: 3.32s	remaining: 2.66s
# 555:	learn: 0.1799737	total: 3.32s	remaining: 2.65s
# 556:	learn: 0.1797229	total: 3.33s	remaining: 2.65s
# 557:	learn: 0.1793822	total: 3.34s	remaining: 2.64s
# 558:	learn: 0.1792715	total: 3.34s	remaining: 2.64s
# 559:	learn: 0.1789956	total: 3.35s	remaining: 2.63s
# 560:	learn: 0.1787867	total: 3.35s	remaining: 2.62s
# 561:	learn: 0.1785035	total: 3.36s	remaining: 2.62s
# 562:	learn: 0.1781981	total: 3.36s	remaining: 2.61s
# 563:	learn: 0.1779023	total: 3.37s	remaining: 2.6s
# 564:	learn: 0.1776535	total: 3.38s	remaining: 2.6s
# 565:	learn: 0.1773041	total: 3.38s	remaining: 2.59s
# 566:	learn: 0.1771203	total: 3.39s	remaining: 2.59s
# 567:	learn: 0.1769489	total: 3.39s	remaining: 2.58s
# 568:	learn: 0.1767081	total: 3.4s	remaining: 2.57s
# 569:	learn: 0.1764450	total: 3.4s	remaining: 2.57s
# 570:	learn: 0.1763179	total: 3.41s	remaining: 2.56s
# 571:	learn: 0.1760454	total: 3.42s	remaining: 2.56s
# 572:	learn: 0.1757676	total: 3.42s	remaining: 2.55s
# 573:	learn: 0.1756092	total: 3.43s	remaining: 2.54s
# 574:	learn: 0.1753486	total: 3.43s	remaining: 2.54s
# 575:	learn: 0.1752135	total: 3.44s	remaining: 2.53s
# 576:	learn: 0.1750383	total: 3.44s	remaining: 2.52s
# 577:	learn: 0.1747960	total: 3.45s	remaining: 2.52s
# 578:	learn: 0.1745026	total: 3.46s	remaining: 2.51s
# 579:	learn: 0.1742194	total: 3.46s	remaining: 2.51s
# 580:	learn: 0.1739493	total: 3.47s	remaining: 2.5s
# 581:	learn: 0.1736516	total: 3.47s	remaining: 2.49s
# 582:	learn: 0.1734206	total: 3.48s	remaining: 2.49s
# 583:	learn: 0.1732613	total: 3.48s	remaining: 2.48s
# 584:	learn: 0.1729388	total: 3.49s	remaining: 2.48s
# 585:	learn: 0.1727757	total: 3.5s	remaining: 2.47s
# 586:	learn: 0.1725323	total: 3.5s	remaining: 2.47s
# 587:	learn: 0.1723870	total: 3.51s	remaining: 2.46s
# 588:	learn: 0.1722700	total: 3.52s	remaining: 2.45s
# 589:	learn: 0.1719598	total: 3.52s	remaining: 2.45s
# 590:	learn: 0.1717770	total: 3.53s	remaining: 2.44s
# 591:	learn: 0.1714541	total: 3.54s	remaining: 2.44s
# 592:	learn: 0.1711573	total: 3.54s	remaining: 2.43s
# 593:	learn: 0.1708422	total: 3.55s	remaining: 2.42s
# 594:	learn: 0.1705167	total: 3.55s	remaining: 2.42s
# 595:	learn: 0.1701515	total: 3.56s	remaining: 2.41s
# 596:	learn: 0.1699999	total: 3.56s	remaining: 2.41s
# 597:	learn: 0.1698036	total: 3.57s	remaining: 2.4s
# 598:	learn: 0.1696550	total: 3.58s	remaining: 2.39s
# 599:	learn: 0.1694658	total: 3.58s	remaining: 2.39s
# 600:	learn: 0.1692410	total: 3.59s	remaining: 2.38s
# 601:	learn: 0.1690708	total: 3.59s	remaining: 2.38s
# 602:	learn: 0.1689307	total: 3.6s	remaining: 2.37s
# 603:	learn: 0.1688197	total: 3.6s	remaining: 2.36s
# 604:	learn: 0.1684792	total: 3.61s	remaining: 2.36s
# 605:	learn: 0.1682017	total: 3.62s	remaining: 2.35s
# 606:	learn: 0.1679853	total: 3.62s	remaining: 2.35s
# 607:	learn: 0.1677369	total: 3.63s	remaining: 2.34s
# 608:	learn: 0.1675623	total: 3.63s	remaining: 2.33s
# 609:	learn: 0.1673515	total: 3.64s	remaining: 2.33s
# 610:	learn: 0.1671556	total: 3.65s	remaining: 2.32s
# 611:	learn: 0.1668715	total: 3.65s	remaining: 2.31s
# 612:	learn: 0.1665852	total: 3.66s	remaining: 2.31s
# 613:	learn: 0.1663876	total: 3.66s	remaining: 2.3s
# 614:	learn: 0.1661488	total: 3.67s	remaining: 2.3s
# 615:	learn: 0.1659204	total: 3.67s	remaining: 2.29s
# 616:	learn: 0.1658057	total: 3.68s	remaining: 2.28s
# 617:	learn: 0.1653781	total: 3.69s	remaining: 2.28s
# 618:	learn: 0.1650872	total: 3.69s	remaining: 2.27s
# 619:	learn: 0.1648780	total: 3.7s	remaining: 2.27s
# 620:	learn: 0.1646078	total: 3.7s	remaining: 2.26s
# 621:	learn: 0.1644387	total: 3.71s	remaining: 2.25s
# 622:	learn: 0.1640997	total: 3.72s	remaining: 2.25s
# 623:	learn: 0.1638496	total: 3.72s	remaining: 2.24s
# 624:	learn: 0.1636638	total: 3.73s	remaining: 2.24s
# 625:	learn: 0.1634765	total: 3.73s	remaining: 2.23s
# 626:	learn: 0.1632817	total: 3.74s	remaining: 2.22s
# 627:	learn: 0.1630641	total: 3.75s	remaining: 2.22s
# 628:	learn: 0.1627787	total: 3.75s	remaining: 2.21s
# 629:	learn: 0.1626105	total: 3.76s	remaining: 2.21s
# 630:	learn: 0.1623766	total: 3.76s	remaining: 2.2s
# 631:	learn: 0.1620403	total: 3.77s	remaining: 2.19s
# 632:	learn: 0.1617195	total: 3.77s	remaining: 2.19s
# 633:	learn: 0.1614338	total: 3.78s	remaining: 2.18s
# 634:	learn: 0.1611021	total: 3.79s	remaining: 2.18s
# 635:	learn: 0.1608643	total: 3.79s	remaining: 2.17s
# 636:	learn: 0.1605708	total: 3.8s	remaining: 2.16s
# 637:	learn: 0.1603241	total: 3.8s	remaining: 2.16s
# 638:	learn: 0.1601931	total: 3.81s	remaining: 2.15s
# 639:	learn: 0.1598812	total: 3.82s	remaining: 2.15s
# 640:	learn: 0.1597143	total: 3.82s	remaining: 2.14s
# 641:	learn: 0.1594695	total: 3.83s	remaining: 2.14s
# 642:	learn: 0.1592751	total: 3.84s	remaining: 2.13s
# 643:	learn: 0.1590842	total: 3.85s	remaining: 2.13s
# 644:	learn: 0.1587823	total: 3.85s	remaining: 2.12s
# 645:	learn: 0.1584971	total: 3.86s	remaining: 2.12s
# 646:	learn: 0.1582215	total: 3.87s	remaining: 2.11s
# 647:	learn: 0.1580796	total: 3.87s	remaining: 2.1s
# 648:	learn: 0.1578259	total: 3.88s	remaining: 2.1s
# 649:	learn: 0.1575422	total: 3.89s	remaining: 2.09s
# 650:	learn: 0.1573306	total: 3.89s	remaining: 2.09s
# 651:	learn: 0.1571418	total: 3.9s	remaining: 2.08s
# 652:	learn: 0.1568718	total: 3.9s	remaining: 2.08s
# 653:	learn: 0.1565206	total: 3.91s	remaining: 2.07s
# 654:	learn: 0.1563018	total: 3.92s	remaining: 2.06s
# 655:	learn: 0.1560867	total: 3.92s	remaining: 2.06s
# 656:	learn: 0.1559453	total: 3.93s	remaining: 2.05s
# 657:	learn: 0.1556919	total: 3.94s	remaining: 2.05s
# 658:	learn: 0.1553991	total: 3.94s	remaining: 2.04s
# 659:	learn: 0.1552039	total: 3.96s	remaining: 2.04s
# 660:	learn: 0.1549247	total: 3.97s	remaining: 2.03s
# 661:	learn: 0.1546980	total: 3.97s	remaining: 2.03s
# 662:	learn: 0.1545793	total: 3.98s	remaining: 2.02s
# 663:	learn: 0.1543947	total: 3.98s	remaining: 2.02s
# 664:	learn: 0.1541268	total: 3.99s	remaining: 2.01s
# 665:	learn: 0.1539201	total: 4s	remaining: 2s
# 666:	learn: 0.1536590	total: 4s	remaining: 2s
# 667:	learn: 0.1534835	total: 4.01s	remaining: 1.99s
# 668:	learn: 0.1532214	total: 4.02s	remaining: 1.99s
# 669:	learn: 0.1530560	total: 4.02s	remaining: 1.98s
# 670:	learn: 0.1528723	total: 4.03s	remaining: 1.98s
# 671:	learn: 0.1526664	total: 4.04s	remaining: 1.97s
# 672:	learn: 0.1524661	total: 4.04s	remaining: 1.96s
# 673:	learn: 0.1522416	total: 4.05s	remaining: 1.96s
# 674:	learn: 0.1519960	total: 4.05s	remaining: 1.95s
# 675:	learn: 0.1517006	total: 4.06s	remaining: 1.95s
# 676:	learn: 0.1515659	total: 4.07s	remaining: 1.94s
# 677:	learn: 0.1514651	total: 4.07s	remaining: 1.93s
# 678:	learn: 0.1512083	total: 4.08s	remaining: 1.93s
# 679:	learn: 0.1510557	total: 4.08s	remaining: 1.92s
# 680:	learn: 0.1509205	total: 4.09s	remaining: 1.92s
# 681:	learn: 0.1507053	total: 4.1s	remaining: 1.91s
# 682:	learn: 0.1503950	total: 4.1s	remaining: 1.9s
# 683:	learn: 0.1502117	total: 4.11s	remaining: 1.9s
# 684:	learn: 0.1499625	total: 4.12s	remaining: 1.89s
# 685:	learn: 0.1498216	total: 4.12s	remaining: 1.89s
# 686:	learn: 0.1495498	total: 4.13s	remaining: 1.88s
# 687:	learn: 0.1493333	total: 4.13s	remaining: 1.88s
# 688:	learn: 0.1490321	total: 4.14s	remaining: 1.87s
# 689:	learn: 0.1488936	total: 4.15s	remaining: 1.86s
# 690:	learn: 0.1486849	total: 4.15s	remaining: 1.86s
# 691:	learn: 0.1485360	total: 4.16s	remaining: 1.85s
# 692:	learn: 0.1483257	total: 4.17s	remaining: 1.84s
# 693:	learn: 0.1481709	total: 4.18s	remaining: 1.84s
# 694:	learn: 0.1479313	total: 4.18s	remaining: 1.84s
# 695:	learn: 0.1476565	total: 4.19s	remaining: 1.83s
# 696:	learn: 0.1474229	total: 4.2s	remaining: 1.82s
# 697:	learn: 0.1470335	total: 4.2s	remaining: 1.82s
# 698:	learn: 0.1467183	total: 4.21s	remaining: 1.81s
# 699:	learn: 0.1464996	total: 4.22s	remaining: 1.81s
# 700:	learn: 0.1463752	total: 4.22s	remaining: 1.8s
# 701:	learn: 0.1461766	total: 4.23s	remaining: 1.79s
# 702:	learn: 0.1460478	total: 4.23s	remaining: 1.79s
# 703:	learn: 0.1457255	total: 4.24s	remaining: 1.78s
# 704:	learn: 0.1455151	total: 4.25s	remaining: 1.78s
# 705:	learn: 0.1453176	total: 4.25s	remaining: 1.77s
# 706:	learn: 0.1451770	total: 4.26s	remaining: 1.76s
# 707:	learn: 0.1449240	total: 4.26s	remaining: 1.76s
# 708:	learn: 0.1446511	total: 4.27s	remaining: 1.75s
# 709:	learn: 0.1443897	total: 4.28s	remaining: 1.75s
# 710:	learn: 0.1443033	total: 4.28s	remaining: 1.74s
# 711:	learn: 0.1441257	total: 4.29s	remaining: 1.74s
# 712:	learn: 0.1439948	total: 4.3s	remaining: 1.73s
# 713:	learn: 0.1439100	total: 4.3s	remaining: 1.72s
# 714:	learn: 0.1437227	total: 4.31s	remaining: 1.72s
# 715:	learn: 0.1434573	total: 4.32s	remaining: 1.71s
# 716:	learn: 0.1432035	total: 4.32s	remaining: 1.71s
# 717:	learn: 0.1429223	total: 4.33s	remaining: 1.7s
# 718:	learn: 0.1428147	total: 4.34s	remaining: 1.7s
# 719:	learn: 0.1425278	total: 4.34s	remaining: 1.69s
# 720:	learn: 0.1422349	total: 4.35s	remaining: 1.68s
# 721:	learn: 0.1420355	total: 4.36s	remaining: 1.68s
# 722:	learn: 0.1418123	total: 4.36s	remaining: 1.67s
# 723:	learn: 0.1416274	total: 4.37s	remaining: 1.67s
# 724:	learn: 0.1414080	total: 4.37s	remaining: 1.66s
# 725:	learn: 0.1411801	total: 4.38s	remaining: 1.65s
# 726:	learn: 0.1410056	total: 4.39s	remaining: 1.65s
# 727:	learn: 0.1408389	total: 4.39s	remaining: 1.64s
# 728:	learn: 0.1406307	total: 4.4s	remaining: 1.64s
# 729:	learn: 0.1404639	total: 4.41s	remaining: 1.63s
# 730:	learn: 0.1402709	total: 4.41s	remaining: 1.62s
# 731:	learn: 0.1400831	total: 4.42s	remaining: 1.62s
# 732:	learn: 0.1398787	total: 4.42s	remaining: 1.61s
# 733:	learn: 0.1396818	total: 4.43s	remaining: 1.61s
# 734:	learn: 0.1395513	total: 4.44s	remaining: 1.6s
# 735:	learn: 0.1394150	total: 4.44s	remaining: 1.59s
# 736:	learn: 0.1391813	total: 4.45s	remaining: 1.59s
# 737:	learn: 0.1390453	total: 4.46s	remaining: 1.58s
# 738:	learn: 0.1388877	total: 4.46s	remaining: 1.57s
# 739:	learn: 0.1386859	total: 4.47s	remaining: 1.57s
# 740:	learn: 0.1385361	total: 4.47s	remaining: 1.56s
# 741:	learn: 0.1384007	total: 4.48s	remaining: 1.56s
# 742:	learn: 0.1381545	total: 4.49s	remaining: 1.55s
# 743:	learn: 0.1379904	total: 4.49s	remaining: 1.54s
# 744:	learn: 0.1377968	total: 4.5s	remaining: 1.54s
# 745:	learn: 0.1376195	total: 4.5s	remaining: 1.53s
# 746:	learn: 0.1375276	total: 4.51s	remaining: 1.53s
# 747:	learn: 0.1372272	total: 4.51s	remaining: 1.52s
# 748:	learn: 0.1371151	total: 4.52s	remaining: 1.51s
# 749:	learn: 0.1368889	total: 4.53s	remaining: 1.51s
# 750:	learn: 0.1366255	total: 4.53s	remaining: 1.5s
# 751:	learn: 0.1365185	total: 4.54s	remaining: 1.5s
# 752:	learn: 0.1363532	total: 4.54s	remaining: 1.49s
# 753:	learn: 0.1361109	total: 4.55s	remaining: 1.48s
# 754:	learn: 0.1359309	total: 4.55s	remaining: 1.48s
# 755:	learn: 0.1356922	total: 4.56s	remaining: 1.47s
# 756:	learn: 0.1355621	total: 4.57s	remaining: 1.47s
# 757:	learn: 0.1352283	total: 4.57s	remaining: 1.46s
# 758:	learn: 0.1349841	total: 4.58s	remaining: 1.45s
# 759:	learn: 0.1348503	total: 4.58s	remaining: 1.45s
# 760:	learn: 0.1347046	total: 4.59s	remaining: 1.44s
# 761:	learn: 0.1345086	total: 4.6s	remaining: 1.44s
# 762:	learn: 0.1342583	total: 4.6s	remaining: 1.43s
# 763:	learn: 0.1339848	total: 4.61s	remaining: 1.42s
# 764:	learn: 0.1338001	total: 4.61s	remaining: 1.42s
# 765:	learn: 0.1335983	total: 4.62s	remaining: 1.41s
# 766:	learn: 0.1334336	total: 4.63s	remaining: 1.41s
# 767:	learn: 0.1332504	total: 4.63s	remaining: 1.4s
# 768:	learn: 0.1330833	total: 4.64s	remaining: 1.39s
# 769:	learn: 0.1328876	total: 4.64s	remaining: 1.39s
# 770:	learn: 0.1327393	total: 4.65s	remaining: 1.38s
# 771:	learn: 0.1324978	total: 4.65s	remaining: 1.37s
# 772:	learn: 0.1324183	total: 4.66s	remaining: 1.37s
# 773:	learn: 0.1321062	total: 4.67s	remaining: 1.36s
# 774:	learn: 0.1320173	total: 4.67s	remaining: 1.36s
# 775:	learn: 0.1318524	total: 4.68s	remaining: 1.35s
# 776:	learn: 0.1316648	total: 4.68s	remaining: 1.34s
# 777:	learn: 0.1315265	total: 4.69s	remaining: 1.34s
# 778:	learn: 0.1313551	total: 4.69s	remaining: 1.33s
# 779:	learn: 0.1311272	total: 4.7s	remaining: 1.32s
# 780:	learn: 0.1308342	total: 4.71s	remaining: 1.32s
# 781:	learn: 0.1306824	total: 4.71s	remaining: 1.31s
# 782:	learn: 0.1305203	total: 4.72s	remaining: 1.31s
# 783:	learn: 0.1304610	total: 4.72s	remaining: 1.3s
# 784:	learn: 0.1302591	total: 4.73s	remaining: 1.29s
# 785:	learn: 0.1300357	total: 4.74s	remaining: 1.29s
# 786:	learn: 0.1299230	total: 4.74s	remaining: 1.28s
# 787:	learn: 0.1297098	total: 4.75s	remaining: 1.28s
# 788:	learn: 0.1295270	total: 4.75s	remaining: 1.27s
# 789:	learn: 0.1293400	total: 4.76s	remaining: 1.26s
# 790:	learn: 0.1291680	total: 4.76s	remaining: 1.26s
# 791:	learn: 0.1290543	total: 4.77s	remaining: 1.25s
# 792:	learn: 0.1287719	total: 4.78s	remaining: 1.25s
# 793:	learn: 0.1286050	total: 4.78s	remaining: 1.24s
# 794:	learn: 0.1284419	total: 4.79s	remaining: 1.23s
# 795:	learn: 0.1283499	total: 4.79s	remaining: 1.23s
# 796:	learn: 0.1280538	total: 4.8s	remaining: 1.22s
# 797:	learn: 0.1278566	total: 4.8s	remaining: 1.22s
# 798:	learn: 0.1277525	total: 4.81s	remaining: 1.21s
# 799:	learn: 0.1276009	total: 4.82s	remaining: 1.2s
# 800:	learn: 0.1273462	total: 4.82s	remaining: 1.2s
# 801:	learn: 0.1271685	total: 4.83s	remaining: 1.19s
# 802:	learn: 0.1270208	total: 4.83s	remaining: 1.19s
# 803:	learn: 0.1267925	total: 4.84s	remaining: 1.18s
# 804:	learn: 0.1265919	total: 4.85s	remaining: 1.17s
# 805:	learn: 0.1264285	total: 4.85s	remaining: 1.17s
# 806:	learn: 0.1263446	total: 4.86s	remaining: 1.16s
# 807:	learn: 0.1261925	total: 4.86s	remaining: 1.16s
# 808:	learn: 0.1260376	total: 4.87s	remaining: 1.15s
# 809:	learn: 0.1259271	total: 4.88s	remaining: 1.14s
# 810:	learn: 0.1257247	total: 4.88s	remaining: 1.14s
# 811:	learn: 0.1256289	total: 4.89s	remaining: 1.13s
# 812:	learn: 0.1254022	total: 4.89s	remaining: 1.13s
# 813:	learn: 0.1252950	total: 4.9s	remaining: 1.12s
# 814:	learn: 0.1251599	total: 4.91s	remaining: 1.11s
# 815:	learn: 0.1249640	total: 4.91s	remaining: 1.11s
# 816:	learn: 0.1246779	total: 4.92s	remaining: 1.1s
# 817:	learn: 0.1244091	total: 4.92s	remaining: 1.09s
# 818:	learn: 0.1242462	total: 4.93s	remaining: 1.09s
# 819:	learn: 0.1241338	total: 4.93s	remaining: 1.08s
# 820:	learn: 0.1240040	total: 4.94s	remaining: 1.08s
# 821:	learn: 0.1237548	total: 4.95s	remaining: 1.07s
# 822:	learn: 0.1235297	total: 4.95s	remaining: 1.06s
# 823:	learn: 0.1234051	total: 4.96s	remaining: 1.06s
# 824:	learn: 0.1232851	total: 4.96s	remaining: 1.05s
# 825:	learn: 0.1231233	total: 4.97s	remaining: 1.05s
# 826:	learn: 0.1228552	total: 4.98s	remaining: 1.04s
# 827:	learn: 0.1226511	total: 4.98s	remaining: 1.03s
# 828:	learn: 0.1224741	total: 4.99s	remaining: 1.03s
# 829:	learn: 0.1222610	total: 5s	remaining: 1.02s
# 830:	learn: 0.1221529	total: 5s	remaining: 1.02s
# 831:	learn: 0.1220030	total: 5.01s	remaining: 1.01s
# 832:	learn: 0.1218712	total: 5.01s	remaining: 1s
# 833:	learn: 0.1217805	total: 5.02s	remaining: 999ms
# 834:	learn: 0.1215975	total: 5.02s	remaining: 993ms
# 835:	learn: 0.1214856	total: 5.03s	remaining: 987ms
# 836:	learn: 0.1214046	total: 5.04s	remaining: 981ms
# 837:	learn: 0.1211257	total: 5.04s	remaining: 975ms
# 838:	learn: 0.1209526	total: 5.05s	remaining: 969ms
# 839:	learn: 0.1207119	total: 5.05s	remaining: 963ms
# 840:	learn: 0.1205880	total: 5.06s	remaining: 956ms
# 841:	learn: 0.1204401	total: 5.06s	remaining: 950ms
# 842:	learn: 0.1203166	total: 5.07s	remaining: 944ms
# 843:	learn: 0.1202170	total: 5.08s	remaining: 938ms
# 844:	learn: 0.1199819	total: 5.08s	remaining: 932ms
# 845:	learn: 0.1198778	total: 5.09s	remaining: 926ms
# 846:	learn: 0.1197521	total: 5.09s	remaining: 920ms
# 847:	learn: 0.1195803	total: 5.1s	remaining: 914ms
# 848:	learn: 0.1193511	total: 5.11s	remaining: 908ms
# 849:	learn: 0.1191546	total: 5.11s	remaining: 902ms
# 850:	learn: 0.1189776	total: 5.12s	remaining: 896ms
# 851:	learn: 0.1188644	total: 5.12s	remaining: 890ms
# 852:	learn: 0.1186648	total: 5.13s	remaining: 884ms
# 853:	learn: 0.1185043	total: 5.13s	remaining: 878ms
# 854:	learn: 0.1183942	total: 5.14s	remaining: 872ms
# 855:	learn: 0.1183065	total: 5.14s	remaining: 866ms
# 856:	learn: 0.1180612	total: 5.15s	remaining: 859ms
# 857:	learn: 0.1179839	total: 5.16s	remaining: 853ms
# 858:	learn: 0.1177300	total: 5.16s	remaining: 847ms
# 859:	learn: 0.1174867	total: 5.17s	remaining: 841ms
# 860:	learn: 0.1172798	total: 5.17s	remaining: 835ms
# 861:	learn: 0.1171469	total: 5.18s	remaining: 829ms
# 862:	learn: 0.1170371	total: 5.18s	remaining: 823ms
# 863:	learn: 0.1168339	total: 5.19s	remaining: 816ms
# 864:	learn: 0.1166769	total: 5.19s	remaining: 810ms
# 865:	learn: 0.1165180	total: 5.2s	remaining: 804ms
# 866:	learn: 0.1162967	total: 5.2s	remaining: 798ms
# 867:	learn: 0.1161742	total: 5.21s	remaining: 792ms
# 868:	learn: 0.1159663	total: 5.21s	remaining: 786ms
# 869:	learn: 0.1157935	total: 5.22s	remaining: 780ms
# 870:	learn: 0.1157280	total: 5.23s	remaining: 774ms
# 871:	learn: 0.1155975	total: 5.23s	remaining: 768ms
# 872:	learn: 0.1153870	total: 5.24s	remaining: 762ms
# 873:	learn: 0.1151564	total: 5.24s	remaining: 756ms
# 874:	learn: 0.1148742	total: 5.25s	remaining: 750ms
# 875:	learn: 0.1146691	total: 5.26s	remaining: 744ms
# 876:	learn: 0.1144816	total: 5.26s	remaining: 738ms
# 877:	learn: 0.1143035	total: 5.27s	remaining: 732ms
# 878:	learn: 0.1141591	total: 5.27s	remaining: 726ms
# 879:	learn: 0.1139957	total: 5.28s	remaining: 720ms
# 880:	learn: 0.1138921	total: 5.29s	remaining: 714ms
# 881:	learn: 0.1137267	total: 5.29s	remaining: 708ms
# 882:	learn: 0.1134712	total: 5.3s	remaining: 702ms
# 883:	learn: 0.1133357	total: 5.3s	remaining: 696ms
# 884:	learn: 0.1132800	total: 5.31s	remaining: 690ms
# 885:	learn: 0.1131422	total: 5.31s	remaining: 684ms
# 886:	learn: 0.1130068	total: 5.32s	remaining: 678ms
# 887:	learn: 0.1128939	total: 5.33s	remaining: 672ms
# 888:	learn: 0.1128077	total: 5.33s	remaining: 666ms
# 889:	learn: 0.1127029	total: 5.34s	remaining: 660ms
# 890:	learn: 0.1125491	total: 5.34s	remaining: 654ms
# 891:	learn: 0.1123507	total: 5.35s	remaining: 648ms
# 892:	learn: 0.1122691	total: 5.36s	remaining: 642ms
# 893:	learn: 0.1121011	total: 5.36s	remaining: 636ms
# 894:	learn: 0.1120126	total: 5.37s	remaining: 630ms
# 895:	learn: 0.1118649	total: 5.37s	remaining: 624ms
# 896:	learn: 0.1117230	total: 5.38s	remaining: 618ms
# 897:	learn: 0.1116742	total: 5.38s	remaining: 612ms
# 898:	learn: 0.1115794	total: 5.39s	remaining: 606ms
# 899:	learn: 0.1113590	total: 5.39s	remaining: 600ms
# 900:	learn: 0.1112159	total: 5.4s	remaining: 594ms
# 901:	learn: 0.1111139	total: 5.41s	remaining: 588ms
# 902:	learn: 0.1109024	total: 5.41s	remaining: 581ms
# 903:	learn: 0.1107964	total: 5.42s	remaining: 575ms
# 904:	learn: 0.1106276	total: 5.42s	remaining: 569ms
# 905:	learn: 0.1105377	total: 5.43s	remaining: 563ms
# 906:	learn: 0.1104615	total: 5.44s	remaining: 557ms
# 907:	learn: 0.1102832	total: 5.44s	remaining: 551ms
# 908:	learn: 0.1101439	total: 5.45s	remaining: 545ms
# 909:	learn: 0.1099560	total: 5.45s	remaining: 539ms
# 910:	learn: 0.1097993	total: 5.46s	remaining: 533ms
# 911:	learn: 0.1096180	total: 5.46s	remaining: 527ms
# 912:	learn: 0.1093858	total: 5.47s	remaining: 521ms
# 913:	learn: 0.1092066	total: 5.48s	remaining: 515ms
# 914:	learn: 0.1090781	total: 5.48s	remaining: 509ms
# 915:	learn: 0.1089239	total: 5.49s	remaining: 503ms
# 916:	learn: 0.1087922	total: 5.49s	remaining: 497ms
# 917:	learn: 0.1086767	total: 5.5s	remaining: 491ms
# 918:	learn: 0.1086048	total: 5.5s	remaining: 485ms
# 919:	learn: 0.1085037	total: 5.51s	remaining: 479ms
# 920:	learn: 0.1083152	total: 5.52s	remaining: 473ms
# 921:	learn: 0.1080753	total: 5.52s	remaining: 467ms
# 922:	learn: 0.1079834	total: 5.53s	remaining: 461ms
# 923:	learn: 0.1078925	total: 5.53s	remaining: 455ms
# 924:	learn: 0.1078090	total: 5.54s	remaining: 449ms
# 925:	learn: 0.1076506	total: 5.54s	remaining: 443ms
# 926:	learn: 0.1074685	total: 5.55s	remaining: 437ms
# 927:	learn: 0.1073380	total: 5.56s	remaining: 431ms
# 928:	learn: 0.1072199	total: 5.56s	remaining: 425ms
# 929:	learn: 0.1070797	total: 5.57s	remaining: 419ms
# 930:	learn: 0.1068826	total: 5.58s	remaining: 413ms
# 931:	learn: 0.1067116	total: 5.58s	remaining: 407ms
# 932:	learn: 0.1066749	total: 5.59s	remaining: 401ms
# 933:	learn: 0.1065089	total: 5.59s	remaining: 395ms
# 934:	learn: 0.1064215	total: 5.6s	remaining: 389ms
# 935:	learn: 0.1062979	total: 5.6s	remaining: 383ms
# 936:	learn: 0.1061809	total: 5.61s	remaining: 377ms
# 937:	learn: 0.1060012	total: 5.62s	remaining: 371ms
# 938:	learn: 0.1058450	total: 5.62s	remaining: 365ms
# 939:	learn: 0.1057298	total: 5.63s	remaining: 359ms
# 940:	learn: 0.1056054	total: 5.63s	remaining: 353ms
# 941:	learn: 0.1054265	total: 5.64s	remaining: 347ms
# 942:	learn: 0.1052687	total: 5.64s	remaining: 341ms
# 943:	learn: 0.1051526	total: 5.65s	remaining: 335ms
# 944:	learn: 0.1050210	total: 5.66s	remaining: 329ms
# 945:	learn: 0.1047529	total: 5.66s	remaining: 323ms
# 946:	learn: 0.1046154	total: 5.67s	remaining: 317ms
# 947:	learn: 0.1045157	total: 5.67s	remaining: 311ms
# 948:	learn: 0.1043378	total: 5.68s	remaining: 305ms
# 949:	learn: 0.1042112	total: 5.68s	remaining: 299ms
# 950:	learn: 0.1040693	total: 5.69s	remaining: 293ms
# 951:	learn: 0.1039208	total: 5.7s	remaining: 287ms
# 952:	learn: 0.1038256	total: 5.7s	remaining: 281ms
# 953:	learn: 0.1036687	total: 5.71s	remaining: 275ms
# 954:	learn: 0.1034964	total: 5.71s	remaining: 269ms
# 955:	learn: 0.1033384	total: 5.72s	remaining: 263ms
# 956:	learn: 0.1032325	total: 5.72s	remaining: 257ms
# 957:	learn: 0.1031141	total: 5.73s	remaining: 251ms
# 958:	learn: 0.1029758	total: 5.74s	remaining: 245ms
# 959:	learn: 0.1028704	total: 5.74s	remaining: 239ms
# 960:	learn: 0.1027389	total: 5.75s	remaining: 233ms
# 961:	learn: 0.1025489	total: 5.75s	remaining: 227ms
# 962:	learn: 0.1024479	total: 5.76s	remaining: 221ms
# 963:	learn: 0.1023461	total: 5.77s	remaining: 215ms
# 964:	learn: 0.1022013	total: 5.77s	remaining: 209ms
# 965:	learn: 0.1020491	total: 5.78s	remaining: 203ms
# 966:	learn: 0.1019844	total: 5.78s	remaining: 197ms
# 967:	learn: 0.1017710	total: 5.79s	remaining: 191ms
# 968:	learn: 0.1017011	total: 5.79s	remaining: 185ms
# 969:	learn: 0.1016200	total: 5.8s	remaining: 179ms
# 970:	learn: 0.1015433	total: 5.81s	remaining: 173ms
# 971:	learn: 0.1013977	total: 5.81s	remaining: 167ms
# 972:	learn: 0.1012581	total: 5.82s	remaining: 161ms
# 973:	learn: 0.1011218	total: 5.82s	remaining: 155ms
# 974:	learn: 0.1008996	total: 5.83s	remaining: 150ms
# 975:	learn: 0.1007398	total: 5.84s	remaining: 144ms
# 976:	learn: 0.1006024	total: 5.84s	remaining: 138ms
# 977:	learn: 0.1005217	total: 5.85s	remaining: 132ms
# 978:	learn: 0.1003744	total: 5.85s	remaining: 126ms
# 979:	learn: 0.1002645	total: 5.86s	remaining: 120ms
# 980:	learn: 0.1001192	total: 5.87s	remaining: 114ms
# 981:	learn: 0.1000041	total: 5.87s	remaining: 108ms
# 982:	learn: 0.0998244	total: 5.88s	remaining: 102ms
# 983:	learn: 0.0997495	total: 5.89s	remaining: 95.7ms
# 984:	learn: 0.0995840	total: 5.89s	remaining: 89.7ms
# 985:	learn: 0.0995012	total: 5.9s	remaining: 83.8ms
# 986:	learn: 0.0992927	total: 5.91s	remaining: 77.8ms
# 987:	learn: 0.0991578	total: 5.91s	remaining: 71.8ms
# 988:	learn: 0.0990036	total: 5.92s	remaining: 65.8ms
# 989:	learn: 0.0988641	total: 5.92s	remaining: 59.8ms
# 990:	learn: 0.0987354	total: 5.93s	remaining: 53.9ms
# 991:	learn: 0.0986056	total: 5.94s	remaining: 47.9ms
# 992:	learn: 0.0984857	total: 5.94s	remaining: 41.9ms
# 993:	learn: 0.0982997	total: 5.95s	remaining: 35.9ms
# 994:	learn: 0.0981049	total: 5.96s	remaining: 29.9ms
# 995:	learn: 0.0979501	total: 5.96s	remaining: 23.9ms
# 996:	learn: 0.0978712	total: 5.97s	remaining: 18ms
# 997:	learn: 0.0977178	total: 5.97s	remaining: 12ms
# 998:	learn: 0.0976443	total: 5.98s	remaining: 5.99ms
# 999:	learn: 0.0975699	total: 5.99s	remaining: 0us

# %%
test_pred = clf.predict(test_embeds)
test_proba = clf.predict_proba(test_embeds)[:, 1]

# %%
print("Accuracy:", accuracy_score(target_test, test_pred))
print("ROC-AUC:", roc_auc_score(target_test, test_proba))
# Out:
# Accuracy: 0.726
# ROC-AUC: 0.7927830211587963

# %% [markdown]
# - COLES embeds + Catboost:
#   - `Accuracy: 0.7328 +- 0.0194`
#   -  `ROC-AUC: 0.8057 +- 0.0088`
#
# ---
#
# - COLES embeds + WinAgg (3 trx) + Catboost:
#   - Accuracy: `0.7272 +- 0.0093`
#   - ROC-AUC: `0.7992 +- 0.0078`
#
# ---
#
# - COLES embeds + WinAgg (5 trx) + Catboost:
#   - Accuracy: `0.7192 +- 0.0079`
#   - ROC-AUC: `0.7977 +- 0.0045`
#
# ---
#
# - COLES embeds + WinAgg (10 trx) + Catboost:
#   - Accuracy: `0.7176 +- 0.0108`
#   - ROC-AUC: `0.7896 +- 0.0057`
#
# **Вывод:** для CoLES - чем больше агрегирующее окно, тем хуже результаты. Также результаты очень просели для окна из 10 транзакций => предполагая, что та же тенденция сохраняется и для других моделей, дальше не используем окно такого размера.

# %% [markdown]
# ---

# %% [markdown]
# - **CPC modeling:**

# %%
seed_everything(222)

# %% [markdown]
# **DataLoaders:**

# %%
data = PtlsDataModule(
    train_data=CpcDataset(
        MemoryMapDataset(data=data_train),
        min_len=85,             
        max_len=105
    ),
    train_num_workers=4,
    train_batch_size=128,
    valid_data=CpcDataset(
        MemoryMapDataset(data=data_test),
        min_len=85,
        max_len=105
    ),
    valid_num_workers=4,
    valid_batch_size=128
)

# %% [markdown]
# **Модель:**

# %%
N_EPOCHS = 20

# %%
agg_encoder_params = dict(
    embeddings={
        "MCC": {"in": 342, "out": 32}, # 8 / 16
        "channel_type": {"in": 7, "out": 32},
        "currency": {"in": 60, "out": 32},
        "trx_category": {"in": 11, "out": 32}            
    },
    numeric_values={"amount": "log"},
    embeddings_noise=0.003,
    k=31,
    time_col="event_time",
    agg_samples=6, # 3, 6
    use_window_attention=False
)

trx_encoder = WinAggregator(**agg_encoder_params)

seq_encoder = RnnSeqEncoder(
    trx_encoder=trx_encoder,
    hidden_size=512,
    type="gru"
)

cpc = CpcModule(
    seq_encoder=seq_encoder,
    n_forward_steps=1, # 2, 1
    n_negatives=40,
    optimizer_partial=partial(torch.optim.Adam, lr=5e-4),
    lr_scheduler_partial=partial(torch.optim.lr_scheduler.StepLR, step_size=5, gamma=0.5)
)

# %% [markdown]
# **Обучение:**

# %%
logger = CometLogger(project_name="evs-ssl-rb", experiment_name="CPC_modeling_WinAgg")

trainer = pl.Trainer(
    logger=logger,
    max_epochs=N_EPOCHS,
    accelerator="gpu",
    devices=1,
    enable_progress_bar=True
)

# %%
trainer.fit(cpc, data)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/askoro/evs-ssl-rb/7cd8ca555d9b4e5090ace2a598899e5d
#
# COMET INFO: Couldn't find a Git repository in '/kaggle/working' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loops/fit_loop.py:310: PossibleUserWarning:
#
# The number of training batches (36) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : CPC_modeling_WinAgg
# COMET INFO:     url                   : https://www.comet.com/askoro/evs-ssl-rb/7cd8ca555d9b4e5090ace2a598899e5d
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [86]               : (1.4521113634109497, 4.163649082183838)
# COMET INFO:     seq_len [14]            : (61.9375, 68.0078125)
# COMET INFO:     valid/cpc_accuracy [20] : (0.4018036425113678, 0.6952918171882629)
# COMET INFO:   Others:
# COMET INFO:     Name : CPC_modeling_WinAgg
# COMET INFO:   Parameters:
# COMET INFO:     test_batch_size   : None
# COMET INFO:     test_drop_last    : False
# COMET INFO:     test_num_workers  : None
# COMET INFO:     train_batch_size  : 128
# COMET INFO:     train_drop_last   : False
# COMET INFO:     train_num_workers : 4
# COMET INFO:     valid_batch_size  : 128
# COMET INFO:     valid_drop_last   : False
# COMET INFO:     valid_num_workers : 4
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:

# %%
trainer.logged_metrics
# Out:
# {'loss': tensor(1.9523),
#  'seq_len': tensor(58.2000),
#  'valid/cpc_accuracy': tensor(0.6821)}

# %%
torch.save(seq_encoder.state_dict(), "cpc_enc_baseline_rosbank.pt")

# %% [markdown]
# **Измерим качество на тесте (catboost поверх эмбеддингов):**

# %%
# !wget "https://drive.google.com/uc?export=download&id=11j6QgNsdOSTK-GRaAJLKObDW7ehS_aqK" -O "cpc_enc_baseline_higher_trx_dim.pt"

# %%
encoder = cpc.seq_encoder

# state_dict = torch.load("./cpc_enc_baseline_higher_trx_dim.pt")
# encoder.load_state_dict(state_dict)

device = "cuda:0"

encoder.to(device)
# Out:
# RnnSeqEncoder(
#   (trx_encoder): WinAggregator(
#     (embeddings): ModuleDict(
#       (MCC): NoisyEmbedding(
#         342, 32, padding_idx=0
#         (dropout): Dropout(p=0, inplace=False)
#       )
#       (channel_type): NoisyEmbedding(
#         7, 32, padding_idx=0
#         (dropout): Dropout(p=0, inplace=False)
#       )
#       (currency): NoisyEmbedding(
#         60, 32, padding_idx=0
#         (dropout): Dropout(p=0, inplace=False)
#       )
#       (trx_category): NoisyEmbedding(
#         11, 32, padding_idx=0
#         (dropout): Dropout(p=0, inplace=False)
#       )
#     )
#     (custom_embeddings): ModuleDict(
#       (amount): LogScaler()
#     )
#     (time2vec_days): Time2Vec()
#   )
#   (seq_encoder): RnnEncoder(
#     (rnn): GRU(161, 512, batch_first=True)
#     (reducer): LastStepEncoder()
#   )
# )

# %%
encoder.seq_encoder.is_reduce_sequence = True

# %%
from tqdm import tqdm

seed_everything(222)

# %%
train_loader = inference_data_loader(data_train, num_workers=0, batch_size=128)
encoder.eval()
train_embeds = None

for i, batch in tqdm(enumerate(train_loader)):
    train_embeds_batch = encoder(batch.to(device))
    if i == 0:
        train_embeds = train_embeds_batch.detach().cpu().numpy()
    else:
        train_embeds = np.concatenate([train_embeds, train_embeds_batch.detach().cpu().numpy()], axis=0)
    
train_embeds
# Out:
# 36it [00:00, 48.88it/s]
# array([[-0.17229109,  0.07615294,  0.07387932, ...,  0.0483517 ,
#         -0.01161854, -0.1190909 ],
#        [ 0.17989685,  0.64318675, -0.45537663, ...,  0.58666295,
#          0.37570205,  0.31505302],
#        [ 0.29434347,  0.6613744 , -0.04085184, ...,  0.03814859,
#          0.65302455,  0.18656495],
#        ...,
#        [ 0.55100775,  0.37672985,  0.15035829, ...,  0.58635485,
#          0.37677187, -0.04708023],
#        [ 0.16981274,  0.62859243, -0.3382272 , ...,  0.4807086 ,
#          0.25789702,  0.11205652],
#        [-0.03994576, -0.19041565,  0.13152125, ...,  0.3004274 ,
#          0.02740382,  0.3298819 ]], dtype=float32)

# %%
test_loader = inference_data_loader(data_test, num_workers=0, batch_size=128)
encoder.eval()
test_embeds = None

for i, batch in tqdm(enumerate(test_loader)):
    test_embeds_batch = encoder(batch.to(device))
    if i == 0:
        test_embeds = test_embeds_batch.detach().cpu().numpy()
    else:
        test_embeds = np.concatenate([test_embeds, test_embeds_batch.detach().cpu().numpy()], axis=0)
    
test_embeds
# Out:
# 4it [00:00, 48.91it/s]
# array([[-0.1913497 ,  0.65974444, -0.18446562, ...,  0.46404174,
#          0.48654094,  0.58440626],
#        [-0.07537233,  0.5729245 ,  0.10845622, ...,  0.13441351,
#          0.37286583, -0.30425724],
#        [ 0.18643904,  0.69629174, -0.14590877, ...,  0.22245212,
#          0.33003503,  0.10039242],
#        ...,
#        [ 0.18698406,  0.761091  ,  0.12840372, ...,  0.4177893 ,
#          0.56784433,  0.01461408],
#        [ 0.17908724,  0.46401167,  0.19052406, ...,  0.3157004 ,
#          0.39695886, -0.2815557 ],
#        [-0.04101846,  0.55337816,  0.09129538, ...,  0.54729146,
#          0.4544642 ,  0.12178972]], dtype=float32)

# %%
clf = CatBoostClassifier(loss_function='MultiClass', task_type="GPU", devices='0', random_state=222)

clf.fit(train_embeds, target_train, plot_file="catboost_log.html")
# Out:
# Learning rate set to 0.088214
# 0:	learn: 0.6662335	total: 9.71ms	remaining: 9.71s
# 1:	learn: 0.6430436	total: 16.5ms	remaining: 8.22s
# 2:	learn: 0.6233235	total: 22.8ms	remaining: 7.59s
# 3:	learn: 0.6065900	total: 29.4ms	remaining: 7.33s
# 4:	learn: 0.5912355	total: 36.1ms	remaining: 7.18s
# 5:	learn: 0.5782384	total: 42.8ms	remaining: 7.09s
# 6:	learn: 0.5666390	total: 49.6ms	remaining: 7.03s
# 7:	learn: 0.5558644	total: 56.4ms	remaining: 7s
# 8:	learn: 0.5465631	total: 63.1ms	remaining: 6.95s
# 9:	learn: 0.5381661	total: 69.6ms	remaining: 6.89s
# 10:	learn: 0.5302764	total: 76.4ms	remaining: 6.87s
# 11:	learn: 0.5228521	total: 82.9ms	remaining: 6.83s
# 12:	learn: 0.5167877	total: 89.7ms	remaining: 6.81s
# 13:	learn: 0.5111705	total: 96.4ms	remaining: 6.79s
# 14:	learn: 0.5061233	total: 103ms	remaining: 6.78s
# 15:	learn: 0.5008920	total: 110ms	remaining: 6.78s
# 16:	learn: 0.4959553	total: 117ms	remaining: 6.78s
# 17:	learn: 0.4916247	total: 124ms	remaining: 6.78s
# 18:	learn: 0.4873912	total: 131ms	remaining: 6.77s
# 19:	learn: 0.4839000	total: 139ms	remaining: 6.8s
# 20:	learn: 0.4812536	total: 146ms	remaining: 6.79s
# 21:	learn: 0.4779033	total: 152ms	remaining: 6.77s
# 22:	learn: 0.4750216	total: 159ms	remaining: 6.75s
# 23:	learn: 0.4724584	total: 166ms	remaining: 6.73s
# 24:	learn: 0.4699201	total: 172ms	remaining: 6.71s
# 25:	learn: 0.4679341	total: 179ms	remaining: 6.69s
# 26:	learn: 0.4654614	total: 185ms	remaining: 6.67s
# 27:	learn: 0.4630041	total: 192ms	remaining: 6.66s
# 28:	learn: 0.4607509	total: 198ms	remaining: 6.64s
# 29:	learn: 0.4585789	total: 205ms	remaining: 6.63s
# 30:	learn: 0.4564965	total: 212ms	remaining: 6.62s
# 31:	learn: 0.4546383	total: 218ms	remaining: 6.61s
# 32:	learn: 0.4527938	total: 225ms	remaining: 6.59s
# 33:	learn: 0.4510868	total: 231ms	remaining: 6.57s
# 34:	learn: 0.4488985	total: 238ms	remaining: 6.56s
# 35:	learn: 0.4465405	total: 244ms	remaining: 6.54s
# 36:	learn: 0.4447164	total: 251ms	remaining: 6.53s
# 37:	learn: 0.4430532	total: 257ms	remaining: 6.52s
# 38:	learn: 0.4415777	total: 264ms	remaining: 6.5s
# 39:	learn: 0.4397088	total: 270ms	remaining: 6.49s
# 40:	learn: 0.4382720	total: 277ms	remaining: 6.47s
# 41:	learn: 0.4372137	total: 283ms	remaining: 6.45s
# 42:	learn: 0.4357552	total: 289ms	remaining: 6.44s
# 43:	learn: 0.4347441	total: 296ms	remaining: 6.43s
# 44:	learn: 0.4333065	total: 302ms	remaining: 6.41s
# 45:	learn: 0.4322442	total: 309ms	remaining: 6.4s
# 46:	learn: 0.4311737	total: 315ms	remaining: 6.39s
# 47:	learn: 0.4297733	total: 321ms	remaining: 6.37s
# 48:	learn: 0.4285196	total: 328ms	remaining: 6.36s
# 49:	learn: 0.4274767	total: 334ms	remaining: 6.34s
# 50:	learn: 0.4260541	total: 340ms	remaining: 6.33s
# 51:	learn: 0.4250405	total: 346ms	remaining: 6.32s
# 52:	learn: 0.4235571	total: 353ms	remaining: 6.31s
# 53:	learn: 0.4222064	total: 360ms	remaining: 6.3s
# 54:	learn: 0.4208554	total: 366ms	remaining: 6.3s
# 55:	learn: 0.4198325	total: 373ms	remaining: 6.28s
# 56:	learn: 0.4186210	total: 379ms	remaining: 6.28s
# 57:	learn: 0.4177154	total: 386ms	remaining: 6.27s
# 58:	learn: 0.4164089	total: 392ms	remaining: 6.26s
# 59:	learn: 0.4152530	total: 399ms	remaining: 6.25s
# 60:	learn: 0.4140572	total: 405ms	remaining: 6.23s
# 61:	learn: 0.4130421	total: 411ms	remaining: 6.22s
# 62:	learn: 0.4113618	total: 417ms	remaining: 6.2s
# 63:	learn: 0.4100599	total: 423ms	remaining: 6.19s
# 64:	learn: 0.4088064	total: 429ms	remaining: 6.17s
# 65:	learn: 0.4078570	total: 435ms	remaining: 6.15s
# 66:	learn: 0.4070094	total: 441ms	remaining: 6.14s
# 67:	learn: 0.4060145	total: 447ms	remaining: 6.12s
# 68:	learn: 0.4051325	total: 453ms	remaining: 6.11s
# 69:	learn: 0.4039949	total: 459ms	remaining: 6.09s
# 70:	learn: 0.4029239	total: 465ms	remaining: 6.08s
# 71:	learn: 0.4015232	total: 471ms	remaining: 6.07s
# 72:	learn: 0.4007559	total: 477ms	remaining: 6.05s
# 73:	learn: 0.3999349	total: 482ms	remaining: 6.04s
# 74:	learn: 0.3987287	total: 488ms	remaining: 6.02s
# 75:	learn: 0.3977294	total: 494ms	remaining: 6s
# 76:	learn: 0.3968243	total: 500ms	remaining: 5.99s
# 77:	learn: 0.3956750	total: 506ms	remaining: 5.98s
# 78:	learn: 0.3947159	total: 512ms	remaining: 5.96s
# 79:	learn: 0.3939380	total: 517ms	remaining: 5.95s
# 80:	learn: 0.3929882	total: 523ms	remaining: 5.93s
# 81:	learn: 0.3919115	total: 529ms	remaining: 5.92s
# 82:	learn: 0.3904762	total: 534ms	remaining: 5.9s
# 83:	learn: 0.3894903	total: 540ms	remaining: 5.89s
# 84:	learn: 0.3885363	total: 547ms	remaining: 5.88s
# 85:	learn: 0.3878492	total: 553ms	remaining: 5.87s
# 86:	learn: 0.3868187	total: 559ms	remaining: 5.86s
# 87:	learn: 0.3862821	total: 564ms	remaining: 5.85s
# 88:	learn: 0.3852879	total: 570ms	remaining: 5.84s
# 89:	learn: 0.3845468	total: 576ms	remaining: 5.83s
# 90:	learn: 0.3836471	total: 582ms	remaining: 5.82s
# 91:	learn: 0.3827267	total: 588ms	remaining: 5.8s
# 92:	learn: 0.3818946	total: 594ms	remaining: 5.79s
# 93:	learn: 0.3812646	total: 600ms	remaining: 5.78s
# 94:	learn: 0.3801931	total: 606ms	remaining: 5.77s
# 95:	learn: 0.3790654	total: 612ms	remaining: 5.76s
# 96:	learn: 0.3780469	total: 618ms	remaining: 5.75s
# 97:	learn: 0.3771458	total: 624ms	remaining: 5.75s
# 98:	learn: 0.3763665	total: 630ms	remaining: 5.73s
# 99:	learn: 0.3752960	total: 636ms	remaining: 5.73s
# 100:	learn: 0.3743067	total: 642ms	remaining: 5.72s
# 101:	learn: 0.3729977	total: 649ms	remaining: 5.71s
# 102:	learn: 0.3722846	total: 655ms	remaining: 5.7s
# 103:	learn: 0.3714661	total: 660ms	remaining: 5.69s
# 104:	learn: 0.3707100	total: 666ms	remaining: 5.68s
# 105:	learn: 0.3701496	total: 672ms	remaining: 5.67s
# 106:	learn: 0.3690747	total: 678ms	remaining: 5.66s
# 107:	learn: 0.3681648	total: 684ms	remaining: 5.65s
# 108:	learn: 0.3674924	total: 689ms	remaining: 5.63s
# 109:	learn: 0.3666381	total: 696ms	remaining: 5.63s
# 110:	learn: 0.3656713	total: 702ms	remaining: 5.62s
# 111:	learn: 0.3650643	total: 708ms	remaining: 5.61s
# 112:	learn: 0.3644458	total: 713ms	remaining: 5.6s
# 113:	learn: 0.3636244	total: 719ms	remaining: 5.59s
# 114:	learn: 0.3627549	total: 725ms	remaining: 5.58s
# 115:	learn: 0.3616940	total: 731ms	remaining: 5.57s
# 116:	learn: 0.3609738	total: 736ms	remaining: 5.56s
# 117:	learn: 0.3601606	total: 743ms	remaining: 5.55s
# 118:	learn: 0.3595329	total: 749ms	remaining: 5.54s
# 119:	learn: 0.3587481	total: 755ms	remaining: 5.53s
# 120:	learn: 0.3580231	total: 760ms	remaining: 5.52s
# 121:	learn: 0.3571013	total: 767ms	remaining: 5.52s
# 122:	learn: 0.3563367	total: 773ms	remaining: 5.51s
# 123:	learn: 0.3555455	total: 779ms	remaining: 5.5s
# 124:	learn: 0.3549373	total: 784ms	remaining: 5.49s
# 125:	learn: 0.3542050	total: 791ms	remaining: 5.48s
# 126:	learn: 0.3533275	total: 797ms	remaining: 5.48s
# 127:	learn: 0.3526806	total: 803ms	remaining: 5.47s
# 128:	learn: 0.3520504	total: 809ms	remaining: 5.46s
# 129:	learn: 0.3514958	total: 814ms	remaining: 5.45s
# 130:	learn: 0.3503630	total: 821ms	remaining: 5.44s
# 131:	learn: 0.3492772	total: 827ms	remaining: 5.43s
# 132:	learn: 0.3486334	total: 833ms	remaining: 5.43s
# 133:	learn: 0.3478418	total: 839ms	remaining: 5.42s
# 134:	learn: 0.3471183	total: 844ms	remaining: 5.41s
# 135:	learn: 0.3465100	total: 850ms	remaining: 5.4s
# 136:	learn: 0.3459237	total: 856ms	remaining: 5.39s
# 137:	learn: 0.3450177	total: 863ms	remaining: 5.39s
# 138:	learn: 0.3443041	total: 869ms	remaining: 5.38s
# 139:	learn: 0.3434288	total: 876ms	remaining: 5.38s
# 140:	learn: 0.3426181	total: 882ms	remaining: 5.37s
# 141:	learn: 0.3421233	total: 888ms	remaining: 5.37s
# 142:	learn: 0.3415888	total: 894ms	remaining: 5.36s
# 143:	learn: 0.3410433	total: 901ms	remaining: 5.35s
# 144:	learn: 0.3403699	total: 907ms	remaining: 5.34s
# 145:	learn: 0.3399675	total: 912ms	remaining: 5.33s
# 146:	learn: 0.3394671	total: 918ms	remaining: 5.33s
# 147:	learn: 0.3388881	total: 923ms	remaining: 5.32s
# 148:	learn: 0.3383749	total: 929ms	remaining: 5.31s
# 149:	learn: 0.3375735	total: 935ms	remaining: 5.3s
# 150:	learn: 0.3367359	total: 941ms	remaining: 5.29s
# 151:	learn: 0.3360285	total: 947ms	remaining: 5.28s
# 152:	learn: 0.3353994	total: 953ms	remaining: 5.27s
# 153:	learn: 0.3347670	total: 958ms	remaining: 5.26s
# 154:	learn: 0.3338077	total: 964ms	remaining: 5.25s
# 155:	learn: 0.3326999	total: 970ms	remaining: 5.25s
# 156:	learn: 0.3320075	total: 977ms	remaining: 5.24s
# 157:	learn: 0.3313064	total: 983ms	remaining: 5.24s
# 158:	learn: 0.3306389	total: 989ms	remaining: 5.23s
# 159:	learn: 0.3300348	total: 995ms	remaining: 5.22s
# 160:	learn: 0.3293573	total: 1s	remaining: 5.22s
# 161:	learn: 0.3286898	total: 1.01s	remaining: 5.22s
# 162:	learn: 0.3278615	total: 1.01s	remaining: 5.22s
# 163:	learn: 0.3273646	total: 1.02s	remaining: 5.21s
# 164:	learn: 0.3268414	total: 1.03s	remaining: 5.21s
# 165:	learn: 0.3261284	total: 1.04s	remaining: 5.21s
# 166:	learn: 0.3255601	total: 1.04s	remaining: 5.22s
# 167:	learn: 0.3249135	total: 1.05s	remaining: 5.21s
# 168:	learn: 0.3241386	total: 1.06s	remaining: 5.21s
# 169:	learn: 0.3234322	total: 1.07s	remaining: 5.21s
# 170:	learn: 0.3224659	total: 1.07s	remaining: 5.21s
# 171:	learn: 0.3219148	total: 1.08s	remaining: 5.22s
# 172:	learn: 0.3214428	total: 1.09s	remaining: 5.22s
# 173:	learn: 0.3208168	total: 1.1s	remaining: 5.22s
# 174:	learn: 0.3202515	total: 1.1s	remaining: 5.21s
# 175:	learn: 0.3195049	total: 1.11s	remaining: 5.21s
# 176:	learn: 0.3188901	total: 1.12s	remaining: 5.2s
# 177:	learn: 0.3184760	total: 1.12s	remaining: 5.19s
# 178:	learn: 0.3179263	total: 1.13s	remaining: 5.19s
# 179:	learn: 0.3172193	total: 1.14s	remaining: 5.18s
# 180:	learn: 0.3164383	total: 1.14s	remaining: 5.18s
# 181:	learn: 0.3156563	total: 1.15s	remaining: 5.17s
# 182:	learn: 0.3151521	total: 1.16s	remaining: 5.17s
# 183:	learn: 0.3144830	total: 1.16s	remaining: 5.16s
# 184:	learn: 0.3138053	total: 1.17s	remaining: 5.16s
# 185:	learn: 0.3130591	total: 1.18s	remaining: 5.15s
# 186:	learn: 0.3119779	total: 1.18s	remaining: 5.15s
# 187:	learn: 0.3113660	total: 1.19s	remaining: 5.14s
# 188:	learn: 0.3107688	total: 1.2s	remaining: 5.14s
# 189:	learn: 0.3103908	total: 1.2s	remaining: 5.13s
# 190:	learn: 0.3095892	total: 1.21s	remaining: 5.12s
# 191:	learn: 0.3089221	total: 1.22s	remaining: 5.12s
# 192:	learn: 0.3081457	total: 1.22s	remaining: 5.11s
# 193:	learn: 0.3072891	total: 1.23s	remaining: 5.11s
# 194:	learn: 0.3067755	total: 1.24s	remaining: 5.1s
# 195:	learn: 0.3059886	total: 1.24s	remaining: 5.09s
# 196:	learn: 0.3051375	total: 1.25s	remaining: 5.09s
# 197:	learn: 0.3045506	total: 1.25s	remaining: 5.08s
# 198:	learn: 0.3037955	total: 1.26s	remaining: 5.08s
# 199:	learn: 0.3032486	total: 1.27s	remaining: 5.07s
# 200:	learn: 0.3023513	total: 1.27s	remaining: 5.07s
# 201:	learn: 0.3020764	total: 1.28s	remaining: 5.06s
# 202:	learn: 0.3015950	total: 1.29s	remaining: 5.06s
# 203:	learn: 0.3008420	total: 1.29s	remaining: 5.05s
# 204:	learn: 0.3001741	total: 1.3s	remaining: 5.05s
# 205:	learn: 0.2994873	total: 1.31s	remaining: 5.04s
# 206:	learn: 0.2990055	total: 1.31s	remaining: 5.04s
# 207:	learn: 0.2984215	total: 1.32s	remaining: 5.03s
# 208:	learn: 0.2978967	total: 1.33s	remaining: 5.02s
# 209:	learn: 0.2973043	total: 1.33s	remaining: 5.01s
# 210:	learn: 0.2968869	total: 1.34s	remaining: 5s
# 211:	learn: 0.2963993	total: 1.34s	remaining: 5s
# 212:	learn: 0.2958857	total: 1.35s	remaining: 4.99s
# 213:	learn: 0.2954003	total: 1.36s	remaining: 4.98s
# 214:	learn: 0.2947434	total: 1.36s	remaining: 4.97s
# 215:	learn: 0.2940267	total: 1.37s	remaining: 4.96s
# 216:	learn: 0.2934587	total: 1.37s	remaining: 4.96s
# 217:	learn: 0.2929686	total: 1.38s	remaining: 4.95s
# 218:	learn: 0.2924236	total: 1.39s	remaining: 4.94s
# 219:	learn: 0.2917314	total: 1.39s	remaining: 4.93s
# 220:	learn: 0.2911316	total: 1.4s	remaining: 4.92s
# 221:	learn: 0.2904655	total: 1.4s	remaining: 4.92s
# 222:	learn: 0.2898720	total: 1.41s	remaining: 4.91s
# 223:	learn: 0.2891536	total: 1.41s	remaining: 4.9s
# 224:	learn: 0.2885677	total: 1.42s	remaining: 4.89s
# 225:	learn: 0.2882160	total: 1.43s	remaining: 4.88s
# 226:	learn: 0.2874391	total: 1.43s	remaining: 4.87s
# 227:	learn: 0.2866149	total: 1.44s	remaining: 4.86s
# 228:	learn: 0.2862589	total: 1.44s	remaining: 4.86s
# 229:	learn: 0.2857585	total: 1.45s	remaining: 4.85s
# 230:	learn: 0.2854298	total: 1.45s	remaining: 4.84s
# 231:	learn: 0.2845502	total: 1.46s	remaining: 4.83s
# 232:	learn: 0.2841128	total: 1.46s	remaining: 4.82s
# 233:	learn: 0.2835546	total: 1.47s	remaining: 4.81s
# 234:	learn: 0.2832063	total: 1.48s	remaining: 4.8s
# 235:	learn: 0.2828096	total: 1.48s	remaining: 4.79s
# 236:	learn: 0.2824835	total: 1.49s	remaining: 4.79s
# 237:	learn: 0.2820470	total: 1.49s	remaining: 4.78s
# 238:	learn: 0.2815263	total: 1.5s	remaining: 4.77s
# 239:	learn: 0.2809168	total: 1.5s	remaining: 4.76s
# 240:	learn: 0.2802549	total: 1.51s	remaining: 4.75s
# 241:	learn: 0.2799093	total: 1.51s	remaining: 4.75s
# 242:	learn: 0.2794863	total: 1.52s	remaining: 4.74s
# 243:	learn: 0.2789152	total: 1.53s	remaining: 4.73s
# 244:	learn: 0.2784866	total: 1.53s	remaining: 4.73s
# 245:	learn: 0.2779438	total: 1.54s	remaining: 4.72s
# 246:	learn: 0.2774125	total: 1.55s	remaining: 4.71s
# 247:	learn: 0.2769405	total: 1.55s	remaining: 4.71s
# 248:	learn: 0.2764067	total: 1.56s	remaining: 4.7s
# 249:	learn: 0.2758269	total: 1.56s	remaining: 4.69s
# 250:	learn: 0.2754015	total: 1.57s	remaining: 4.68s
# 251:	learn: 0.2747578	total: 1.57s	remaining: 4.67s
# 252:	learn: 0.2741159	total: 1.58s	remaining: 4.67s
# 253:	learn: 0.2735308	total: 1.59s	remaining: 4.66s
# 254:	learn: 0.2729685	total: 1.59s	remaining: 4.65s
# 255:	learn: 0.2724109	total: 1.6s	remaining: 4.64s
# 256:	learn: 0.2719537	total: 1.6s	remaining: 4.64s
# 257:	learn: 0.2715475	total: 1.61s	remaining: 4.63s
# 258:	learn: 0.2711103	total: 1.61s	remaining: 4.62s
# 259:	learn: 0.2704822	total: 1.62s	remaining: 4.61s
# 260:	learn: 0.2699141	total: 1.63s	remaining: 4.61s
# 261:	learn: 0.2693355	total: 1.63s	remaining: 4.6s
# 262:	learn: 0.2690901	total: 1.64s	remaining: 4.59s
# 263:	learn: 0.2682918	total: 1.64s	remaining: 4.58s
# 264:	learn: 0.2674751	total: 1.65s	remaining: 4.58s
# 265:	learn: 0.2669942	total: 1.66s	remaining: 4.57s
# 266:	learn: 0.2666551	total: 1.66s	remaining: 4.56s
# 267:	learn: 0.2658592	total: 1.67s	remaining: 4.55s
# 268:	learn: 0.2653641	total: 1.67s	remaining: 4.54s
# 269:	learn: 0.2648522	total: 1.68s	remaining: 4.54s
# 270:	learn: 0.2642770	total: 1.68s	remaining: 4.53s
# 271:	learn: 0.2633995	total: 1.69s	remaining: 4.52s
# 272:	learn: 0.2629559	total: 1.7s	remaining: 4.52s
# 273:	learn: 0.2625647	total: 1.7s	remaining: 4.51s
# 274:	learn: 0.2621615	total: 1.71s	remaining: 4.5s
# 275:	learn: 0.2618675	total: 1.71s	remaining: 4.49s
# 276:	learn: 0.2614466	total: 1.72s	remaining: 4.49s
# 277:	learn: 0.2610604	total: 1.72s	remaining: 4.48s
# 278:	learn: 0.2604449	total: 1.73s	remaining: 4.47s
# 279:	learn: 0.2598732	total: 1.74s	remaining: 4.46s
# 280:	learn: 0.2593745	total: 1.74s	remaining: 4.46s
# 281:	learn: 0.2589855	total: 1.75s	remaining: 4.45s
# 282:	learn: 0.2585882	total: 1.75s	remaining: 4.44s
# 283:	learn: 0.2579772	total: 1.76s	remaining: 4.43s
# 284:	learn: 0.2576546	total: 1.76s	remaining: 4.43s
# 285:	learn: 0.2570856	total: 1.77s	remaining: 4.42s
# 286:	learn: 0.2564771	total: 1.78s	remaining: 4.41s
# 287:	learn: 0.2559376	total: 1.78s	remaining: 4.41s
# 288:	learn: 0.2553368	total: 1.79s	remaining: 4.4s
# 289:	learn: 0.2549358	total: 1.79s	remaining: 4.39s
# 290:	learn: 0.2543814	total: 1.8s	remaining: 4.39s
# 291:	learn: 0.2537808	total: 1.81s	remaining: 4.38s
# 292:	learn: 0.2530106	total: 1.81s	remaining: 4.37s
# 293:	learn: 0.2525241	total: 1.82s	remaining: 4.37s
# 294:	learn: 0.2522194	total: 1.82s	remaining: 4.36s
# 295:	learn: 0.2516071	total: 1.83s	remaining: 4.35s
# 296:	learn: 0.2511501	total: 1.83s	remaining: 4.34s
# 297:	learn: 0.2507058	total: 1.84s	remaining: 4.34s
# 298:	learn: 0.2500643	total: 1.85s	remaining: 4.33s
# 299:	learn: 0.2496199	total: 1.85s	remaining: 4.32s
# 300:	learn: 0.2491501	total: 1.86s	remaining: 4.32s
# 301:	learn: 0.2485038	total: 1.86s	remaining: 4.31s
# 302:	learn: 0.2480345	total: 1.87s	remaining: 4.3s
# 303:	learn: 0.2475677	total: 1.88s	remaining: 4.29s
# 304:	learn: 0.2472241	total: 1.88s	remaining: 4.29s
# 305:	learn: 0.2466068	total: 1.89s	remaining: 4.28s
# 306:	learn: 0.2463592	total: 1.89s	remaining: 4.28s
# 307:	learn: 0.2460661	total: 1.9s	remaining: 4.27s
# 308:	learn: 0.2456075	total: 1.91s	remaining: 4.26s
# 309:	learn: 0.2451958	total: 1.91s	remaining: 4.25s
# 310:	learn: 0.2446142	total: 1.92s	remaining: 4.25s
# 311:	learn: 0.2442963	total: 1.92s	remaining: 4.24s
# 312:	learn: 0.2436345	total: 1.93s	remaining: 4.23s
# 313:	learn: 0.2432353	total: 1.94s	remaining: 4.23s
# 314:	learn: 0.2430089	total: 1.94s	remaining: 4.22s
# 315:	learn: 0.2424147	total: 1.95s	remaining: 4.21s
# 316:	learn: 0.2419978	total: 1.95s	remaining: 4.21s
# 317:	learn: 0.2411940	total: 1.96s	remaining: 4.2s
# 318:	learn: 0.2407376	total: 1.97s	remaining: 4.2s
# 319:	learn: 0.2400869	total: 1.97s	remaining: 4.19s
# 320:	learn: 0.2394325	total: 1.98s	remaining: 4.18s
# 321:	learn: 0.2389979	total: 1.98s	remaining: 4.17s
# 322:	learn: 0.2386643	total: 1.99s	remaining: 4.17s
# 323:	learn: 0.2379635	total: 1.99s	remaining: 4.16s
# 324:	learn: 0.2374643	total: 2s	remaining: 4.16s
# 325:	learn: 0.2370705	total: 2.01s	remaining: 4.15s
# 326:	learn: 0.2368746	total: 2.01s	remaining: 4.14s
# 327:	learn: 0.2363862	total: 2.02s	remaining: 4.13s
# 328:	learn: 0.2360134	total: 2.02s	remaining: 4.13s
# 329:	learn: 0.2355846	total: 2.03s	remaining: 4.12s
# 330:	learn: 0.2350865	total: 2.04s	remaining: 4.11s
# 331:	learn: 0.2347714	total: 2.04s	remaining: 4.11s
# 332:	learn: 0.2340616	total: 2.05s	remaining: 4.1s
# 333:	learn: 0.2336306	total: 2.05s	remaining: 4.09s
# 334:	learn: 0.2332064	total: 2.06s	remaining: 4.09s
# 335:	learn: 0.2327454	total: 2.06s	remaining: 4.08s
# 336:	learn: 0.2323840	total: 2.07s	remaining: 4.08s
# 337:	learn: 0.2319122	total: 2.08s	remaining: 4.07s
# 338:	learn: 0.2315216	total: 2.08s	remaining: 4.06s
# 339:	learn: 0.2312301	total: 2.09s	remaining: 4.06s
# 340:	learn: 0.2309280	total: 2.1s	remaining: 4.05s
# 341:	learn: 0.2305947	total: 2.1s	remaining: 4.04s
# 342:	learn: 0.2302304	total: 2.11s	remaining: 4.04s
# 343:	learn: 0.2297176	total: 2.11s	remaining: 4.03s
# 344:	learn: 0.2293212	total: 2.12s	remaining: 4.02s
# 345:	learn: 0.2288327	total: 2.13s	remaining: 4.02s
# 346:	learn: 0.2284629	total: 2.13s	remaining: 4.01s
# 347:	learn: 0.2280642	total: 2.14s	remaining: 4s
# 348:	learn: 0.2274807	total: 2.14s	remaining: 4s
# 349:	learn: 0.2272156	total: 2.15s	remaining: 3.99s
# 350:	learn: 0.2266635	total: 2.16s	remaining: 3.99s
# 351:	learn: 0.2262498	total: 2.16s	remaining: 3.98s
# 352:	learn: 0.2259043	total: 2.17s	remaining: 3.98s
# 353:	learn: 0.2255138	total: 2.17s	remaining: 3.97s
# 354:	learn: 0.2250199	total: 2.18s	remaining: 3.96s
# 355:	learn: 0.2245794	total: 2.19s	remaining: 3.96s
# 356:	learn: 0.2241727	total: 2.19s	remaining: 3.95s
# 357:	learn: 0.2237475	total: 2.2s	remaining: 3.94s
# 358:	learn: 0.2234254	total: 2.21s	remaining: 3.94s
# 359:	learn: 0.2230270	total: 2.21s	remaining: 3.93s
# 360:	learn: 0.2225130	total: 2.22s	remaining: 3.93s
# 361:	learn: 0.2220139	total: 2.22s	remaining: 3.92s
# 362:	learn: 0.2216081	total: 2.23s	remaining: 3.91s
# 363:	learn: 0.2211397	total: 2.24s	remaining: 3.91s
# 364:	learn: 0.2205593	total: 2.24s	remaining: 3.9s
# 365:	learn: 0.2203298	total: 2.25s	remaining: 3.9s
# 366:	learn: 0.2201738	total: 2.25s	remaining: 3.89s
# 367:	learn: 0.2198776	total: 2.26s	remaining: 3.88s
# 368:	learn: 0.2194053	total: 2.27s	remaining: 3.88s
# 369:	learn: 0.2189412	total: 2.27s	remaining: 3.87s
# 370:	learn: 0.2186286	total: 2.28s	remaining: 3.87s
# 371:	learn: 0.2182653	total: 2.29s	remaining: 3.86s
# 372:	learn: 0.2178334	total: 2.29s	remaining: 3.85s
# 373:	learn: 0.2175011	total: 2.3s	remaining: 3.85s
# 374:	learn: 0.2170653	total: 2.3s	remaining: 3.84s
# 375:	learn: 0.2167502	total: 2.31s	remaining: 3.83s
# 376:	learn: 0.2165315	total: 2.32s	remaining: 3.83s
# 377:	learn: 0.2161277	total: 2.32s	remaining: 3.82s
# 378:	learn: 0.2155661	total: 2.33s	remaining: 3.82s
# 379:	learn: 0.2151540	total: 2.33s	remaining: 3.81s
# 380:	learn: 0.2148830	total: 2.34s	remaining: 3.8s
# 381:	learn: 0.2143869	total: 2.35s	remaining: 3.8s
# 382:	learn: 0.2139596	total: 2.35s	remaining: 3.79s
# 383:	learn: 0.2137621	total: 2.36s	remaining: 3.78s
# 384:	learn: 0.2134547	total: 2.37s	remaining: 3.78s
# 385:	learn: 0.2128452	total: 2.37s	remaining: 3.77s
# 386:	learn: 0.2124918	total: 2.38s	remaining: 3.76s
# 387:	learn: 0.2122380	total: 2.38s	remaining: 3.76s
# 388:	learn: 0.2119072	total: 2.39s	remaining: 3.75s
# 389:	learn: 0.2116406	total: 2.39s	remaining: 3.74s
# 390:	learn: 0.2112254	total: 2.4s	remaining: 3.74s
# 391:	learn: 0.2108198	total: 2.4s	remaining: 3.73s
# 392:	learn: 0.2104772	total: 2.41s	remaining: 3.72s
# 393:	learn: 0.2101459	total: 2.42s	remaining: 3.72s
# 394:	learn: 0.2098732	total: 2.42s	remaining: 3.71s
# 395:	learn: 0.2095297	total: 2.43s	remaining: 3.7s
# 396:	learn: 0.2092057	total: 2.43s	remaining: 3.7s
# 397:	learn: 0.2085659	total: 2.44s	remaining: 3.69s
# 398:	learn: 0.2082033	total: 2.44s	remaining: 3.68s
# 399:	learn: 0.2077216	total: 2.45s	remaining: 3.68s
# 400:	learn: 0.2071727	total: 2.46s	remaining: 3.67s
# 401:	learn: 0.2069764	total: 2.46s	remaining: 3.66s
# 402:	learn: 0.2067061	total: 2.47s	remaining: 3.66s
# 403:	learn: 0.2063264	total: 2.47s	remaining: 3.65s
# 404:	learn: 0.2060740	total: 2.48s	remaining: 3.64s
# 405:	learn: 0.2056659	total: 2.48s	remaining: 3.64s
# 406:	learn: 0.2052648	total: 2.49s	remaining: 3.63s
# 407:	learn: 0.2049907	total: 2.5s	remaining: 3.62s
# 408:	learn: 0.2046072	total: 2.5s	remaining: 3.62s
# 409:	learn: 0.2041941	total: 2.51s	remaining: 3.61s
# 410:	learn: 0.2036754	total: 2.51s	remaining: 3.6s
# 411:	learn: 0.2034246	total: 2.52s	remaining: 3.6s
# 412:	learn: 0.2029918	total: 2.52s	remaining: 3.59s
# 413:	learn: 0.2027607	total: 2.53s	remaining: 3.58s
# 414:	learn: 0.2024581	total: 2.54s	remaining: 3.58s
# 415:	learn: 0.2021047	total: 2.54s	remaining: 3.57s
# 416:	learn: 0.2018373	total: 2.55s	remaining: 3.56s
# 417:	learn: 0.2013280	total: 2.55s	remaining: 3.56s
# 418:	learn: 0.2008929	total: 2.56s	remaining: 3.55s
# 419:	learn: 0.2006516	total: 2.57s	remaining: 3.54s
# 420:	learn: 0.2004299	total: 2.57s	remaining: 3.54s
# 421:	learn: 0.2000286	total: 2.58s	remaining: 3.53s
# 422:	learn: 0.1998566	total: 2.58s	remaining: 3.53s
# 423:	learn: 0.1995786	total: 2.59s	remaining: 3.52s
# 424:	learn: 0.1993296	total: 2.6s	remaining: 3.51s
# 425:	learn: 0.1989860	total: 2.6s	remaining: 3.51s
# 426:	learn: 0.1985332	total: 2.61s	remaining: 3.5s
# 427:	learn: 0.1982282	total: 2.62s	remaining: 3.5s
# 428:	learn: 0.1979023	total: 2.62s	remaining: 3.49s
# 429:	learn: 0.1974972	total: 2.63s	remaining: 3.48s
# 430:	learn: 0.1969196	total: 2.63s	remaining: 3.48s
# 431:	learn: 0.1963933	total: 2.64s	remaining: 3.47s
# 432:	learn: 0.1961305	total: 2.65s	remaining: 3.46s
# 433:	learn: 0.1958750	total: 2.65s	remaining: 3.46s
# 434:	learn: 0.1954914	total: 2.66s	remaining: 3.45s
# 435:	learn: 0.1952675	total: 2.66s	remaining: 3.44s
# 436:	learn: 0.1949398	total: 2.67s	remaining: 3.44s
# 437:	learn: 0.1945702	total: 2.67s	remaining: 3.43s
# 438:	learn: 0.1941740	total: 2.68s	remaining: 3.42s
# 439:	learn: 0.1936614	total: 2.69s	remaining: 3.42s
# 440:	learn: 0.1933582	total: 2.69s	remaining: 3.41s
# 441:	learn: 0.1928870	total: 2.7s	remaining: 3.4s
# 442:	learn: 0.1926272	total: 2.7s	remaining: 3.4s
# 443:	learn: 0.1924152	total: 2.71s	remaining: 3.39s
# 444:	learn: 0.1920849	total: 2.71s	remaining: 3.38s
# 445:	learn: 0.1918153	total: 2.72s	remaining: 3.38s
# 446:	learn: 0.1914298	total: 2.73s	remaining: 3.37s
# 447:	learn: 0.1911279	total: 2.73s	remaining: 3.37s
# 448:	learn: 0.1907917	total: 2.74s	remaining: 3.36s
# 449:	learn: 0.1905597	total: 2.74s	remaining: 3.35s
# 450:	learn: 0.1902915	total: 2.75s	remaining: 3.35s
# 451:	learn: 0.1900503	total: 2.75s	remaining: 3.34s
# 452:	learn: 0.1894103	total: 2.76s	remaining: 3.33s
# 453:	learn: 0.1891544	total: 2.77s	remaining: 3.33s
# 454:	learn: 0.1888416	total: 2.77s	remaining: 3.32s
# 455:	learn: 0.1885746	total: 2.78s	remaining: 3.31s
# 456:	learn: 0.1882550	total: 2.78s	remaining: 3.31s
# 457:	learn: 0.1878894	total: 2.79s	remaining: 3.3s
# 458:	learn: 0.1876807	total: 2.79s	remaining: 3.29s
# 459:	learn: 0.1874357	total: 2.8s	remaining: 3.29s
# 460:	learn: 0.1872198	total: 2.81s	remaining: 3.28s
# 461:	learn: 0.1868725	total: 2.81s	remaining: 3.27s
# 462:	learn: 0.1865129	total: 2.82s	remaining: 3.27s
# 463:	learn: 0.1862678	total: 2.82s	remaining: 3.26s
# 464:	learn: 0.1860853	total: 2.83s	remaining: 3.26s
# 465:	learn: 0.1857131	total: 2.84s	remaining: 3.25s
# 466:	learn: 0.1854995	total: 2.84s	remaining: 3.24s
# 467:	learn: 0.1853051	total: 2.85s	remaining: 3.24s
# 468:	learn: 0.1849171	total: 2.85s	remaining: 3.23s
# 469:	learn: 0.1846866	total: 2.86s	remaining: 3.23s
# 470:	learn: 0.1843162	total: 2.87s	remaining: 3.22s
# 471:	learn: 0.1841117	total: 2.87s	remaining: 3.21s
# 472:	learn: 0.1837967	total: 2.88s	remaining: 3.21s
# 473:	learn: 0.1835337	total: 2.88s	remaining: 3.2s
# 474:	learn: 0.1832008	total: 2.89s	remaining: 3.19s
# 475:	learn: 0.1828647	total: 2.89s	remaining: 3.19s
# 476:	learn: 0.1823434	total: 2.9s	remaining: 3.18s
# 477:	learn: 0.1820963	total: 2.91s	remaining: 3.17s
# 478:	learn: 0.1818985	total: 2.91s	remaining: 3.17s
# 479:	learn: 0.1814327	total: 2.92s	remaining: 3.16s
# 480:	learn: 0.1812106	total: 2.92s	remaining: 3.15s
# 481:	learn: 0.1808302	total: 2.93s	remaining: 3.15s
# 482:	learn: 0.1805708	total: 2.94s	remaining: 3.14s
# 483:	learn: 0.1802772	total: 2.94s	remaining: 3.13s
# 484:	learn: 0.1801646	total: 2.95s	remaining: 3.13s
# 485:	learn: 0.1799103	total: 2.95s	remaining: 3.12s
# 486:	learn: 0.1795342	total: 2.96s	remaining: 3.12s
# 487:	learn: 0.1792627	total: 2.96s	remaining: 3.11s
# 488:	learn: 0.1789570	total: 2.97s	remaining: 3.1s
# 489:	learn: 0.1786179	total: 2.98s	remaining: 3.1s
# 490:	learn: 0.1782899	total: 2.98s	remaining: 3.09s
# 491:	learn: 0.1780752	total: 2.99s	remaining: 3.09s
# 492:	learn: 0.1779055	total: 3s	remaining: 3.08s
# 493:	learn: 0.1774390	total: 3s	remaining: 3.08s
# 494:	learn: 0.1770752	total: 3.01s	remaining: 3.07s
# 495:	learn: 0.1768438	total: 3.02s	remaining: 3.06s
# 496:	learn: 0.1766113	total: 3.02s	remaining: 3.06s
# 497:	learn: 0.1764551	total: 3.03s	remaining: 3.05s
# 498:	learn: 0.1761959	total: 3.03s	remaining: 3.04s
# 499:	learn: 0.1759369	total: 3.04s	remaining: 3.04s
# 500:	learn: 0.1757759	total: 3.04s	remaining: 3.03s
# 501:	learn: 0.1754139	total: 3.05s	remaining: 3.03s
# 502:	learn: 0.1750559	total: 3.06s	remaining: 3.02s
# 503:	learn: 0.1747539	total: 3.06s	remaining: 3.01s
# 504:	learn: 0.1744724	total: 3.07s	remaining: 3.01s
# 505:	learn: 0.1741021	total: 3.07s	remaining: 3s
# 506:	learn: 0.1737463	total: 3.08s	remaining: 3s
# 507:	learn: 0.1735435	total: 3.09s	remaining: 2.99s
# 508:	learn: 0.1732543	total: 3.09s	remaining: 2.98s
# 509:	learn: 0.1730499	total: 3.1s	remaining: 2.98s
# 510:	learn: 0.1728157	total: 3.1s	remaining: 2.97s
# 511:	learn: 0.1726024	total: 3.11s	remaining: 2.96s
# 512:	learn: 0.1722845	total: 3.12s	remaining: 2.96s
# 513:	learn: 0.1719195	total: 3.12s	remaining: 2.95s
# 514:	learn: 0.1716186	total: 3.13s	remaining: 2.95s
# 515:	learn: 0.1714207	total: 3.13s	remaining: 2.94s
# 516:	learn: 0.1712067	total: 3.14s	remaining: 2.93s
# 517:	learn: 0.1709439	total: 3.15s	remaining: 2.93s
# 518:	learn: 0.1708315	total: 3.15s	remaining: 2.92s
# 519:	learn: 0.1703989	total: 3.16s	remaining: 2.92s
# 520:	learn: 0.1702029	total: 3.16s	remaining: 2.91s
# 521:	learn: 0.1700448	total: 3.17s	remaining: 2.9s
# 522:	learn: 0.1697005	total: 3.18s	remaining: 2.9s
# 523:	learn: 0.1695469	total: 3.18s	remaining: 2.89s
# 524:	learn: 0.1693241	total: 3.19s	remaining: 2.88s
# 525:	learn: 0.1692031	total: 3.19s	remaining: 2.88s
# 526:	learn: 0.1689251	total: 3.2s	remaining: 2.87s
# 527:	learn: 0.1686429	total: 3.21s	remaining: 2.87s
# 528:	learn: 0.1684975	total: 3.21s	remaining: 2.86s
# 529:	learn: 0.1681386	total: 3.22s	remaining: 2.85s
# 530:	learn: 0.1678580	total: 3.23s	remaining: 2.85s
# 531:	learn: 0.1676963	total: 3.23s	remaining: 2.84s
# 532:	learn: 0.1674567	total: 3.24s	remaining: 2.84s
# 533:	learn: 0.1671435	total: 3.25s	remaining: 2.83s
# 534:	learn: 0.1669265	total: 3.25s	remaining: 2.83s
# 535:	learn: 0.1666356	total: 3.26s	remaining: 2.82s
# 536:	learn: 0.1665408	total: 3.26s	remaining: 2.81s
# 537:	learn: 0.1662751	total: 3.27s	remaining: 2.81s
# 538:	learn: 0.1659818	total: 3.28s	remaining: 2.8s
# 539:	learn: 0.1657509	total: 3.28s	remaining: 2.8s
# 540:	learn: 0.1656046	total: 3.29s	remaining: 2.79s
# 541:	learn: 0.1651151	total: 3.3s	remaining: 2.79s
# 542:	learn: 0.1647391	total: 3.3s	remaining: 2.78s
# 543:	learn: 0.1645796	total: 3.31s	remaining: 2.77s
# 544:	learn: 0.1643420	total: 3.31s	remaining: 2.77s
# 545:	learn: 0.1639651	total: 3.32s	remaining: 2.76s
# 546:	learn: 0.1636933	total: 3.33s	remaining: 2.75s
# 547:	learn: 0.1634807	total: 3.33s	remaining: 2.75s
# 548:	learn: 0.1632296	total: 3.34s	remaining: 2.74s
# 549:	learn: 0.1629812	total: 3.34s	remaining: 2.74s
# 550:	learn: 0.1626663	total: 3.35s	remaining: 2.73s
# 551:	learn: 0.1624906	total: 3.36s	remaining: 2.72s
# 552:	learn: 0.1622303	total: 3.36s	remaining: 2.72s
# 553:	learn: 0.1620910	total: 3.37s	remaining: 2.71s
# 554:	learn: 0.1617284	total: 3.38s	remaining: 2.71s
# 555:	learn: 0.1614757	total: 3.38s	remaining: 2.7s
# 556:	learn: 0.1612842	total: 3.39s	remaining: 2.69s
# 557:	learn: 0.1609702	total: 3.4s	remaining: 2.69s
# 558:	learn: 0.1607382	total: 3.4s	remaining: 2.68s
# 559:	learn: 0.1605611	total: 3.41s	remaining: 2.68s
# 560:	learn: 0.1602588	total: 3.41s	remaining: 2.67s
# 561:	learn: 0.1601008	total: 3.42s	remaining: 2.66s
# 562:	learn: 0.1598343	total: 3.42s	remaining: 2.66s
# 563:	learn: 0.1594820	total: 3.43s	remaining: 2.65s
# 564:	learn: 0.1592676	total: 3.44s	remaining: 2.65s
# 565:	learn: 0.1590043	total: 3.44s	remaining: 2.64s
# 566:	learn: 0.1587620	total: 3.45s	remaining: 2.63s
# 567:	learn: 0.1584061	total: 3.45s	remaining: 2.63s
# 568:	learn: 0.1582427	total: 3.46s	remaining: 2.62s
# 569:	learn: 0.1580791	total: 3.46s	remaining: 2.61s
# 570:	learn: 0.1579342	total: 3.47s	remaining: 2.61s
# 571:	learn: 0.1576422	total: 3.48s	remaining: 2.6s
# 572:	learn: 0.1573542	total: 3.48s	remaining: 2.6s
# 573:	learn: 0.1571377	total: 3.49s	remaining: 2.59s
# 574:	learn: 0.1568051	total: 3.49s	remaining: 2.58s
# 575:	learn: 0.1566604	total: 3.5s	remaining: 2.58s
# 576:	learn: 0.1564670	total: 3.51s	remaining: 2.57s
# 577:	learn: 0.1562637	total: 3.51s	remaining: 2.56s
# 578:	learn: 0.1560410	total: 3.52s	remaining: 2.56s
# 579:	learn: 0.1558048	total: 3.52s	remaining: 2.55s
# 580:	learn: 0.1555501	total: 3.53s	remaining: 2.54s
# 581:	learn: 0.1551623	total: 3.54s	remaining: 2.54s
# 582:	learn: 0.1549353	total: 3.54s	remaining: 2.53s
# 583:	learn: 0.1545587	total: 3.55s	remaining: 2.53s
# 584:	learn: 0.1543732	total: 3.55s	remaining: 2.52s
# 585:	learn: 0.1539595	total: 3.56s	remaining: 2.52s
# 586:	learn: 0.1536721	total: 3.57s	remaining: 2.51s
# 587:	learn: 0.1534718	total: 3.57s	remaining: 2.5s
# 588:	learn: 0.1532816	total: 3.58s	remaining: 2.5s
# 589:	learn: 0.1531634	total: 3.58s	remaining: 2.49s
# 590:	learn: 0.1530058	total: 3.59s	remaining: 2.48s
# 591:	learn: 0.1527064	total: 3.6s	remaining: 2.48s
# 592:	learn: 0.1524821	total: 3.6s	remaining: 2.47s
# 593:	learn: 0.1521425	total: 3.61s	remaining: 2.46s
# 594:	learn: 0.1519322	total: 3.61s	remaining: 2.46s
# 595:	learn: 0.1516952	total: 3.62s	remaining: 2.45s
# 596:	learn: 0.1514336	total: 3.62s	remaining: 2.45s
# 597:	learn: 0.1512139	total: 3.63s	remaining: 2.44s
# 598:	learn: 0.1508859	total: 3.63s	remaining: 2.43s
# 599:	learn: 0.1507511	total: 3.64s	remaining: 2.43s
# 600:	learn: 0.1503996	total: 3.65s	remaining: 2.42s
# 601:	learn: 0.1501457	total: 3.65s	remaining: 2.41s
# 602:	learn: 0.1497165	total: 3.66s	remaining: 2.41s
# 603:	learn: 0.1494958	total: 3.66s	remaining: 2.4s
# 604:	learn: 0.1491917	total: 3.67s	remaining: 2.4s
# 605:	learn: 0.1489288	total: 3.68s	remaining: 2.39s
# 606:	learn: 0.1486798	total: 3.68s	remaining: 2.38s
# 607:	learn: 0.1483295	total: 3.69s	remaining: 2.38s
# 608:	learn: 0.1480592	total: 3.69s	remaining: 2.37s
# 609:	learn: 0.1476925	total: 3.7s	remaining: 2.37s
# 610:	learn: 0.1475189	total: 3.71s	remaining: 2.36s
# 611:	learn: 0.1473451	total: 3.71s	remaining: 2.35s
# 612:	learn: 0.1471076	total: 3.72s	remaining: 2.35s
# 613:	learn: 0.1469054	total: 3.72s	remaining: 2.34s
# 614:	learn: 0.1467400	total: 3.73s	remaining: 2.33s
# 615:	learn: 0.1466126	total: 3.73s	remaining: 2.33s
# 616:	learn: 0.1464719	total: 3.74s	remaining: 2.32s
# 617:	learn: 0.1462530	total: 3.74s	remaining: 2.31s
# 618:	learn: 0.1459762	total: 3.75s	remaining: 2.31s
# 619:	learn: 0.1458232	total: 3.76s	remaining: 2.3s
# 620:	learn: 0.1456213	total: 3.76s	remaining: 2.3s
# 621:	learn: 0.1454034	total: 3.77s	remaining: 2.29s
# 622:	learn: 0.1452479	total: 3.78s	remaining: 2.29s
# 623:	learn: 0.1450075	total: 3.78s	remaining: 2.28s
# 624:	learn: 0.1447728	total: 3.79s	remaining: 2.27s
# 625:	learn: 0.1446309	total: 3.79s	remaining: 2.27s
# 626:	learn: 0.1443757	total: 3.8s	remaining: 2.26s
# 627:	learn: 0.1441739	total: 3.81s	remaining: 2.25s
# 628:	learn: 0.1439811	total: 3.81s	remaining: 2.25s
# 629:	learn: 0.1437508	total: 3.82s	remaining: 2.24s
# 630:	learn: 0.1435387	total: 3.83s	remaining: 2.24s
# 631:	learn: 0.1433575	total: 3.83s	remaining: 2.23s
# 632:	learn: 0.1430970	total: 3.84s	remaining: 2.23s
# 633:	learn: 0.1427780	total: 3.85s	remaining: 2.22s
# 634:	learn: 0.1425468	total: 3.85s	remaining: 2.21s
# 635:	learn: 0.1423195	total: 3.86s	remaining: 2.21s
# 636:	learn: 0.1420712	total: 3.86s	remaining: 2.2s
# 637:	learn: 0.1417246	total: 3.87s	remaining: 2.2s
# 638:	learn: 0.1414820	total: 3.88s	remaining: 2.19s
# 639:	learn: 0.1412636	total: 3.88s	remaining: 2.18s
# 640:	learn: 0.1410910	total: 3.89s	remaining: 2.18s
# 641:	learn: 0.1408417	total: 3.9s	remaining: 2.17s
# 642:	learn: 0.1404674	total: 3.9s	remaining: 2.17s
# 643:	learn: 0.1402227	total: 3.91s	remaining: 2.16s
# 644:	learn: 0.1399730	total: 3.91s	remaining: 2.15s
# 645:	learn: 0.1398171	total: 3.92s	remaining: 2.15s
# 646:	learn: 0.1396598	total: 3.92s	remaining: 2.14s
# 647:	learn: 0.1394973	total: 3.93s	remaining: 2.13s
# 648:	learn: 0.1393247	total: 3.94s	remaining: 2.13s
# 649:	learn: 0.1390264	total: 3.94s	remaining: 2.12s
# 650:	learn: 0.1388196	total: 3.95s	remaining: 2.12s
# 651:	learn: 0.1385768	total: 3.96s	remaining: 2.11s
# 652:	learn: 0.1383043	total: 3.96s	remaining: 2.1s
# 653:	learn: 0.1381536	total: 3.97s	remaining: 2.1s
# 654:	learn: 0.1379878	total: 3.97s	remaining: 2.09s
# 655:	learn: 0.1378066	total: 3.98s	remaining: 2.09s
# 656:	learn: 0.1375845	total: 3.98s	remaining: 2.08s
# 657:	learn: 0.1372853	total: 3.99s	remaining: 2.07s
# 658:	learn: 0.1370981	total: 4s	remaining: 2.07s
# 659:	learn: 0.1368707	total: 4s	remaining: 2.06s
# 660:	learn: 0.1367668	total: 4.01s	remaining: 2.06s
# 661:	learn: 0.1365466	total: 4.01s	remaining: 2.05s
# 662:	learn: 0.1363430	total: 4.02s	remaining: 2.04s
# 663:	learn: 0.1360941	total: 4.03s	remaining: 2.04s
# 664:	learn: 0.1358994	total: 4.03s	remaining: 2.03s
# 665:	learn: 0.1358282	total: 4.04s	remaining: 2.02s
# 666:	learn: 0.1356450	total: 4.04s	remaining: 2.02s
# 667:	learn: 0.1354609	total: 4.05s	remaining: 2.01s
# 668:	learn: 0.1350939	total: 4.05s	remaining: 2s
# 669:	learn: 0.1348864	total: 4.06s	remaining: 2s
# 670:	learn: 0.1347782	total: 4.07s	remaining: 1.99s
# 671:	learn: 0.1345252	total: 4.07s	remaining: 1.99s
# 672:	learn: 0.1341990	total: 4.08s	remaining: 1.98s
# 673:	learn: 0.1340099	total: 4.08s	remaining: 1.97s
# 674:	learn: 0.1338862	total: 4.09s	remaining: 1.97s
# 675:	learn: 0.1336313	total: 4.09s	remaining: 1.96s
# 676:	learn: 0.1334457	total: 4.1s	remaining: 1.96s
# 677:	learn: 0.1331809	total: 4.1s	remaining: 1.95s
# 678:	learn: 0.1330644	total: 4.11s	remaining: 1.94s
# 679:	learn: 0.1328663	total: 4.12s	remaining: 1.94s
# 680:	learn: 0.1327027	total: 4.12s	remaining: 1.93s
# 681:	learn: 0.1324414	total: 4.13s	remaining: 1.92s
# 682:	learn: 0.1322777	total: 4.13s	remaining: 1.92s
# 683:	learn: 0.1320995	total: 4.14s	remaining: 1.91s
# 684:	learn: 0.1319135	total: 4.14s	remaining: 1.91s
# 685:	learn: 0.1317834	total: 4.15s	remaining: 1.9s
# 686:	learn: 0.1316446	total: 4.16s	remaining: 1.89s
# 687:	learn: 0.1314961	total: 4.16s	remaining: 1.89s
# 688:	learn: 0.1313615	total: 4.17s	remaining: 1.88s
# 689:	learn: 0.1312844	total: 4.18s	remaining: 1.88s
# 690:	learn: 0.1310381	total: 4.18s	remaining: 1.87s
# 691:	learn: 0.1307925	total: 4.19s	remaining: 1.86s
# 692:	learn: 0.1306175	total: 4.2s	remaining: 1.86s
# 693:	learn: 0.1304053	total: 4.21s	remaining: 1.85s
# 694:	learn: 0.1301998	total: 4.22s	remaining: 1.85s
# 695:	learn: 0.1299361	total: 4.22s	remaining: 1.84s
# 696:	learn: 0.1295628	total: 4.23s	remaining: 1.84s
# 697:	learn: 0.1293832	total: 4.24s	remaining: 1.83s
# 698:	learn: 0.1292313	total: 4.24s	remaining: 1.83s
# 699:	learn: 0.1291529	total: 4.25s	remaining: 1.82s
# 700:	learn: 0.1288760	total: 4.25s	remaining: 1.81s
# 701:	learn: 0.1286153	total: 4.26s	remaining: 1.81s
# 702:	learn: 0.1283367	total: 4.26s	remaining: 1.8s
# 703:	learn: 0.1282335	total: 4.27s	remaining: 1.79s
# 704:	learn: 0.1280111	total: 4.28s	remaining: 1.79s
# 705:	learn: 0.1278716	total: 4.28s	remaining: 1.78s
# 706:	learn: 0.1277410	total: 4.29s	remaining: 1.78s
# 707:	learn: 0.1276320	total: 4.29s	remaining: 1.77s
# 708:	learn: 0.1274802	total: 4.3s	remaining: 1.76s
# 709:	learn: 0.1272936	total: 4.31s	remaining: 1.76s
# 710:	learn: 0.1271320	total: 4.31s	remaining: 1.75s
# 711:	learn: 0.1270121	total: 4.32s	remaining: 1.75s
# 712:	learn: 0.1267396	total: 4.33s	remaining: 1.74s
# 713:	learn: 0.1265357	total: 4.33s	remaining: 1.74s
# 714:	learn: 0.1263616	total: 4.34s	remaining: 1.73s
# 715:	learn: 0.1260583	total: 4.35s	remaining: 1.73s
# 716:	learn: 0.1259109	total: 4.36s	remaining: 1.72s
# 717:	learn: 0.1257531	total: 4.37s	remaining: 1.71s
# 718:	learn: 0.1255794	total: 4.37s	remaining: 1.71s
# 719:	learn: 0.1253694	total: 4.38s	remaining: 1.7s
# 720:	learn: 0.1252839	total: 4.38s	remaining: 1.7s
# 721:	learn: 0.1251250	total: 4.39s	remaining: 1.69s
# 722:	learn: 0.1250407	total: 4.4s	remaining: 1.68s
# 723:	learn: 0.1248166	total: 4.4s	remaining: 1.68s
# 724:	learn: 0.1245715	total: 4.41s	remaining: 1.67s
# 725:	learn: 0.1243184	total: 4.42s	remaining: 1.67s
# 726:	learn: 0.1241891	total: 4.42s	remaining: 1.66s
# 727:	learn: 0.1240438	total: 4.43s	remaining: 1.65s
# 728:	learn: 0.1239374	total: 4.43s	remaining: 1.65s
# 729:	learn: 0.1238425	total: 4.44s	remaining: 1.64s
# 730:	learn: 0.1236151	total: 4.45s	remaining: 1.64s
# 731:	learn: 0.1234138	total: 4.46s	remaining: 1.63s
# 732:	learn: 0.1232705	total: 4.46s	remaining: 1.63s
# 733:	learn: 0.1231211	total: 4.47s	remaining: 1.62s
# 734:	learn: 0.1229199	total: 4.47s	remaining: 1.61s
# 735:	learn: 0.1227809	total: 4.48s	remaining: 1.61s
# 736:	learn: 0.1225687	total: 4.49s	remaining: 1.6s
# 737:	learn: 0.1223922	total: 4.5s	remaining: 1.6s
# 738:	learn: 0.1223068	total: 4.5s	remaining: 1.59s
# 739:	learn: 0.1221107	total: 4.51s	remaining: 1.58s
# 740:	learn: 0.1218798	total: 4.52s	remaining: 1.58s
# 741:	learn: 0.1217005	total: 4.53s	remaining: 1.57s
# 742:	learn: 0.1215273	total: 4.54s	remaining: 1.57s
# 743:	learn: 0.1213417	total: 4.54s	remaining: 1.56s
# 744:	learn: 0.1212248	total: 4.55s	remaining: 1.56s
# 745:	learn: 0.1211048	total: 4.56s	remaining: 1.55s
# 746:	learn: 0.1208307	total: 4.56s	remaining: 1.54s
# 747:	learn: 0.1206831	total: 4.57s	remaining: 1.54s
# 748:	learn: 0.1204725	total: 4.58s	remaining: 1.53s
# 749:	learn: 0.1202339	total: 4.58s	remaining: 1.53s
# 750:	learn: 0.1200583	total: 4.59s	remaining: 1.52s
# 751:	learn: 0.1199552	total: 4.6s	remaining: 1.52s
# 752:	learn: 0.1197786	total: 4.61s	remaining: 1.51s
# 753:	learn: 0.1196394	total: 4.61s	remaining: 1.5s
# 754:	learn: 0.1194958	total: 4.62s	remaining: 1.5s
# 755:	learn: 0.1192024	total: 4.63s	remaining: 1.49s
# 756:	learn: 0.1190544	total: 4.63s	remaining: 1.49s
# 757:	learn: 0.1188622	total: 4.64s	remaining: 1.48s
# 758:	learn: 0.1186957	total: 4.64s	remaining: 1.48s
# 759:	learn: 0.1184883	total: 4.65s	remaining: 1.47s
# 760:	learn: 0.1184386	total: 4.66s	remaining: 1.46s
# 761:	learn: 0.1182997	total: 4.67s	remaining: 1.46s
# 762:	learn: 0.1181017	total: 4.67s	remaining: 1.45s
# 763:	learn: 0.1180239	total: 4.68s	remaining: 1.45s
# 764:	learn: 0.1179531	total: 4.69s	remaining: 1.44s
# 765:	learn: 0.1177398	total: 4.69s	remaining: 1.43s
# 766:	learn: 0.1175600	total: 4.7s	remaining: 1.43s
# 767:	learn: 0.1174333	total: 4.71s	remaining: 1.42s
# 768:	learn: 0.1173878	total: 4.71s	remaining: 1.42s
# 769:	learn: 0.1171865	total: 4.72s	remaining: 1.41s
# 770:	learn: 0.1170256	total: 4.73s	remaining: 1.4s
# 771:	learn: 0.1168440	total: 4.73s	remaining: 1.4s
# 772:	learn: 0.1166622	total: 4.74s	remaining: 1.39s
# 773:	learn: 0.1165368	total: 4.75s	remaining: 1.39s
# 774:	learn: 0.1163821	total: 4.75s	remaining: 1.38s
# 775:	learn: 0.1162071	total: 4.76s	remaining: 1.37s
# 776:	learn: 0.1160043	total: 4.76s	remaining: 1.37s
# 777:	learn: 0.1158958	total: 4.77s	remaining: 1.36s
# 778:	learn: 0.1157129	total: 4.78s	remaining: 1.35s
# 779:	learn: 0.1155601	total: 4.78s	remaining: 1.35s
# 780:	learn: 0.1154148	total: 4.79s	remaining: 1.34s
# 781:	learn: 0.1152435	total: 4.79s	remaining: 1.34s
# 782:	learn: 0.1151095	total: 4.8s	remaining: 1.33s
# 783:	learn: 0.1148613	total: 4.8s	remaining: 1.32s
# 784:	learn: 0.1147563	total: 4.81s	remaining: 1.32s
# 785:	learn: 0.1144594	total: 4.82s	remaining: 1.31s
# 786:	learn: 0.1142386	total: 4.82s	remaining: 1.3s
# 787:	learn: 0.1139989	total: 4.83s	remaining: 1.3s
# 788:	learn: 0.1139174	total: 4.83s	remaining: 1.29s
# 789:	learn: 0.1137193	total: 4.84s	remaining: 1.29s
# 790:	learn: 0.1134361	total: 4.85s	remaining: 1.28s
# 791:	learn: 0.1132826	total: 4.85s	remaining: 1.27s
# 792:	learn: 0.1131611	total: 4.86s	remaining: 1.27s
# 793:	learn: 0.1128157	total: 4.87s	remaining: 1.26s
# 794:	learn: 0.1126727	total: 4.87s	remaining: 1.26s
# 795:	learn: 0.1125547	total: 4.88s	remaining: 1.25s
# 796:	learn: 0.1124152	total: 4.88s	remaining: 1.24s
# 797:	learn: 0.1121687	total: 4.89s	remaining: 1.24s
# 798:	learn: 0.1120208	total: 4.89s	remaining: 1.23s
# 799:	learn: 0.1118516	total: 4.9s	remaining: 1.23s
# 800:	learn: 0.1116700	total: 4.91s	remaining: 1.22s
# 801:	learn: 0.1114992	total: 4.91s	remaining: 1.21s
# 802:	learn: 0.1113392	total: 4.92s	remaining: 1.21s
# 803:	learn: 0.1111965	total: 4.92s	remaining: 1.2s
# 804:	learn: 0.1110591	total: 4.93s	remaining: 1.19s
# 805:	learn: 0.1109864	total: 4.93s	remaining: 1.19s
# 806:	learn: 0.1107770	total: 4.94s	remaining: 1.18s
# 807:	learn: 0.1106343	total: 4.95s	remaining: 1.18s
# 808:	learn: 0.1104609	total: 4.95s	remaining: 1.17s
# 809:	learn: 0.1103158	total: 4.96s	remaining: 1.16s
# 810:	learn: 0.1102258	total: 4.96s	remaining: 1.16s
# 811:	learn: 0.1100266	total: 4.97s	remaining: 1.15s
# 812:	learn: 0.1098827	total: 4.97s	remaining: 1.14s
# 813:	learn: 0.1096330	total: 4.98s	remaining: 1.14s
# 814:	learn: 0.1094470	total: 4.99s	remaining: 1.13s
# 815:	learn: 0.1092879	total: 4.99s	remaining: 1.13s
# 816:	learn: 0.1090633	total: 5s	remaining: 1.12s
# 817:	learn: 0.1089311	total: 5s	remaining: 1.11s
# 818:	learn: 0.1087471	total: 5.01s	remaining: 1.11s
# 819:	learn: 0.1085431	total: 5.02s	remaining: 1.1s
# 820:	learn: 0.1083781	total: 5.02s	remaining: 1.09s
# 821:	learn: 0.1082431	total: 5.03s	remaining: 1.09s
# 822:	learn: 0.1081054	total: 5.03s	remaining: 1.08s
# 823:	learn: 0.1079497	total: 5.04s	remaining: 1.08s
# 824:	learn: 0.1077993	total: 5.05s	remaining: 1.07s
# 825:	learn: 0.1076118	total: 5.05s	remaining: 1.06s
# 826:	learn: 0.1074925	total: 5.06s	remaining: 1.06s
# 827:	learn: 0.1072760	total: 5.06s	remaining: 1.05s
# 828:	learn: 0.1071876	total: 5.07s	remaining: 1.04s
# 829:	learn: 0.1070838	total: 5.07s	remaining: 1.04s
# 830:	learn: 0.1069871	total: 5.08s	remaining: 1.03s
# 831:	learn: 0.1068419	total: 5.08s	remaining: 1.03s
# 832:	learn: 0.1067211	total: 5.09s	remaining: 1.02s
# 833:	learn: 0.1065205	total: 5.09s	remaining: 1.01s
# 834:	learn: 0.1062772	total: 5.1s	remaining: 1.01s
# 835:	learn: 0.1060811	total: 5.1s	remaining: 1s
# 836:	learn: 0.1058935	total: 5.11s	remaining: 995ms
# 837:	learn: 0.1057977	total: 5.12s	remaining: 989ms
# 838:	learn: 0.1056795	total: 5.12s	remaining: 983ms
# 839:	learn: 0.1055081	total: 5.13s	remaining: 977ms
# 840:	learn: 0.1053590	total: 5.13s	remaining: 971ms
# 841:	learn: 0.1052503	total: 5.14s	remaining: 964ms
# 842:	learn: 0.1051574	total: 5.14s	remaining: 958ms
# 843:	learn: 0.1048748	total: 5.15s	remaining: 952ms
# 844:	learn: 0.1047648	total: 5.16s	remaining: 946ms
# 845:	learn: 0.1046263	total: 5.16s	remaining: 940ms
# 846:	learn: 0.1044805	total: 5.17s	remaining: 934ms
# 847:	learn: 0.1043432	total: 5.17s	remaining: 927ms
# 848:	learn: 0.1042193	total: 5.18s	remaining: 921ms
# 849:	learn: 0.1039598	total: 5.19s	remaining: 915ms
# 850:	learn: 0.1038676	total: 5.19s	remaining: 909ms
# 851:	learn: 0.1036672	total: 5.2s	remaining: 903ms
# 852:	learn: 0.1035205	total: 5.2s	remaining: 897ms
# 853:	learn: 0.1034077	total: 5.21s	remaining: 891ms
# 854:	learn: 0.1032850	total: 5.21s	remaining: 884ms
# 855:	learn: 0.1030807	total: 5.22s	remaining: 878ms
# 856:	learn: 0.1029549	total: 5.23s	remaining: 872ms
# 857:	learn: 0.1028175	total: 5.23s	remaining: 866ms
# 858:	learn: 0.1026998	total: 5.24s	remaining: 860ms
# 859:	learn: 0.1026154	total: 5.24s	remaining: 854ms
# 860:	learn: 0.1024948	total: 5.25s	remaining: 848ms
# 861:	learn: 0.1023962	total: 5.25s	remaining: 841ms
# 862:	learn: 0.1023283	total: 5.26s	remaining: 835ms
# 863:	learn: 0.1021726	total: 5.27s	remaining: 829ms
# 864:	learn: 0.1019886	total: 5.27s	remaining: 823ms
# 865:	learn: 0.1018557	total: 5.28s	remaining: 817ms
# 866:	learn: 0.1017249	total: 5.28s	remaining: 811ms
# 867:	learn: 0.1016124	total: 5.29s	remaining: 805ms
# 868:	learn: 0.1013751	total: 5.3s	remaining: 798ms
# 869:	learn: 0.1012490	total: 5.3s	remaining: 792ms
# 870:	learn: 0.1011518	total: 5.31s	remaining: 786ms
# 871:	learn: 0.1010273	total: 5.31s	remaining: 780ms
# 872:	learn: 0.1008643	total: 5.32s	remaining: 774ms
# 873:	learn: 0.1007416	total: 5.33s	remaining: 768ms
# 874:	learn: 0.1006222	total: 5.33s	remaining: 762ms
# 875:	learn: 0.1005159	total: 5.34s	remaining: 755ms
# 876:	learn: 0.1003589	total: 5.34s	remaining: 749ms
# 877:	learn: 0.1002146	total: 5.35s	remaining: 743ms
# 878:	learn: 0.0999916	total: 5.35s	remaining: 737ms
# 879:	learn: 0.0998649	total: 5.36s	remaining: 731ms
# 880:	learn: 0.0998115	total: 5.37s	remaining: 725ms
# 881:	learn: 0.0996623	total: 5.37s	remaining: 719ms
# 882:	learn: 0.0995007	total: 5.38s	remaining: 713ms
# 883:	learn: 0.0992759	total: 5.38s	remaining: 707ms
# 884:	learn: 0.0991959	total: 5.39s	remaining: 700ms
# 885:	learn: 0.0991234	total: 5.39s	remaining: 694ms
# 886:	learn: 0.0990611	total: 5.4s	remaining: 688ms
# 887:	learn: 0.0989359	total: 5.41s	remaining: 682ms
# 888:	learn: 0.0987577	total: 5.41s	remaining: 676ms
# 889:	learn: 0.0985327	total: 5.42s	remaining: 670ms
# 890:	learn: 0.0984507	total: 5.42s	remaining: 664ms
# 891:	learn: 0.0983811	total: 5.43s	remaining: 657ms
# 892:	learn: 0.0983068	total: 5.43s	remaining: 651ms
# 893:	learn: 0.0981225	total: 5.44s	remaining: 645ms
# 894:	learn: 0.0980119	total: 5.45s	remaining: 639ms
# 895:	learn: 0.0979252	total: 5.45s	remaining: 633ms
# 896:	learn: 0.0977351	total: 5.46s	remaining: 627ms
# 897:	learn: 0.0975830	total: 5.46s	remaining: 621ms
# 898:	learn: 0.0975122	total: 5.47s	remaining: 615ms
# 899:	learn: 0.0973737	total: 5.48s	remaining: 609ms
# 900:	learn: 0.0972468	total: 5.48s	remaining: 602ms
# 901:	learn: 0.0971406	total: 5.49s	remaining: 596ms
# 902:	learn: 0.0970872	total: 5.49s	remaining: 590ms
# 903:	learn: 0.0968999	total: 5.5s	remaining: 584ms
# 904:	learn: 0.0968031	total: 5.5s	remaining: 578ms
# 905:	learn: 0.0965033	total: 5.51s	remaining: 572ms
# 906:	learn: 0.0963616	total: 5.52s	remaining: 566ms
# 907:	learn: 0.0961446	total: 5.52s	remaining: 560ms
# 908:	learn: 0.0960803	total: 5.53s	remaining: 553ms
# 909:	learn: 0.0959802	total: 5.53s	remaining: 547ms
# 910:	learn: 0.0958628	total: 5.54s	remaining: 541ms
# 911:	learn: 0.0957327	total: 5.55s	remaining: 535ms
# 912:	learn: 0.0955856	total: 5.55s	remaining: 529ms
# 913:	learn: 0.0954656	total: 5.56s	remaining: 523ms
# 914:	learn: 0.0953345	total: 5.56s	remaining: 517ms
# 915:	learn: 0.0951470	total: 5.57s	remaining: 511ms
# 916:	learn: 0.0950251	total: 5.58s	remaining: 505ms
# 917:	learn: 0.0949674	total: 5.58s	remaining: 499ms
# 918:	learn: 0.0947777	total: 5.59s	remaining: 492ms
# 919:	learn: 0.0946285	total: 5.59s	remaining: 486ms
# 920:	learn: 0.0944811	total: 5.6s	remaining: 480ms
# 921:	learn: 0.0943069	total: 5.6s	remaining: 474ms
# 922:	learn: 0.0941772	total: 5.61s	remaining: 468ms
# 923:	learn: 0.0940221	total: 5.62s	remaining: 462ms
# 924:	learn: 0.0939427	total: 5.62s	remaining: 456ms
# 925:	learn: 0.0938875	total: 5.63s	remaining: 450ms
# 926:	learn: 0.0937850	total: 5.64s	remaining: 444ms
# 927:	learn: 0.0936118	total: 5.64s	remaining: 438ms
# 928:	learn: 0.0935044	total: 5.65s	remaining: 432ms
# 929:	learn: 0.0933168	total: 5.66s	remaining: 426ms
# 930:	learn: 0.0932100	total: 5.66s	remaining: 420ms
# 931:	learn: 0.0930905	total: 5.67s	remaining: 414ms
# 932:	learn: 0.0929740	total: 5.67s	remaining: 408ms
# 933:	learn: 0.0928402	total: 5.68s	remaining: 402ms
# 934:	learn: 0.0927112	total: 5.69s	remaining: 395ms
# 935:	learn: 0.0925565	total: 5.7s	remaining: 389ms
# 936:	learn: 0.0924099	total: 5.7s	remaining: 383ms
# 937:	learn: 0.0923004	total: 5.71s	remaining: 377ms
# 938:	learn: 0.0921937	total: 5.71s	remaining: 371ms
# 939:	learn: 0.0919957	total: 5.72s	remaining: 365ms
# 940:	learn: 0.0918465	total: 5.73s	remaining: 359ms
# 941:	learn: 0.0916784	total: 5.73s	remaining: 353ms
# 942:	learn: 0.0915177	total: 5.74s	remaining: 347ms
# 943:	learn: 0.0913617	total: 5.75s	remaining: 341ms
# 944:	learn: 0.0912645	total: 5.75s	remaining: 335ms
# 945:	learn: 0.0911076	total: 5.76s	remaining: 329ms
# 946:	learn: 0.0909611	total: 5.77s	remaining: 323ms
# 947:	learn: 0.0908099	total: 5.77s	remaining: 317ms
# 948:	learn: 0.0907230	total: 5.78s	remaining: 311ms
# 949:	learn: 0.0906342	total: 5.79s	remaining: 305ms
# 950:	learn: 0.0905541	total: 5.79s	remaining: 299ms
# 951:	learn: 0.0903652	total: 5.8s	remaining: 292ms
# 952:	learn: 0.0902829	total: 5.81s	remaining: 286ms
# 953:	learn: 0.0901930	total: 5.81s	remaining: 280ms
# 954:	learn: 0.0900688	total: 5.82s	remaining: 274ms
# 955:	learn: 0.0899452	total: 5.82s	remaining: 268ms
# 956:	learn: 0.0897923	total: 5.83s	remaining: 262ms
# 957:	learn: 0.0896763	total: 5.83s	remaining: 256ms
# 958:	learn: 0.0895569	total: 5.84s	remaining: 250ms
# 959:	learn: 0.0893802	total: 5.84s	remaining: 244ms
# 960:	learn: 0.0893007	total: 5.85s	remaining: 237ms
# 961:	learn: 0.0891236	total: 5.86s	remaining: 231ms
# 962:	learn: 0.0890316	total: 5.86s	remaining: 225ms
# 963:	learn: 0.0889488	total: 5.87s	remaining: 219ms
# 964:	learn: 0.0887881	total: 5.87s	remaining: 213ms
# 965:	learn: 0.0886829	total: 5.88s	remaining: 207ms
# 966:	learn: 0.0885751	total: 5.88s	remaining: 201ms
# 967:	learn: 0.0884085	total: 5.89s	remaining: 195ms
# 968:	learn: 0.0882689	total: 5.89s	remaining: 189ms
# 969:	learn: 0.0881314	total: 5.9s	remaining: 183ms
# 970:	learn: 0.0880077	total: 5.91s	remaining: 176ms
# 971:	learn: 0.0879483	total: 5.91s	remaining: 170ms
# 972:	learn: 0.0877807	total: 5.92s	remaining: 164ms
# 973:	learn: 0.0877178	total: 5.92s	remaining: 158ms
# 974:	learn: 0.0875611	total: 5.93s	remaining: 152ms
# 975:	learn: 0.0873922	total: 5.94s	remaining: 146ms
# 976:	learn: 0.0873086	total: 5.94s	remaining: 140ms
# 977:	learn: 0.0871942	total: 5.95s	remaining: 134ms
# 978:	learn: 0.0870154	total: 5.96s	remaining: 128ms
# 979:	learn: 0.0869057	total: 5.96s	remaining: 122ms
# 980:	learn: 0.0868173	total: 5.97s	remaining: 116ms
# 981:	learn: 0.0866815	total: 5.97s	remaining: 109ms
# 982:	learn: 0.0865833	total: 5.98s	remaining: 103ms
# 983:	learn: 0.0864820	total: 5.98s	remaining: 97.3ms
# 984:	learn: 0.0863422	total: 5.99s	remaining: 91.2ms
# 985:	learn: 0.0862409	total: 6s	remaining: 85.1ms
# 986:	learn: 0.0861392	total: 6s	remaining: 79ms
# 987:	learn: 0.0860638	total: 6s	remaining: 72.9ms
# 988:	learn: 0.0859424	total: 6.01s	remaining: 66.9ms
# 989:	learn: 0.0857327	total: 6.02s	remaining: 60.8ms
# 990:	learn: 0.0856168	total: 6.02s	remaining: 54.7ms
# 991:	learn: 0.0854989	total: 6.03s	remaining: 48.6ms
# 992:	learn: 0.0854083	total: 6.03s	remaining: 42.5ms
# 993:	learn: 0.0853140	total: 6.04s	remaining: 36.5ms
# 994:	learn: 0.0852137	total: 6.04s	remaining: 30.4ms
# 995:	learn: 0.0851571	total: 6.05s	remaining: 24.3ms
# 996:	learn: 0.0849938	total: 6.05s	remaining: 18.2ms
# 997:	learn: 0.0848865	total: 6.06s	remaining: 12.1ms
# 998:	learn: 0.0848150	total: 6.07s	remaining: 6.07ms
# 999:	learn: 0.0846763	total: 6.07s	remaining: 0us

# %%
test_pred = clf.predict(test_embeds)
test_proba = clf.predict_proba(test_embeds)[:, 1]

# %%
print("Accuracy:", accuracy_score(target_test, test_pred))
print("ROC-AUC:", roc_auc_score(target_test, test_proba))
# Out:
# Accuracy: 0.758
# ROC-AUC: 0.8204173479464474

# %%
arr = np.array([0.7942562043677452, 0.8178109468844603, 0.8084214275307184, 0.8204173479464474])

arr.mean(), arr.std()
# Out:
# (0.8102264816823428, 0.01024311775791973)

# %% [markdown]
# - CPC context embeds + Catboost:
#   - `Accuracy: 0.748 +- 0.0033`
#   - `ROC-AUC: 0.81 +- 0.0048`
#
# ---
#
# - CPC context embeds + WinAgg (3 trx) + Catboost:
#   - `Accuracy: 0.7504 +- 0.0093`
#   - `ROC-AUC: 0.8136 +- 0.0087`
#
# ---
#
# - CPC context embeds + WinAgg (5 trx) + Catboost:
#   - `Accuracy: 0.7352 +- 0.0047`
#   - `ROC-AUC: 0.8086 +- 0.0055`
#
# ---
#
# - CPC context embeds (2 forward steps) + WinAgg (3 trx) + Catboost:
#   - `Accuracy: 0.7475 +- 0.0086`
#   - `ROC-AUC: 0.8099 +- 0.0069`
#
# ---
#
# - CPC context embeds (1 forward step) + WinAgg (6 trx) + Catboost:
#   - `Accuracy: 0.748 +- 0.0062` (`max: 0.758` - выше, чем во всех остальных случаях)
#   - `ROC-AUC: 0.8102 +- 0.0102` (`max: 0.8204173479464474` - выше, чем во всех остальных случаях)
#
#
# **Вывод:** оптимальный размер окна - 3 - при таком сжатии  информации качество в среднем лучше, дальнейшее сжатие информации (при бОльших размерах окна) лишь ухудшает результаты.

# %% [markdown]
# ---

# %% [markdown]
# - **GPT:**

# %%
seed_everything(222)

# %% [markdown]
# **DataLoaders:**

# %%
data = PtlsDataModule(
    train_data=GptDataset(
        MemoryMapDataset(data=data_train),
        min_len=1000, # 85
        max_len=1200 # 105
    ),
    train_num_workers=4,
    train_batch_size=64,
    valid_data=GptDataset(
        MemoryMapDataset(data=data_test),
        min_len=1000,
        max_len=1200
    ),
    valid_num_workers=4,
    valid_batch_size=64
)

# %% [markdown]
# **Модель:**

# %%
from torchmetrics import MeanMetric
from typing import Tuple, Dict, List, Union
from torch import nn
import torch.nn.functional as F 
from ptls.nn.seq_encoder.abs_seq_encoder import AbsSeqEncoder
from ptls.nn import PBL2Norm
from ptls.data_load.padded_batch import PaddedBatch


class MeanPooling(torch.nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, pb: PaddedBatch):
        payload = pb.payload # (B, T, H)
        mask = pb.seq_len_mask.bool()
        pb_mean = payload.sum(dim=1) / mask.float().sum(dim=1, keepdim=True)
        return pb_mean


class StatPooling(torch.nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, pb: PaddedBatch):
        payload = pb.payload # (B, T, H)
        mask = pb.seq_len_mask.bool()
        inf_mask = torch.zeros_like(mask, device=mask.device).float()
        inf_mask[~mask] = -torch.inf
        
        pb_mean = payload.sum(dim=1) / mask.float().sum(dim=1, keepdim=True)
        pb_max = torch.max(payload + inf_mask.unsqueeze(-1), dim=1)[0]
        pb_stat = torch.cat((pb_mean, pb_max), dim=1)
        return pb_stat


class GPTHead(torch.nn.Module):   
    def __init__(self, input_size, n_classes, hidden_size=64, drop_p=0.1):
        super().__init__()
        self.head = nn.Sequential(
            nn.Linear(input_size, hidden_size, bias=True),
            nn.GELU(),
            nn.Dropout(drop_p),
            nn.Linear(hidden_size, n_classes)
        )
    def forward(self, x):
        x = self.head(x)
        return x


class GptPretrainModule(pl.LightningModule):
    """GPT2 Language model

    Sequence transactions are encoded by `trx_encoder`.
    Then `seq_encoder` encodes the given sequence 
    (we actually use NN to modify sequence transactions representations,
    then (during inference) we calculate the mean of these encoded transactions to get the representation of the whole sequence).
    After this we use heads to predict the classes of features of the future transaction.

    Parameters
    ----------
    trx_encoder:
        Module for transform dict with feature sequences to sequence of transaction representations
    seq_encoder:
        Module for sequence processing. Generally this is transformer based encoder. Rnn is also possible
        Should work without sequence reduction
    head_hidden_size:
        Hidden size of heads for feature prediction
    seed_seq_len:
         Size of starting sequence without loss 
    total_steps:
        total_steps expected in OneCycle lr scheduler
    max_lr:
        max_lr of OneCycle lr scheduler
    weight_decay:
        weight_decay of Adam optimizer
    pct_start:
        % of total_steps when lr increase
    norm_predict:
        use l2 norm for transformer output or not
    """

    def __init__(self,
                 trx_encoder: torch.nn.Module,
                 seq_encoder: AbsSeqEncoder,
                 head_hidden_size: int = 64,
                 total_steps: int = 64000,
                 seed_seq_len: int = 16,
                 max_lr: float = 0.00005,
                 weight_decay: float = 0.0,
                 pct_start: float = 0.1,
                 norm_predict: bool = False
                 ):

        super().__init__()
        self.save_hyperparameters(ignore=['trx_encoder', 'seq_encoder'])

        self.trx_encoder = trx_encoder
        self._seq_encoder = seq_encoder
        self._seq_encoder.is_reduce_sequence = False

        self.head = nn.ModuleDict()
        for col_name, noisy_emb in self.trx_encoder.embeddings.items():
            self.head[col_name] = GPTHead(input_size=self._seq_encoder.embedding_size, hidden_size=head_hidden_size, n_classes=noisy_emb.num_embeddings)

        if self.hparams.norm_predict:
            self.fn_norm_predict = PBL2Norm()

        self.loss = nn.CrossEntropyLoss(ignore_index=0)

        self.train_gpt_loss = MeanMetric()
        self.valid_gpt_loss = MeanMetric()

    def forward(self, batch: PaddedBatch):
        z_trx = self.trx_encoder(batch) 
        out = self._seq_encoder(z_trx)
        if self.hparams.norm_predict:
            out = self.fn_norm_predict(out)
        return out

    def loss_gpt(self, logits, labels):
        loss = 0
        for col_name, head in self.head.items():
            y_pred = head(logits[:, self.hparams.seed_seq_len:-1, :])
            y_pred = y_pred.view(-1, y_pred.size(-1))

            y_true = labels[col_name][:, self.hparams.seed_seq_len+1:]
            y_true = torch.flatten(y_true.long())
            
            loss += self.loss(y_pred, y_true)
            
        return loss

    def training_step(self, batch, batch_idx):
        out = self.forward(batch)  # PB: B, T, H
        out = out.payload if isinstance(out, PaddedBatch) else out
        labels = batch.payload
        
        loss_gpt = self.loss_gpt(out, labels)
        self.train_gpt_loss(loss_gpt)
        self.log(f'loss', loss_gpt, sync_dist=True)
        return loss_gpt

    def validation_step(self, batch, batch_idx):
        out = self.forward(batch)  # PB: B, T, H
        out = out.payload if isinstance(out, PaddedBatch) else out
        labels = batch.payload
        
        loss_gpt = self.loss_gpt(out, labels)
        self.valid_gpt_loss(loss_gpt)

    def on_training_epoch_end(self):
        self.log('train loss (by epochs)', self.train_gpt_loss, prog_bar=True, logger=True, sync_dist=True, rank_zero_only=True)

    def on_validation_epoch_end(self):
        self.log('val loss (by epochs)', self.valid_gpt_loss, prog_bar=True, logger=True, sync_dist=True, rank_zero_only=True)

    def configure_optimizers(self):
        optim = torch.optim.NAdam(self.parameters(),
                                  lr=self.hparams.max_lr,
                                  weight_decay=self.hparams.weight_decay
                                 )
        
        scheduler = torch.optim.lr_scheduler.OneCycleLR(
            optimizer=optim,
            max_lr=self.hparams.max_lr,
            total_steps=self.hparams.total_steps,
            pct_start=self.hparams.pct_start,
            anneal_strategy='cos',
            cycle_momentum=False,
            div_factor=25.0,
            final_div_factor=10000.0,
            three_phase=False
        )
        
        scheduler = {'scheduler': scheduler, 'interval': 'step'}
        return [optim], [scheduler]
    
    @property
    def seq_encoder(self):
        return GPTInferenceModule(pretrained_model=self)


class GPTInferenceModule(torch.nn.Module):
    def __init__(self, pretrained_model):
        super().__init__()
        self.model = pretrained_model
        self.model.is_reduce_sequence = False
        self.mean_pooling = MeanPooling()
        self.stat_pooling = StatPooling()

    def forward(self, batch, eval_strategy="mean"):
        z_trx = self.model.trx_encoder(batch)
        out = self.model._seq_encoder(z_trx)
        out = out if isinstance(out, PaddedBatch) else PaddedBatch(out, batch.seq_lens)

        if eval_strategy == "mean":
            out = self.mean_pooling(out)
        elif eval_strategy == "stat":
            out = self.stat_pooling(out)

        if self.model.hparams.norm_predict:
            out = out / (out.pow(2).sum(dim=-1, keepdim=True) + 1e-9).pow(0.5)
        return out

# %%
class WinAggGPTPretrainModule(GptPretrainModule):
    def __init__(self,
                 trx_encoder: torch.nn.Module,
                 seq_encoder: AbsSeqEncoder,
                 head_hidden_size: int = 64,
                 total_steps: int = 64000,
                 seed_seq_len: int = 16,
                 max_lr: float = 0.00005,
                 weight_decay: float = 0.0,
                 pct_start: float = 0.1,
                 norm_predict: bool = False
                 ):
        super().__init__(
            trx_encoder=trx_encoder,
            seq_encoder=seq_encoder,
            head_hidden_size=head_hidden_size,
            total_steps=total_steps,
            seed_seq_len=seed_seq_len,
            max_lr=max_lr,
            weight_decay=weight_decay,
            pct_start=pct_start,
            norm_predict=norm_predict
        )
        self.agg_samples = trx_encoder.agg_samples

    def loss_gpt(self, logits, labels):
        loss = 0
        
        for col_name, head in self.head.items():
            out = head(logits[:, self.hparams.seed_seq_len:-1, :])
            
            y_true = labels[col_name][:, ((self.hparams.seed_seq_len + 1) * self.agg_samples)::self.agg_samples]
            y_true = torch.flatten(y_true.long())
            
            if y_true.shape[0] < out.shape[0] * out.shape[1]:
                pred = out[:, :-1, :]
                pred = pred.reshape(-1, pred.size(-1))
            else:
                pred = out.reshape(-1, out.size(-1))
                    
            loss += self.loss(pred, y_true)
                
        return loss


class WinAggGPTPretrainModule_MultiLabel(GptPretrainModule):
    def __init__(self,
                 trx_encoder: torch.nn.Module,
                 seq_encoder: AbsSeqEncoder,
                 head_hidden_size: int = 64,
                 total_steps: int = 64000,
                 seed_seq_len: int = 16,
                 max_lr: float = 0.00005,
                 weight_decay: float = 0.0,
                 pct_start: float = 0.1,
                 norm_predict: bool = False
                 ):
        super().__init__(
            trx_encoder=trx_encoder,
            seq_encoder=seq_encoder,
            head_hidden_size=head_hidden_size,
            total_steps=total_steps,
            seed_seq_len=seed_seq_len,
            max_lr=max_lr,
            weight_decay=weight_decay,
            pct_start=pct_start,
            norm_predict=norm_predict
        )
        self.agg_samples = trx_encoder.agg_samples
        self.loss = nn.MultiLabelSoftMarginLoss()

    def loss_gpt(self, logits, labels):
        loss = 0
        
        for col_name, head in self.head.items():
            pred = head(logits[:, self.hparams.seed_seq_len:-1, :])

            ohe_labels = torch.zeros((pred.shape[0] * pred.shape[1], pred.shape[2]), device=pred.device)
            
            for shift in range(self.agg_samples):
                y_true = labels[col_name][:, ((self.hparams.seed_seq_len + 1) * self.agg_samples + shift)::self.agg_samples]
                y_true = torch.flatten(y_true.long())
                ohe_labels_part = F.one_hot(y_true, num_classes=pred.shape[2])
                
                if ohe_labels_part.shape[0] < pred.shape[0] * pred.shape[1]:
                    padding = torch.zeros((pred.shape[0], 1, pred.shape[2]), device=ohe_labels_part.device)
                    ohe_labels_part = torch.cat((ohe_labels_part.reshape(pred.shape[0], pred.shape[1] - 1, pred.shape[2]), padding), dim=1).reshape(pred.shape[0] * pred.shape[1], pred.shape[2])
                
                ohe_labels += ohe_labels_part

            ohe_labels[ohe_labels > 1] = 1
            
            pred = pred.reshape(-1, pred.size(-1))

            loss += self.loss(pred, ohe_labels)
                
        return loss

# %%
N_EPOCHS = 20

# %%
agg_encoder_params = dict(
    embeddings_noise=0.003,
    embeddings={
        "MCC": {"in": 342, "out": 16},
        "channel_type": {"in": 7, "out": 16},
        "currency": {"in": 60, "out": 16},
        "trx_category": {"in": 11, "out": 16},
        "amount": {"in": BINS_NUM, "out": 16}
    },
    k=15,
    time_col="event_time",
    agg_samples=5, # 3, 5, 10
    use_window_attention=False
)

trx_encoder = WinAggregator(**agg_encoder_params)

seq_encoder = GptEncoder(
    n_embd=trx_encoder.output_size,
    n_layer=6,
    n_head=6,
    n_inner=512,
    activation_function="gelu_new",
    resid_pdrop=0.1,
    embd_pdrop=0.1,
    attn_pdrop=0.1,
    n_positions=2048,
    use_positional_encoding=True,
    use_start_random_shift=True,
    is_reduce_sequence=False
)

gpt = WinAggGPTPretrainModule_MultiLabel(
    trx_encoder=trx_encoder,
    seq_encoder=seq_encoder,
    head_hidden_size=512,
    total_steps=(N_EPOCHS * 71), # num_epochs * num_steps_per_epoch
    seed_seq_len=16,
    max_lr=3e-3,
    weight_decay=3e-4,
    pct_start=0.1,
    norm_predict=False
)

# %% [markdown]
# **Обучение:**

# %%
logger = CometLogger(project_name="evs-ssl-rb", experiment_name="GPT_modeling_WinAgg (multilabel, 5 trx)")

trainer = pl.Trainer(
    logger=logger,
    max_epochs=N_EPOCHS,
    accelerator="gpu",
    devices=1,
    enable_progress_bar=True
)

# %%
trainer.fit(gpt, data)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Couldn't find a Git repository in '/kaggle/working' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/askoro/evs-ssl-rb/023c4195f71940bbb9b238a3bc43da91
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : GPT_modeling_WinAgg (multilabel, 5 trx)
# COMET INFO:     url                   : https://www.comet.com/askoro/evs-ssl-rb/023c4195f71940bbb9b238a3bc43da91
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [170]                : (0.03635042905807495, 3.478447198867798)
# COMET INFO:     val loss (by epochs) [20] : (0.0783764198422432, 0.11562386155128479)
# COMET INFO:   Others:
# COMET INFO:     Name : GPT_modeling_WinAgg (multilabel, 5 trx)
# COMET INFO:   Parameters:
# COMET INFO:     head_hidden_size  : 512
# COMET INFO:     max_lr            : 0.003
# COMET INFO:     norm_predict      : False
# COMET INFO:     pct_start         : 0.1
# COMET INFO:     seed_seq_len      : 16
# COMET INFO:     test_batch_size   : None
# COMET INFO:     test_drop_last    : False
# COMET INFO:     test_num_workers  : None
# COMET INFO:     total_steps       : 1420
# COMET INFO:     train_batch_size  : 64
# COMET INFO:     train_drop_last   : False
# COMET INFO:     train_num_workers : 4
# COMET INFO:     valid_batch_size  : 64
# COMET INFO:     valid_drop_last   : False
# COMET INFO:     valid_num_workers : 4
# COMET INFO:     weight_decay      : 0.0003
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:

# %%
trainer.logged_metrics
# Out:
# {'loss': tensor(0.0740), 'val loss (by epochs)': tensor(0.0784)}

# %%
encoder = gpt.seq_encoder

# %%
torch.save(encoder.state_dict(), "gpt_baseline_rosbank.pt")

# %% [markdown]
# **Измерим качество на тесте (catboost поверх эмбеддингов):**

# %%
# import gdown

# gdown.download("https://drive.google.com/uc?export=download&id=1YBstN7hpEIREo7zORmPoEZ_0NyBgfjm6", "gpt_baseline_NAdam.pt")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1YBstN7hpEIREo7zORmPoEZ_0NyBgfjm6
# From (redirected): https://drive.google.com/uc?export=download&id=1YBstN7hpEIREo7zORmPoEZ_0NyBgfjm6&confirm=t&uuid=b0f44bc3-b84b-425c-968f-016e419987af
# To: /kaggle/working/gpt_baseline_NAdam.pt
# 100%|██████████| 34.7M/34.7M [00:00<00:00, 83.5MB/s]
# 'gpt_baseline_NAdam.pt'

# %%
# state_dict = torch.load("./gpt_baseline_NAdam.pt")
# encoder.load_state_dict(state_dict)

device = "cuda:0"

encoder.to(device)
# Out:
# GPTInferenceModule(
#   (model): WinAggGPTPretrainModule_MultiLabel(
#     (trx_encoder): WinAggregator(
#       (embeddings): ModuleDict(
#         (MCC): NoisyEmbedding(
#           342, 16, padding_idx=0
#           (dropout): Dropout(p=0, inplace=False)
#         )
#         (channel_type): NoisyEmbedding(
#           7, 16, padding_idx=0
#           (dropout): Dropout(p=0, inplace=False)
#         )
#         (currency): NoisyEmbedding(
#           60, 16, padding_idx=0
#           (dropout): Dropout(p=0, inplace=False)
#         )
#         (trx_category): NoisyEmbedding(
#           11, 16, padding_idx=0
#           (dropout): Dropout(p=0, inplace=False)
#         )
#         (amount): NoisyEmbedding(
#           128, 16, padding_idx=0
#           (dropout): Dropout(p=0, inplace=False)
#         )
#       )
#       (custom_embeddings): ModuleDict()
#       (time2vec_days): Time2Vec()
#     )
#     (_seq_encoder): GptEncoder(
#       (transf): GPT2Model(
#         (wte): Embedding(4, 96)
#         (wpe): Embedding(2048, 96)
#         (drop): Dropout(p=0.1, inplace=False)
#         (h): ModuleList(
#           (0-5): 6 x GPT2Block(
#             (ln_1): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#             (attn): GPT2SdpaAttention(
#               (c_attn): Conv1D(nf=288, nx=96)
#               (c_proj): Conv1D(nf=96, nx=96)
#               (attn_dropout): Dropout(p=0.1, inplace=False)
#               (resid_dropout): Dropout(p=0.1, inplace=False)
#             )
#             (ln_2): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#             (mlp): GPT2MLP(
#               (c_fc): Conv1D(nf=512, nx=96)
#               (c_proj): Conv1D(nf=96, nx=512)
#               (act): NewGELUActivation()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (ln_f): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (head): ModuleDict(
#       (MCC): GPTHead(
#         (head): Sequential(
#           (0): Linear(in_features=96, out_features=512, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.1, inplace=False)
#           (3): Linear(in_features=512, out_features=342, bias=True)
#         )
#       )
#       (channel_type): GPTHead(
#         (head): Sequential(
#           (0): Linear(in_features=96, out_features=512, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.1, inplace=False)
#           (3): Linear(in_features=512, out_features=7, bias=True)
#         )
#       )
#       (currency): GPTHead(
#         (head): Sequential(
#           (0): Linear(in_features=96, out_features=512, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.1, inplace=False)
#           (3): Linear(in_features=512, out_features=60, bias=True)
#         )
#       )
#       (trx_category): GPTHead(
#         (head): Sequential(
#           (0): Linear(in_features=96, out_features=512, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.1, inplace=False)
#           (3): Linear(in_features=512, out_features=11, bias=True)
#         )
#       )
#       (amount): GPTHead(
#         (head): Sequential(
#           (0): Linear(in_features=96, out_features=512, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.1, inplace=False)
#           (3): Linear(in_features=512, out_features=128, bias=True)
#         )
#       )
#     )
#     (loss): MultiLabelSoftMarginLoss()
#     (train_gpt_loss): MeanMetric()
#     (valid_gpt_loss): MeanMetric()
#   )
#   (mean_pooling): MeanPooling()
#   (stat_pooling): StatPooling()
# )

# %%
from tqdm import tqdm

seed_everything(222)

# %%
train_loader = inference_data_loader(data_train, num_workers=0, batch_size=8)
encoder.eval()
train_embeds = None

for i, batch in tqdm(enumerate(train_loader)):
    train_embeds_batch = encoder(batch.to(device), eval_strategy="stat")
    if i == 0:
        train_embeds = train_embeds_batch.detach().cpu().numpy()
    else:
        train_embeds = np.concatenate([train_embeds, train_embeds_batch.detach().cpu().numpy()], axis=0)
    
train_embeds
# Out:
# 0it [00:00, ?it/s]
# 11it [00:00, 107.11it/s]
# 24it [00:00, 116.16it/s]
# 36it [00:00, 117.59it/s]
# 48it [00:00, 118.14it/s]
# 60it [00:00, 118.70it/s]
# 72it [00:00, 118.12it/s]
# 84it [00:00, 117.74it/s]
# 96it [00:00, 117.83it/s]
# 109it [00:00, 119.85it/s]
# 121it [00:01, 119.69it/s]
# 134it [00:01, 120.58it/s]
# 147it [00:01, 120.60it/s]
# 160it [00:01, 120.97it/s]
# 173it [00:01, 121.09it/s]
# 186it [00:01, 120.08it/s]
# 199it [00:01, 118.80it/s]
# 211it [00:01, 117.78it/s]
# 223it [00:01, 115.12it/s]
# 235it [00:02, 110.94it/s]
# 247it [00:02, 108.29it/s]
# 258it [00:02, 97.99it/s]
# 268it [00:02, 98.11it/s]
# 278it [00:02, 90.21it/s]
# 288it [00:02, 90.62it/s]
# 298it [00:02, 92.26it/s]
# 309it [00:02, 96.92it/s]
# 320it [00:02, 98.95it/s]
# 331it [00:03, 100.05it/s]
# 342it [00:03, 101.79it/s]
# 353it [00:03, 101.02it/s]
# 364it [00:03, 100.31it/s]
# 375it [00:03, 102.35it/s]
# 386it [00:03, 102.13it/s]
# 397it [00:03, 102.10it/s]
# 409it [00:03, 105.39it/s]
# 420it [00:03, 104.97it/s]
# 431it [00:03, 105.02it/s]
# 443it [00:04, 107.48it/s]
# 454it [00:04, 105.19it/s]
# 465it [00:04, 104.91it/s]
# 477it [00:04, 107.05it/s]
# 488it [00:04, 104.26it/s]
# 499it [00:04, 103.14it/s]
# 510it [00:04, 102.98it/s]
# 521it [00:04, 102.26it/s]
# 532it [00:04, 100.34it/s]
# 543it [00:05, 101.29it/s]
# 563it [00:05, 107.02it/s]
# array([[-25.822071  ,  22.912663  , -25.888826  , ...,  -0.19523391,
#          -0.7979302 ,   1.3875624 ],
#        [ -0.59063154,   0.7692774 ,  -0.637765  , ...,   0.50447834,
#           1.371344  ,   1.2060875 ],
#        [ -2.4906378 ,   2.3601081 ,  -2.9877772 , ...,   0.40426877,
#           0.9248251 ,   0.66799915],
#        ...,
#        [ -0.2188473 ,   0.30268428,  -0.25666034, ...,   0.33622214,
#           1.1035528 ,   1.1789192 ],
#        [ -0.13735084,   0.13351558,  -0.11687493, ...,   0.4347997 ,
#           1.0213431 ,   0.95732176],
#        [ -1.1434615 ,   1.1937857 ,  -1.1824086 , ...,   0.3767729 ,
#           1.6559262 ,   0.80085385]], dtype=float32)

# %%
test_loader = inference_data_loader(data_test, num_workers=0, batch_size=8)
encoder.eval()
test_embeds = None

for i, batch in tqdm(enumerate(test_loader)):
    test_embeds_batch = encoder(batch.to(device), eval_strategy="stat")
    if i == 0:
        test_embeds = test_embeds_batch.detach().cpu().numpy()
    else:
        test_embeds = np.concatenate([test_embeds, test_embeds_batch.detach().cpu().numpy()], axis=0)
    
test_embeds
# Out:
# 0it [00:00, ?it/s]
# 12it [00:00, 116.86it/s]
# 25it [00:00, 119.50it/s]
# 38it [00:00, 120.82it/s]
# 63it [00:00, 121.03it/s]
# array([[-0.18037276,  0.35385185, -0.16759218, ...,  0.5003021 ,
#          1.5556029 ,  1.058405  ],
#        [-2.3018196 ,  2.3530893 , -2.2054327 , ...,  0.5673783 ,
#          1.1191154 , -0.11645429],
#        [-0.24052781,  0.31528875, -0.20900111, ...,  0.5904805 ,
#          1.4916421 ,  0.9909107 ],
#        ...,
#        [-6.38664   ,  6.560318  , -6.7763    , ...,  0.27152824,
#          0.62476355,  0.06293894],
#        [-1.5524892 ,  1.7268795 , -1.7173613 , ...,  0.36882314,
#          1.553221  , -0.3531581 ],
#        [-0.07585675,  0.16789986, -0.13623281, ...,  0.54330325,
#          1.8575021 ,  1.3175907 ]], dtype=float32)

# %%
clf = CatBoostClassifier(loss_function='MultiClass', task_type="GPU", devices='0', random_state=222)

clf.fit(train_embeds, target_train, plot_file="catboost_log.html")
# Out:
# Learning rate set to 0.088214
# 0:	learn: 0.6698056	total: 8.31ms	remaining: 8.3s
# 1:	learn: 0.6503327	total: 13.5ms	remaining: 6.75s
# 2:	learn: 0.6335206	total: 18.6ms	remaining: 6.2s
# 3:	learn: 0.6189962	total: 23.7ms	remaining: 5.9s
# 4:	learn: 0.6068010	total: 28.9ms	remaining: 5.76s
# 5:	learn: 0.5951043	total: 34.1ms	remaining: 5.64s
# 6:	learn: 0.5857027	total: 39.2ms	remaining: 5.56s
# 7:	learn: 0.5767852	total: 44.4ms	remaining: 5.5s
# 8:	learn: 0.5694263	total: 49.9ms	remaining: 5.49s
# 9:	learn: 0.5617789	total: 55ms	remaining: 5.44s
# 10:	learn: 0.5558262	total: 60ms	remaining: 5.39s
# 11:	learn: 0.5496730	total: 65.3ms	remaining: 5.37s
# 12:	learn: 0.5445872	total: 70.2ms	remaining: 5.33s
# 13:	learn: 0.5401463	total: 75.3ms	remaining: 5.3s
# 14:	learn: 0.5359452	total: 80.7ms	remaining: 5.3s
# 15:	learn: 0.5322547	total: 85.8ms	remaining: 5.27s
# 16:	learn: 0.5285830	total: 90.9ms	remaining: 5.25s
# 17:	learn: 0.5252331	total: 95.9ms	remaining: 5.23s
# 18:	learn: 0.5222176	total: 101ms	remaining: 5.21s
# 19:	learn: 0.5195031	total: 106ms	remaining: 5.2s
# 20:	learn: 0.5171344	total: 111ms	remaining: 5.19s
# 21:	learn: 0.5144066	total: 116ms	remaining: 5.18s
# 22:	learn: 0.5118165	total: 122ms	remaining: 5.17s
# 23:	learn: 0.5094752	total: 127ms	remaining: 5.15s
# 24:	learn: 0.5069427	total: 132ms	remaining: 5.17s
# 25:	learn: 0.5051558	total: 138ms	remaining: 5.16s
# 26:	learn: 0.5033003	total: 143ms	remaining: 5.15s
# 27:	learn: 0.5008567	total: 148ms	remaining: 5.13s
# 28:	learn: 0.4985989	total: 153ms	remaining: 5.13s
# 29:	learn: 0.4966481	total: 158ms	remaining: 5.11s
# 30:	learn: 0.4948757	total: 163ms	remaining: 5.11s
# 31:	learn: 0.4936598	total: 168ms	remaining: 5.09s
# 32:	learn: 0.4920967	total: 173ms	remaining: 5.08s
# 33:	learn: 0.4900465	total: 179ms	remaining: 5.08s
# 34:	learn: 0.4878261	total: 184ms	remaining: 5.08s
# 35:	learn: 0.4860731	total: 189ms	remaining: 5.07s
# 36:	learn: 0.4845973	total: 194ms	remaining: 5.06s
# 37:	learn: 0.4824932	total: 199ms	remaining: 5.05s
# 38:	learn: 0.4811263	total: 205ms	remaining: 5.04s
# 39:	learn: 0.4794640	total: 210ms	remaining: 5.04s
# 40:	learn: 0.4777425	total: 215ms	remaining: 5.04s
# 41:	learn: 0.4763573	total: 221ms	remaining: 5.04s
# 42:	learn: 0.4752862	total: 226ms	remaining: 5.02s
# 43:	learn: 0.4740908	total: 231ms	remaining: 5.01s
# 44:	learn: 0.4726734	total: 235ms	remaining: 4.99s
# 45:	learn: 0.4714753	total: 239ms	remaining: 4.97s
# 46:	learn: 0.4701673	total: 244ms	remaining: 4.94s
# 47:	learn: 0.4693415	total: 248ms	remaining: 4.92s
# 48:	learn: 0.4682550	total: 252ms	remaining: 4.9s
# 49:	learn: 0.4668502	total: 257ms	remaining: 4.88s
# 50:	learn: 0.4647575	total: 261ms	remaining: 4.87s
# 51:	learn: 0.4632125	total: 266ms	remaining: 4.85s
# 52:	learn: 0.4621966	total: 270ms	remaining: 4.83s
# 53:	learn: 0.4610233	total: 275ms	remaining: 4.81s
# 54:	learn: 0.4597291	total: 279ms	remaining: 4.79s
# 55:	learn: 0.4583319	total: 284ms	remaining: 4.78s
# 56:	learn: 0.4573855	total: 288ms	remaining: 4.76s
# 57:	learn: 0.4562074	total: 292ms	remaining: 4.75s
# 58:	learn: 0.4549670	total: 297ms	remaining: 4.73s
# 59:	learn: 0.4539000	total: 301ms	remaining: 4.71s
# 60:	learn: 0.4524799	total: 306ms	remaining: 4.71s
# 61:	learn: 0.4512802	total: 310ms	remaining: 4.69s
# 62:	learn: 0.4498884	total: 314ms	remaining: 4.67s
# 63:	learn: 0.4490918	total: 319ms	remaining: 4.66s
# 64:	learn: 0.4478816	total: 323ms	remaining: 4.65s
# 65:	learn: 0.4468156	total: 328ms	remaining: 4.64s
# 66:	learn: 0.4458684	total: 333ms	remaining: 4.63s
# 67:	learn: 0.4446686	total: 337ms	remaining: 4.62s
# 68:	learn: 0.4436135	total: 341ms	remaining: 4.61s
# 69:	learn: 0.4427038	total: 346ms	remaining: 4.59s
# 70:	learn: 0.4413576	total: 350ms	remaining: 4.58s
# 71:	learn: 0.4400994	total: 355ms	remaining: 4.57s
# 72:	learn: 0.4392168	total: 359ms	remaining: 4.56s
# 73:	learn: 0.4380920	total: 364ms	remaining: 4.55s
# 74:	learn: 0.4373907	total: 368ms	remaining: 4.54s
# 75:	learn: 0.4365266	total: 372ms	remaining: 4.53s
# 76:	learn: 0.4357462	total: 377ms	remaining: 4.52s
# 77:	learn: 0.4349993	total: 382ms	remaining: 4.52s
# 78:	learn: 0.4341236	total: 387ms	remaining: 4.51s
# 79:	learn: 0.4331556	total: 392ms	remaining: 4.51s
# 80:	learn: 0.4319254	total: 397ms	remaining: 4.5s
# 81:	learn: 0.4310857	total: 402ms	remaining: 4.5s
# 82:	learn: 0.4300068	total: 406ms	remaining: 4.49s
# 83:	learn: 0.4292115	total: 410ms	remaining: 4.47s
# 84:	learn: 0.4283200	total: 415ms	remaining: 4.47s
# 85:	learn: 0.4272490	total: 419ms	remaining: 4.46s
# 86:	learn: 0.4261460	total: 424ms	remaining: 4.45s
# 87:	learn: 0.4253850	total: 428ms	remaining: 4.44s
# 88:	learn: 0.4246995	total: 433ms	remaining: 4.43s
# 89:	learn: 0.4240317	total: 437ms	remaining: 4.42s
# 90:	learn: 0.4234445	total: 442ms	remaining: 4.41s
# 91:	learn: 0.4223909	total: 446ms	remaining: 4.41s
# 92:	learn: 0.4217557	total: 451ms	remaining: 4.39s
# 93:	learn: 0.4210112	total: 455ms	remaining: 4.39s
# 94:	learn: 0.4202502	total: 460ms	remaining: 4.38s
# 95:	learn: 0.4192772	total: 464ms	remaining: 4.37s
# 96:	learn: 0.4184524	total: 469ms	remaining: 4.36s
# 97:	learn: 0.4176125	total: 473ms	remaining: 4.36s
# 98:	learn: 0.4169105	total: 478ms	remaining: 4.35s
# 99:	learn: 0.4162142	total: 482ms	remaining: 4.34s
# 100:	learn: 0.4150799	total: 486ms	remaining: 4.33s
# 101:	learn: 0.4144722	total: 491ms	remaining: 4.32s
# 102:	learn: 0.4136257	total: 495ms	remaining: 4.31s
# 103:	learn: 0.4127053	total: 500ms	remaining: 4.31s
# 104:	learn: 0.4122008	total: 504ms	remaining: 4.3s
# 105:	learn: 0.4114372	total: 509ms	remaining: 4.29s
# 106:	learn: 0.4103494	total: 513ms	remaining: 4.28s
# 107:	learn: 0.4092339	total: 518ms	remaining: 4.28s
# 108:	learn: 0.4083738	total: 523ms	remaining: 4.27s
# 109:	learn: 0.4074513	total: 527ms	remaining: 4.26s
# 110:	learn: 0.4065842	total: 531ms	remaining: 4.26s
# 111:	learn: 0.4057776	total: 536ms	remaining: 4.25s
# 112:	learn: 0.4050943	total: 540ms	remaining: 4.24s
# 113:	learn: 0.4041447	total: 545ms	remaining: 4.24s
# 114:	learn: 0.4032265	total: 550ms	remaining: 4.23s
# 115:	learn: 0.4024717	total: 555ms	remaining: 4.23s
# 116:	learn: 0.4015946	total: 560ms	remaining: 4.23s
# 117:	learn: 0.4007531	total: 565ms	remaining: 4.22s
# 118:	learn: 0.3999842	total: 570ms	remaining: 4.22s
# 119:	learn: 0.3993354	total: 575ms	remaining: 4.21s
# 120:	learn: 0.3983449	total: 580ms	remaining: 4.21s
# 121:	learn: 0.3976535	total: 585ms	remaining: 4.21s
# 122:	learn: 0.3971220	total: 590ms	remaining: 4.2s
# 123:	learn: 0.3961012	total: 595ms	remaining: 4.2s
# 124:	learn: 0.3953426	total: 600ms	remaining: 4.2s
# 125:	learn: 0.3942998	total: 604ms	remaining: 4.19s
# 126:	learn: 0.3934976	total: 609ms	remaining: 4.19s
# 127:	learn: 0.3929316	total: 614ms	remaining: 4.18s
# 128:	learn: 0.3918997	total: 619ms	remaining: 4.18s
# 129:	learn: 0.3910519	total: 624ms	remaining: 4.18s
# 130:	learn: 0.3903496	total: 629ms	remaining: 4.17s
# 131:	learn: 0.3894296	total: 634ms	remaining: 4.17s
# 132:	learn: 0.3886507	total: 638ms	remaining: 4.16s
# 133:	learn: 0.3875814	total: 642ms	remaining: 4.15s
# 134:	learn: 0.3866300	total: 647ms	remaining: 4.14s
# 135:	learn: 0.3858753	total: 652ms	remaining: 4.14s
# 136:	learn: 0.3850053	total: 657ms	remaining: 4.14s
# 137:	learn: 0.3839207	total: 662ms	remaining: 4.13s
# 138:	learn: 0.3833735	total: 666ms	remaining: 4.12s
# 139:	learn: 0.3828920	total: 670ms	remaining: 4.12s
# 140:	learn: 0.3821040	total: 675ms	remaining: 4.11s
# 141:	learn: 0.3814809	total: 679ms	remaining: 4.1s
# 142:	learn: 0.3808722	total: 684ms	remaining: 4.1s
# 143:	learn: 0.3802709	total: 688ms	remaining: 4.09s
# 144:	learn: 0.3797517	total: 693ms	remaining: 4.09s
# 145:	learn: 0.3790363	total: 697ms	remaining: 4.08s
# 146:	learn: 0.3782737	total: 702ms	remaining: 4.07s
# 147:	learn: 0.3777896	total: 706ms	remaining: 4.07s
# 148:	learn: 0.3770780	total: 711ms	remaining: 4.06s
# 149:	learn: 0.3759579	total: 716ms	remaining: 4.06s
# 150:	learn: 0.3752464	total: 721ms	remaining: 4.06s
# 151:	learn: 0.3745451	total: 727ms	remaining: 4.05s
# 152:	learn: 0.3739056	total: 731ms	remaining: 4.05s
# 153:	learn: 0.3730153	total: 736ms	remaining: 4.04s
# 154:	learn: 0.3723005	total: 742ms	remaining: 4.04s
# 155:	learn: 0.3715285	total: 747ms	remaining: 4.04s
# 156:	learn: 0.3708038	total: 752ms	remaining: 4.04s
# 157:	learn: 0.3700279	total: 756ms	remaining: 4.03s
# 158:	learn: 0.3695038	total: 761ms	remaining: 4.03s
# 159:	learn: 0.3688492	total: 766ms	remaining: 4.02s
# 160:	learn: 0.3683467	total: 771ms	remaining: 4.02s
# 161:	learn: 0.3677334	total: 776ms	remaining: 4.01s
# 162:	learn: 0.3670764	total: 781ms	remaining: 4.01s
# 163:	learn: 0.3666469	total: 785ms	remaining: 4s
# 164:	learn: 0.3656830	total: 790ms	remaining: 4s
# 165:	learn: 0.3648131	total: 794ms	remaining: 3.99s
# 166:	learn: 0.3639649	total: 799ms	remaining: 3.98s
# 167:	learn: 0.3633678	total: 803ms	remaining: 3.98s
# 168:	learn: 0.3627442	total: 807ms	remaining: 3.97s
# 169:	learn: 0.3618405	total: 812ms	remaining: 3.97s
# 170:	learn: 0.3614419	total: 817ms	remaining: 3.96s
# 171:	learn: 0.3606711	total: 821ms	remaining: 3.95s
# 172:	learn: 0.3596257	total: 826ms	remaining: 3.95s
# 173:	learn: 0.3588780	total: 830ms	remaining: 3.94s
# 174:	learn: 0.3580604	total: 835ms	remaining: 3.93s
# 175:	learn: 0.3572173	total: 839ms	remaining: 3.93s
# 176:	learn: 0.3562679	total: 844ms	remaining: 3.92s
# 177:	learn: 0.3557987	total: 848ms	remaining: 3.92s
# 178:	learn: 0.3551882	total: 853ms	remaining: 3.91s
# 179:	learn: 0.3545419	total: 857ms	remaining: 3.9s
# 180:	learn: 0.3536801	total: 861ms	remaining: 3.9s
# 181:	learn: 0.3531087	total: 866ms	remaining: 3.89s
# 182:	learn: 0.3525331	total: 870ms	remaining: 3.88s
# 183:	learn: 0.3518487	total: 875ms	remaining: 3.88s
# 184:	learn: 0.3508748	total: 879ms	remaining: 3.87s
# 185:	learn: 0.3502359	total: 884ms	remaining: 3.87s
# 186:	learn: 0.3490634	total: 888ms	remaining: 3.86s
# 187:	learn: 0.3485628	total: 892ms	remaining: 3.85s
# 188:	learn: 0.3480564	total: 897ms	remaining: 3.85s
# 189:	learn: 0.3474106	total: 901ms	remaining: 3.84s
# 190:	learn: 0.3467410	total: 906ms	remaining: 3.84s
# 191:	learn: 0.3462388	total: 910ms	remaining: 3.83s
# 192:	learn: 0.3457230	total: 915ms	remaining: 3.82s
# 193:	learn: 0.3453532	total: 919ms	remaining: 3.82s
# 194:	learn: 0.3447606	total: 923ms	remaining: 3.81s
# 195:	learn: 0.3438190	total: 928ms	remaining: 3.81s
# 196:	learn: 0.3431031	total: 933ms	remaining: 3.8s
# 197:	learn: 0.3424895	total: 937ms	remaining: 3.8s
# 198:	learn: 0.3419619	total: 942ms	remaining: 3.79s
# 199:	learn: 0.3415129	total: 946ms	remaining: 3.79s
# 200:	learn: 0.3411403	total: 951ms	remaining: 3.78s
# 201:	learn: 0.3407616	total: 955ms	remaining: 3.77s
# 202:	learn: 0.3402307	total: 960ms	remaining: 3.77s
# 203:	learn: 0.3397578	total: 964ms	remaining: 3.76s
# 204:	learn: 0.3389316	total: 968ms	remaining: 3.75s
# 205:	learn: 0.3382931	total: 973ms	remaining: 3.75s
# 206:	learn: 0.3380076	total: 978ms	remaining: 3.75s
# 207:	learn: 0.3374067	total: 983ms	remaining: 3.74s
# 208:	learn: 0.3369017	total: 987ms	remaining: 3.74s
# 209:	learn: 0.3361682	total: 992ms	remaining: 3.73s
# 210:	learn: 0.3358091	total: 997ms	remaining: 3.73s
# 211:	learn: 0.3351918	total: 1s	remaining: 3.72s
# 212:	learn: 0.3347757	total: 1.01s	remaining: 3.72s
# 213:	learn: 0.3343400	total: 1.01s	remaining: 3.71s
# 214:	learn: 0.3338720	total: 1.02s	remaining: 3.71s
# 215:	learn: 0.3332086	total: 1.02s	remaining: 3.71s
# 216:	learn: 0.3325707	total: 1.02s	remaining: 3.7s
# 217:	learn: 0.3319720	total: 1.03s	remaining: 3.7s
# 218:	learn: 0.3313425	total: 1.03s	remaining: 3.69s
# 219:	learn: 0.3308693	total: 1.04s	remaining: 3.69s
# 220:	learn: 0.3302840	total: 1.04s	remaining: 3.69s
# 221:	learn: 0.3296969	total: 1.05s	remaining: 3.68s
# 222:	learn: 0.3293329	total: 1.05s	remaining: 3.68s
# 223:	learn: 0.3288536	total: 1.06s	remaining: 3.67s
# 224:	learn: 0.3282796	total: 1.06s	remaining: 3.67s
# 225:	learn: 0.3278171	total: 1.07s	remaining: 3.66s
# 226:	learn: 0.3272759	total: 1.07s	remaining: 3.66s
# 227:	learn: 0.3267653	total: 1.08s	remaining: 3.65s
# 228:	learn: 0.3262695	total: 1.08s	remaining: 3.65s
# 229:	learn: 0.3256514	total: 1.09s	remaining: 3.65s
# 230:	learn: 0.3250824	total: 1.09s	remaining: 3.64s
# 231:	learn: 0.3245358	total: 1.1s	remaining: 3.64s
# 232:	learn: 0.3239273	total: 1.1s	remaining: 3.63s
# 233:	learn: 0.3233843	total: 1.11s	remaining: 3.63s
# 234:	learn: 0.3231388	total: 1.11s	remaining: 3.62s
# 235:	learn: 0.3228886	total: 1.12s	remaining: 3.62s
# 236:	learn: 0.3222680	total: 1.12s	remaining: 3.61s
# 237:	learn: 0.3215469	total: 1.13s	remaining: 3.61s
# 238:	learn: 0.3210128	total: 1.13s	remaining: 3.6s
# 239:	learn: 0.3204029	total: 1.14s	remaining: 3.6s
# 240:	learn: 0.3196075	total: 1.14s	remaining: 3.59s
# 241:	learn: 0.3191150	total: 1.14s	remaining: 3.59s
# 242:	learn: 0.3184871	total: 1.15s	remaining: 3.58s
# 243:	learn: 0.3181494	total: 1.15s	remaining: 3.58s
# 244:	learn: 0.3178406	total: 1.16s	remaining: 3.57s
# 245:	learn: 0.3172677	total: 1.16s	remaining: 3.56s
# 246:	learn: 0.3167228	total: 1.17s	remaining: 3.56s
# 247:	learn: 0.3160115	total: 1.17s	remaining: 3.55s
# 248:	learn: 0.3155496	total: 1.18s	remaining: 3.55s
# 249:	learn: 0.3150143	total: 1.18s	remaining: 3.54s
# 250:	learn: 0.3145154	total: 1.19s	remaining: 3.54s
# 251:	learn: 0.3138049	total: 1.19s	remaining: 3.53s
# 252:	learn: 0.3131431	total: 1.19s	remaining: 3.53s
# 253:	learn: 0.3124581	total: 1.2s	remaining: 3.52s
# 254:	learn: 0.3119408	total: 1.2s	remaining: 3.52s
# 255:	learn: 0.3113204	total: 1.21s	remaining: 3.51s
# 256:	learn: 0.3105702	total: 1.21s	remaining: 3.51s
# 257:	learn: 0.3098621	total: 1.22s	remaining: 3.5s
# 258:	learn: 0.3094664	total: 1.22s	remaining: 3.5s
# 259:	learn: 0.3090662	total: 1.23s	remaining: 3.49s
# 260:	learn: 0.3086027	total: 1.23s	remaining: 3.48s
# 261:	learn: 0.3081904	total: 1.24s	remaining: 3.48s
# 262:	learn: 0.3077687	total: 1.24s	remaining: 3.47s
# 263:	learn: 0.3067993	total: 1.24s	remaining: 3.47s
# 264:	learn: 0.3061658	total: 1.25s	remaining: 3.46s
# 265:	learn: 0.3057016	total: 1.25s	remaining: 3.46s
# 266:	learn: 0.3051126	total: 1.26s	remaining: 3.45s
# 267:	learn: 0.3044712	total: 1.26s	remaining: 3.45s
# 268:	learn: 0.3040226	total: 1.27s	remaining: 3.44s
# 269:	learn: 0.3036369	total: 1.27s	remaining: 3.44s
# 270:	learn: 0.3030108	total: 1.27s	remaining: 3.43s
# 271:	learn: 0.3025858	total: 1.28s	remaining: 3.42s
# 272:	learn: 0.3020469	total: 1.28s	remaining: 3.42s
# 273:	learn: 0.3015377	total: 1.29s	remaining: 3.42s
# 274:	learn: 0.3008066	total: 1.29s	remaining: 3.41s
# 275:	learn: 0.3001533	total: 1.3s	remaining: 3.4s
# 276:	learn: 0.2995218	total: 1.3s	remaining: 3.4s
# 277:	learn: 0.2988961	total: 1.31s	remaining: 3.39s
# 278:	learn: 0.2984675	total: 1.31s	remaining: 3.39s
# 279:	learn: 0.2979444	total: 1.32s	remaining: 3.38s
# 280:	learn: 0.2972571	total: 1.32s	remaining: 3.38s
# 281:	learn: 0.2969220	total: 1.32s	remaining: 3.37s
# 282:	learn: 0.2960434	total: 1.33s	remaining: 3.37s
# 283:	learn: 0.2955050	total: 1.33s	remaining: 3.36s
# 284:	learn: 0.2950638	total: 1.34s	remaining: 3.36s
# 285:	learn: 0.2944639	total: 1.34s	remaining: 3.35s
# 286:	learn: 0.2939908	total: 1.35s	remaining: 3.35s
# 287:	learn: 0.2934589	total: 1.35s	remaining: 3.34s
# 288:	learn: 0.2930263	total: 1.36s	remaining: 3.34s
# 289:	learn: 0.2927430	total: 1.36s	remaining: 3.33s
# 290:	learn: 0.2920956	total: 1.36s	remaining: 3.33s
# 291:	learn: 0.2916384	total: 1.37s	remaining: 3.32s
# 292:	learn: 0.2911758	total: 1.37s	remaining: 3.32s
# 293:	learn: 0.2908231	total: 1.38s	remaining: 3.31s
# 294:	learn: 0.2903834	total: 1.38s	remaining: 3.31s
# 295:	learn: 0.2898765	total: 1.39s	remaining: 3.31s
# 296:	learn: 0.2893170	total: 1.39s	remaining: 3.3s
# 297:	learn: 0.2888347	total: 1.4s	remaining: 3.3s
# 298:	learn: 0.2884972	total: 1.4s	remaining: 3.29s
# 299:	learn: 0.2879361	total: 1.41s	remaining: 3.29s
# 300:	learn: 0.2876072	total: 1.41s	remaining: 3.28s
# 301:	learn: 0.2872443	total: 1.42s	remaining: 3.27s
# 302:	learn: 0.2869653	total: 1.42s	remaining: 3.27s
# 303:	learn: 0.2864226	total: 1.43s	remaining: 3.27s
# 304:	learn: 0.2858579	total: 1.43s	remaining: 3.26s
# 305:	learn: 0.2854146	total: 1.43s	remaining: 3.25s
# 306:	learn: 0.2848128	total: 1.44s	remaining: 3.25s
# 307:	learn: 0.2842293	total: 1.44s	remaining: 3.24s
# 308:	learn: 0.2839700	total: 1.45s	remaining: 3.24s
# 309:	learn: 0.2834437	total: 1.45s	remaining: 3.23s
# 310:	learn: 0.2830548	total: 1.46s	remaining: 3.23s
# 311:	learn: 0.2826769	total: 1.46s	remaining: 3.22s
# 312:	learn: 0.2821786	total: 1.47s	remaining: 3.22s
# 313:	learn: 0.2819959	total: 1.47s	remaining: 3.21s
# 314:	learn: 0.2815508	total: 1.47s	remaining: 3.21s
# 315:	learn: 0.2807814	total: 1.48s	remaining: 3.2s
# 316:	learn: 0.2803004	total: 1.48s	remaining: 3.2s
# 317:	learn: 0.2798449	total: 1.49s	remaining: 3.19s
# 318:	learn: 0.2794360	total: 1.49s	remaining: 3.19s
# 319:	learn: 0.2791484	total: 1.5s	remaining: 3.18s
# 320:	learn: 0.2787178	total: 1.5s	remaining: 3.18s
# 321:	learn: 0.2785346	total: 1.51s	remaining: 3.17s
# 322:	learn: 0.2780992	total: 1.51s	remaining: 3.17s
# 323:	learn: 0.2777112	total: 1.52s	remaining: 3.16s
# 324:	learn: 0.2770663	total: 1.52s	remaining: 3.16s
# 325:	learn: 0.2765017	total: 1.53s	remaining: 3.16s
# 326:	learn: 0.2762243	total: 1.53s	remaining: 3.15s
# 327:	learn: 0.2757987	total: 1.54s	remaining: 3.15s
# 328:	learn: 0.2751389	total: 1.54s	remaining: 3.14s
# 329:	learn: 0.2746948	total: 1.55s	remaining: 3.14s
# 330:	learn: 0.2742653	total: 1.55s	remaining: 3.13s
# 331:	learn: 0.2736819	total: 1.56s	remaining: 3.13s
# 332:	learn: 0.2733235	total: 1.56s	remaining: 3.13s
# 333:	learn: 0.2729863	total: 1.57s	remaining: 3.12s
# 334:	learn: 0.2726189	total: 1.57s	remaining: 3.12s
# 335:	learn: 0.2719838	total: 1.58s	remaining: 3.12s
# 336:	learn: 0.2711086	total: 1.58s	remaining: 3.11s
# 337:	learn: 0.2708488	total: 1.59s	remaining: 3.11s
# 338:	learn: 0.2702791	total: 1.59s	remaining: 3.1s
# 339:	learn: 0.2698459	total: 1.6s	remaining: 3.1s
# 340:	learn: 0.2693881	total: 1.6s	remaining: 3.1s
# 341:	learn: 0.2690057	total: 1.61s	remaining: 3.09s
# 342:	learn: 0.2685867	total: 1.61s	remaining: 3.09s
# 343:	learn: 0.2681444	total: 1.62s	remaining: 3.08s
# 344:	learn: 0.2678108	total: 1.62s	remaining: 3.08s
# 345:	learn: 0.2674416	total: 1.63s	remaining: 3.07s
# 346:	learn: 0.2669717	total: 1.63s	remaining: 3.07s
# 347:	learn: 0.2666509	total: 1.64s	remaining: 3.07s
# 348:	learn: 0.2660993	total: 1.64s	remaining: 3.06s
# 349:	learn: 0.2658753	total: 1.65s	remaining: 3.06s
# 350:	learn: 0.2654306	total: 1.65s	remaining: 3.05s
# 351:	learn: 0.2650996	total: 1.65s	remaining: 3.05s
# 352:	learn: 0.2647209	total: 1.66s	remaining: 3.04s
# 353:	learn: 0.2643134	total: 1.66s	remaining: 3.04s
# 354:	learn: 0.2640762	total: 1.67s	remaining: 3.03s
# 355:	learn: 0.2635176	total: 1.67s	remaining: 3.03s
# 356:	learn: 0.2632202	total: 1.68s	remaining: 3.02s
# 357:	learn: 0.2627410	total: 1.68s	remaining: 3.02s
# 358:	learn: 0.2622871	total: 1.69s	remaining: 3.01s
# 359:	learn: 0.2620464	total: 1.69s	remaining: 3.01s
# 360:	learn: 0.2614201	total: 1.7s	remaining: 3.01s
# 361:	learn: 0.2611335	total: 1.7s	remaining: 3s
# 362:	learn: 0.2608233	total: 1.71s	remaining: 3s
# 363:	learn: 0.2605455	total: 1.71s	remaining: 2.99s
# 364:	learn: 0.2601798	total: 1.72s	remaining: 2.99s
# 365:	learn: 0.2598744	total: 1.72s	remaining: 2.98s
# 366:	learn: 0.2594859	total: 1.73s	remaining: 2.98s
# 367:	learn: 0.2589492	total: 1.73s	remaining: 2.98s
# 368:	learn: 0.2585119	total: 1.74s	remaining: 2.97s
# 369:	learn: 0.2580041	total: 1.74s	remaining: 2.97s
# 370:	learn: 0.2575633	total: 1.75s	remaining: 2.96s
# 371:	learn: 0.2571364	total: 1.75s	remaining: 2.96s
# 372:	learn: 0.2566536	total: 1.76s	remaining: 2.95s
# 373:	learn: 0.2560261	total: 1.76s	remaining: 2.95s
# 374:	learn: 0.2557603	total: 1.77s	remaining: 2.94s
# 375:	learn: 0.2552759	total: 1.77s	remaining: 2.94s
# 376:	learn: 0.2547810	total: 1.78s	remaining: 2.94s
# 377:	learn: 0.2544271	total: 1.78s	remaining: 2.93s
# 378:	learn: 0.2540238	total: 1.79s	remaining: 2.93s
# 379:	learn: 0.2536440	total: 1.79s	remaining: 2.92s
# 380:	learn: 0.2533342	total: 1.8s	remaining: 2.92s
# 381:	learn: 0.2530897	total: 1.8s	remaining: 2.91s
# 382:	learn: 0.2526846	total: 1.81s	remaining: 2.91s
# 383:	learn: 0.2523762	total: 1.81s	remaining: 2.91s
# 384:	learn: 0.2518842	total: 1.82s	remaining: 2.9s
# 385:	learn: 0.2514406	total: 1.82s	remaining: 2.9s
# 386:	learn: 0.2511258	total: 1.82s	remaining: 2.89s
# 387:	learn: 0.2506556	total: 1.83s	remaining: 2.89s
# 388:	learn: 0.2501974	total: 1.83s	remaining: 2.88s
# 389:	learn: 0.2497876	total: 1.84s	remaining: 2.88s
# 390:	learn: 0.2495145	total: 1.84s	remaining: 2.87s
# 391:	learn: 0.2490660	total: 1.85s	remaining: 2.87s
# 392:	learn: 0.2486267	total: 1.85s	remaining: 2.86s
# 393:	learn: 0.2483885	total: 1.86s	remaining: 2.86s
# 394:	learn: 0.2480060	total: 1.86s	remaining: 2.85s
# 395:	learn: 0.2477005	total: 1.86s	remaining: 2.85s
# 396:	learn: 0.2472662	total: 1.87s	remaining: 2.84s
# 397:	learn: 0.2469120	total: 1.88s	remaining: 2.84s
# 398:	learn: 0.2466060	total: 1.88s	remaining: 2.83s
# 399:	learn: 0.2462628	total: 1.88s	remaining: 2.83s
# 400:	learn: 0.2456478	total: 1.89s	remaining: 2.82s
# 401:	learn: 0.2453480	total: 1.89s	remaining: 2.81s
# 402:	learn: 0.2448855	total: 1.9s	remaining: 2.81s
# 403:	learn: 0.2445341	total: 1.9s	remaining: 2.81s
# 404:	learn: 0.2443577	total: 1.91s	remaining: 2.8s
# 405:	learn: 0.2440716	total: 1.91s	remaining: 2.8s
# 406:	learn: 0.2435702	total: 1.92s	remaining: 2.79s
# 407:	learn: 0.2431827	total: 1.92s	remaining: 2.79s
# 408:	learn: 0.2425128	total: 1.93s	remaining: 2.79s
# 409:	learn: 0.2422278	total: 1.93s	remaining: 2.78s
# 410:	learn: 0.2418354	total: 1.94s	remaining: 2.78s
# 411:	learn: 0.2415550	total: 1.94s	remaining: 2.77s
# 412:	learn: 0.2412140	total: 1.95s	remaining: 2.77s
# 413:	learn: 0.2407750	total: 1.95s	remaining: 2.76s
# 414:	learn: 0.2404443	total: 1.96s	remaining: 2.76s
# 415:	learn: 0.2399491	total: 1.96s	remaining: 2.75s
# 416:	learn: 0.2396505	total: 1.97s	remaining: 2.75s
# 417:	learn: 0.2393471	total: 1.97s	remaining: 2.74s
# 418:	learn: 0.2391480	total: 1.97s	remaining: 2.74s
# 419:	learn: 0.2386153	total: 1.98s	remaining: 2.73s
# 420:	learn: 0.2383714	total: 1.98s	remaining: 2.73s
# 421:	learn: 0.2380229	total: 1.99s	remaining: 2.72s
# 422:	learn: 0.2373784	total: 1.99s	remaining: 2.72s
# 423:	learn: 0.2369084	total: 2s	remaining: 2.71s
# 424:	learn: 0.2365385	total: 2s	remaining: 2.71s
# 425:	learn: 0.2361053	total: 2s	remaining: 2.7s
# 426:	learn: 0.2356313	total: 2.01s	remaining: 2.7s
# 427:	learn: 0.2353242	total: 2.01s	remaining: 2.69s
# 428:	learn: 0.2350272	total: 2.02s	remaining: 2.69s
# 429:	learn: 0.2347409	total: 2.02s	remaining: 2.68s
# 430:	learn: 0.2343394	total: 2.03s	remaining: 2.68s
# 431:	learn: 0.2340067	total: 2.03s	remaining: 2.67s
# 432:	learn: 0.2333910	total: 2.04s	remaining: 2.67s
# 433:	learn: 0.2331249	total: 2.04s	remaining: 2.67s
# 434:	learn: 0.2329169	total: 2.05s	remaining: 2.66s
# 435:	learn: 0.2325532	total: 2.05s	remaining: 2.66s
# 436:	learn: 0.2320109	total: 2.06s	remaining: 2.65s
# 437:	learn: 0.2316425	total: 2.06s	remaining: 2.65s
# 438:	learn: 0.2313885	total: 2.07s	remaining: 2.64s
# 439:	learn: 0.2311474	total: 2.07s	remaining: 2.64s
# 440:	learn: 0.2307720	total: 2.08s	remaining: 2.63s
# 441:	learn: 0.2302679	total: 2.08s	remaining: 2.63s
# 442:	learn: 0.2298332	total: 2.09s	remaining: 2.63s
# 443:	learn: 0.2295656	total: 2.09s	remaining: 2.62s
# 444:	learn: 0.2292015	total: 2.1s	remaining: 2.62s
# 445:	learn: 0.2289274	total: 2.1s	remaining: 2.61s
# 446:	learn: 0.2285589	total: 2.11s	remaining: 2.61s
# 447:	learn: 0.2282583	total: 2.11s	remaining: 2.6s
# 448:	learn: 0.2280203	total: 2.12s	remaining: 2.6s
# 449:	learn: 0.2278179	total: 2.12s	remaining: 2.59s
# 450:	learn: 0.2275912	total: 2.13s	remaining: 2.59s
# 451:	learn: 0.2271629	total: 2.13s	remaining: 2.58s
# 452:	learn: 0.2268076	total: 2.13s	remaining: 2.58s
# 453:	learn: 0.2264653	total: 2.14s	remaining: 2.57s
# 454:	learn: 0.2260555	total: 2.14s	remaining: 2.57s
# 455:	learn: 0.2256050	total: 2.15s	remaining: 2.56s
# 456:	learn: 0.2252838	total: 2.15s	remaining: 2.56s
# 457:	learn: 0.2248689	total: 2.16s	remaining: 2.55s
# 458:	learn: 0.2244196	total: 2.16s	remaining: 2.55s
# 459:	learn: 0.2242272	total: 2.17s	remaining: 2.54s
# 460:	learn: 0.2240594	total: 2.17s	remaining: 2.54s
# 461:	learn: 0.2236600	total: 2.17s	remaining: 2.53s
# 462:	learn: 0.2233291	total: 2.18s	remaining: 2.53s
# 463:	learn: 0.2230457	total: 2.18s	remaining: 2.52s
# 464:	learn: 0.2226391	total: 2.19s	remaining: 2.52s
# 465:	learn: 0.2222636	total: 2.19s	remaining: 2.51s
# 466:	learn: 0.2219037	total: 2.2s	remaining: 2.51s
# 467:	learn: 0.2218043	total: 2.2s	remaining: 2.5s
# 468:	learn: 0.2213528	total: 2.21s	remaining: 2.5s
# 469:	learn: 0.2209396	total: 2.21s	remaining: 2.5s
# 470:	learn: 0.2204575	total: 2.22s	remaining: 2.49s
# 471:	learn: 0.2201250	total: 2.22s	remaining: 2.49s
# 472:	learn: 0.2198616	total: 2.23s	remaining: 2.48s
# 473:	learn: 0.2196367	total: 2.23s	remaining: 2.48s
# 474:	learn: 0.2193170	total: 2.24s	remaining: 2.47s
# 475:	learn: 0.2190433	total: 2.24s	remaining: 2.47s
# 476:	learn: 0.2188375	total: 2.25s	remaining: 2.46s
# 477:	learn: 0.2183363	total: 2.25s	remaining: 2.46s
# 478:	learn: 0.2180376	total: 2.25s	remaining: 2.45s
# 479:	learn: 0.2176208	total: 2.26s	remaining: 2.45s
# 480:	learn: 0.2172859	total: 2.26s	remaining: 2.44s
# 481:	learn: 0.2169566	total: 2.27s	remaining: 2.44s
# 482:	learn: 0.2166248	total: 2.27s	remaining: 2.43s
# 483:	learn: 0.2161408	total: 2.28s	remaining: 2.43s
# 484:	learn: 0.2159294	total: 2.28s	remaining: 2.42s
# 485:	learn: 0.2156582	total: 2.29s	remaining: 2.42s
# 486:	learn: 0.2152796	total: 2.29s	remaining: 2.41s
# 487:	learn: 0.2149944	total: 2.3s	remaining: 2.41s
# 488:	learn: 0.2146232	total: 2.3s	remaining: 2.4s
# 489:	learn: 0.2142570	total: 2.31s	remaining: 2.4s
# 490:	learn: 0.2139284	total: 2.31s	remaining: 2.4s
# 491:	learn: 0.2135734	total: 2.31s	remaining: 2.39s
# 492:	learn: 0.2132455	total: 2.32s	remaining: 2.39s
# 493:	learn: 0.2128008	total: 2.33s	remaining: 2.38s
# 494:	learn: 0.2124480	total: 2.33s	remaining: 2.38s
# 495:	learn: 0.2119591	total: 2.33s	remaining: 2.37s
# 496:	learn: 0.2117095	total: 2.34s	remaining: 2.37s
# 497:	learn: 0.2115130	total: 2.34s	remaining: 2.36s
# 498:	learn: 0.2110883	total: 2.35s	remaining: 2.36s
# 499:	learn: 0.2107236	total: 2.35s	remaining: 2.35s
# 500:	learn: 0.2103476	total: 2.36s	remaining: 2.35s
# 501:	learn: 0.2100716	total: 2.36s	remaining: 2.35s
# 502:	learn: 0.2097005	total: 2.37s	remaining: 2.34s
# 503:	learn: 0.2094202	total: 2.37s	remaining: 2.34s
# 504:	learn: 0.2091077	total: 2.38s	remaining: 2.33s
# 505:	learn: 0.2086368	total: 2.38s	remaining: 2.33s
# 506:	learn: 0.2082525	total: 2.39s	remaining: 2.32s
# 507:	learn: 0.2079677	total: 2.39s	remaining: 2.32s
# 508:	learn: 0.2078022	total: 2.4s	remaining: 2.31s
# 509:	learn: 0.2075989	total: 2.4s	remaining: 2.31s
# 510:	learn: 0.2073455	total: 2.41s	remaining: 2.31s
# 511:	learn: 0.2070105	total: 2.42s	remaining: 2.3s
# 512:	learn: 0.2067623	total: 2.42s	remaining: 2.3s
# 513:	learn: 0.2064735	total: 2.42s	remaining: 2.29s
# 514:	learn: 0.2058825	total: 2.43s	remaining: 2.29s
# 515:	learn: 0.2055987	total: 2.44s	remaining: 2.28s
# 516:	learn: 0.2052861	total: 2.44s	remaining: 2.28s
# 517:	learn: 0.2048568	total: 2.44s	remaining: 2.27s
# 518:	learn: 0.2046263	total: 2.45s	remaining: 2.27s
# 519:	learn: 0.2043013	total: 2.46s	remaining: 2.27s
# 520:	learn: 0.2039436	total: 2.46s	remaining: 2.26s
# 521:	learn: 0.2037545	total: 2.46s	remaining: 2.26s
# 522:	learn: 0.2034867	total: 2.47s	remaining: 2.25s
# 523:	learn: 0.2033115	total: 2.48s	remaining: 2.25s
# 524:	learn: 0.2030576	total: 2.48s	remaining: 2.24s
# 525:	learn: 0.2029393	total: 2.48s	remaining: 2.24s
# 526:	learn: 0.2026615	total: 2.49s	remaining: 2.23s
# 527:	learn: 0.2024553	total: 2.49s	remaining: 2.23s
# 528:	learn: 0.2022810	total: 2.5s	remaining: 2.23s
# 529:	learn: 0.2019794	total: 2.5s	remaining: 2.22s
# 530:	learn: 0.2017464	total: 2.51s	remaining: 2.22s
# 531:	learn: 0.2014994	total: 2.51s	remaining: 2.21s
# 532:	learn: 0.2010866	total: 2.52s	remaining: 2.21s
# 533:	learn: 0.2006460	total: 2.52s	remaining: 2.2s
# 534:	learn: 0.2002637	total: 2.53s	remaining: 2.2s
# 535:	learn: 0.2000173	total: 2.53s	remaining: 2.19s
# 536:	learn: 0.1997575	total: 2.54s	remaining: 2.19s
# 537:	learn: 0.1994620	total: 2.54s	remaining: 2.18s
# 538:	learn: 0.1993033	total: 2.55s	remaining: 2.18s
# 539:	learn: 0.1990348	total: 2.55s	remaining: 2.17s
# 540:	learn: 0.1987088	total: 2.56s	remaining: 2.17s
# 541:	learn: 0.1984572	total: 2.56s	remaining: 2.16s
# 542:	learn: 0.1981445	total: 2.57s	remaining: 2.16s
# 543:	learn: 0.1977311	total: 2.57s	remaining: 2.15s
# 544:	learn: 0.1975186	total: 2.58s	remaining: 2.15s
# 545:	learn: 0.1972733	total: 2.58s	remaining: 2.15s
# 546:	learn: 0.1971068	total: 2.58s	remaining: 2.14s
# 547:	learn: 0.1968714	total: 2.59s	remaining: 2.14s
# 548:	learn: 0.1966419	total: 2.6s	remaining: 2.13s
# 549:	learn: 0.1963566	total: 2.6s	remaining: 2.13s
# 550:	learn: 0.1960237	total: 2.6s	remaining: 2.12s
# 551:	learn: 0.1957118	total: 2.61s	remaining: 2.12s
# 552:	learn: 0.1954301	total: 2.61s	remaining: 2.11s
# 553:	learn: 0.1950461	total: 2.62s	remaining: 2.11s
# 554:	learn: 0.1947037	total: 2.62s	remaining: 2.1s
# 555:	learn: 0.1944972	total: 2.63s	remaining: 2.1s
# 556:	learn: 0.1941291	total: 2.63s	remaining: 2.1s
# 557:	learn: 0.1938314	total: 2.64s	remaining: 2.09s
# 558:	learn: 0.1934710	total: 2.64s	remaining: 2.08s
# 559:	learn: 0.1933071	total: 2.65s	remaining: 2.08s
# 560:	learn: 0.1929771	total: 2.65s	remaining: 2.08s
# 561:	learn: 0.1925892	total: 2.66s	remaining: 2.07s
# 562:	learn: 0.1924015	total: 2.66s	remaining: 2.07s
# 563:	learn: 0.1919183	total: 2.67s	remaining: 2.06s
# 564:	learn: 0.1916608	total: 2.67s	remaining: 2.06s
# 565:	learn: 0.1913027	total: 2.68s	remaining: 2.05s
# 566:	learn: 0.1910408	total: 2.68s	remaining: 2.05s
# 567:	learn: 0.1908083	total: 2.69s	remaining: 2.04s
# 568:	learn: 0.1905495	total: 2.69s	remaining: 2.04s
# 569:	learn: 0.1902768	total: 2.7s	remaining: 2.03s
# 570:	learn: 0.1898707	total: 2.7s	remaining: 2.03s
# 571:	learn: 0.1897248	total: 2.71s	remaining: 2.02s
# 572:	learn: 0.1894951	total: 2.71s	remaining: 2.02s
# 573:	learn: 0.1891620	total: 2.72s	remaining: 2.02s
# 574:	learn: 0.1889604	total: 2.72s	remaining: 2.01s
# 575:	learn: 0.1886154	total: 2.73s	remaining: 2.01s
# 576:	learn: 0.1881891	total: 2.73s	remaining: 2s
# 577:	learn: 0.1878603	total: 2.73s	remaining: 2s
# 578:	learn: 0.1877293	total: 2.74s	remaining: 1.99s
# 579:	learn: 0.1875074	total: 2.74s	remaining: 1.99s
# 580:	learn: 0.1873337	total: 2.75s	remaining: 1.98s
# 581:	learn: 0.1871139	total: 2.75s	remaining: 1.98s
# 582:	learn: 0.1868605	total: 2.76s	remaining: 1.97s
# 583:	learn: 0.1865047	total: 2.76s	remaining: 1.97s
# 584:	learn: 0.1861307	total: 2.77s	remaining: 1.96s
# 585:	learn: 0.1859813	total: 2.77s	remaining: 1.96s
# 586:	learn: 0.1858652	total: 2.77s	remaining: 1.95s
# 587:	learn: 0.1857387	total: 2.78s	remaining: 1.95s
# 588:	learn: 0.1854756	total: 2.78s	remaining: 1.94s
# 589:	learn: 0.1851184	total: 2.79s	remaining: 1.94s
# 590:	learn: 0.1848183	total: 2.79s	remaining: 1.93s
# 591:	learn: 0.1847028	total: 2.8s	remaining: 1.93s
# 592:	learn: 0.1844401	total: 2.8s	remaining: 1.92s
# 593:	learn: 0.1842513	total: 2.81s	remaining: 1.92s
# 594:	learn: 0.1839477	total: 2.81s	remaining: 1.91s
# 595:	learn: 0.1835890	total: 2.82s	remaining: 1.91s
# 596:	learn: 0.1833619	total: 2.82s	remaining: 1.91s
# 597:	learn: 0.1831820	total: 2.83s	remaining: 1.9s
# 598:	learn: 0.1830564	total: 2.83s	remaining: 1.9s
# 599:	learn: 0.1829182	total: 2.84s	remaining: 1.89s
# 600:	learn: 0.1825377	total: 2.84s	remaining: 1.89s
# 601:	learn: 0.1822909	total: 2.85s	remaining: 1.88s
# 602:	learn: 0.1819657	total: 2.85s	remaining: 1.88s
# 603:	learn: 0.1817702	total: 2.85s	remaining: 1.87s
# 604:	learn: 0.1814570	total: 2.86s	remaining: 1.87s
# 605:	learn: 0.1811895	total: 2.86s	remaining: 1.86s
# 606:	learn: 0.1808728	total: 2.87s	remaining: 1.86s
# 607:	learn: 0.1806896	total: 2.87s	remaining: 1.85s
# 608:	learn: 0.1804169	total: 2.88s	remaining: 1.85s
# 609:	learn: 0.1802284	total: 2.88s	remaining: 1.84s
# 610:	learn: 0.1800325	total: 2.88s	remaining: 1.84s
# 611:	learn: 0.1795964	total: 2.89s	remaining: 1.83s
# 612:	learn: 0.1793809	total: 2.9s	remaining: 1.83s
# 613:	learn: 0.1791623	total: 2.9s	remaining: 1.82s
# 614:	learn: 0.1789311	total: 2.9s	remaining: 1.82s
# 615:	learn: 0.1784893	total: 2.91s	remaining: 1.81s
# 616:	learn: 0.1783362	total: 2.91s	remaining: 1.81s
# 617:	learn: 0.1781420	total: 2.92s	remaining: 1.8s
# 618:	learn: 0.1779592	total: 2.92s	remaining: 1.8s
# 619:	learn: 0.1776385	total: 2.93s	remaining: 1.79s
# 620:	learn: 0.1771594	total: 2.93s	remaining: 1.79s
# 621:	learn: 0.1768821	total: 2.94s	remaining: 1.78s
# 622:	learn: 0.1766942	total: 2.94s	remaining: 1.78s
# 623:	learn: 0.1763637	total: 2.94s	remaining: 1.77s
# 624:	learn: 0.1762222	total: 2.95s	remaining: 1.77s
# 625:	learn: 0.1759774	total: 2.95s	remaining: 1.76s
# 626:	learn: 0.1758691	total: 2.96s	remaining: 1.76s
# 627:	learn: 0.1757109	total: 2.96s	remaining: 1.75s
# 628:	learn: 0.1754179	total: 2.97s	remaining: 1.75s
# 629:	learn: 0.1751095	total: 2.97s	remaining: 1.75s
# 630:	learn: 0.1749796	total: 2.98s	remaining: 1.74s
# 631:	learn: 0.1747316	total: 2.98s	remaining: 1.74s
# 632:	learn: 0.1745352	total: 2.99s	remaining: 1.73s
# 633:	learn: 0.1743453	total: 2.99s	remaining: 1.73s
# 634:	learn: 0.1740186	total: 3s	remaining: 1.72s
# 635:	learn: 0.1737399	total: 3s	remaining: 1.72s
# 636:	learn: 0.1735327	total: 3.01s	remaining: 1.71s
# 637:	learn: 0.1733657	total: 3.01s	remaining: 1.71s
# 638:	learn: 0.1730656	total: 3.02s	remaining: 1.7s
# 639:	learn: 0.1728079	total: 3.02s	remaining: 1.7s
# 640:	learn: 0.1725020	total: 3.02s	remaining: 1.69s
# 641:	learn: 0.1723746	total: 3.03s	remaining: 1.69s
# 642:	learn: 0.1721287	total: 3.03s	remaining: 1.68s
# 643:	learn: 0.1717864	total: 3.04s	remaining: 1.68s
# 644:	learn: 0.1715712	total: 3.04s	remaining: 1.67s
# 645:	learn: 0.1712179	total: 3.05s	remaining: 1.67s
# 646:	learn: 0.1710250	total: 3.05s	remaining: 1.66s
# 647:	learn: 0.1707161	total: 3.06s	remaining: 1.66s
# 648:	learn: 0.1705144	total: 3.06s	remaining: 1.66s
# 649:	learn: 0.1702355	total: 3.06s	remaining: 1.65s
# 650:	learn: 0.1698410	total: 3.07s	remaining: 1.65s
# 651:	learn: 0.1695985	total: 3.07s	remaining: 1.64s
# 652:	learn: 0.1692568	total: 3.08s	remaining: 1.64s
# 653:	learn: 0.1690678	total: 3.08s	remaining: 1.63s
# 654:	learn: 0.1689642	total: 3.09s	remaining: 1.63s
# 655:	learn: 0.1687400	total: 3.09s	remaining: 1.62s
# 656:	learn: 0.1684543	total: 3.1s	remaining: 1.62s
# 657:	learn: 0.1681064	total: 3.1s	remaining: 1.61s
# 658:	learn: 0.1678781	total: 3.11s	remaining: 1.61s
# 659:	learn: 0.1677166	total: 3.11s	remaining: 1.6s
# 660:	learn: 0.1675121	total: 3.12s	remaining: 1.6s
# 661:	learn: 0.1672837	total: 3.12s	remaining: 1.59s
# 662:	learn: 0.1669908	total: 3.13s	remaining: 1.59s
# 663:	learn: 0.1667651	total: 3.13s	remaining: 1.58s
# 664:	learn: 0.1666455	total: 3.14s	remaining: 1.58s
# 665:	learn: 0.1662479	total: 3.14s	remaining: 1.58s
# 666:	learn: 0.1660050	total: 3.15s	remaining: 1.57s
# 667:	learn: 0.1657435	total: 3.15s	remaining: 1.57s
# 668:	learn: 0.1656254	total: 3.16s	remaining: 1.56s
# 669:	learn: 0.1653877	total: 3.16s	remaining: 1.56s
# 670:	learn: 0.1650868	total: 3.17s	remaining: 1.55s
# 671:	learn: 0.1649298	total: 3.17s	remaining: 1.55s
# 672:	learn: 0.1647108	total: 3.18s	remaining: 1.54s
# 673:	learn: 0.1643536	total: 3.18s	remaining: 1.54s
# 674:	learn: 0.1640501	total: 3.19s	remaining: 1.53s
# 675:	learn: 0.1638487	total: 3.19s	remaining: 1.53s
# 676:	learn: 0.1634631	total: 3.2s	remaining: 1.52s
# 677:	learn: 0.1632265	total: 3.2s	remaining: 1.52s
# 678:	learn: 0.1629971	total: 3.21s	remaining: 1.52s
# 679:	learn: 0.1628452	total: 3.21s	remaining: 1.51s
# 680:	learn: 0.1626933	total: 3.22s	remaining: 1.51s
# 681:	learn: 0.1624023	total: 3.22s	remaining: 1.5s
# 682:	learn: 0.1621140	total: 3.23s	remaining: 1.5s
# 683:	learn: 0.1619289	total: 3.23s	remaining: 1.49s
# 684:	learn: 0.1617978	total: 3.24s	remaining: 1.49s
# 685:	learn: 0.1616144	total: 3.24s	remaining: 1.48s
# 686:	learn: 0.1614924	total: 3.25s	remaining: 1.48s
# 687:	learn: 0.1613496	total: 3.25s	remaining: 1.47s
# 688:	learn: 0.1611650	total: 3.25s	remaining: 1.47s
# 689:	learn: 0.1608704	total: 3.26s	remaining: 1.47s
# 690:	learn: 0.1606631	total: 3.27s	remaining: 1.46s
# 691:	learn: 0.1605101	total: 3.27s	remaining: 1.46s
# 692:	learn: 0.1603993	total: 3.27s	remaining: 1.45s
# 693:	learn: 0.1601993	total: 3.28s	remaining: 1.45s
# 694:	learn: 0.1599908	total: 3.29s	remaining: 1.44s
# 695:	learn: 0.1598226	total: 3.29s	remaining: 1.44s
# 696:	learn: 0.1596184	total: 3.29s	remaining: 1.43s
# 697:	learn: 0.1593442	total: 3.3s	remaining: 1.43s
# 698:	learn: 0.1592533	total: 3.3s	remaining: 1.42s
# 699:	learn: 0.1589940	total: 3.31s	remaining: 1.42s
# 700:	learn: 0.1588463	total: 3.31s	remaining: 1.41s
# 701:	learn: 0.1585752	total: 3.32s	remaining: 1.41s
# 702:	learn: 0.1584129	total: 3.32s	remaining: 1.4s
# 703:	learn: 0.1581823	total: 3.33s	remaining: 1.4s
# 704:	learn: 0.1578524	total: 3.33s	remaining: 1.39s
# 705:	learn: 0.1575347	total: 3.34s	remaining: 1.39s
# 706:	learn: 0.1572405	total: 3.34s	remaining: 1.38s
# 707:	learn: 0.1570984	total: 3.34s	remaining: 1.38s
# 708:	learn: 0.1568483	total: 3.35s	remaining: 1.37s
# 709:	learn: 0.1565831	total: 3.35s	remaining: 1.37s
# 710:	learn: 0.1564782	total: 3.36s	remaining: 1.36s
# 711:	learn: 0.1562897	total: 3.36s	remaining: 1.36s
# 712:	learn: 0.1561542	total: 3.37s	remaining: 1.35s
# 713:	learn: 0.1560691	total: 3.37s	remaining: 1.35s
# 714:	learn: 0.1557699	total: 3.38s	remaining: 1.34s
# 715:	learn: 0.1555695	total: 3.38s	remaining: 1.34s
# 716:	learn: 0.1552630	total: 3.39s	remaining: 1.34s
# 717:	learn: 0.1550391	total: 3.39s	remaining: 1.33s
# 718:	learn: 0.1548493	total: 3.39s	remaining: 1.33s
# 719:	learn: 0.1546079	total: 3.4s	remaining: 1.32s
# 720:	learn: 0.1544001	total: 3.4s	remaining: 1.32s
# 721:	learn: 0.1542128	total: 3.41s	remaining: 1.31s
# 722:	learn: 0.1540218	total: 3.41s	remaining: 1.31s
# 723:	learn: 0.1538718	total: 3.42s	remaining: 1.3s
# 724:	learn: 0.1536788	total: 3.42s	remaining: 1.3s
# 725:	learn: 0.1534883	total: 3.42s	remaining: 1.29s
# 726:	learn: 0.1533672	total: 3.43s	remaining: 1.29s
# 727:	learn: 0.1531917	total: 3.44s	remaining: 1.28s
# 728:	learn: 0.1530036	total: 3.44s	remaining: 1.28s
# 729:	learn: 0.1527985	total: 3.44s	remaining: 1.27s
# 730:	learn: 0.1525569	total: 3.45s	remaining: 1.27s
# 731:	learn: 0.1524223	total: 3.45s	remaining: 1.26s
# 732:	learn: 0.1523175	total: 3.46s	remaining: 1.26s
# 733:	learn: 0.1520790	total: 3.46s	remaining: 1.25s
# 734:	learn: 0.1516877	total: 3.47s	remaining: 1.25s
# 735:	learn: 0.1515294	total: 3.47s	remaining: 1.25s
# 736:	learn: 0.1513459	total: 3.48s	remaining: 1.24s
# 737:	learn: 0.1512391	total: 3.48s	remaining: 1.24s
# 738:	learn: 0.1510289	total: 3.49s	remaining: 1.23s
# 739:	learn: 0.1508414	total: 3.49s	remaining: 1.23s
# 740:	learn: 0.1506837	total: 3.5s	remaining: 1.22s
# 741:	learn: 0.1504454	total: 3.5s	remaining: 1.22s
# 742:	learn: 0.1502778	total: 3.51s	remaining: 1.21s
# 743:	learn: 0.1500531	total: 3.51s	remaining: 1.21s
# 744:	learn: 0.1498538	total: 3.52s	remaining: 1.2s
# 745:	learn: 0.1496218	total: 3.52s	remaining: 1.2s
# 746:	learn: 0.1494086	total: 3.52s	remaining: 1.19s
# 747:	learn: 0.1491058	total: 3.53s	remaining: 1.19s
# 748:	learn: 0.1489037	total: 3.53s	remaining: 1.18s
# 749:	learn: 0.1488055	total: 3.54s	remaining: 1.18s
# 750:	learn: 0.1486064	total: 3.54s	remaining: 1.17s
# 751:	learn: 0.1483885	total: 3.55s	remaining: 1.17s
# 752:	learn: 0.1482571	total: 3.55s	remaining: 1.16s
# 753:	learn: 0.1480581	total: 3.56s	remaining: 1.16s
# 754:	learn: 0.1479276	total: 3.56s	remaining: 1.16s
# 755:	learn: 0.1477432	total: 3.56s	remaining: 1.15s
# 756:	learn: 0.1476498	total: 3.57s	remaining: 1.15s
# 757:	learn: 0.1474975	total: 3.57s	remaining: 1.14s
# 758:	learn: 0.1472489	total: 3.58s	remaining: 1.14s
# 759:	learn: 0.1470304	total: 3.58s	remaining: 1.13s
# 760:	learn: 0.1468888	total: 3.59s	remaining: 1.13s
# 761:	learn: 0.1466504	total: 3.59s	remaining: 1.12s
# 762:	learn: 0.1464841	total: 3.6s	remaining: 1.12s
# 763:	learn: 0.1462968	total: 3.6s	remaining: 1.11s
# 764:	learn: 0.1460790	total: 3.61s	remaining: 1.11s
# 765:	learn: 0.1459160	total: 3.61s	remaining: 1.1s
# 766:	learn: 0.1457622	total: 3.62s	remaining: 1.1s
# 767:	learn: 0.1455957	total: 3.62s	remaining: 1.09s
# 768:	learn: 0.1453717	total: 3.63s	remaining: 1.09s
# 769:	learn: 0.1452289	total: 3.63s	remaining: 1.08s
# 770:	learn: 0.1450511	total: 3.64s	remaining: 1.08s
# 771:	learn: 0.1449096	total: 3.64s	remaining: 1.07s
# 772:	learn: 0.1446476	total: 3.65s	remaining: 1.07s
# 773:	learn: 0.1444430	total: 3.65s	remaining: 1.07s
# 774:	learn: 0.1441930	total: 3.66s	remaining: 1.06s
# 775:	learn: 0.1440822	total: 3.66s	remaining: 1.06s
# 776:	learn: 0.1438416	total: 3.67s	remaining: 1.05s
# 777:	learn: 0.1436458	total: 3.67s	remaining: 1.05s
# 778:	learn: 0.1435095	total: 3.67s	remaining: 1.04s
# 779:	learn: 0.1434094	total: 3.68s	remaining: 1.04s
# 780:	learn: 0.1432223	total: 3.68s	remaining: 1.03s
# 781:	learn: 0.1430787	total: 3.69s	remaining: 1.03s
# 782:	learn: 0.1429698	total: 3.69s	remaining: 1.02s
# 783:	learn: 0.1427407	total: 3.7s	remaining: 1.02s
# 784:	learn: 0.1426405	total: 3.7s	remaining: 1.01s
# 785:	learn: 0.1424057	total: 3.71s	remaining: 1.01s
# 786:	learn: 0.1421999	total: 3.71s	remaining: 1s
# 787:	learn: 0.1419368	total: 3.71s	remaining: 999ms
# 788:	learn: 0.1418612	total: 3.72s	remaining: 995ms
# 789:	learn: 0.1417060	total: 3.72s	remaining: 990ms
# 790:	learn: 0.1414557	total: 3.73s	remaining: 985ms
# 791:	learn: 0.1412456	total: 3.73s	remaining: 980ms
# 792:	learn: 0.1410178	total: 3.74s	remaining: 976ms
# 793:	learn: 0.1408061	total: 3.74s	remaining: 971ms
# 794:	learn: 0.1405860	total: 3.75s	remaining: 966ms
# 795:	learn: 0.1404376	total: 3.75s	remaining: 961ms
# 796:	learn: 0.1402778	total: 3.75s	remaining: 956ms
# 797:	learn: 0.1401464	total: 3.76s	remaining: 952ms
# 798:	learn: 0.1399283	total: 3.76s	remaining: 947ms
# 799:	learn: 0.1396891	total: 3.77s	remaining: 942ms
# 800:	learn: 0.1394116	total: 3.77s	remaining: 938ms
# 801:	learn: 0.1392448	total: 3.78s	remaining: 933ms
# 802:	learn: 0.1391865	total: 3.78s	remaining: 928ms
# 803:	learn: 0.1390356	total: 3.79s	remaining: 924ms
# 804:	learn: 0.1389175	total: 3.79s	remaining: 919ms
# 805:	learn: 0.1387458	total: 3.8s	remaining: 914ms
# 806:	learn: 0.1384477	total: 3.8s	remaining: 909ms
# 807:	learn: 0.1382745	total: 3.81s	remaining: 905ms
# 808:	learn: 0.1380073	total: 3.81s	remaining: 900ms
# 809:	learn: 0.1378885	total: 3.81s	remaining: 895ms
# 810:	learn: 0.1377069	total: 3.82s	remaining: 890ms
# 811:	learn: 0.1375587	total: 3.82s	remaining: 885ms
# 812:	learn: 0.1374472	total: 3.83s	remaining: 881ms
# 813:	learn: 0.1371748	total: 3.83s	remaining: 876ms
# 814:	learn: 0.1369911	total: 3.84s	remaining: 871ms
# 815:	learn: 0.1368445	total: 3.84s	remaining: 866ms
# 816:	learn: 0.1366432	total: 3.85s	remaining: 862ms
# 817:	learn: 0.1365176	total: 3.85s	remaining: 857ms
# 818:	learn: 0.1363454	total: 3.85s	remaining: 852ms
# 819:	learn: 0.1362048	total: 3.86s	remaining: 847ms
# 820:	learn: 0.1359859	total: 3.86s	remaining: 843ms
# 821:	learn: 0.1357336	total: 3.87s	remaining: 838ms
# 822:	learn: 0.1355380	total: 3.87s	remaining: 833ms
# 823:	learn: 0.1354270	total: 3.88s	remaining: 828ms
# 824:	learn: 0.1352691	total: 3.88s	remaining: 824ms
# 825:	learn: 0.1349784	total: 3.89s	remaining: 819ms
# 826:	learn: 0.1348640	total: 3.89s	remaining: 814ms
# 827:	learn: 0.1346549	total: 3.9s	remaining: 810ms
# 828:	learn: 0.1344759	total: 3.9s	remaining: 805ms
# 829:	learn: 0.1341919	total: 3.91s	remaining: 800ms
# 830:	learn: 0.1340087	total: 3.91s	remaining: 795ms
# 831:	learn: 0.1338938	total: 3.92s	remaining: 791ms
# 832:	learn: 0.1337232	total: 3.92s	remaining: 786ms
# 833:	learn: 0.1336506	total: 3.92s	remaining: 781ms
# 834:	learn: 0.1335223	total: 3.93s	remaining: 776ms
# 835:	learn: 0.1333544	total: 3.93s	remaining: 772ms
# 836:	learn: 0.1331133	total: 3.94s	remaining: 767ms
# 837:	learn: 0.1330055	total: 3.94s	remaining: 762ms
# 838:	learn: 0.1327266	total: 3.95s	remaining: 757ms
# 839:	learn: 0.1326168	total: 3.95s	remaining: 753ms
# 840:	learn: 0.1325071	total: 3.96s	remaining: 748ms
# 841:	learn: 0.1323190	total: 3.96s	remaining: 743ms
# 842:	learn: 0.1321187	total: 3.96s	remaining: 738ms
# 843:	learn: 0.1319680	total: 3.97s	remaining: 734ms
# 844:	learn: 0.1318143	total: 3.97s	remaining: 729ms
# 845:	learn: 0.1316675	total: 3.98s	remaining: 724ms
# 846:	learn: 0.1314954	total: 3.98s	remaining: 720ms
# 847:	learn: 0.1313226	total: 3.99s	remaining: 715ms
# 848:	learn: 0.1312045	total: 3.99s	remaining: 710ms
# 849:	learn: 0.1310419	total: 4s	remaining: 706ms
# 850:	learn: 0.1308219	total: 4s	remaining: 701ms
# 851:	learn: 0.1306597	total: 4.01s	remaining: 696ms
# 852:	learn: 0.1304754	total: 4.01s	remaining: 692ms
# 853:	learn: 0.1303282	total: 4.02s	remaining: 687ms
# 854:	learn: 0.1301429	total: 4.02s	remaining: 682ms
# 855:	learn: 0.1298878	total: 4.03s	remaining: 677ms
# 856:	learn: 0.1296418	total: 4.03s	remaining: 673ms
# 857:	learn: 0.1294346	total: 4.03s	remaining: 668ms
# 858:	learn: 0.1293200	total: 4.04s	remaining: 663ms
# 859:	learn: 0.1290390	total: 4.04s	remaining: 658ms
# 860:	learn: 0.1289115	total: 4.05s	remaining: 654ms
# 861:	learn: 0.1288129	total: 4.05s	remaining: 649ms
# 862:	learn: 0.1286722	total: 4.06s	remaining: 644ms
# 863:	learn: 0.1284807	total: 4.06s	remaining: 639ms
# 864:	learn: 0.1282952	total: 4.07s	remaining: 634ms
# 865:	learn: 0.1282197	total: 4.07s	remaining: 630ms
# 866:	learn: 0.1281080	total: 4.07s	remaining: 625ms
# 867:	learn: 0.1279070	total: 4.08s	remaining: 620ms
# 868:	learn: 0.1277228	total: 4.08s	remaining: 616ms
# 869:	learn: 0.1275877	total: 4.09s	remaining: 611ms
# 870:	learn: 0.1274364	total: 4.09s	remaining: 606ms
# 871:	learn: 0.1272902	total: 4.1s	remaining: 601ms
# 872:	learn: 0.1271408	total: 4.1s	remaining: 597ms
# 873:	learn: 0.1270014	total: 4.11s	remaining: 592ms
# 874:	learn: 0.1268231	total: 4.11s	remaining: 587ms
# 875:	learn: 0.1266190	total: 4.11s	remaining: 582ms
# 876:	learn: 0.1264998	total: 4.12s	remaining: 578ms
# 877:	learn: 0.1263057	total: 4.12s	remaining: 573ms
# 878:	learn: 0.1261441	total: 4.13s	remaining: 568ms
# 879:	learn: 0.1259614	total: 4.13s	remaining: 563ms
# 880:	learn: 0.1258483	total: 4.14s	remaining: 559ms
# 881:	learn: 0.1255896	total: 4.14s	remaining: 554ms
# 882:	learn: 0.1253442	total: 4.14s	remaining: 549ms
# 883:	learn: 0.1251981	total: 4.15s	remaining: 545ms
# 884:	learn: 0.1249777	total: 4.15s	remaining: 540ms
# 885:	learn: 0.1249555	total: 4.16s	remaining: 535ms
# 886:	learn: 0.1247469	total: 4.16s	remaining: 530ms
# 887:	learn: 0.1246455	total: 4.17s	remaining: 526ms
# 888:	learn: 0.1244946	total: 4.17s	remaining: 521ms
# 889:	learn: 0.1243498	total: 4.18s	remaining: 516ms
# 890:	learn: 0.1240682	total: 4.18s	remaining: 512ms
# 891:	learn: 0.1238924	total: 4.18s	remaining: 507ms
# 892:	learn: 0.1238272	total: 4.19s	remaining: 502ms
# 893:	learn: 0.1237135	total: 4.19s	remaining: 497ms
# 894:	learn: 0.1236653	total: 4.2s	remaining: 493ms
# 895:	learn: 0.1235815	total: 4.2s	remaining: 488ms
# 896:	learn: 0.1233826	total: 4.21s	remaining: 483ms
# 897:	learn: 0.1231635	total: 4.21s	remaining: 478ms
# 898:	learn: 0.1229779	total: 4.22s	remaining: 474ms
# 899:	learn: 0.1228030	total: 4.22s	remaining: 469ms
# 900:	learn: 0.1226779	total: 4.23s	remaining: 464ms
# 901:	learn: 0.1225169	total: 4.23s	remaining: 460ms
# 902:	learn: 0.1223817	total: 4.24s	remaining: 455ms
# 903:	learn: 0.1221773	total: 4.24s	remaining: 450ms
# 904:	learn: 0.1220535	total: 4.24s	remaining: 446ms
# 905:	learn: 0.1220043	total: 4.25s	remaining: 441ms
# 906:	learn: 0.1218270	total: 4.25s	remaining: 436ms
# 907:	learn: 0.1217288	total: 4.26s	remaining: 431ms
# 908:	learn: 0.1215433	total: 4.26s	remaining: 427ms
# 909:	learn: 0.1212759	total: 4.27s	remaining: 422ms
# 910:	learn: 0.1212046	total: 4.27s	remaining: 417ms
# 911:	learn: 0.1210482	total: 4.28s	remaining: 413ms
# 912:	learn: 0.1208543	total: 4.28s	remaining: 408ms
# 913:	learn: 0.1207511	total: 4.29s	remaining: 403ms
# 914:	learn: 0.1206347	total: 4.29s	remaining: 399ms
# 915:	learn: 0.1204143	total: 4.29s	remaining: 394ms
# 916:	learn: 0.1202580	total: 4.3s	remaining: 389ms
# 917:	learn: 0.1201753	total: 4.3s	remaining: 384ms
# 918:	learn: 0.1200097	total: 4.31s	remaining: 380ms
# 919:	learn: 0.1197957	total: 4.31s	remaining: 375ms
# 920:	learn: 0.1197302	total: 4.32s	remaining: 370ms
# 921:	learn: 0.1196200	total: 4.32s	remaining: 366ms
# 922:	learn: 0.1194689	total: 4.33s	remaining: 361ms
# 923:	learn: 0.1192810	total: 4.33s	remaining: 356ms
# 924:	learn: 0.1191749	total: 4.33s	remaining: 351ms
# 925:	learn: 0.1190419	total: 4.34s	remaining: 347ms
# 926:	learn: 0.1188799	total: 4.34s	remaining: 342ms
# 927:	learn: 0.1188031	total: 4.35s	remaining: 337ms
# 928:	learn: 0.1186744	total: 4.35s	remaining: 333ms
# 929:	learn: 0.1185436	total: 4.36s	remaining: 328ms
# 930:	learn: 0.1183814	total: 4.36s	remaining: 323ms
# 931:	learn: 0.1181779	total: 4.37s	remaining: 319ms
# 932:	learn: 0.1180955	total: 4.37s	remaining: 314ms
# 933:	learn: 0.1179737	total: 4.38s	remaining: 309ms
# 934:	learn: 0.1177830	total: 4.38s	remaining: 305ms
# 935:	learn: 0.1175817	total: 4.39s	remaining: 300ms
# 936:	learn: 0.1174320	total: 4.39s	remaining: 295ms
# 937:	learn: 0.1172507	total: 4.4s	remaining: 291ms
# 938:	learn: 0.1170730	total: 4.4s	remaining: 286ms
# 939:	learn: 0.1169239	total: 4.41s	remaining: 281ms
# 940:	learn: 0.1168480	total: 4.41s	remaining: 276ms
# 941:	learn: 0.1167715	total: 4.41s	remaining: 272ms
# 942:	learn: 0.1165984	total: 4.42s	remaining: 267ms
# 943:	learn: 0.1164870	total: 4.42s	remaining: 262ms
# 944:	learn: 0.1163358	total: 4.43s	remaining: 258ms
# 945:	learn: 0.1162239	total: 4.43s	remaining: 253ms
# 946:	learn: 0.1160527	total: 4.44s	remaining: 248ms
# 947:	learn: 0.1158347	total: 4.44s	remaining: 244ms
# 948:	learn: 0.1157106	total: 4.45s	remaining: 239ms
# 949:	learn: 0.1155241	total: 4.45s	remaining: 234ms
# 950:	learn: 0.1153420	total: 4.45s	remaining: 230ms
# 951:	learn: 0.1152537	total: 4.46s	remaining: 225ms
# 952:	learn: 0.1151598	total: 4.46s	remaining: 220ms
# 953:	learn: 0.1149838	total: 4.47s	remaining: 215ms
# 954:	learn: 0.1148554	total: 4.47s	remaining: 211ms
# 955:	learn: 0.1146979	total: 4.48s	remaining: 206ms
# 956:	learn: 0.1145899	total: 4.48s	remaining: 201ms
# 957:	learn: 0.1144120	total: 4.49s	remaining: 197ms
# 958:	learn: 0.1142183	total: 4.49s	remaining: 192ms
# 959:	learn: 0.1140830	total: 4.5s	remaining: 187ms
# 960:	learn: 0.1139868	total: 4.5s	remaining: 183ms
# 961:	learn: 0.1138434	total: 4.51s	remaining: 178ms
# 962:	learn: 0.1136711	total: 4.51s	remaining: 173ms
# 963:	learn: 0.1135125	total: 4.51s	remaining: 169ms
# 964:	learn: 0.1134241	total: 4.52s	remaining: 164ms
# 965:	learn: 0.1132873	total: 4.52s	remaining: 159ms
# 966:	learn: 0.1131965	total: 4.53s	remaining: 155ms
# 967:	learn: 0.1130977	total: 4.53s	remaining: 150ms
# 968:	learn: 0.1129839	total: 4.54s	remaining: 145ms
# 969:	learn: 0.1128502	total: 4.54s	remaining: 140ms
# 970:	learn: 0.1127062	total: 4.55s	remaining: 136ms
# 971:	learn: 0.1125332	total: 4.55s	remaining: 131ms
# 972:	learn: 0.1124111	total: 4.55s	remaining: 126ms
# 973:	learn: 0.1123031	total: 4.56s	remaining: 122ms
# 974:	learn: 0.1121840	total: 4.56s	remaining: 117ms
# 975:	learn: 0.1120861	total: 4.57s	remaining: 112ms
# 976:	learn: 0.1119802	total: 4.57s	remaining: 108ms
# 977:	learn: 0.1117956	total: 4.58s	remaining: 103ms
# 978:	learn: 0.1116758	total: 4.58s	remaining: 98.3ms
# 979:	learn: 0.1115796	total: 4.58s	remaining: 93.6ms
# 980:	learn: 0.1114926	total: 4.59s	remaining: 88.9ms
# 981:	learn: 0.1113825	total: 4.59s	remaining: 84.2ms
# 982:	learn: 0.1112155	total: 4.6s	remaining: 79.5ms
# 983:	learn: 0.1110876	total: 4.6s	remaining: 74.9ms
# 984:	learn: 0.1109671	total: 4.61s	remaining: 70.2ms
# 985:	learn: 0.1108418	total: 4.61s	remaining: 65.5ms
# 986:	learn: 0.1107739	total: 4.62s	remaining: 60.8ms
# 987:	learn: 0.1106862	total: 4.62s	remaining: 56.1ms
# 988:	learn: 0.1105811	total: 4.63s	remaining: 51.4ms
# 989:	learn: 0.1104863	total: 4.63s	remaining: 46.8ms
# 990:	learn: 0.1103609	total: 4.63s	remaining: 42.1ms
# 991:	learn: 0.1102489	total: 4.64s	remaining: 37.4ms
# 992:	learn: 0.1101764	total: 4.64s	remaining: 32.7ms
# 993:	learn: 0.1099439	total: 4.65s	remaining: 28.1ms
# 994:	learn: 0.1098422	total: 4.65s	remaining: 23.4ms
# 995:	learn: 0.1097282	total: 4.66s	remaining: 18.7ms
# 996:	learn: 0.1096254	total: 4.66s	remaining: 14ms
# 997:	learn: 0.1095106	total: 4.67s	remaining: 9.35ms
# 998:	learn: 0.1093634	total: 4.67s	remaining: 4.68ms
# 999:	learn: 0.1092694	total: 4.67s	remaining: 0us

# %%
test_pred = clf.predict(test_embeds)
test_proba = clf.predict_proba(test_embeds)[:, 1]

# %%
print("Accuracy:", accuracy_score(target_test, test_pred))
print("ROC-AUC:", roc_auc_score(target_test, test_proba))
# Out:
# Accuracy: 0.708
# ROC-AUC: 0.7841543766492367

# %% [markdown]
# - GPT embeds + Catboost:
#   - `Accuracy: 0.7304 +- 0.0101`
#   - `ROC-AUC: 0.7957 +- 0.0091`
#
# ---
#
# **Пришлось уменьшить количество warmup-эпох, так как процесс обучения был крайне нестабилен.**
#
# - GPT embeds + WinAgg (single trx pred, 3 trx window) + Catboost:
#   - `Accuracy: 0.7188 +- 0.0156`
#   - `ROC-AUC: 0.7899 +- 0.0142`
#
# ---
#
# - GPT embeds + WinAgg (single trx pred, 5 trx window) + Catboost:
#   - `Accuracy: 0.7125 +- 0.0107`
#   - `ROC-AUC: 0.781 +- 0.0025`
#
# ---
#
# - GPT embeds + WinAgg (multilabel pred, 3 trx window) + Catboost:
#   - `Accuracy: 0.727 +- 0.0122`
#   - `ROC-AUC: 0.7946 +- 0.0156`
#
# ---
#
# - GPT embeds + WinAgg (multilabel pred, 5 trx window) + Catboost:
#   - `Accuracy: 0.7135 +- 0.0074`
#   - `ROC-AUC: 0.7921 +- 0.0051`

# %% [markdown]
# # Итоги.

# %% [markdown]
# | Method                                |    Accuracy           | ROC-AUC         |
# |---------------------------------------|-----------------------|-----------------|
# | **Flattened Sequences**               | 0.67 ± 0.0046         | 0.7536 ± 0.003  |
# | **GRU (+ MLP)**                       | 0.746 ± 0.0076        | 0.8148 ± 0.0037 |
# | **CoLES**                             | 0.733 ± 0.019         | 0.8057 ± 0.0088 |
# | **CPC Modeling**                      | 0.748 ± 0.003         | 0.81 ± 0.0048   |
# | **GPT2**                              | 0.73 ± 0.01           | 0.7957 ± 0.0091 |
# | **CoLES w/ WinAgg** (best setup)      | 0.727 ± 0.009         | 0.7992 ± 0.0078 |
# | **CPC w/ WinAgg** (best setup)        | 0.748 ± 0.006         | 0.8102 ± 0.0102 |
# | **GPT w/ WinAgg** (1 next trx pred)   | 0.7188 ± 0.016        | 0.7899 ± 0.0142 |
# | **GPT w/ WinAgg** (multilabel pred)   | 0.727 ± 0.012         | 0.7946 ± 0.0156 |
